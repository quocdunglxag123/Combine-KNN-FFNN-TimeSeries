# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
from numpy import sqrt 
import time

#Tien Xu Ly
from sklearn.preprocessing import MinMaxScaler

#Draw Flot
import matplotlib.pyplot as plt

#Cacuale error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error

#distance Libaray
from dtw import dtw
from scipy.spatial.distance import euclidean

#FFNN Libarary
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from sklearn.model_selection import GridSearchCV
from keras.wrappers.scikit_learn import KerasRegressor

# %%
# Đọc Dữ Liệu
# @param   filePath     Đường dẫn tập dữ liệu CSV
# @return  df           Tập dữ liệu csv dưới dạng df
def readData(filePath):
    # Load dữ liệu
    dataCSV = pd.read_csv(filePath)
    df=dataCSV[['Close']]
    return df

# Tiền Xử lý Dữ Liệu
# @param  Data   Tập dữ liệu
# @return df     Dữ liệu đã được tiền xử lý
def cleanData(df):
    # Replace null values with 0
    df.fillna(0, inplace=True)
    # Remove outliers by replacing values outside of 10 standard deviations with the mean
    std = df['Close'].std()
    mean = df['Close'].mean()
    df['Close'] = np.where(df['Close'] > (mean + 10*std), mean, df['Close'])
    df['Close'] = np.where(df['Close'] < (mean - 10*std), mean, df['Close'])
    # Scale data_AMZN to range [0, 1]
    scaler = MinMaxScaler()
    df['Close'] = scaler.fit_transform(df['Close'].values.reshape(-1, 1))
    # Fill in missing values with the mean of the previous and next values
    df['Close'] = df['Close'].interpolate(method='linear')
    return df

# Chia dữ liệu thành train set và test set
# @param  data                      Tập dữ liệu
# @param  percentTrain              Tỷ lệ Tập train
# @return train_data, test_data     Tập train và test   
def splitData(data, percentTrain):
    train_size = int(len(data) * (percentTrain/100))
    train = data.iloc[:train_size, :]
    test = data.iloc[train_size:, :]
    return train, test

# Xử lý dữ liệu thành dữ liệu đầu vào và đầu ra cho mô hình
# @param      data            Dữ liệu cần chia cửa sổ
# @param      size_window     Kích thước cửa sổ
# @param      size_predict    Kích thước cửa sổ dự đoán
# @param      stepWindow      số điểm dữ liệu trượt
# @return     X, y            mảng cửa sổ mẫu và mảng điểm dự đoán tương ứng
def prepare_data(data, size_window, size_predict, stepWindow):
    X, y = [], []
    startWindow = 0
    for i in range(len(data) - size_window - 1):
        if (len(data[(startWindow + size_window):(startWindow + size_window + size_predict) , 0]) != size_predict):
            break
        X.append(data[startWindow:(startWindow + size_window), :])
        y.append(data[(startWindow + size_window):(startWindow + size_window + size_predict) , 0])
        startWindow += stepWindow
    return np.array(X), np.array(y)

#---------KNN-----------
# Fucntion Tính khoảng cách giữa 2 chuỗi thời gian
# @param    ts1            Chuỗi thứ nhất
# @param    ts2            Chuỗi thứ hai
# @return   euclidean      Khoảng cách euclidean    
def euclidean_distance(ts1, ts2):
    ts1= ts1.flatten()
    ts2= ts2.flatten()
    return euclidean(ts1,ts2)

# Function lấy ra k chuỗi gần nhất
# @param    k             Số lượng chuỗi gần nhất
# @param    distanceArr   Mảng khoảng cách
# @return   argsort       Vị trí chuỗi gần nhất        
def kSimilarityTimeSeries(k, distanceArr):
    distances = np.array(distanceArr)
    return distances.argsort()[:k] 

# Tính khoảng cách DTW
# @param    ts1            Chuỗi thứ nhất
# @param    ts2            Chuỗi thứ hai
# @return   euclidean      Khoảng cách euclidean  
def dtw_dist(ts1, ts2):
    dist, _, _, _ = dtw(ts1, ts2, dist=lambda ts1, ts2: np.abs(ts1 - ts2))
    return dist

# Thêm Dữ liệu
# @param    X_train               Cửa sổ mẫu train
# @param    y_train               Cửa sổ dự đoán train
# @param    XTest                 Cửa sổ mẫu test
# @param    yTest                 Cửa sổ dự đoán test
# @return   X_train, y_train      Khoảng cách euclidean 
def toTrain(X_train, y_train, XTest, yTest):
    X_train.append(XTest)
    y_train.append(yTest)
    return np.array(X_train), np.array(y_train)

# Dự đoán Euclidean
# @param    nameData           Tên tập dữ liệu
# @param    k                  Số lượng chuỗi gần nhất
# @param    typeDistance       Độ đo sử dụng (Dtw, euclidean)
# @param    X_train            Cửa sổ mẫu train
# @param    y_train            Cửa sổ dự đoán train
# @param    X_test             Cửa sổ mẫu test
# @param    y_test             Cửa sổ dự đoán test
# @return   y_pred_arr         Mảng dự đoán
def predict_KNN(k, typeDistance, X_train, y_train, X_test, y_test):
    y_pred_arr=[]
    for iTest in range(len(X_test)):
        if(k>len(X_train)):
            k=len(X_train)
        distanceArr=[]
        for iTrain in range(len(X_train)-size_window+2):
            if(typeDistance == 'Dtw'):
                distance = dtw_dist(X_test[iTest],X_train[iTrain])
            else:
                distance = euclidean_distance(X_test[iTest],X_train[iTrain])
            distanceArr.append(distance)
        indexKNN= kSimilarityTimeSeries(k,distanceArr)
        y_pred = np.mean(y_train[indexKNN])
        y_pred_arr.append(y_pred)
        X_train, y_train = toTrain(X_train.tolist(), y_train.tolist(),X_test[iTest].tolist(), y_test[iTest].tolist())
        y_pred = np.array(y_pred_arr)
   
    return y_pred


#----------------FFNN--------------------------
# Khởi tạo mô hình FFNN
# @param    neuralInput         Kích thước Cửa sổ mẫu/ số neural lớp input
# @param    num_layers_hidden   Số lượng lớp ẩn
# @param    num_neural_hidden   Số neural lớp ẩn
# @param    neuralOutput         Số neural lớp ouput
# @return   model               Mô hình FFNN
def create_model_FFNN(neuralInput, num_layers_hidden=1, neuralHidden=1, neuralOutput=1):
    model = Sequential()
    for i in range(num_layers_hidden):
        if i == 0:
            model.add(Dense(neuralHidden, input_dim= neuralInput, activation='sigmoid'))
        else:
            model.add(Dense(neuralHidden, activation='sigmoid'))
    model.add(Dense(neuralOutput))
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model


# Train FFNN 
# @param    nameData          Tên tập dữ liệu
# @param    size_window       Kích thước Cửa sổ mẫu/ số neural lớp input
# @param    X_train           cửa sổ mẫu tập train
# @param    y_train           Cửa sổ dự đoán tập train
# @param    neuralHidden      Số neural lớp ẩn
# @param    numHiddenLayer    Số lớp ẩn
# @param    size_predict      Kích thước Cửa sổ dự đoán/ Số neural lớp ouput
# @return   best_params_FFNN  Tham số tốt nhất cho mô hình FFNN                
def train_FFNN(nameData, typePredict, size_window, X_train, y_train, neuralHidden, numHiddenLayer, size_predict):
    #param search
    param_grid_FFNN = {'batch_size': [8, 16, 32, 64, 128],
              'epochs': [50, 100, 150, 200, 250, 300],
              'neuralHidden': [neuralHidden],
              'num_layers_hidden' : [numHiddenLayer],
              'neuralInput' : [size_window],
              'neuralOutput' : [size_predict]}

    # create the model
    model_FFNN = KerasRegressor(build_fn=create_model_FFNN, verbose=0)
    
    # perform the grid search
    grid_FFNN = GridSearchCV(estimator=model_FFNN, param_grid=param_grid_FFNN, cv=3)
    grid_result_FFNN = grid_FFNN.fit(X_train, y_train)
    
    # train the model with the best parameters
    best_params_FFNN = grid_result_FFNN.best_params_
    
    model_FFNN = create_model_FFNN( best_params_FFNN['neuralInput'], best_params_FFNN['num_layers_hidden'], best_params_FFNN['neuralHidden'],best_params_FFNN['neuralOutput'])
    model_FFNN.fit(X_train, y_train, epochs=best_params_FFNN['epochs'], batch_size=best_params_FFNN['batch_size'], verbose=2, callbacks=[EarlyStopping(monitor='loss', patience=10)], shuffle=False)
    
    if(typePredict=='FFNN_Find_NeuralHidden'):
        model_FFNN.save_weights('../BestParam/FFNN/'+nameData+'/FFNN_Find_NeuralHidden/'+str(int(best_params_FFNN['num_layers_hidden']))+'_HiddenLayer_'+str(int(best_params_FFNN['neuralHidden']))+'_NeuralHidden_'+str(int(best_params_FFNN['batch_size']))+'_BatchSize_'+str(int(best_params_FFNN['epochs']))+'_Epoch_'+nameData+'.h5')   
    elif (typePredict=='FFNN_Find_NumberHiddenLayer'):
        model_FFNN.save_weights('../BestParam/FFNN/'+nameData+'/FFNN_Find_NumberHiddenLayer/'+str(int(best_params_FFNN['num_layers_hidden']))+'_HiddenLayer_'+str(int(best_params_FFNN['neuralHidden']))+'_NeuralHidden_'+str(int(best_params_FFNN['batch_size']))+'_BatchSize_'+str(int(best_params_FFNN['epochs']))+'_Epoch_'+nameData+'.h5')   
    else:
        model_FFNN.save_weights('../BestParam/TuanTu/'+nameData+'/FFNN_Find_NumberHiddenLayer/'+str(int(best_params_FFNN['num_layers_hidden']))+'_HiddenLayer_'+str(int(best_params_FFNN['neuralHidden']))+'_NeuralHidden_'+str(int(best_params_FFNN['batch_size']))+'_BatchSize_'+str(int(best_params_FFNN['epochs']))+'_Epoch_'+nameData+'.h5')   
    return best_params_FFNN



# Train FFNN 
# @param    nameData          Tên tập dữ liệu
# @param    size_window       Kích thước Cửa sổ mẫu/ số neural lớp input
# @param    X_train           cửa sổ mẫu tập train
# @param    y_train           Cửa sổ dự đoán tập train
# @param    batchSize         Số lượng mẫu được đưa vào với mỗi lần lặp (epoch)
# @param    epoch             Số lần lặp cập nhật trọng số
# @param    neuralHidden      Số neural lớp ẩn
# @param    numHiddenLayer    Số lớp ẩn
# @param    size_predict      Kích thước Cửa sổ dự đoán/ Số neural lớp ouput
# @return   best_params_FFNN  Tham số tốt nhất cho mô hình FFNN                
def train_best_param_FFNN(nameData, typePredict, size_window, X_train, y_train, batchSize, epoch, neuralHidden, numHiddenLayer, size_predict):
    #param search
    param_grid_FFNN = {'batch_size': batchSize,
              'epochs': epoch,
              'neuralHidden': neuralHidden,
              'num_layers_hidden' : numHiddenLayer,
              'neuralInput' : size_window,
              'neuralOutput' : size_predict}
    
    model_FFNN = create_model_FFNN( param_grid_FFNN['neuralInput'], param_grid_FFNN['num_layers_hidden'], param_grid_FFNN['neuralHidden'],param_grid_FFNN['neuralOutput'])
    model_FFNN.fit(X_train, y_train, epochs=param_grid_FFNN['epochs'], batch_size=param_grid_FFNN['batch_size'], verbose=2, callbacks=[EarlyStopping(monitor='loss', patience=10)], shuffle=False)
    
    if(typePredict=='FFNN_Find_NeuralHidden'):
        model_FFNN.save_weights('../BestParam/FFNN/'+nameData+'/FFNN_Find_NeuralHidden/'+str(int(param_grid_FFNN['num_layers_hidden']))+'_HiddenLayer_'+str(int(param_grid_FFNN['neuralHidden']))+'_NeuralHidden_'+str(int(param_grid_FFNN['batch_size']))+'_BatchSize_'+str(int(param_grid_FFNN['epochs']))+'_Epoch_'+nameData+'.h5')   
    elif (typePredict=='FFNN_Find_NumberHiddenLayer'):
        model_FFNN.save_weights('../BestParam/FFNN/'+nameData+'/FFNN_Find_NumberHiddenLayer/'+str(int(param_grid_FFNN['num_layers_hidden']))+'_HiddenLayer_'+str(int(param_grid_FFNN['neuralHidden']))+'_NeuralHidden_'+str(int(param_grid_FFNN['batch_size']))+'_BatchSize_'+str(int(param_grid_FFNN['epochs']))+'_Epoch_'+nameData+'.h5')   
    elif (typePredict=='FFNN_Find_NumberHiddenLayer_SongSong'):
        model_FFNN.save_weights('../BestParam/SongSong/'+nameData+'/FFNN_Find_BestWeights/'+str(int(param_grid_FFNN['num_layers_hidden']))+'_HiddenLayer_'+str(int(param_grid_FFNN['neuralHidden']))+'_NeuralHidden_'+str(int(param_grid_FFNN['batch_size']))+'_BatchSize_'+str(int(param_grid_FFNN['epochs']))+'_Epoch_'+nameData+'.h5')   
    else:
        model_FFNN.save_weights('../BestParam/TuanTu/'+nameData+'/FFNN_Find_BestWeights/'+str(int(param_grid_FFNN['num_layers_hidden']))+'_HiddenLayer_'+str(int(param_grid_FFNN['neuralHidden']))+'_NeuralHidden_'+str(int(param_grid_FFNN['batch_size']))+'_BatchSize_'+str(int(param_grid_FFNN['epochs']))+'_Epoch_'+nameData+'.h5')   
   
    return param_grid_FFNN

# Dự Đoán FFNN 
# @param    nameData          Tên tập dữ liệu
# @param    typePredict       Thực hiện loại dự đoán (FFNN_Find_NeuralHidden,FFNN_Find_NumberHiddenLayer,CombinePredict)
# @param    X_train           cửa sổ mẫu tập train
# @param    y_train           Cửa sổ dự đoán tập train
# @param    X_test            Cửa sổ dự đoán tập train
# @param    best_params_FFNN  Cửa sổ dự đoán tập train
# @return   predictions_FFNN  Mảng dự đoán
def predict_FFNN(nameData, typePredict, X_train, y_train, X_test, best_params_FFNN):
    model_FFNN1 = Sequential()
    for i in range(best_params_FFNN['num_layers_hidden']):
        if i == 0:
            model_FFNN1.add(Dense(best_params_FFNN['neuralHidden'], input_dim= best_params_FFNN['neuralInput'], activation='sigmoid'))
        else:
            model_FFNN1.add(Dense(best_params_FFNN['neuralHidden'], activation='sigmoid'))
    model_FFNN1.add(Dense(best_params_FFNN['neuralOutput']))
    
    if(typePredict=='FFNN_Find_NeuralHidden'):
        model_FFNN1.load_weights('../BestParam/FFNN/'+nameData+'/FFNN_Find_NeuralHidden/'+str(int(best_params_FFNN['num_layers_hidden']))+'_HiddenLayer_'+str(int(best_params_FFNN['neuralHidden']))+'_NeuralHidden_'+str(int(best_params_FFNN['batch_size']))+'_BatchSize_'+str(int(best_params_FFNN['epochs']))+'_Epoch_'+nameData+'.h5')   
    elif (typePredict=='FFNN_Find_NumberHiddenLayer'):
        model_FFNN1.load_weights('../BestParam/FFNN/'+nameData+'/FFNN_Find_NumberHiddenLayer/'+str(int(best_params_FFNN['num_layers_hidden']))+'_HiddenLayer_'+str(int(best_params_FFNN['neuralHidden']))+'_NeuralHidden_'+str(int(best_params_FFNN['batch_size']))+'_BatchSize_'+str(int(best_params_FFNN['epochs']))+'_Epoch_'+nameData+'.h5')   
    elif (typePredict=='FFNN_Find_NumberHiddenLayer_SongSong'):
        model_FFNN1.load_weights('../BestParam/SongSong/'+nameData+'/FFNN_Find_BestWeights/'+str(int(best_params_FFNN['num_layers_hidden']))+'_HiddenLayer_'+str(int(best_params_FFNN['neuralHidden']))+'_NeuralHidden_'+str(int(best_params_FFNN['batch_size']))+'_BatchSize_'+str(int(best_params_FFNN['epochs']))+'_Epoch_'+nameData+'.h5')   
    else:
        model_FFNN1.load_weights('../BestParam/TuanTu/'+nameData+'/FFNN_Find_BestWeights/'+str(int(best_params_FFNN['num_layers_hidden']))+'_HiddenLayer_'+str(int(best_params_FFNN['neuralHidden']))+'_NeuralHidden_'+str(int(best_params_FFNN['batch_size']))+'_BatchSize_'+str(int(best_params_FFNN['epochs']))+'_Epoch_'+nameData+'.h5')   
   
    model_FFNN1.compile(loss='mean_squared_error', optimizer='adam')
    
    predictions_FFNN = model_FFNN1.predict(X_test)
    return predictions_FFNN

#---------------------Song Song------------------------------#

# Lai Ghép Song Song
# @param    y_pred_FFNN     Mảng dự đoán của FFNN
# @param    y_pred_KNN      Mảng dự đoán của KNN
# @param    y_test          Mảng chuỗi thực tế
# @return   y_pred_combine  Mảng dự đoán kết hợp
def predictHybrid(y_pred_FFNN,y_pred_KNN,y_test):
    FFNNSubKNN=[]
    TestSubKNN=[]
    weightEl=[]
    for i in range(len(y_pred_FFNN)):
        FFNNSubKNN.append(y_pred_FFNN[i]-y_pred_KNN[i])
        TestSubKNN.append(y_test[i]-y_pred_KNN[i])

    for j in range(len(FFNNSubKNN)):
        weightEl.append(((FFNNSubKNN[j]*TestSubKNN[j])/ (FFNNSubKNN[j]*FFNNSubKNN[j])))
    
    weight = np.array(weightEl)
    
    y_pred_combine=[]
    for i in range(len(weight)):
        y_pred_combine.append(weight[i]*y_pred_FFNN[i]+(1-weight[i])*y_pred_KNN[i])
    y_pred_combine=np.array(y_pred_combine)
    return y_pred_combine

#---------------------Tuần Tự------------------------------#

# Tính Lỗi Theo Từng Ngày
# @param    y_pred_KNN      Mảng dự đoán của KNN
# @param    y_test          Mảng chuỗi thực tế
# @return   mseWithDay     Mảng lỗi theo ngày
def mseWithDay(y_pred_KNN, y_test):
    mseDay = []
    for i in range(len(y_pred_KNN)):
        mseDay.append([abs((y_test[i] - y_pred_KNN[i]))])
    mseDay=np.array(mseDay)
    return mseDay

def predictSum(y_pred_mse,y_pred_KNN):
    pred_knn_ffnn=[]
    for i in range(len(y_pred_mse)):
        pred_knn_ffnn.append(y_pred_KNN[i]+y_pred_mse[i])
    pred_knn_ffnn=np.array(pred_knn_ffnn)
    return pred_knn_ffnn

# %%
nameData= 'MDLY'
filePath= '../../Dataset/'+nameData+'.csv'
timeSeries = readData(filePath)
timeSeries = cleanData(timeSeries)
percentTrain = 80
train_data, test_data = splitData(timeSeries, percentTrain)

size_window = 7
size_predict=1
stepWindow=1
X_train, y_train = prepare_data(train_data.values, size_window, size_predict, stepWindow)
X_test, y_test =   prepare_data(test_data.values, size_window, size_predict, stepWindow)

numHiddenLayer= 1

df_MseWith_Neural = pd.DataFrame([],  columns =  ["Neural Hidden","Batch_Size","Epoch", "MSE","Time Train", "Time Test", "Total Time"])

for neuralHidden in range(1,21):
    
    start_Train= time.time()
    best_param = train_FFNN(nameData, 'FFNN_Find_NeuralHidden', size_window, X_train, y_train, neuralHidden, numHiddenLayer, size_predict)
    end_Train = time.time()
    
    start_Test= time.time()
    predictions_FFNN= predict_FFNN(nameData, 'FFNN_Find_NeuralHidden', X_train, y_train, X_test, best_param)
    end_Test = time.time()

    timeTrain = end_Train - start_Train
    timeTest = end_Test -  start_Test
    totalTime = timeTrain+ timeTest
    
    rowMseWithNeural = pd.Series([neuralHidden,best_param['batch_size'],best_param['epochs'], mean_squared_error(y_test , predictions_FFNN), timeTrain, timeTest, totalTime], index=df_MseWith_Neural.columns)
    df_MseWith_Neural = df_MseWith_Neural.append(rowMseWithNeural,ignore_index=True)
# Out:
# WARNING:tensorflow:5 out of the last 16 calls to <function Model.make_test_function.<locals>.test_function at 0x0000027E5F4F48B0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_test_function.<locals>.test_function at 0x0000027E5E379CA0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Epoch 1/300
# 138/138 - 2s - loss: 0.0956 - 2s/epoch - 17ms/step
# Epoch 2/300
# 138/138 - 0s - loss: 0.0482 - 272ms/epoch - 2ms/step
# Epoch 3/300
# 138/138 - 0s - loss: 0.0324 - 253ms/epoch - 2ms/step
# Epoch 4/300
# 138/138 - 0s - loss: 0.0284 - 249ms/epoch - 2ms/step
# Epoch 5/300
# 138/138 - 0s - loss: 0.0272 - 240ms/epoch - 2ms/step
# Epoch 6/300
# 138/138 - 0s - loss: 0.0267 - 238ms/epoch - 2ms/step
# Epoch 7/300
# 138/138 - 0s - loss: 0.0263 - 240ms/epoch - 2ms/step
# Epoch 8/300
# 138/138 - 0s - loss: 0.0259 - 236ms/epoch - 2ms/step
# Epoch 9/300
# 138/138 - 0s - loss: 0.0256 - 252ms/epoch - 2ms/step
# Epoch 10/300
# 138/138 - 0s - loss: 0.0252 - 260ms/epoch - 2ms/step
# Epoch 11/300
# 138/138 - 0s - loss: 0.0248 - 251ms/epoch - 2ms/step
# Epoch 12/300
# 138/138 - 0s - loss: 0.0244 - 238ms/epoch - 2ms/step
# Epoch 13/300
# 138/138 - 0s - loss: 0.0240 - 252ms/epoch - 2ms/step
# Epoch 14/300
# 138/138 - 0s - loss: 0.0235 - 299ms/epoch - 2ms/step
# Epoch 15/300
# 138/138 - 0s - loss: 0.0231 - 275ms/epoch - 2ms/step
# Epoch 16/300
# 138/138 - 0s - loss: 0.0226 - 265ms/epoch - 2ms/step
# Epoch 17/300
# 138/138 - 0s - loss: 0.0221 - 281ms/epoch - 2ms/step
# Epoch 18/300
# 138/138 - 0s - loss: 0.0216 - 280ms/epoch - 2ms/step
# Epoch 19/300
# 138/138 - 0s - loss: 0.0211 - 263ms/epoch - 2ms/step
# Epoch 20/300
# 138/138 - 0s - loss: 0.0205 - 298ms/epoch - 2ms/step
# Epoch 21/300
# 138/138 - 0s - loss: 0.0200 - 261ms/epoch - 2ms/step
# Epoch 22/300
# 138/138 - 0s - loss: 0.0194 - 268ms/epoch - 2ms/step
# Epoch 23/300
# 138/138 - 0s - loss: 0.0189 - 290ms/epoch - 2ms/step
# Epoch 24/300
# 138/138 - 0s - loss: 0.0183 - 270ms/epoch - 2ms/step
# Epoch 25/300
# 138/138 - 0s - loss: 0.0177 - 314ms/epoch - 2ms/step
# Epoch 26/300
# 138/138 - 0s - loss: 0.0170 - 322ms/epoch - 2ms/step
# Epoch 27/300
# 138/138 - 0s - loss: 0.0164 - 316ms/epoch - 2ms/step
# Epoch 28/300
# 138/138 - 0s - loss: 0.0158 - 264ms/epoch - 2ms/step
# Epoch 29/300
# 138/138 - 0s - loss: 0.0152 - 264ms/epoch - 2ms/step
# Epoch 30/300
# 138/138 - 0s - loss: 0.0145 - 264ms/epoch - 2ms/step
# Epoch 31/300
# 138/138 - 0s - loss: 0.0139 - 253ms/epoch - 2ms/step
# Epoch 32/300
# 138/138 - 0s - loss: 0.0133 - 255ms/epoch - 2ms/step
# Epoch 33/300
# 138/138 - 0s - loss: 0.0126 - 251ms/epoch - 2ms/step
# Epoch 34/300
# 138/138 - 0s - loss: 0.0120 - 238ms/epoch - 2ms/step
# Epoch 35/300
# 138/138 - 0s - loss: 0.0114 - 237ms/epoch - 2ms/step
# Epoch 36/300
# 138/138 - 0s - loss: 0.0108 - 256ms/epoch - 2ms/step
# Epoch 37/300
# 138/138 - 0s - loss: 0.0102 - 253ms/epoch - 2ms/step
# Epoch 38/300
# 138/138 - 0s - loss: 0.0096 - 253ms/epoch - 2ms/step
# Epoch 39/300
# 138/138 - 0s - loss: 0.0090 - 238ms/epoch - 2ms/step
# Epoch 40/300
# 138/138 - 0s - loss: 0.0084 - 256ms/epoch - 2ms/step
# Epoch 41/300
# 138/138 - 0s - loss: 0.0079 - 238ms/epoch - 2ms/step
# Epoch 42/300
# 138/138 - 0s - loss: 0.0073 - 239ms/epoch - 2ms/step
# Epoch 43/300
# 138/138 - 0s - loss: 0.0068 - 239ms/epoch - 2ms/step
# Epoch 44/300
# 138/138 - 0s - loss: 0.0064 - 239ms/epoch - 2ms/step
# Epoch 45/300
# 138/138 - 0s - loss: 0.0059 - 299ms/epoch - 2ms/step
# Epoch 46/300
# 138/138 - 0s - loss: 0.0055 - 275ms/epoch - 2ms/step
# Epoch 47/300
# 138/138 - 0s - loss: 0.0050 - 314ms/epoch - 2ms/step
# Epoch 48/300
# 138/138 - 0s - loss: 0.0046 - 291ms/epoch - 2ms/step
# Epoch 49/300
# 138/138 - 0s - loss: 0.0043 - 278ms/epoch - 2ms/step
# Epoch 50/300
# 138/138 - 0s - loss: 0.0039 - 305ms/epoch - 2ms/step
# Epoch 51/300
# 138/138 - 0s - loss: 0.0036 - 287ms/epoch - 2ms/step
# Epoch 52/300
# 138/138 - 0s - loss: 0.0033 - 278ms/epoch - 2ms/step
# Epoch 53/300
# 138/138 - 0s - loss: 0.0031 - 248ms/epoch - 2ms/step
# Epoch 54/300
# 138/138 - 0s - loss: 0.0028 - 330ms/epoch - 2ms/step
# Epoch 55/300
# 138/138 - 0s - loss: 0.0026 - 318ms/epoch - 2ms/step
# Epoch 56/300
# 138/138 - 0s - loss: 0.0024 - 320ms/epoch - 2ms/step
# Epoch 57/300
# 138/138 - 0s - loss: 0.0023 - 306ms/epoch - 2ms/step
# Epoch 58/300
# 138/138 - 0s - loss: 0.0021 - 290ms/epoch - 2ms/step
# Epoch 59/300
# 138/138 - 0s - loss: 0.0020 - 285ms/epoch - 2ms/step
# Epoch 60/300
# 138/138 - 0s - loss: 0.0019 - 337ms/epoch - 2ms/step
# Epoch 61/300
# 138/138 - 0s - loss: 0.0018 - 285ms/epoch - 2ms/step
# Epoch 62/300
# 138/138 - 0s - loss: 0.0017 - 351ms/epoch - 3ms/step
# Epoch 63/300
# 138/138 - 0s - loss: 0.0016 - 286ms/epoch - 2ms/step
# Epoch 64/300
# 138/138 - 0s - loss: 0.0015 - 271ms/epoch - 2ms/step
# Epoch 65/300
# 138/138 - 0s - loss: 0.0015 - 293ms/epoch - 2ms/step
# Epoch 66/300
# 138/138 - 0s - loss: 0.0014 - 309ms/epoch - 2ms/step
# Epoch 67/300
# 138/138 - 0s - loss: 0.0014 - 305ms/epoch - 2ms/step
# Epoch 68/300
# 138/138 - 0s - loss: 0.0013 - 256ms/epoch - 2ms/step
# Epoch 69/300
# 138/138 - 0s - loss: 0.0013 - 342ms/epoch - 2ms/step
# Epoch 70/300
# 138/138 - 0s - loss: 0.0012 - 349ms/epoch - 3ms/step
# Epoch 71/300
# 138/138 - 0s - loss: 0.0012 - 313ms/epoch - 2ms/step
# Epoch 72/300
# 138/138 - 0s - loss: 0.0012 - 320ms/epoch - 2ms/step
# Epoch 73/300
# 138/138 - 0s - loss: 0.0012 - 336ms/epoch - 2ms/step
# Epoch 74/300
# 138/138 - 0s - loss: 0.0011 - 331ms/epoch - 2ms/step
# Epoch 75/300
# 138/138 - 0s - loss: 0.0011 - 284ms/epoch - 2ms/step
# Epoch 76/300
# 138/138 - 0s - loss: 0.0011 - 309ms/epoch - 2ms/step
# Epoch 77/300
# 138/138 - 0s - loss: 0.0011 - 320ms/epoch - 2ms/step
# Epoch 78/300
# 138/138 - 0s - loss: 0.0011 - 258ms/epoch - 2ms/step
# Epoch 79/300
# 138/138 - 0s - loss: 0.0011 - 361ms/epoch - 3ms/step
# Epoch 80/300
# 138/138 - 0s - loss: 0.0010 - 315ms/epoch - 2ms/step
# Epoch 81/300
# 138/138 - 0s - loss: 0.0010 - 331ms/epoch - 2ms/step
# Epoch 82/300
# 138/138 - 0s - loss: 0.0010 - 354ms/epoch - 3ms/step
# Epoch 83/300
# 138/138 - 0s - loss: 0.0010 - 331ms/epoch - 2ms/step
# Epoch 84/300
# 138/138 - 0s - loss: 0.0010 - 289ms/epoch - 2ms/step
# Epoch 85/300
# 138/138 - 0s - loss: 9.9044e-04 - 275ms/epoch - 2ms/step
# Epoch 86/300
# 138/138 - 0s - loss: 9.8029e-04 - 298ms/epoch - 2ms/step
# Epoch 87/300
# 138/138 - 0s - loss: 9.7062e-04 - 354ms/epoch - 3ms/step
# Epoch 88/300
# 138/138 - 0s - loss: 9.6137e-04 - 295ms/epoch - 2ms/step
# Epoch 89/300
# 138/138 - 0s - loss: 9.5254e-04 - 277ms/epoch - 2ms/step
# Epoch 90/300
# 138/138 - 0s - loss: 9.4410e-04 - 343ms/epoch - 2ms/step
# Epoch 91/300
# 138/138 - 0s - loss: 9.3601e-04 - 303ms/epoch - 2ms/step
# Epoch 92/300
# 138/138 - 0s - loss: 9.2826e-04 - 299ms/epoch - 2ms/step
# Epoch 93/300
# 138/138 - 0s - loss: 9.2084e-04 - 289ms/epoch - 2ms/step
# Epoch 94/300
# 138/138 - 0s - loss: 9.1372e-04 - 246ms/epoch - 2ms/step
# Epoch 95/300
# 138/138 - 0s - loss: 9.0688e-04 - 298ms/epoch - 2ms/step
# Epoch 96/300
# 138/138 - 0s - loss: 9.0031e-04 - 326ms/epoch - 2ms/step
# Epoch 97/300
# 138/138 - 0s - loss: 8.9400e-04 - 287ms/epoch - 2ms/step
# Epoch 98/300
# 138/138 - 0s - loss: 8.8793e-04 - 286ms/epoch - 2ms/step
# Epoch 99/300
# 138/138 - 0s - loss: 8.8209e-04 - 276ms/epoch - 2ms/step
# Epoch 100/300
# 138/138 - 0s - loss: 8.7646e-04 - 311ms/epoch - 2ms/step
# Epoch 101/300
# 138/138 - 0s - loss: 8.7103e-04 - 260ms/epoch - 2ms/step
# Epoch 102/300
# 138/138 - 0s - loss: 8.6580e-04 - 317ms/epoch - 2ms/step
# Epoch 103/300
# 138/138 - 0s - loss: 8.6075e-04 - 319ms/epoch - 2ms/step
# Epoch 104/300
# 138/138 - 0s - loss: 8.5586e-04 - 288ms/epoch - 2ms/step
# Epoch 105/300
# 138/138 - 0s - loss: 8.5114e-04 - 296ms/epoch - 2ms/step
# Epoch 106/300
# 138/138 - 0s - loss: 8.4657e-04 - 260ms/epoch - 2ms/step
# Epoch 107/300
# 138/138 - 0s - loss: 8.4215e-04 - 238ms/epoch - 2ms/step
# Epoch 108/300
# 138/138 - 0s - loss: 8.3786e-04 - 256ms/epoch - 2ms/step
# Epoch 109/300
# 138/138 - 0s - loss: 8.3369e-04 - 253ms/epoch - 2ms/step
# Epoch 110/300
# 138/138 - 0s - loss: 8.2965e-04 - 253ms/epoch - 2ms/step
# Epoch 111/300
# 138/138 - 0s - loss: 8.2572e-04 - 254ms/epoch - 2ms/step
# Epoch 112/300
# 138/138 - 0s - loss: 8.2190e-04 - 240ms/epoch - 2ms/step
# Epoch 113/300
# 138/138 - 0s - loss: 8.1818e-04 - 253ms/epoch - 2ms/step
# Epoch 114/300
# 138/138 - 0s - loss: 8.1455e-04 - 253ms/epoch - 2ms/step
# Epoch 115/300
# 138/138 - 0s - loss: 8.1102e-04 - 252ms/epoch - 2ms/step
# Epoch 116/300
# 138/138 - 0s - loss: 8.0756e-04 - 226ms/epoch - 2ms/step
# Epoch 117/300
# 138/138 - 0s - loss: 8.0419e-04 - 256ms/epoch - 2ms/step
# Epoch 118/300
# 138/138 - 0s - loss: 8.0090e-04 - 251ms/epoch - 2ms/step
# Epoch 119/300
# 138/138 - 0s - loss: 7.9767e-04 - 249ms/epoch - 2ms/step
# Epoch 120/300
# 138/138 - 0s - loss: 7.9452e-04 - 247ms/epoch - 2ms/step
# Epoch 121/300
# 138/138 - 0s - loss: 7.9142e-04 - 299ms/epoch - 2ms/step
# Epoch 122/300
# 138/138 - 0s - loss: 7.8839e-04 - 321ms/epoch - 2ms/step
# Epoch 123/300
# 138/138 - 0s - loss: 7.8541e-04 - 289ms/epoch - 2ms/step
# Epoch 124/300
# 138/138 - 0s - loss: 7.8249e-04 - 308ms/epoch - 2ms/step
# Epoch 125/300
# 138/138 - 0s - loss: 7.7961e-04 - 292ms/epoch - 2ms/step
# Epoch 126/300
# 138/138 - 0s - loss: 7.7679e-04 - 309ms/epoch - 2ms/step
# Epoch 127/300
# 138/138 - 0s - loss: 7.7401e-04 - 259ms/epoch - 2ms/step
# Epoch 128/300
# 138/138 - 0s - loss: 7.7127e-04 - 295ms/epoch - 2ms/step
# Epoch 129/300
# 138/138 - 0s - loss: 7.6857e-04 - 279ms/epoch - 2ms/step
# Epoch 130/300
# 138/138 - 0s - loss: 7.6592e-04 - 280ms/epoch - 2ms/step
# Epoch 131/300
# 138/138 - 0s - loss: 7.6330e-04 - 310ms/epoch - 2ms/step
# Epoch 132/300
# 138/138 - 0s - loss: 7.6071e-04 - 290ms/epoch - 2ms/step
# Epoch 133/300
# 138/138 - 0s - loss: 7.5816e-04 - 296ms/epoch - 2ms/step
# Epoch 134/300
# 138/138 - 0s - loss: 7.5563e-04 - 337ms/epoch - 2ms/step
# Epoch 135/300
# 138/138 - 0s - loss: 7.5314e-04 - 304ms/epoch - 2ms/step
# Epoch 136/300
# 138/138 - 0s - loss: 7.5068e-04 - 292ms/epoch - 2ms/step
# Epoch 137/300
# 138/138 - 0s - loss: 7.4824e-04 - 276ms/epoch - 2ms/step
# Epoch 138/300
# 138/138 - 0s - loss: 7.4583e-04 - 247ms/epoch - 2ms/step
# Epoch 139/300
# 138/138 - 0s - loss: 7.4344e-04 - 253ms/epoch - 2ms/step
# Epoch 140/300
# 138/138 - 0s - loss: 7.4108e-04 - 285ms/epoch - 2ms/step
# Epoch 141/300
# 138/138 - 0s - loss: 7.3874e-04 - 249ms/epoch - 2ms/step
# Epoch 142/300
# 138/138 - 0s - loss: 7.3642e-04 - 268ms/epoch - 2ms/step
# Epoch 143/300
# 138/138 - 0s - loss: 7.3412e-04 - 251ms/epoch - 2ms/step
# Epoch 144/300
# 138/138 - 0s - loss: 7.3185e-04 - 238ms/epoch - 2ms/step
# Epoch 145/300
# 138/138 - 0s - loss: 7.2959e-04 - 237ms/epoch - 2ms/step
# Epoch 146/300
# 138/138 - 0s - loss: 7.2734e-04 - 256ms/epoch - 2ms/step
# Epoch 147/300
# 138/138 - 0s - loss: 7.2512e-04 - 253ms/epoch - 2ms/step
# Epoch 148/300
# 138/138 - 0s - loss: 7.2292e-04 - 237ms/epoch - 2ms/step
# Epoch 149/300
# 138/138 - 0s - loss: 7.2073e-04 - 254ms/epoch - 2ms/step
# Epoch 150/300
# 138/138 - 0s - loss: 7.1855e-04 - 268ms/epoch - 2ms/step
# Epoch 151/300
# 138/138 - 0s - loss: 7.1639e-04 - 251ms/epoch - 2ms/step
# Epoch 152/300
# 138/138 - 0s - loss: 7.1425e-04 - 238ms/epoch - 2ms/step
# Epoch 153/300
# 138/138 - 0s - loss: 7.1212e-04 - 319ms/epoch - 2ms/step
# Epoch 154/300
# 138/138 - 0s - loss: 7.1000e-04 - 286ms/epoch - 2ms/step
# Epoch 155/300
# 138/138 - 0s - loss: 7.0790e-04 - 271ms/epoch - 2ms/step
# Epoch 156/300
# 138/138 - 0s - loss: 7.0581e-04 - 308ms/epoch - 2ms/step
# Epoch 157/300
# 138/138 - 0s - loss: 7.0374e-04 - 274ms/epoch - 2ms/step
# Epoch 158/300
# 138/138 - 0s - loss: 7.0168e-04 - 367ms/epoch - 3ms/step
# Epoch 159/300
# 138/138 - 0s - loss: 6.9962e-04 - 300ms/epoch - 2ms/step
# Epoch 160/300
# 138/138 - 0s - loss: 6.9758e-04 - 322ms/epoch - 2ms/step
# Epoch 161/300
# 138/138 - 0s - loss: 6.9556e-04 - 343ms/epoch - 2ms/step
# Epoch 162/300
# 138/138 - 0s - loss: 6.9354e-04 - 314ms/epoch - 2ms/step
# Epoch 163/300
# 138/138 - 0s - loss: 6.9154e-04 - 333ms/epoch - 2ms/step
# Epoch 164/300
# 138/138 - 0s - loss: 6.8954e-04 - 271ms/epoch - 2ms/step
# Epoch 165/300
# 138/138 - 0s - loss: 6.8756e-04 - 252ms/epoch - 2ms/step
# Epoch 166/300
# 138/138 - 0s - loss: 6.8559e-04 - 238ms/epoch - 2ms/step
# Epoch 167/300
# 138/138 - 0s - loss: 6.8362e-04 - 271ms/epoch - 2ms/step
# Epoch 168/300
# 138/138 - 0s - loss: 6.8167e-04 - 247ms/epoch - 2ms/step
# Epoch 169/300
# 138/138 - 0s - loss: 6.7973e-04 - 256ms/epoch - 2ms/step
# Epoch 170/300
# 138/138 - 0s - loss: 6.7780e-04 - 269ms/epoch - 2ms/step
# Epoch 171/300
# 138/138 - 0s - loss: 6.7587e-04 - 251ms/epoch - 2ms/step
# Epoch 172/300
# 138/138 - 0s - loss: 6.7396e-04 - 238ms/epoch - 2ms/step
# Epoch 173/300
# 138/138 - 0s - loss: 6.7206e-04 - 255ms/epoch - 2ms/step
# Epoch 174/300
# 138/138 - 0s - loss: 6.7016e-04 - 282ms/epoch - 2ms/step
# Epoch 175/300
# 138/138 - 0s - loss: 6.6828e-04 - 265ms/epoch - 2ms/step
# Epoch 176/300
# 138/138 - 0s - loss: 6.6640e-04 - 253ms/epoch - 2ms/step
# Epoch 177/300
# 138/138 - 0s - loss: 6.6453e-04 - 251ms/epoch - 2ms/step
# Epoch 178/300
# 138/138 - 0s - loss: 6.6268e-04 - 240ms/epoch - 2ms/step
# Epoch 179/300
# 138/138 - 0s - loss: 6.6083e-04 - 271ms/epoch - 2ms/step
# Epoch 180/300
# 138/138 - 0s - loss: 6.5898e-04 - 296ms/epoch - 2ms/step
# Epoch 181/300
# 138/138 - 0s - loss: 6.5715e-04 - 291ms/epoch - 2ms/step
# Epoch 182/300
# 138/138 - 0s - loss: 6.5533e-04 - 323ms/epoch - 2ms/step
# Epoch 183/300
# 138/138 - 0s - loss: 6.5351e-04 - 272ms/epoch - 2ms/step
# Epoch 184/300
# 138/138 - 0s - loss: 6.5170e-04 - 293ms/epoch - 2ms/step
# Epoch 185/300
# 138/138 - 0s - loss: 6.4991e-04 - 293ms/epoch - 2ms/step
# Epoch 186/300
# 138/138 - 0s - loss: 6.4811e-04 - 325ms/epoch - 2ms/step
# Epoch 187/300
# 138/138 - 0s - loss: 6.4633e-04 - 319ms/epoch - 2ms/step
# Epoch 188/300
# 138/138 - 0s - loss: 6.4456e-04 - 301ms/epoch - 2ms/step
# Epoch 189/300
# 138/138 - 0s - loss: 6.4279e-04 - 298ms/epoch - 2ms/step
# Epoch 190/300
# 138/138 - 0s - loss: 6.4103e-04 - 275ms/epoch - 2ms/step
# Epoch 191/300
# 138/138 - 0s - loss: 6.3928e-04 - 294ms/epoch - 2ms/step
# Epoch 192/300
# 138/138 - 0s - loss: 6.3754e-04 - 235ms/epoch - 2ms/step
# Epoch 193/300
# 138/138 - 0s - loss: 6.3581e-04 - 237ms/epoch - 2ms/step
# Epoch 194/300
# 138/138 - 0s - loss: 6.3408e-04 - 240ms/epoch - 2ms/step
# Epoch 195/300
# 138/138 - 0s - loss: 6.3236e-04 - 224ms/epoch - 2ms/step
# Epoch 196/300
# 138/138 - 0s - loss: 6.3065e-04 - 225ms/epoch - 2ms/step
# Epoch 197/300
# 138/138 - 0s - loss: 6.2894e-04 - 226ms/epoch - 2ms/step
# Epoch 198/300
# 138/138 - 0s - loss: 6.2725e-04 - 241ms/epoch - 2ms/step
# Epoch 199/300
# 138/138 - 0s - loss: 6.2556e-04 - 222ms/epoch - 2ms/step
# Epoch 200/300
# 138/138 - 0s - loss: 6.2388e-04 - 225ms/epoch - 2ms/step
# Epoch 201/300
# 138/138 - 0s - loss: 6.2220e-04 - 271ms/epoch - 2ms/step
# Epoch 202/300
# 138/138 - 0s - loss: 6.2054e-04 - 250ms/epoch - 2ms/step
# Epoch 203/300
# 138/138 - 0s - loss: 6.1888e-04 - 239ms/epoch - 2ms/step
# Epoch 204/300
# 138/138 - 0s - loss: 6.1723e-04 - 270ms/epoch - 2ms/step
# Epoch 205/300
# 138/138 - 0s - loss: 6.1558e-04 - 264ms/epoch - 2ms/step
# Epoch 206/300
# 138/138 - 0s - loss: 6.1395e-04 - 252ms/epoch - 2ms/step
# Epoch 207/300
# 138/138 - 0s - loss: 6.1232e-04 - 255ms/epoch - 2ms/step
# Epoch 208/300
# 138/138 - 0s - loss: 6.1070e-04 - 254ms/epoch - 2ms/step
# Epoch 209/300
# 138/138 - 0s - loss: 6.0908e-04 - 236ms/epoch - 2ms/step
# Epoch 210/300
# 138/138 - 0s - loss: 6.0747e-04 - 239ms/epoch - 2ms/step
# Epoch 211/300
# 138/138 - 0s - loss: 6.0587e-04 - 301ms/epoch - 2ms/step
# Epoch 212/300
# 138/138 - 0s - loss: 6.0428e-04 - 324ms/epoch - 2ms/step
# Epoch 213/300
# 138/138 - 0s - loss: 6.0269e-04 - 307ms/epoch - 2ms/step
# Epoch 214/300
# 138/138 - 0s - loss: 6.0111e-04 - 289ms/epoch - 2ms/step
# Epoch 215/300
# 138/138 - 0s - loss: 5.9954e-04 - 282ms/epoch - 2ms/step
# Epoch 216/300
# 138/138 - 0s - loss: 5.9798e-04 - 322ms/epoch - 2ms/step
# Epoch 217/300
# 138/138 - 0s - loss: 5.9642e-04 - 304ms/epoch - 2ms/step
# Epoch 218/300
# 138/138 - 0s - loss: 5.9487e-04 - 289ms/epoch - 2ms/step
# Epoch 219/300
# 138/138 - 0s - loss: 5.9333e-04 - 278ms/epoch - 2ms/step
# Epoch 220/300
# 138/138 - 0s - loss: 5.9179e-04 - 298ms/epoch - 2ms/step
# Epoch 221/300
# 138/138 - 0s - loss: 5.9026e-04 - 262ms/epoch - 2ms/step
# Epoch 222/300
# 138/138 - 0s - loss: 5.8874e-04 - 329ms/epoch - 2ms/step
# Epoch 223/300
# 138/138 - 0s - loss: 5.8722e-04 - 257ms/epoch - 2ms/step
# Epoch 224/300
# 138/138 - 0s - loss: 5.8571e-04 - 241ms/epoch - 2ms/step
# Epoch 225/300
# 138/138 - 0s - loss: 5.8421e-04 - 252ms/epoch - 2ms/step
# Epoch 226/300
# 138/138 - 0s - loss: 5.8272e-04 - 267ms/epoch - 2ms/step
# Epoch 227/300
# 138/138 - 0s - loss: 5.8123e-04 - 253ms/epoch - 2ms/step
# Epoch 228/300
# 138/138 - 0s - loss: 5.7975e-04 - 239ms/epoch - 2ms/step
# Epoch 229/300
# 138/138 - 0s - loss: 5.7827e-04 - 253ms/epoch - 2ms/step
# Epoch 230/300
# 138/138 - 0s - loss: 5.7680e-04 - 267ms/epoch - 2ms/step
# Epoch 231/300
# 138/138 - 0s - loss: 5.7534e-04 - 239ms/epoch - 2ms/step
# Epoch 232/300
# 138/138 - 0s - loss: 5.7389e-04 - 254ms/epoch - 2ms/step
# Epoch 233/300
# 138/138 - 0s - loss: 5.7244e-04 - 253ms/epoch - 2ms/step
# Epoch 234/300
# 138/138 - 0s - loss: 5.7100e-04 - 238ms/epoch - 2ms/step
# Epoch 235/300
# 138/138 - 0s - loss: 5.6956e-04 - 239ms/epoch - 2ms/step
# Epoch 236/300
# 138/138 - 0s - loss: 5.6814e-04 - 253ms/epoch - 2ms/step
# Epoch 237/300
# 138/138 - 0s - loss: 5.6671e-04 - 238ms/epoch - 2ms/step
# Epoch 238/300
# 138/138 - 0s - loss: 5.6530e-04 - 256ms/epoch - 2ms/step
# Epoch 239/300
# 138/138 - 0s - loss: 5.6389e-04 - 298ms/epoch - 2ms/step
# Epoch 240/300
# 138/138 - 0s - loss: 5.6249e-04 - 308ms/epoch - 2ms/step
# Epoch 241/300
# 138/138 - 0s - loss: 5.6110e-04 - 329ms/epoch - 2ms/step
# Epoch 242/300
# 138/138 - 0s - loss: 5.5971e-04 - 285ms/epoch - 2ms/step
# Epoch 243/300
# 138/138 - 0s - loss: 5.5833e-04 - 247ms/epoch - 2ms/step
# Epoch 244/300
# 138/138 - 0s - loss: 5.5695e-04 - 253ms/epoch - 2ms/step
# Epoch 245/300
# 138/138 - 0s - loss: 5.5558e-04 - 252ms/epoch - 2ms/step
# Epoch 246/300
# 138/138 - 0s - loss: 5.5422e-04 - 253ms/epoch - 2ms/step
# Epoch 247/300
# 138/138 - 0s - loss: 5.5286e-04 - 255ms/epoch - 2ms/step
# Epoch 248/300
# 138/138 - 0s - loss: 5.5152e-04 - 264ms/epoch - 2ms/step
# Epoch 249/300
# 138/138 - 0s - loss: 5.5017e-04 - 254ms/epoch - 2ms/step
# Epoch 250/300
# 138/138 - 0s - loss: 5.4884e-04 - 269ms/epoch - 2ms/step
# Epoch 251/300
# 138/138 - 0s - loss: 5.4751e-04 - 235ms/epoch - 2ms/step
# Epoch 252/300
# 138/138 - 0s - loss: 5.4618e-04 - 241ms/epoch - 2ms/step
# Epoch 253/300
# 138/138 - 0s - loss: 5.4487e-04 - 253ms/epoch - 2ms/step
# Epoch 254/300
# 138/138 - 0s - loss: 5.4355e-04 - 237ms/epoch - 2ms/step
# Epoch 255/300
# 138/138 - 0s - loss: 5.4225e-04 - 254ms/epoch - 2ms/step
# Epoch 256/300
# 138/138 - 0s - loss: 5.4095e-04 - 243ms/epoch - 2ms/step
# Epoch 257/300
# 138/138 - 0s - loss: 5.3966e-04 - 267ms/epoch - 2ms/step
# Epoch 258/300
# 138/138 - 0s - loss: 5.3837e-04 - 253ms/epoch - 2ms/step
# Epoch 259/300
# 138/138 - 0s - loss: 5.3710e-04 - 244ms/epoch - 2ms/step
# Epoch 260/300
# 138/138 - 0s - loss: 5.3582e-04 - 254ms/epoch - 2ms/step
# Epoch 261/300
# 138/138 - 0s - loss: 5.3456e-04 - 253ms/epoch - 2ms/step
# Epoch 262/300
# 138/138 - 0s - loss: 5.3329e-04 - 253ms/epoch - 2ms/step
# Epoch 263/300
# 138/138 - 0s - loss: 5.3204e-04 - 269ms/epoch - 2ms/step
# Epoch 264/300
# 138/138 - 0s - loss: 5.3079e-04 - 251ms/epoch - 2ms/step
# Epoch 265/300
# 138/138 - 0s - loss: 5.2955e-04 - 253ms/epoch - 2ms/step
# Epoch 266/300
# 138/138 - 0s - loss: 5.2831e-04 - 269ms/epoch - 2ms/step
# Epoch 267/300
# 138/138 - 0s - loss: 5.2708e-04 - 265ms/epoch - 2ms/step
# Epoch 268/300
# 138/138 - 0s - loss: 5.2586e-04 - 269ms/epoch - 2ms/step
# Epoch 269/300
# 138/138 - 0s - loss: 5.2464e-04 - 267ms/epoch - 2ms/step
# Epoch 270/300
# 138/138 - 0s - loss: 5.2343e-04 - 235ms/epoch - 2ms/step
# Epoch 271/300
# 138/138 - 0s - loss: 5.2223e-04 - 258ms/epoch - 2ms/step
# Epoch 272/300
# 138/138 - 0s - loss: 5.2103e-04 - 314ms/epoch - 2ms/step
# Epoch 273/300
# 138/138 - 0s - loss: 5.1983e-04 - 243ms/epoch - 2ms/step
# Epoch 274/300
# 138/138 - 0s - loss: 5.1865e-04 - 251ms/epoch - 2ms/step
# Epoch 275/300
# 138/138 - 0s - loss: 5.1747e-04 - 271ms/epoch - 2ms/step
# Epoch 276/300
# 138/138 - 0s - loss: 5.1629e-04 - 267ms/epoch - 2ms/step
# Epoch 277/300
# 138/138 - 0s - loss: 5.1512e-04 - 236ms/epoch - 2ms/step
# Epoch 278/300
# 138/138 - 0s - loss: 5.1396e-04 - 240ms/epoch - 2ms/step
# Epoch 279/300
# 138/138 - 0s - loss: 5.1280e-04 - 255ms/epoch - 2ms/step
# Epoch 280/300
# 138/138 - 0s - loss: 5.1165e-04 - 282ms/epoch - 2ms/step
# Epoch 281/300
# 138/138 - 0s - loss: 5.1050e-04 - 237ms/epoch - 2ms/step
# Epoch 282/300
# 138/138 - 0s - loss: 5.0936e-04 - 255ms/epoch - 2ms/step
# Epoch 283/300
# 138/138 - 0s - loss: 5.0823e-04 - 254ms/epoch - 2ms/step
# Epoch 284/300
# 138/138 - 0s - loss: 5.0710e-04 - 251ms/epoch - 2ms/step
# Epoch 285/300
# 138/138 - 0s - loss: 5.0598e-04 - 238ms/epoch - 2ms/step
# Epoch 286/300
# 138/138 - 0s - loss: 5.0486e-04 - 303ms/epoch - 2ms/step
# Epoch 287/300
# 138/138 - 0s - loss: 5.0375e-04 - 369ms/epoch - 3ms/step
# Epoch 288/300
# 138/138 - 0s - loss: 5.0265e-04 - 266ms/epoch - 2ms/step
# Epoch 289/300
# 138/138 - 0s - loss: 5.0155e-04 - 251ms/epoch - 2ms/step
# Epoch 290/300
# 138/138 - 0s - loss: 5.0045e-04 - 316ms/epoch - 2ms/step
# Epoch 291/300
# 138/138 - 0s - loss: 4.9937e-04 - 304ms/epoch - 2ms/step
# Epoch 292/300
# 138/138 - 0s - loss: 4.9828e-04 - 291ms/epoch - 2ms/step
# Epoch 293/300
# 138/138 - 0s - loss: 4.9721e-04 - 292ms/epoch - 2ms/step
# Epoch 294/300
# 138/138 - 0s - loss: 4.9614e-04 - 286ms/epoch - 2ms/step
# Epoch 295/300
# 138/138 - 0s - loss: 4.9507e-04 - 308ms/epoch - 2ms/step
# Epoch 296/300
# 138/138 - 0s - loss: 4.9401e-04 - 247ms/epoch - 2ms/step
# Epoch 297/300
# 138/138 - 0s - loss: 4.9296e-04 - 253ms/epoch - 2ms/step
# Epoch 298/300
# 138/138 - 0s - loss: 4.9191e-04 - 251ms/epoch - 2ms/step
# Epoch 299/300
# 138/138 - 0s - loss: 4.9087e-04 - 254ms/epoch - 2ms/step
# Epoch 300/300
# 138/138 - 0s - loss: 4.8983e-04 - 253ms/epoch - 2ms/step
# 9/9 [==============================] - 0s 3ms/step
# Epoch 1/300
# 138/138 - 2s - loss: 0.3628 - 2s/epoch - 11ms/step
# Epoch 2/300
# 138/138 - 0s - loss: 0.0747 - 319ms/epoch - 2ms/step
# Epoch 3/300
# 138/138 - 0s - loss: 0.0279 - 320ms/epoch - 2ms/step
# Epoch 4/300
# 138/138 - 0s - loss: 0.0250 - 305ms/epoch - 2ms/step
# Epoch 5/300
# 138/138 - 0s - loss: 0.0245 - 307ms/epoch - 2ms/step
# Epoch 6/300
# 138/138 - 0s - loss: 0.0231 - 306ms/epoch - 2ms/step
# Epoch 7/300
# 138/138 - 0s - loss: 0.0214 - 354ms/epoch - 3ms/step
# Epoch 8/300
# 138/138 - 0s - loss: 0.0197 - 266ms/epoch - 2ms/step
# Epoch 9/300
# 138/138 - 0s - loss: 0.0181 - 251ms/epoch - 2ms/step
# Epoch 10/300
# 138/138 - 0s - loss: 0.0167 - 269ms/epoch - 2ms/step
# Epoch 11/300
# 138/138 - 0s - loss: 0.0153 - 240ms/epoch - 2ms/step
# Epoch 12/300
# 138/138 - 0s - loss: 0.0141 - 250ms/epoch - 2ms/step
# Epoch 13/300
# 138/138 - 0s - loss: 0.0130 - 241ms/epoch - 2ms/step
# Epoch 14/300
# 138/138 - 0s - loss: 0.0119 - 237ms/epoch - 2ms/step
# Epoch 15/300
# 138/138 - 0s - loss: 0.0110 - 240ms/epoch - 2ms/step
# Epoch 16/300
# 138/138 - 0s - loss: 0.0102 - 238ms/epoch - 2ms/step
# Epoch 17/300
# 138/138 - 0s - loss: 0.0094 - 240ms/epoch - 2ms/step
# Epoch 18/300
# 138/138 - 0s - loss: 0.0087 - 242ms/epoch - 2ms/step
# Epoch 19/300
# 138/138 - 0s - loss: 0.0081 - 255ms/epoch - 2ms/step
# Epoch 20/300
# 138/138 - 0s - loss: 0.0075 - 254ms/epoch - 2ms/step
# Epoch 21/300
# 138/138 - 0s - loss: 0.0069 - 281ms/epoch - 2ms/step
# Epoch 22/300
# 138/138 - 0s - loss: 0.0064 - 307ms/epoch - 2ms/step
# Epoch 23/300
# 138/138 - 0s - loss: 0.0060 - 292ms/epoch - 2ms/step
# Epoch 24/300
# 138/138 - 0s - loss: 0.0055 - 356ms/epoch - 3ms/step
# Epoch 25/300
# 138/138 - 0s - loss: 0.0051 - 328ms/epoch - 2ms/step
# Epoch 26/300
# 138/138 - 0s - loss: 0.0048 - 276ms/epoch - 2ms/step
# Epoch 27/300
# 138/138 - 0s - loss: 0.0044 - 277ms/epoch - 2ms/step
# Epoch 28/300
# 138/138 - 0s - loss: 0.0041 - 309ms/epoch - 2ms/step
# Epoch 29/300
# 138/138 - 0s - loss: 0.0038 - 307ms/epoch - 2ms/step
# Epoch 30/300
# 138/138 - 0s - loss: 0.0035 - 307ms/epoch - 2ms/step
# Epoch 31/300
# 138/138 - 0s - loss: 0.0033 - 289ms/epoch - 2ms/step
# Epoch 32/300
# 138/138 - 0s - loss: 0.0030 - 282ms/epoch - 2ms/step
# Epoch 33/300
# 138/138 - 0s - loss: 0.0028 - 310ms/epoch - 2ms/step
# Epoch 34/300
# 138/138 - 0s - loss: 0.0026 - 289ms/epoch - 2ms/step
# Epoch 35/300
# 138/138 - 0s - loss: 0.0024 - 264ms/epoch - 2ms/step
# Epoch 36/300
# 138/138 - 0s - loss: 0.0023 - 264ms/epoch - 2ms/step
# Epoch 37/300
# 138/138 - 0s - loss: 0.0021 - 285ms/epoch - 2ms/step
# Epoch 38/300
# 138/138 - 0s - loss: 0.0020 - 278ms/epoch - 2ms/step
# Epoch 39/300
# 138/138 - 0s - loss: 0.0019 - 358ms/epoch - 3ms/step
# Epoch 40/300
# 138/138 - 0s - loss: 0.0018 - 298ms/epoch - 2ms/step
# Epoch 41/300
# 138/138 - 0s - loss: 0.0017 - 271ms/epoch - 2ms/step
# Epoch 42/300
# 138/138 - 0s - loss: 0.0017 - 282ms/epoch - 2ms/step
# Epoch 43/300
# 138/138 - 0s - loss: 0.0016 - 354ms/epoch - 3ms/step
# Epoch 44/300
# 138/138 - 0s - loss: 0.0015 - 269ms/epoch - 2ms/step
# Epoch 45/300
# 138/138 - 0s - loss: 0.0015 - 297ms/epoch - 2ms/step
# Epoch 46/300
# 138/138 - 0s - loss: 0.0015 - 292ms/epoch - 2ms/step
# Epoch 47/300
# 138/138 - 0s - loss: 0.0014 - 327ms/epoch - 2ms/step
# Epoch 48/300
# 138/138 - 0s - loss: 0.0014 - 269ms/epoch - 2ms/step
# Epoch 49/300
# 138/138 - 0s - loss: 0.0014 - 297ms/epoch - 2ms/step
# Epoch 50/300
# 138/138 - 0s - loss: 0.0013 - 262ms/epoch - 2ms/step
# Epoch 51/300
# 138/138 - 0s - loss: 0.0013 - 266ms/epoch - 2ms/step
# Epoch 52/300
# 138/138 - 0s - loss: 0.0013 - 237ms/epoch - 2ms/step
# Epoch 53/300
# 138/138 - 0s - loss: 0.0013 - 240ms/epoch - 2ms/step
# Epoch 54/300
# 138/138 - 0s - loss: 0.0013 - 255ms/epoch - 2ms/step
# Epoch 55/300
# 138/138 - 0s - loss: 0.0013 - 274ms/epoch - 2ms/step
# Epoch 56/300
# 138/138 - 0s - loss: 0.0012 - 247ms/epoch - 2ms/step
# Epoch 57/300
# 138/138 - 0s - loss: 0.0012 - 286ms/epoch - 2ms/step
# Epoch 58/300
# 138/138 - 0s - loss: 0.0012 - 249ms/epoch - 2ms/step
# Epoch 59/300
# 138/138 - 0s - loss: 0.0012 - 254ms/epoch - 2ms/step
# Epoch 60/300
# 138/138 - 0s - loss: 0.0012 - 253ms/epoch - 2ms/step
# Epoch 61/300
# 138/138 - 0s - loss: 0.0012 - 224ms/epoch - 2ms/step
# Epoch 62/300
# 138/138 - 0s - loss: 0.0012 - 224ms/epoch - 2ms/step
# Epoch 63/300
# 138/138 - 0s - loss: 0.0012 - 240ms/epoch - 2ms/step
# Epoch 64/300
# 138/138 - 0s - loss: 0.0012 - 238ms/epoch - 2ms/step
# Epoch 65/300
# 138/138 - 0s - loss: 0.0012 - 254ms/epoch - 2ms/step
# Epoch 66/300
# 138/138 - 0s - loss: 0.0011 - 251ms/epoch - 2ms/step
# Epoch 67/300
# 138/138 - 0s - loss: 0.0011 - 302ms/epoch - 2ms/step
# Epoch 68/300
# 138/138 - 0s - loss: 0.0011 - 274ms/epoch - 2ms/step
# Epoch 69/300
# 138/138 - 0s - loss: 0.0011 - 298ms/epoch - 2ms/step
# Epoch 70/300
# 138/138 - 0s - loss: 0.0011 - 278ms/epoch - 2ms/step
# Epoch 71/300
# 138/138 - 0s - loss: 0.0011 - 282ms/epoch - 2ms/step
# Epoch 72/300
# 138/138 - 0s - loss: 0.0011 - 292ms/epoch - 2ms/step
# Epoch 73/300
# 138/138 - 0s - loss: 0.0011 - 357ms/epoch - 3ms/step
# Epoch 74/300
# 138/138 - 0s - loss: 0.0011 - 299ms/epoch - 2ms/step
# Epoch 75/300
# 138/138 - 0s - loss: 0.0011 - 309ms/epoch - 2ms/step
# Epoch 76/300
# 138/138 - 0s - loss: 0.0011 - 273ms/epoch - 2ms/step
# Epoch 77/300
# 138/138 - 0s - loss: 0.0010 - 314ms/epoch - 2ms/step
# Epoch 78/300
# 138/138 - 0s - loss: 0.0010 - 288ms/epoch - 2ms/step
# Epoch 79/300
# 138/138 - 0s - loss: 0.0010 - 262ms/epoch - 2ms/step
# Epoch 80/300
# 138/138 - 0s - loss: 0.0010 - 240ms/epoch - 2ms/step
# Epoch 81/300
# 138/138 - 0s - loss: 0.0010 - 269ms/epoch - 2ms/step
# Epoch 82/300
# 138/138 - 0s - loss: 0.0010 - 252ms/epoch - 2ms/step
# Epoch 83/300
# 138/138 - 0s - loss: 9.9544e-04 - 253ms/epoch - 2ms/step
# Epoch 84/300
# 138/138 - 0s - loss: 9.8721e-04 - 253ms/epoch - 2ms/step
# Epoch 85/300
# 138/138 - 0s - loss: 9.7908e-04 - 254ms/epoch - 2ms/step
# Epoch 86/300
# 138/138 - 0s - loss: 9.7107e-04 - 253ms/epoch - 2ms/step
# Epoch 87/300
# 138/138 - 0s - loss: 9.6316e-04 - 237ms/epoch - 2ms/step
# Epoch 88/300
# 138/138 - 0s - loss: 9.5535e-04 - 253ms/epoch - 2ms/step
# Epoch 89/300
# 138/138 - 0s - loss: 9.4764e-04 - 251ms/epoch - 2ms/step
# Epoch 90/300
# 138/138 - 0s - loss: 9.4003e-04 - 251ms/epoch - 2ms/step
# Epoch 91/300
# 138/138 - 0s - loss: 9.3252e-04 - 253ms/epoch - 2ms/step
# Epoch 92/300
# 138/138 - 0s - loss: 9.2511e-04 - 251ms/epoch - 2ms/step
# Epoch 93/300
# 138/138 - 0s - loss: 9.1779e-04 - 246ms/epoch - 2ms/step
# Epoch 94/300
# 138/138 - 0s - loss: 9.1057e-04 - 254ms/epoch - 2ms/step
# Epoch 95/300
# 138/138 - 0s - loss: 9.0343e-04 - 300ms/epoch - 2ms/step
# Epoch 96/300
# 138/138 - 0s - loss: 8.9639e-04 - 307ms/epoch - 2ms/step
# Epoch 97/300
# 138/138 - 0s - loss: 8.8943e-04 - 276ms/epoch - 2ms/step
# Epoch 98/300
# 138/138 - 0s - loss: 8.8255e-04 - 277ms/epoch - 2ms/step
# Epoch 99/300
# 138/138 - 0s - loss: 8.7576e-04 - 268ms/epoch - 2ms/step
# Epoch 100/300
# 138/138 - 0s - loss: 8.6905e-04 - 298ms/epoch - 2ms/step
# Epoch 101/300
# 138/138 - 0s - loss: 8.6241e-04 - 259ms/epoch - 2ms/step
# Epoch 102/300
# 138/138 - 0s - loss: 8.5586e-04 - 253ms/epoch - 2ms/step
# Epoch 103/300
# 138/138 - 0s - loss: 8.4937e-04 - 254ms/epoch - 2ms/step
# Epoch 104/300
# 138/138 - 0s - loss: 8.4296e-04 - 240ms/epoch - 2ms/step
# Epoch 105/300
# 138/138 - 0s - loss: 8.3662e-04 - 266ms/epoch - 2ms/step
# Epoch 106/300
# 138/138 - 0s - loss: 8.3035e-04 - 251ms/epoch - 2ms/step
# Epoch 107/300
# 138/138 - 0s - loss: 8.2415e-04 - 254ms/epoch - 2ms/step
# Epoch 108/300
# 138/138 - 0s - loss: 8.1802e-04 - 237ms/epoch - 2ms/step
# Epoch 109/300
# 138/138 - 0s - loss: 8.1195e-04 - 233ms/epoch - 2ms/step
# Epoch 110/300
# 138/138 - 0s - loss: 8.0595e-04 - 252ms/epoch - 2ms/step
# Epoch 111/300
# 138/138 - 0s - loss: 8.0000e-04 - 224ms/epoch - 2ms/step
# Epoch 112/300
# 138/138 - 0s - loss: 7.9412e-04 - 242ms/epoch - 2ms/step
# Epoch 113/300
# 138/138 - 0s - loss: 7.8830e-04 - 253ms/epoch - 2ms/step
# Epoch 114/300
# 138/138 - 0s - loss: 7.8254e-04 - 254ms/epoch - 2ms/step
# Epoch 115/300
# 138/138 - 0s - loss: 7.7684e-04 - 253ms/epoch - 2ms/step
# Epoch 116/300
# 138/138 - 0s - loss: 7.7119e-04 - 269ms/epoch - 2ms/step
# Epoch 117/300
# 138/138 - 0s - loss: 7.6560e-04 - 251ms/epoch - 2ms/step
# Epoch 118/300
# 138/138 - 0s - loss: 7.6007e-04 - 253ms/epoch - 2ms/step
# Epoch 119/300
# 138/138 - 0s - loss: 7.5459e-04 - 236ms/epoch - 2ms/step
# Epoch 120/300
# 138/138 - 0s - loss: 7.4916e-04 - 253ms/epoch - 2ms/step
# Epoch 121/300
# 138/138 - 0s - loss: 7.4379e-04 - 300ms/epoch - 2ms/step
# Epoch 122/300
# 138/138 - 0s - loss: 7.3846e-04 - 276ms/epoch - 2ms/step
# Epoch 123/300
# 138/138 - 0s - loss: 7.3319e-04 - 262ms/epoch - 2ms/step
# Epoch 124/300
# 138/138 - 0s - loss: 7.2797e-04 - 283ms/epoch - 2ms/step
# Epoch 125/300
# 138/138 - 0s - loss: 7.2280e-04 - 324ms/epoch - 2ms/step
# Epoch 126/300
# 138/138 - 0s - loss: 7.1768e-04 - 321ms/epoch - 2ms/step
# Epoch 127/300
# 138/138 - 0s - loss: 7.1261e-04 - 320ms/epoch - 2ms/step
# Epoch 128/300
# 138/138 - 0s - loss: 7.0758e-04 - 261ms/epoch - 2ms/step
# Epoch 129/300
# 138/138 - 0s - loss: 7.0260e-04 - 344ms/epoch - 2ms/step
# Epoch 130/300
# 138/138 - 0s - loss: 6.9767e-04 - 316ms/epoch - 2ms/step
# Epoch 131/300
# 138/138 - 0s - loss: 6.9279e-04 - 351ms/epoch - 3ms/step
# Epoch 132/300
# 138/138 - 0s - loss: 6.8794e-04 - 338ms/epoch - 2ms/step
# Epoch 133/300
# 138/138 - 0s - loss: 6.8315e-04 - 298ms/epoch - 2ms/step
# Epoch 134/300
# 138/138 - 0s - loss: 6.7840e-04 - 322ms/epoch - 2ms/step
# Epoch 135/300
# 138/138 - 0s - loss: 6.7369e-04 - 351ms/epoch - 3ms/step
# Epoch 136/300
# 138/138 - 0s - loss: 6.6903e-04 - 360ms/epoch - 3ms/step
# Epoch 137/300
# 138/138 - 0s - loss: 6.6441e-04 - 331ms/epoch - 2ms/step
# Epoch 138/300
# 138/138 - 0s - loss: 6.5984e-04 - 303ms/epoch - 2ms/step
# Epoch 139/300
# 138/138 - 0s - loss: 6.5530e-04 - 277ms/epoch - 2ms/step
# Epoch 140/300
# 138/138 - 0s - loss: 6.5081e-04 - 341ms/epoch - 2ms/step
# Epoch 141/300
# 138/138 - 0s - loss: 6.4637e-04 - 253ms/epoch - 2ms/step
# Epoch 142/300
# 138/138 - 0s - loss: 6.4196e-04 - 253ms/epoch - 2ms/step
# Epoch 143/300
# 138/138 - 0s - loss: 6.3759e-04 - 297ms/epoch - 2ms/step
# Epoch 144/300
# 138/138 - 0s - loss: 6.3327e-04 - 261ms/epoch - 2ms/step
# Epoch 145/300
# 138/138 - 0s - loss: 6.2898e-04 - 221ms/epoch - 2ms/step
# Epoch 146/300
# 138/138 - 0s - loss: 6.2474e-04 - 256ms/epoch - 2ms/step
# Epoch 147/300
# 138/138 - 0s - loss: 6.2053e-04 - 238ms/epoch - 2ms/step
# Epoch 148/300
# 138/138 - 0s - loss: 6.1636e-04 - 240ms/epoch - 2ms/step
# Epoch 149/300
# 138/138 - 0s - loss: 6.1224e-04 - 241ms/epoch - 2ms/step
# Epoch 150/300
# 138/138 - 0s - loss: 6.0816e-04 - 256ms/epoch - 2ms/step
# Epoch 151/300
# 138/138 - 0s - loss: 6.0411e-04 - 253ms/epoch - 2ms/step
# Epoch 152/300
# 138/138 - 0s - loss: 6.0010e-04 - 254ms/epoch - 2ms/step
# Epoch 153/300
# 138/138 - 0s - loss: 5.9613e-04 - 237ms/epoch - 2ms/step
# Epoch 154/300
# 138/138 - 0s - loss: 5.9220e-04 - 241ms/epoch - 2ms/step
# Epoch 155/300
# 138/138 - 0s - loss: 5.8831e-04 - 239ms/epoch - 2ms/step
# Epoch 156/300
# 138/138 - 0s - loss: 5.8445e-04 - 241ms/epoch - 2ms/step
# Epoch 157/300
# 138/138 - 0s - loss: 5.8064e-04 - 240ms/epoch - 2ms/step
# Epoch 158/300
# 138/138 - 0s - loss: 5.7686e-04 - 253ms/epoch - 2ms/step
# Epoch 159/300
# 138/138 - 0s - loss: 5.7311e-04 - 350ms/epoch - 3ms/step
# Epoch 160/300
# 138/138 - 0s - loss: 5.6941e-04 - 264ms/epoch - 2ms/step
# Epoch 161/300
# 138/138 - 0s - loss: 5.6574e-04 - 251ms/epoch - 2ms/step
# Epoch 162/300
# 138/138 - 0s - loss: 5.6211e-04 - 255ms/epoch - 2ms/step
# Epoch 163/300
# 138/138 - 0s - loss: 5.5852e-04 - 266ms/epoch - 2ms/step
# Epoch 164/300
# 138/138 - 0s - loss: 5.5496e-04 - 252ms/epoch - 2ms/step
# Epoch 165/300
# 138/138 - 0s - loss: 5.5144e-04 - 236ms/epoch - 2ms/step
# Epoch 166/300
# 138/138 - 0s - loss: 5.4795e-04 - 258ms/epoch - 2ms/step
# Epoch 167/300
# 138/138 - 0s - loss: 5.4450e-04 - 344ms/epoch - 2ms/step
# Epoch 168/300
# 138/138 - 0s - loss: 5.4109e-04 - 272ms/epoch - 2ms/step
# Epoch 169/300
# 138/138 - 0s - loss: 5.3772e-04 - 296ms/epoch - 2ms/step
# Epoch 170/300
# 138/138 - 0s - loss: 5.3438e-04 - 263ms/epoch - 2ms/step
# Epoch 171/300
# 138/138 - 0s - loss: 5.3107e-04 - 251ms/epoch - 2ms/step
# Epoch 172/300
# 138/138 - 0s - loss: 5.2781e-04 - 253ms/epoch - 2ms/step
# Epoch 173/300
# 138/138 - 0s - loss: 5.2457e-04 - 236ms/epoch - 2ms/step
# Epoch 174/300
# 138/138 - 0s - loss: 5.2138e-04 - 254ms/epoch - 2ms/step
# Epoch 175/300
# 138/138 - 0s - loss: 5.1822e-04 - 250ms/epoch - 2ms/step
# Epoch 176/300
# 138/138 - 0s - loss: 5.1509e-04 - 266ms/epoch - 2ms/step
# Epoch 177/300
# 138/138 - 0s - loss: 5.1200e-04 - 249ms/epoch - 2ms/step
# Epoch 178/300
# 138/138 - 0s - loss: 5.0894e-04 - 253ms/epoch - 2ms/step
# Epoch 179/300
# 138/138 - 0s - loss: 5.0592e-04 - 254ms/epoch - 2ms/step
# Epoch 180/300
# 138/138 - 0s - loss: 5.0294e-04 - 238ms/epoch - 2ms/step
# Epoch 181/300
# 138/138 - 0s - loss: 4.9998e-04 - 239ms/epoch - 2ms/step
# Epoch 182/300
# 138/138 - 0s - loss: 4.9707e-04 - 253ms/epoch - 2ms/step
# Epoch 183/300
# 138/138 - 0s - loss: 4.9418e-04 - 254ms/epoch - 2ms/step
# Epoch 184/300
# 138/138 - 0s - loss: 4.9134e-04 - 266ms/epoch - 2ms/step
# Epoch 185/300
# 138/138 - 0s - loss: 4.8852e-04 - 254ms/epoch - 2ms/step
# Epoch 186/300
# 138/138 - 0s - loss: 4.8574e-04 - 284ms/epoch - 2ms/step
# Epoch 187/300
# 138/138 - 0s - loss: 4.8300e-04 - 278ms/epoch - 2ms/step
# Epoch 188/300
# 138/138 - 0s - loss: 4.8028e-04 - 296ms/epoch - 2ms/step
# Epoch 189/300
# 138/138 - 0s - loss: 4.7760e-04 - 305ms/epoch - 2ms/step
# Epoch 190/300
# 138/138 - 0s - loss: 4.7496e-04 - 244ms/epoch - 2ms/step
# Epoch 191/300
# 138/138 - 0s - loss: 4.7235e-04 - 316ms/epoch - 2ms/step
# Epoch 192/300
# 138/138 - 0s - loss: 4.6977e-04 - 273ms/epoch - 2ms/step
# Epoch 193/300
# 138/138 - 0s - loss: 4.6722e-04 - 297ms/epoch - 2ms/step
# Epoch 194/300
# 138/138 - 0s - loss: 4.6471e-04 - 294ms/epoch - 2ms/step
# Epoch 195/300
# 138/138 - 0s - loss: 4.6223e-04 - 262ms/epoch - 2ms/step
# Epoch 196/300
# 138/138 - 0s - loss: 4.5978e-04 - 267ms/epoch - 2ms/step
# Epoch 197/300
# 138/138 - 0s - loss: 4.5736e-04 - 264ms/epoch - 2ms/step
# Epoch 198/300
# 138/138 - 0s - loss: 4.5497e-04 - 255ms/epoch - 2ms/step
# Epoch 199/300
# 138/138 - 0s - loss: 4.5262e-04 - 254ms/epoch - 2ms/step
# Epoch 200/300
# 138/138 - 0s - loss: 4.5030e-04 - 251ms/epoch - 2ms/step
# Epoch 201/300
# 138/138 - 0s - loss: 4.4801e-04 - 253ms/epoch - 2ms/step
# Epoch 202/300
# 138/138 - 0s - loss: 4.4574e-04 - 254ms/epoch - 2ms/step
# Epoch 203/300
# 138/138 - 0s - loss: 4.4351e-04 - 237ms/epoch - 2ms/step
# Epoch 204/300
# 138/138 - 0s - loss: 4.4132e-04 - 227ms/epoch - 2ms/step
# Epoch 205/300
# 138/138 - 0s - loss: 4.3915e-04 - 251ms/epoch - 2ms/step
# Epoch 206/300
# 138/138 - 0s - loss: 4.3701e-04 - 253ms/epoch - 2ms/step
# Epoch 207/300
# 138/138 - 0s - loss: 4.3490e-04 - 236ms/epoch - 2ms/step
# Epoch 208/300
# 138/138 - 0s - loss: 4.3282e-04 - 224ms/epoch - 2ms/step
# Epoch 209/300
# 138/138 - 0s - loss: 4.3077e-04 - 243ms/epoch - 2ms/step
# Epoch 210/300
# 138/138 - 0s - loss: 4.2875e-04 - 285ms/epoch - 2ms/step
# Epoch 211/300
# 138/138 - 0s - loss: 4.2675e-04 - 264ms/epoch - 2ms/step
# Epoch 212/300
# 138/138 - 0s - loss: 4.2479e-04 - 262ms/epoch - 2ms/step
# Epoch 213/300
# 138/138 - 0s - loss: 4.2285e-04 - 242ms/epoch - 2ms/step
# Epoch 214/300
# 138/138 - 0s - loss: 4.2094e-04 - 236ms/epoch - 2ms/step
# Epoch 215/300
# 138/138 - 0s - loss: 4.1906e-04 - 271ms/epoch - 2ms/step
# Epoch 216/300
# 138/138 - 0s - loss: 4.1721e-04 - 252ms/epoch - 2ms/step
# Epoch 217/300
# 138/138 - 0s - loss: 4.1538e-04 - 253ms/epoch - 2ms/step
# Epoch 218/300
# 138/138 - 0s - loss: 4.1357e-04 - 240ms/epoch - 2ms/step
# Epoch 219/300
# 138/138 - 0s - loss: 4.1180e-04 - 251ms/epoch - 2ms/step
# Epoch 220/300
# 138/138 - 0s - loss: 4.1005e-04 - 249ms/epoch - 2ms/step
# Epoch 221/300
# 138/138 - 0s - loss: 4.0832e-04 - 258ms/epoch - 2ms/step
# Epoch 222/300
# 138/138 - 0s - loss: 4.0662e-04 - 268ms/epoch - 2ms/step
# Epoch 223/300
# 138/138 - 0s - loss: 4.0495e-04 - 268ms/epoch - 2ms/step
# Epoch 224/300
# 138/138 - 0s - loss: 4.0330e-04 - 266ms/epoch - 2ms/step
# Epoch 225/300
# 138/138 - 0s - loss: 4.0167e-04 - 392ms/epoch - 3ms/step
# Epoch 226/300
# 138/138 - 0s - loss: 4.0007e-04 - 260ms/epoch - 2ms/step
# Epoch 227/300
# 138/138 - 0s - loss: 3.9849e-04 - 284ms/epoch - 2ms/step
# Epoch 228/300
# 138/138 - 0s - loss: 3.9694e-04 - 325ms/epoch - 2ms/step
# Epoch 229/300
# 138/138 - 0s - loss: 3.9541e-04 - 333ms/epoch - 2ms/step
# Epoch 230/300
# 138/138 - 0s - loss: 3.9390e-04 - 333ms/epoch - 2ms/step
# Epoch 231/300
# 138/138 - 0s - loss: 3.9241e-04 - 334ms/epoch - 2ms/step
# Epoch 232/300
# 138/138 - 0s - loss: 3.9095e-04 - 288ms/epoch - 2ms/step
# Epoch 233/300
# 138/138 - 0s - loss: 3.8951e-04 - 261ms/epoch - 2ms/step
# Epoch 234/300
# 138/138 - 0s - loss: 3.8809e-04 - 296ms/epoch - 2ms/step
# Epoch 235/300
# 138/138 - 0s - loss: 3.8669e-04 - 309ms/epoch - 2ms/step
# Epoch 236/300
# 138/138 - 0s - loss: 3.8531e-04 - 325ms/epoch - 2ms/step
# Epoch 237/300
# 138/138 - 0s - loss: 3.8395e-04 - 283ms/epoch - 2ms/step
# Epoch 238/300
# 138/138 - 0s - loss: 3.8261e-04 - 338ms/epoch - 2ms/step
# Epoch 239/300
# 138/138 - 0s - loss: 3.8129e-04 - 302ms/epoch - 2ms/step
# Epoch 240/300
# 138/138 - 0s - loss: 3.7999e-04 - 293ms/epoch - 2ms/step
# Epoch 241/300
# 138/138 - 0s - loss: 3.7871e-04 - 291ms/epoch - 2ms/step
# Epoch 242/300
# 138/138 - 0s - loss: 3.7745e-04 - 268ms/epoch - 2ms/step
# Epoch 243/300
# 138/138 - 0s - loss: 3.7621e-04 - 309ms/epoch - 2ms/step
# Epoch 244/300
# 138/138 - 0s - loss: 3.7499e-04 - 321ms/epoch - 2ms/step
# Epoch 245/300
# 138/138 - 0s - loss: 3.7378e-04 - 307ms/epoch - 2ms/step
# Epoch 246/300
# 138/138 - 0s - loss: 3.7260e-04 - 289ms/epoch - 2ms/step
# Epoch 247/300
# 138/138 - 0s - loss: 3.7143e-04 - 334ms/epoch - 2ms/step
# Epoch 248/300
# 138/138 - 0s - loss: 3.7028e-04 - 266ms/epoch - 2ms/step
# Epoch 249/300
# 138/138 - 0s - loss: 3.6914e-04 - 236ms/epoch - 2ms/step
# Epoch 250/300
# 138/138 - 0s - loss: 3.6803e-04 - 222ms/epoch - 2ms/step
# Epoch 251/300
# 138/138 - 0s - loss: 3.6693e-04 - 228ms/epoch - 2ms/step
# Epoch 252/300
# 138/138 - 0s - loss: 3.6584e-04 - 213ms/epoch - 2ms/step
# Epoch 253/300
# 138/138 - 0s - loss: 3.6478e-04 - 211ms/epoch - 2ms/step
# Epoch 254/300
# 138/138 - 0s - loss: 3.6372e-04 - 213ms/epoch - 2ms/step
# Epoch 255/300
# 138/138 - 0s - loss: 3.6269e-04 - 214ms/epoch - 2ms/step
# Epoch 256/300
# 138/138 - 0s - loss: 3.6167e-04 - 228ms/epoch - 2ms/step
# Epoch 257/300
# 138/138 - 0s - loss: 3.6066e-04 - 198ms/epoch - 1ms/step
# Epoch 258/300
# 138/138 - 0s - loss: 3.5967e-04 - 211ms/epoch - 2ms/step
# Epoch 259/300
# 138/138 - 0s - loss: 3.5870e-04 - 260ms/epoch - 2ms/step
# Epoch 260/300
# 138/138 - 0s - loss: 3.5773e-04 - 238ms/epoch - 2ms/step
# Epoch 261/300
# 138/138 - 0s - loss: 3.5679e-04 - 253ms/epoch - 2ms/step
# Epoch 262/300
# 138/138 - 0s - loss: 3.5586e-04 - 253ms/epoch - 2ms/step
# Epoch 263/300
# 138/138 - 0s - loss: 3.5494e-04 - 251ms/epoch - 2ms/step
# Epoch 264/300
# 138/138 - 0s - loss: 3.5403e-04 - 253ms/epoch - 2ms/step
# Epoch 265/300
# 138/138 - 0s - loss: 3.5314e-04 - 253ms/epoch - 2ms/step
# Epoch 266/300
# 138/138 - 0s - loss: 3.5226e-04 - 269ms/epoch - 2ms/step
# Epoch 267/300
# 138/138 - 0s - loss: 3.5139e-04 - 252ms/epoch - 2ms/step
# Epoch 268/300
# 138/138 - 0s - loss: 3.5054e-04 - 251ms/epoch - 2ms/step
# Epoch 269/300
# 138/138 - 0s - loss: 3.4970e-04 - 247ms/epoch - 2ms/step
# Epoch 270/300
# 138/138 - 0s - loss: 3.4887e-04 - 244ms/epoch - 2ms/step
# Epoch 271/300
# 138/138 - 0s - loss: 3.4806e-04 - 253ms/epoch - 2ms/step
# Epoch 272/300
# 138/138 - 0s - loss: 3.4725e-04 - 254ms/epoch - 2ms/step
# Epoch 273/300
# 138/138 - 0s - loss: 3.4646e-04 - 238ms/epoch - 2ms/step
# Epoch 274/300
# 138/138 - 0s - loss: 3.4568e-04 - 226ms/epoch - 2ms/step
# Epoch 275/300
# 138/138 - 0s - loss: 3.4491e-04 - 253ms/epoch - 2ms/step
# Epoch 276/300
# 138/138 - 0s - loss: 3.4415e-04 - 253ms/epoch - 2ms/step
# Epoch 277/300
# 138/138 - 0s - loss: 3.4340e-04 - 253ms/epoch - 2ms/step
# Epoch 278/300
# 138/138 - 0s - loss: 3.4266e-04 - 253ms/epoch - 2ms/step
# Epoch 279/300
# 138/138 - 0s - loss: 3.4194e-04 - 334ms/epoch - 2ms/step
# Epoch 280/300
# 138/138 - 0s - loss: 3.4122e-04 - 269ms/epoch - 2ms/step
# Epoch 281/300
# 138/138 - 0s - loss: 3.4052e-04 - 265ms/epoch - 2ms/step
# Epoch 282/300
# 138/138 - 0s - loss: 3.3982e-04 - 251ms/epoch - 2ms/step
# Epoch 283/300
# 138/138 - 0s - loss: 3.3914e-04 - 253ms/epoch - 2ms/step
# Epoch 284/300
# 138/138 - 0s - loss: 3.3846e-04 - 267ms/epoch - 2ms/step
# Epoch 285/300
# 138/138 - 0s - loss: 3.3779e-04 - 249ms/epoch - 2ms/step
# Epoch 286/300
# 138/138 - 0s - loss: 3.3714e-04 - 240ms/epoch - 2ms/step
# Epoch 287/300
# 138/138 - 0s - loss: 3.3649e-04 - 251ms/epoch - 2ms/step
# Epoch 288/300
# 138/138 - 0s - loss: 3.3585e-04 - 243ms/epoch - 2ms/step
# Epoch 289/300
# 138/138 - 0s - loss: 3.3522e-04 - 238ms/epoch - 2ms/step
# Epoch 290/300
# 138/138 - 0s - loss: 3.3460e-04 - 240ms/epoch - 2ms/step
# Epoch 291/300
# 138/138 - 0s - loss: 3.3398e-04 - 237ms/epoch - 2ms/step
# Epoch 292/300
# 138/138 - 0s - loss: 3.3338e-04 - 226ms/epoch - 2ms/step
# Epoch 293/300
# 138/138 - 0s - loss: 3.3278e-04 - 256ms/epoch - 2ms/step
# Epoch 294/300
# 138/138 - 0s - loss: 3.3220e-04 - 285ms/epoch - 2ms/step
# Epoch 295/300
# 138/138 - 0s - loss: 3.3162e-04 - 274ms/epoch - 2ms/step
# Epoch 296/300
# 138/138 - 0s - loss: 3.3104e-04 - 333ms/epoch - 2ms/step
# Epoch 297/300
# 138/138 - 0s - loss: 3.3048e-04 - 299ms/epoch - 2ms/step
# Epoch 298/300
# 138/138 - 0s - loss: 3.2992e-04 - 273ms/epoch - 2ms/step
# Epoch 299/300
# 138/138 - 0s - loss: 3.2937e-04 - 327ms/epoch - 2ms/step
# Epoch 300/300
# 138/138 - 0s - loss: 3.2883e-04 - 302ms/epoch - 2ms/step
# 9/9 [==============================] - 0s 2ms/step
# Epoch 1/300
# 69/69 - 2s - loss: 0.1286 - 2s/epoch - 26ms/step
# Epoch 2/300
# 69/69 - 0s - loss: 0.0538 - 135ms/epoch - 2ms/step
# Epoch 3/300
# 69/69 - 0s - loss: 0.0308 - 148ms/epoch - 2ms/step
# Epoch 4/300
# 69/69 - 0s - loss: 0.0242 - 133ms/epoch - 2ms/step
# Epoch 5/300
# 69/69 - 0s - loss: 0.0212 - 118ms/epoch - 2ms/step
# Epoch 6/300
# 69/69 - 0s - loss: 0.0191 - 147ms/epoch - 2ms/step
# Epoch 7/300
# 69/69 - 0s - loss: 0.0173 - 149ms/epoch - 2ms/step
# Epoch 8/300
# 69/69 - 0s - loss: 0.0156 - 147ms/epoch - 2ms/step
# Epoch 9/300
# 69/69 - 0s - loss: 0.0140 - 133ms/epoch - 2ms/step
# Epoch 10/300
# 69/69 - 0s - loss: 0.0125 - 132ms/epoch - 2ms/step
# Epoch 11/300
# 69/69 - 0s - loss: 0.0111 - 133ms/epoch - 2ms/step
# Epoch 12/300
# 69/69 - 0s - loss: 0.0098 - 148ms/epoch - 2ms/step
# Epoch 13/300
# 69/69 - 0s - loss: 0.0086 - 129ms/epoch - 2ms/step
# Epoch 14/300
# 69/69 - 0s - loss: 0.0076 - 117ms/epoch - 2ms/step
# Epoch 15/300
# 69/69 - 0s - loss: 0.0067 - 134ms/epoch - 2ms/step
# Epoch 16/300
# 69/69 - 0s - loss: 0.0059 - 133ms/epoch - 2ms/step
# Epoch 17/300
# 69/69 - 0s - loss: 0.0051 - 134ms/epoch - 2ms/step
# Epoch 18/300
# 69/69 - 0s - loss: 0.0045 - 133ms/epoch - 2ms/step
# Epoch 19/300
# 69/69 - 0s - loss: 0.0040 - 131ms/epoch - 2ms/step
# Epoch 20/300
# 69/69 - 0s - loss: 0.0036 - 134ms/epoch - 2ms/step
# Epoch 21/300
# 69/69 - 0s - loss: 0.0032 - 133ms/epoch - 2ms/step
# Epoch 22/300
# 69/69 - 0s - loss: 0.0028 - 165ms/epoch - 2ms/step
# Epoch 23/300
# 69/69 - 0s - loss: 0.0026 - 128ms/epoch - 2ms/step
# Epoch 24/300
# 69/69 - 0s - loss: 0.0024 - 136ms/epoch - 2ms/step
# Epoch 25/300
# 69/69 - 0s - loss: 0.0022 - 131ms/epoch - 2ms/step
# Epoch 26/300
# 69/69 - 0s - loss: 0.0020 - 133ms/epoch - 2ms/step
# Epoch 27/300
# 69/69 - 0s - loss: 0.0019 - 149ms/epoch - 2ms/step
# Epoch 28/300
# 69/69 - 0s - loss: 0.0018 - 151ms/epoch - 2ms/step
# Epoch 29/300
# 69/69 - 0s - loss: 0.0017 - 191ms/epoch - 3ms/step
# Epoch 30/300
# 69/69 - 0s - loss: 0.0017 - 153ms/epoch - 2ms/step
# Epoch 31/300
# 69/69 - 0s - loss: 0.0016 - 128ms/epoch - 2ms/step
# Epoch 32/300
# 69/69 - 0s - loss: 0.0016 - 133ms/epoch - 2ms/step
# Epoch 33/300
# 69/69 - 0s - loss: 0.0015 - 147ms/epoch - 2ms/step
# Epoch 34/300
# 69/69 - 0s - loss: 0.0015 - 133ms/epoch - 2ms/step
# Epoch 35/300
# 69/69 - 0s - loss: 0.0015 - 133ms/epoch - 2ms/step
# Epoch 36/300
# 69/69 - 0s - loss: 0.0015 - 132ms/epoch - 2ms/step
# Epoch 37/300
# 69/69 - 0s - loss: 0.0014 - 147ms/epoch - 2ms/step
# Epoch 38/300
# 69/69 - 0s - loss: 0.0014 - 131ms/epoch - 2ms/step
# Epoch 39/300
# 69/69 - 0s - loss: 0.0014 - 166ms/epoch - 2ms/step
# Epoch 40/300
# 69/69 - 0s - loss: 0.0014 - 183ms/epoch - 3ms/step
# Epoch 41/300
# 69/69 - 0s - loss: 0.0014 - 142ms/epoch - 2ms/step
# Epoch 42/300
# 69/69 - 0s - loss: 0.0014 - 133ms/epoch - 2ms/step
# Epoch 43/300
# 69/69 - 0s - loss: 0.0014 - 133ms/epoch - 2ms/step
# Epoch 44/300
# 69/69 - 0s - loss: 0.0014 - 133ms/epoch - 2ms/step
# Epoch 45/300
# 69/69 - 0s - loss: 0.0014 - 131ms/epoch - 2ms/step
# Epoch 46/300
# 69/69 - 0s - loss: 0.0014 - 147ms/epoch - 2ms/step
# Epoch 47/300
# 69/69 - 0s - loss: 0.0014 - 136ms/epoch - 2ms/step
# Epoch 48/300
# 69/69 - 0s - loss: 0.0013 - 146ms/epoch - 2ms/step
# Epoch 49/300
# 69/69 - 0s - loss: 0.0013 - 147ms/epoch - 2ms/step
# Epoch 50/300
# 69/69 - 0s - loss: 0.0013 - 147ms/epoch - 2ms/step
# Epoch 51/300
# 69/69 - 0s - loss: 0.0013 - 131ms/epoch - 2ms/step
# Epoch 52/300
# 69/69 - 0s - loss: 0.0013 - 117ms/epoch - 2ms/step
# Epoch 53/300
# 69/69 - 0s - loss: 0.0013 - 141ms/epoch - 2ms/step
# Epoch 54/300
# 69/69 - 0s - loss: 0.0013 - 126ms/epoch - 2ms/step
# Epoch 55/300
# 69/69 - 0s - loss: 0.0013 - 137ms/epoch - 2ms/step
# Epoch 56/300
# 69/69 - 0s - loss: 0.0013 - 125ms/epoch - 2ms/step
# Epoch 57/300
# 69/69 - 0s - loss: 0.0013 - 133ms/epoch - 2ms/step
# Epoch 58/300
# 69/69 - 0s - loss: 0.0013 - 133ms/epoch - 2ms/step
# Epoch 59/300
# 69/69 - 0s - loss: 0.0013 - 131ms/epoch - 2ms/step
# Epoch 60/300
# 69/69 - 0s - loss: 0.0013 - 125ms/epoch - 2ms/step
# Epoch 61/300
# 69/69 - 0s - loss: 0.0013 - 132ms/epoch - 2ms/step
# Epoch 62/300
# 69/69 - 0s - loss: 0.0012 - 133ms/epoch - 2ms/step
# Epoch 63/300
# 69/69 - 0s - loss: 0.0012 - 133ms/epoch - 2ms/step
# Epoch 64/300
# 69/69 - 0s - loss: 0.0012 - 131ms/epoch - 2ms/step
# Epoch 65/300
# 69/69 - 0s - loss: 0.0012 - 136ms/epoch - 2ms/step
# Epoch 66/300
# 69/69 - 0s - loss: 0.0012 - 134ms/epoch - 2ms/step
# Epoch 67/300
# 69/69 - 0s - loss: 0.0012 - 118ms/epoch - 2ms/step
# Epoch 68/300
# 69/69 - 0s - loss: 0.0012 - 202ms/epoch - 3ms/step
# Epoch 69/300
# 69/69 - 0s - loss: 0.0012 - 160ms/epoch - 2ms/step
# Epoch 70/300
# 69/69 - 0s - loss: 0.0012 - 166ms/epoch - 2ms/step
# Epoch 71/300
# 69/69 - 0s - loss: 0.0012 - 153ms/epoch - 2ms/step
# Epoch 72/300
# 69/69 - 0s - loss: 0.0012 - 151ms/epoch - 2ms/step
# Epoch 73/300
# 69/69 - 0s - loss: 0.0012 - 153ms/epoch - 2ms/step
# Epoch 74/300
# 69/69 - 0s - loss: 0.0012 - 168ms/epoch - 2ms/step
# Epoch 75/300
# ...
# Epoch 78/300
# 138/138 - 0s - loss: 5.9276e-04 - 194ms/epoch - 1ms/step
# Epoch 79/300
# 138/138 - 0s - loss: 5.8978e-04 - 136ms/epoch - 982us/step
# Epoch 80/300
# 138/138 - 0s - loss: 5.8687e-04 - 134ms/epoch - 970us/step
# Epoch 81/300
# 138/138 - 0s - loss: 5.8403e-04 - 177ms/epoch - 1ms/step
# Epoch 82/300
# 138/138 - 0s - loss: 5.8124e-04 - 125ms/epoch - 905us/step
# Epoch 83/300
# 138/138 - 0s - loss: 5.7852e-04 - 133ms/epoch - 965us/step
# Epoch 84/300
# 138/138 - 0s - loss: 5.7586e-04 - 209ms/epoch - 2ms/step
# Epoch 85/300
# 138/138 - 0s - loss: 5.7327e-04 - 140ms/epoch - 1ms/step
# Epoch 86/300
# 138/138 - 0s - loss: 5.7073e-04 - 157ms/epoch - 1ms/step
# Epoch 87/300
# 138/138 - 0s - loss: 5.6824e-04 - 164ms/epoch - 1ms/step
# Epoch 88/300
# 138/138 - 0s - loss: 5.6582e-04 - 174ms/epoch - 1ms/step
# Epoch 89/300
# 138/138 - 0s - loss: 5.6344e-04 - 140ms/epoch - 1ms/step
# Epoch 90/300
# 138/138 - 0s - loss: 5.6112e-04 - 150ms/epoch - 1ms/step
# Epoch 91/300
# 138/138 - 0s - loss: 5.5886e-04 - 132ms/epoch - 958us/step
# Epoch 92/300
# 138/138 - 0s - loss: 5.5664e-04 - 194ms/epoch - 1ms/step
# Epoch 93/300
# 138/138 - 0s - loss: 5.5447e-04 - 138ms/epoch - 997us/step
# Epoch 94/300
# 138/138 - 0s - loss: 5.5234e-04 - 146ms/epoch - 1ms/step
# Epoch 95/300
# 138/138 - 0s - loss: 5.5026e-04 - 147ms/epoch - 1ms/step
# Epoch 96/300
# 138/138 - 0s - loss: 5.4822e-04 - 193ms/epoch - 1ms/step
# Epoch 97/300
# 138/138 - 0s - loss: 5.4622e-04 - 156ms/epoch - 1ms/step
# Epoch 98/300
# 138/138 - 0s - loss: 5.4426e-04 - 146ms/epoch - 1ms/step
# Epoch 99/300
# 138/138 - 0s - loss: 5.4233e-04 - 147ms/epoch - 1ms/step
# Epoch 100/300
# 138/138 - 0s - loss: 5.4044e-04 - 131ms/epoch - 950us/step
# Epoch 101/300
# 138/138 - 0s - loss: 5.3858e-04 - 194ms/epoch - 1ms/step
# Epoch 102/300
# 138/138 - 0s - loss: 5.3675e-04 - 167ms/epoch - 1ms/step
# Epoch 103/300
# 138/138 - 0s - loss: 5.3494e-04 - 155ms/epoch - 1ms/step
# Epoch 104/300
# 138/138 - 0s - loss: 5.3316e-04 - 209ms/epoch - 2ms/step
# Epoch 105/300
# 138/138 - 0s - loss: 5.3140e-04 - 135ms/epoch - 981us/step
# Epoch 106/300
# 138/138 - 0s - loss: 5.2966e-04 - 198ms/epoch - 1ms/step
# Epoch 107/300
# 138/138 - 0s - loss: 5.2793e-04 - 138ms/epoch - 1ms/step
# Epoch 108/300
# 138/138 - 0s - loss: 5.2622e-04 - 164ms/epoch - 1ms/step
# Epoch 109/300
# 138/138 - 0s - loss: 5.2452e-04 - 158ms/epoch - 1ms/step
# Epoch 110/300
# 138/138 - 0s - loss: 5.2284e-04 - 129ms/epoch - 932us/step
# Epoch 111/300
# 138/138 - 0s - loss: 5.2115e-04 - 194ms/epoch - 1ms/step
# Epoch 112/300
# 138/138 - 0s - loss: 5.1948e-04 - 153ms/epoch - 1ms/step
# Epoch 113/300
# 138/138 - 0s - loss: 5.1780e-04 - 149ms/epoch - 1ms/step
# Epoch 114/300
# 138/138 - 0s - loss: 5.1612e-04 - 193ms/epoch - 1ms/step
# Epoch 115/300
# 138/138 - 0s - loss: 5.1444e-04 - 138ms/epoch - 999us/step
# Epoch 116/300
# 138/138 - 0s - loss: 5.1276e-04 - 132ms/epoch - 959us/step
# Epoch 117/300
# 138/138 - 0s - loss: 5.1106e-04 - 146ms/epoch - 1ms/step
# Epoch 118/300
# 138/138 - 0s - loss: 5.0936e-04 - 193ms/epoch - 1ms/step
# Epoch 119/300
# 138/138 - 0s - loss: 5.0764e-04 - 138ms/epoch - 999us/step
# Epoch 120/300
# 138/138 - 0s - loss: 5.0591e-04 - 164ms/epoch - 1ms/step
# Epoch 121/300
# 138/138 - 0s - loss: 5.0416e-04 - 212ms/epoch - 2ms/step
# Epoch 122/300
# 138/138 - 0s - loss: 5.0240e-04 - 158ms/epoch - 1ms/step
# Epoch 123/300
# 138/138 - 0s - loss: 5.0062e-04 - 131ms/epoch - 950us/step
# Epoch 124/300
# 138/138 - 0s - loss: 4.9881e-04 - 147ms/epoch - 1ms/step
# Epoch 125/300
# 138/138 - 0s - loss: 4.9699e-04 - 180ms/epoch - 1ms/step
# Epoch 126/300
# 138/138 - 0s - loss: 4.9514e-04 - 158ms/epoch - 1ms/step
# Epoch 127/300
# 138/138 - 0s - loss: 4.9327e-04 - 129ms/epoch - 933us/step
# Epoch 128/300
# 138/138 - 0s - loss: 4.9138e-04 - 134ms/epoch - 970us/step
# Epoch 129/300
# 138/138 - 0s - loss: 4.8946e-04 - 146ms/epoch - 1ms/step
# Epoch 130/300
# 138/138 - 0s - loss: 4.8753e-04 - 193ms/epoch - 1ms/step
# Epoch 131/300
# 138/138 - 0s - loss: 4.8556e-04 - 135ms/epoch - 981us/step
# Epoch 132/300
# 138/138 - 0s - loss: 4.8357e-04 - 154ms/epoch - 1ms/step
# Epoch 133/300
# 138/138 - 0s - loss: 4.8156e-04 - 141ms/epoch - 1ms/step
# Epoch 134/300
# 138/138 - 0s - loss: 4.7952e-04 - 177ms/epoch - 1ms/step
# Epoch 135/300
# 138/138 - 0s - loss: 4.7746e-04 - 163ms/epoch - 1ms/step
# Epoch 136/300
# 138/138 - 0s - loss: 4.7537e-04 - 189ms/epoch - 1ms/step
# Epoch 137/300
# 138/138 - 0s - loss: 4.7327e-04 - 154ms/epoch - 1ms/step
# Epoch 138/300
# 138/138 - 0s - loss: 4.7114e-04 - 196ms/epoch - 1ms/step
# Epoch 139/300
# 138/138 - 0s - loss: 4.6899e-04 - 151ms/epoch - 1ms/step
# Epoch 140/300
# 138/138 - 0s - loss: 4.6682e-04 - 193ms/epoch - 1ms/step
# Epoch 141/300
# 138/138 - 0s - loss: 4.6463e-04 - 140ms/epoch - 1ms/step
# Epoch 142/300
# 138/138 - 0s - loss: 4.6243e-04 - 178ms/epoch - 1ms/step
# Epoch 143/300
# 138/138 - 0s - loss: 4.6021e-04 - 158ms/epoch - 1ms/step
# Epoch 144/300
# 138/138 - 0s - loss: 4.5797e-04 - 144ms/epoch - 1ms/step
# Epoch 145/300
# 138/138 - 0s - loss: 4.5572e-04 - 133ms/epoch - 965us/step
# Epoch 146/300
# 138/138 - 0s - loss: 4.5346e-04 - 194ms/epoch - 1ms/step
# Epoch 147/300
# 138/138 - 0s - loss: 4.5118e-04 - 138ms/epoch - 999us/step
# Epoch 148/300
# 138/138 - 0s - loss: 4.4890e-04 - 131ms/epoch - 950us/step
# Epoch 149/300
# 138/138 - 0s - loss: 4.4662e-04 - 180ms/epoch - 1ms/step
# Epoch 150/300
# 138/138 - 0s - loss: 4.4433e-04 - 138ms/epoch - 997us/step
# Epoch 151/300
# 138/138 - 0s - loss: 4.4205e-04 - 149ms/epoch - 1ms/step
# Epoch 152/300
# 138/138 - 0s - loss: 4.3977e-04 - 145ms/epoch - 1ms/step
# Epoch 153/300
# 138/138 - 0s - loss: 4.3750e-04 - 191ms/epoch - 1ms/step
# Epoch 154/300
# 138/138 - 0s - loss: 4.3523e-04 - 142ms/epoch - 1ms/step
# Epoch 155/300
# 138/138 - 0s - loss: 4.3299e-04 - 147ms/epoch - 1ms/step
# Epoch 156/300
# 138/138 - 0s - loss: 4.3075e-04 - 146ms/epoch - 1ms/step
# Epoch 157/300
# 138/138 - 0s - loss: 4.2854e-04 - 209ms/epoch - 2ms/step
# Epoch 158/300
# 138/138 - 0s - loss: 4.2634e-04 - 135ms/epoch - 981us/step
# Epoch 159/300
# 138/138 - 0s - loss: 4.2416e-04 - 150ms/epoch - 1ms/step
# Epoch 160/300
# 138/138 - 0s - loss: 4.2201e-04 - 146ms/epoch - 1ms/step
# Epoch 161/300
# 138/138 - 0s - loss: 4.1988e-04 - 194ms/epoch - 1ms/step
# Epoch 162/300
# 138/138 - 0s - loss: 4.1777e-04 - 153ms/epoch - 1ms/step
# Epoch 163/300
# 138/138 - 0s - loss: 4.1570e-04 - 147ms/epoch - 1ms/step
# Epoch 164/300
# 138/138 - 0s - loss: 4.1366e-04 - 147ms/epoch - 1ms/step
# Epoch 165/300
# 138/138 - 0s - loss: 4.1165e-04 - 147ms/epoch - 1ms/step
# Epoch 166/300
# 138/138 - 0s - loss: 4.0968e-04 - 193ms/epoch - 1ms/step
# Epoch 167/300
# 138/138 - 0s - loss: 4.0774e-04 - 167ms/epoch - 1ms/step
# Epoch 168/300
# 138/138 - 0s - loss: 4.0586e-04 - 160ms/epoch - 1ms/step
# Epoch 169/300
# 138/138 - 0s - loss: 4.0401e-04 - 176ms/epoch - 1ms/step
# Epoch 170/300
# 138/138 - 0s - loss: 4.0222e-04 - 158ms/epoch - 1ms/step
# Epoch 171/300
# 138/138 - 0s - loss: 4.0047e-04 - 157ms/epoch - 1ms/step
# Epoch 172/300
# 138/138 - 0s - loss: 3.9878e-04 - 161ms/epoch - 1ms/step
# Epoch 173/300
# 138/138 - 0s - loss: 3.9714e-04 - 144ms/epoch - 1ms/step
# Epoch 174/300
# 138/138 - 0s - loss: 3.9556e-04 - 179ms/epoch - 1ms/step
# Epoch 175/300
# 138/138 - 0s - loss: 3.9403e-04 - 139ms/epoch - 1ms/step
# Epoch 176/300
# 138/138 - 0s - loss: 3.9255e-04 - 131ms/epoch - 950us/step
# Epoch 177/300
# 138/138 - 0s - loss: 3.9112e-04 - 178ms/epoch - 1ms/step
# Epoch 178/300
# 138/138 - 0s - loss: 3.8975e-04 - 160ms/epoch - 1ms/step
# Epoch 179/300
# 138/138 - 0s - loss: 3.8842e-04 - 145ms/epoch - 1ms/step
# Epoch 180/300
# 138/138 - 0s - loss: 3.8714e-04 - 162ms/epoch - 1ms/step
# Epoch 181/300
# 138/138 - 0s - loss: 3.8590e-04 - 176ms/epoch - 1ms/step
# Epoch 182/300
# 138/138 - 0s - loss: 3.8471e-04 - 140ms/epoch - 1ms/step
# Epoch 183/300
# 138/138 - 0s - loss: 3.8356e-04 - 149ms/epoch - 1ms/step
# Epoch 184/300
# 138/138 - 0s - loss: 3.8244e-04 - 178ms/epoch - 1ms/step
# Epoch 185/300
# 138/138 - 0s - loss: 3.8137e-04 - 139ms/epoch - 1ms/step
# Epoch 186/300
# 138/138 - 0s - loss: 3.8033e-04 - 131ms/epoch - 950us/step
# Epoch 187/300
# 138/138 - 0s - loss: 3.7933e-04 - 133ms/epoch - 964us/step
# Epoch 188/300
# 138/138 - 0s - loss: 3.7836e-04 - 147ms/epoch - 1ms/step
# Epoch 189/300
# 138/138 - 0s - loss: 3.7743e-04 - 194ms/epoch - 1ms/step
# Epoch 190/300
# 138/138 - 0s - loss: 3.7652e-04 - 139ms/epoch - 1ms/step
# Epoch 191/300
# 138/138 - 0s - loss: 3.7565e-04 - 147ms/epoch - 1ms/step
# Epoch 192/300
# 138/138 - 0s - loss: 3.7480e-04 - 133ms/epoch - 964us/step
# Epoch 193/300
# 138/138 - 0s - loss: 3.7398e-04 - 194ms/epoch - 1ms/step
# Epoch 194/300
# 138/138 - 0s - loss: 3.7318e-04 - 136ms/epoch - 986us/step
# Epoch 195/300
# 138/138 - 0s - loss: 3.7242e-04 - 149ms/epoch - 1ms/step
# Epoch 196/300
# 138/138 - 0s - loss: 3.7167e-04 - 133ms/epoch - 964us/step
# Epoch 197/300
# 138/138 - 0s - loss: 3.7095e-04 - 144ms/epoch - 1ms/step
# Epoch 198/300
# 138/138 - 0s - loss: 3.7025e-04 - 196ms/epoch - 1ms/step
# Epoch 199/300
# 138/138 - 0s - loss: 3.6957e-04 - 171ms/epoch - 1ms/step
# Epoch 200/300
# 138/138 - 0s - loss: 3.6892e-04 - 158ms/epoch - 1ms/step
# Epoch 201/300
# 138/138 - 0s - loss: 3.6828e-04 - 158ms/epoch - 1ms/step
# Epoch 202/300
# 138/138 - 0s - loss: 3.6766e-04 - 176ms/epoch - 1ms/step
# Epoch 203/300
# 138/138 - 0s - loss: 3.6707e-04 - 144ms/epoch - 1ms/step
# Epoch 204/300
# 138/138 - 0s - loss: 3.6648e-04 - 163ms/epoch - 1ms/step
# Epoch 205/300
# 138/138 - 0s - loss: 3.6592e-04 - 141ms/epoch - 1ms/step
# Epoch 206/300
# 138/138 - 0s - loss: 3.6537e-04 - 178ms/epoch - 1ms/step
# Epoch 207/300
# 138/138 - 0s - loss: 3.6484e-04 - 157ms/epoch - 1ms/step
# Epoch 208/300
# 138/138 - 0s - loss: 3.6432e-04 - 129ms/epoch - 936us/step
# Epoch 209/300
# 138/138 - 0s - loss: 3.6382e-04 - 178ms/epoch - 1ms/step
# Epoch 210/300
# 138/138 - 0s - loss: 3.6333e-04 - 173ms/epoch - 1ms/step
# Epoch 211/300
# 138/138 - 0s - loss: 3.6286e-04 - 127ms/epoch - 920us/step
# Epoch 212/300
# 138/138 - 0s - loss: 3.6239e-04 - 149ms/epoch - 1ms/step
# Epoch 213/300
# 138/138 - 0s - loss: 3.6194e-04 - 194ms/epoch - 1ms/step
# Epoch 214/300
# 138/138 - 0s - loss: 3.6150e-04 - 140ms/epoch - 1ms/step
# Epoch 215/300
# 138/138 - 0s - loss: 3.6108e-04 - 147ms/epoch - 1ms/step
# Epoch 216/300
# 138/138 - 0s - loss: 3.6066e-04 - 162ms/epoch - 1ms/step
# Epoch 217/300
# 138/138 - 0s - loss: 3.6026e-04 - 173ms/epoch - 1ms/step
# Epoch 218/300
# 138/138 - 0s - loss: 3.5986e-04 - 144ms/epoch - 1ms/step
# Epoch 219/300
# 138/138 - 0s - loss: 3.5948e-04 - 147ms/epoch - 1ms/step
# Epoch 220/300
# 138/138 - 0s - loss: 3.5910e-04 - 133ms/epoch - 966us/step
# Epoch 221/300
# 138/138 - 0s - loss: 3.5873e-04 - 194ms/epoch - 1ms/step
# Epoch 222/300
# 138/138 - 0s - loss: 3.5838e-04 - 135ms/epoch - 982us/step
# Epoch 223/300
# 138/138 - 0s - loss: 3.5803e-04 - 133ms/epoch - 967us/step
# Epoch 224/300
# 138/138 - 0s - loss: 3.5768e-04 - 147ms/epoch - 1ms/step
# Epoch 225/300
# 138/138 - 0s - loss: 3.5735e-04 - 194ms/epoch - 1ms/step
# Epoch 226/300
# 138/138 - 0s - loss: 3.5702e-04 - 140ms/epoch - 1ms/step
# Epoch 227/300
# 138/138 - 0s - loss: 3.5670e-04 - 147ms/epoch - 1ms/step
# Epoch 228/300
# 138/138 - 0s - loss: 3.5639e-04 - 146ms/epoch - 1ms/step
# Epoch 229/300
# 138/138 - 0s - loss: 3.5609e-04 - 147ms/epoch - 1ms/step
# Epoch 230/300
# 138/138 - 0s - loss: 3.5579e-04 - 193ms/epoch - 1ms/step
# Epoch 231/300
# 138/138 - 0s - loss: 3.5549e-04 - 169ms/epoch - 1ms/step
# Epoch 232/300
# 138/138 - 0s - loss: 3.5521e-04 - 176ms/epoch - 1ms/step
# Epoch 233/300
# 138/138 - 0s - loss: 3.5492e-04 - 158ms/epoch - 1ms/step
# Epoch 234/300
# 138/138 - 0s - loss: 3.5465e-04 - 176ms/epoch - 1ms/step
# Epoch 235/300
# 138/138 - 0s - loss: 3.5438e-04 - 142ms/epoch - 1ms/step
# Epoch 236/300
# 138/138 - 0s - loss: 3.5411e-04 - 178ms/epoch - 1ms/step
# Epoch 237/300
# 138/138 - 0s - loss: 3.5386e-04 - 142ms/epoch - 1ms/step
# Epoch 238/300
# 138/138 - 0s - loss: 3.5360e-04 - 164ms/epoch - 1ms/step
# Epoch 239/300
# 138/138 - 0s - loss: 3.5335e-04 - 158ms/epoch - 1ms/step
# Epoch 240/300
# 138/138 - 0s - loss: 3.5310e-04 - 145ms/epoch - 1ms/step
# Epoch 241/300
# 138/138 - 0s - loss: 3.5286e-04 - 162ms/epoch - 1ms/step
# Epoch 242/300
# 138/138 - 0s - loss: 3.5263e-04 - 176ms/epoch - 1ms/step
# Epoch 243/300
# 138/138 - 0s - loss: 3.5239e-04 - 142ms/epoch - 1ms/step
# Epoch 244/300
# 138/138 - 0s - loss: 3.5216e-04 - 147ms/epoch - 1ms/step
# Epoch 245/300
# 138/138 - 0s - loss: 3.5194e-04 - 194ms/epoch - 1ms/step
# Epoch 246/300
# 138/138 - 0s - loss: 3.5172e-04 - 139ms/epoch - 1ms/step
# Epoch 247/300
# 138/138 - 0s - loss: 3.5150e-04 - 147ms/epoch - 1ms/step
# Epoch 248/300
# 138/138 - 0s - loss: 3.5129e-04 - 162ms/epoch - 1ms/step
# Epoch 249/300
# 138/138 - 0s - loss: 3.5107e-04 - 173ms/epoch - 1ms/step
# Epoch 250/300
# 138/138 - 0s - loss: 3.5087e-04 - 144ms/epoch - 1ms/step
# Epoch 251/300
# 138/138 - 0s - loss: 3.5066e-04 - 133ms/epoch - 964us/step
# Epoch 252/300
# 138/138 - 0s - loss: 3.5046e-04 - 145ms/epoch - 1ms/step
# Epoch 253/300
# 138/138 - 0s - loss: 3.5026e-04 - 196ms/epoch - 1ms/step
# Epoch 254/300
# 138/138 - 0s - loss: 3.5007e-04 - 122ms/epoch - 881us/step
# Epoch 255/300
# 138/138 - 0s - loss: 3.4988e-04 - 147ms/epoch - 1ms/step
# Epoch 256/300
# 138/138 - 0s - loss: 3.4968e-04 - 149ms/epoch - 1ms/step
# Epoch 257/300
# 138/138 - 0s - loss: 3.4950e-04 - 194ms/epoch - 1ms/step
# Epoch 258/300
# 138/138 - 0s - loss: 3.4931e-04 - 138ms/epoch - 997us/step
# Epoch 259/300
# 138/138 - 0s - loss: 3.4913e-04 - 133ms/epoch - 967us/step
# Epoch 260/300
# 138/138 - 0s - loss: 3.4895e-04 - 147ms/epoch - 1ms/step
# Epoch 261/300
# 138/138 - 0s - loss: 3.4877e-04 - 149ms/epoch - 1ms/step
# Epoch 262/300
# 138/138 - 0s - loss: 3.4859e-04 - 192ms/epoch - 1ms/step
# Epoch 263/300
# 138/138 - 0s - loss: 3.4842e-04 - 169ms/epoch - 1ms/step
# Epoch 264/300
# 138/138 - 0s - loss: 3.4825e-04 - 175ms/epoch - 1ms/step
# Epoch 265/300
# 138/138 - 0s - loss: 3.4808e-04 - 174ms/epoch - 1ms/step
# Epoch 266/300
# 138/138 - 0s - loss: 3.4791e-04 - 158ms/epoch - 1ms/step
# Epoch 267/300
# 138/138 - 0s - loss: 3.4774e-04 - 173ms/epoch - 1ms/step
# Epoch 268/300
# 138/138 - 0s - loss: 3.4758e-04 - 159ms/epoch - 1ms/step
# Epoch 269/300
# 138/138 - 0s - loss: 3.4742e-04 - 144ms/epoch - 1ms/step
# Epoch 270/300
# 138/138 - 0s - loss: 3.4726e-04 - 210ms/epoch - 2ms/step
# Epoch 271/300
# 138/138 - 0s - loss: 3.4710e-04 - 135ms/epoch - 980us/step
# Epoch 272/300
# 138/138 - 0s - loss: 3.4694e-04 - 133ms/epoch - 966us/step
# Epoch 273/300
# 138/138 - 0s - loss: 3.4679e-04 - 180ms/epoch - 1ms/step
# Epoch 274/300
# 138/138 - 0s - loss: 3.4663e-04 - 140ms/epoch - 1ms/step
# Epoch 275/300
# 138/138 - 0s - loss: 3.4648e-04 - 131ms/epoch - 950us/step
# Epoch 276/300
# 138/138 - 0s - loss: 3.4633e-04 - 194ms/epoch - 1ms/step
# Epoch 277/300
# 138/138 - 0s - loss: 3.4618e-04 - 153ms/epoch - 1ms/step
# Epoch 278/300
# 138/138 - 0s - loss: 3.4603e-04 - 147ms/epoch - 1ms/step
# Epoch 279/300
# 138/138 - 0s - loss: 3.4588e-04 - 146ms/epoch - 1ms/step
# Epoch 280/300
# 138/138 - 0s - loss: 3.4574e-04 - 194ms/epoch - 1ms/step
# Epoch 281/300
# 138/138 - 0s - loss: 3.4559e-04 - 122ms/epoch - 884us/step
# Epoch 282/300
# 138/138 - 0s - loss: 3.4545e-04 - 133ms/epoch - 966us/step
# Epoch 283/300
# 138/138 - 0s - loss: 3.4530e-04 - 162ms/epoch - 1ms/step
# Epoch 284/300
# 138/138 - 0s - loss: 3.4516e-04 - 161ms/epoch - 1ms/step
# Epoch 285/300
# 138/138 - 0s - loss: 3.4502e-04 - 190ms/epoch - 1ms/step
# Epoch 286/300
# 138/138 - 0s - loss: 3.4488e-04 - 138ms/epoch - 997us/step
# Epoch 287/300
# 138/138 - 0s - loss: 3.4474e-04 - 147ms/epoch - 1ms/step
# Epoch 288/300
# 138/138 - 0s - loss: 3.4461e-04 - 178ms/epoch - 1ms/step
# Epoch 289/300
# 138/138 - 0s - loss: 3.4447e-04 - 158ms/epoch - 1ms/step
# Epoch 290/300
# 138/138 - 0s - loss: 3.4433e-04 - 191ms/epoch - 1ms/step
# Epoch 291/300
# 138/138 - 0s - loss: 3.4420e-04 - 169ms/epoch - 1ms/step
# Epoch 292/300
# 138/138 - 0s - loss: 3.4406e-04 - 175ms/epoch - 1ms/step
# Epoch 293/300
# 138/138 - 0s - loss: 3.4393e-04 - 174ms/epoch - 1ms/step
# Epoch 294/300
# 138/138 - 0s - loss: 3.4380e-04 - 157ms/epoch - 1ms/step
# Epoch 295/300
# 138/138 - 0s - loss: 3.4367e-04 - 144ms/epoch - 1ms/step
# Epoch 296/300
# 138/138 - 0s - loss: 3.4353e-04 - 194ms/epoch - 1ms/step
# Epoch 297/300
# 138/138 - 0s - loss: 3.4341e-04 - 138ms/epoch - 997us/step
# Epoch 298/300
# 138/138 - 0s - loss: 3.4328e-04 - 149ms/epoch - 1ms/step
# Epoch 299/300
# 138/138 - 0s - loss: 3.4315e-04 - 192ms/epoch - 1ms/step
# Epoch 300/300
# 138/138 - 0s - loss: 3.4302e-04 - 140ms/epoch - 1ms/step
# 9/9 [==============================] - 0s 2ms/step

# %%
df_MseWith_Neural
# Out:
#     Neural Hidden  Batch_Size  Epoch       MSE   Time Train  Time Test  \
# 0             1.0         8.0  300.0  0.001128  1635.227291   0.521306
# 1             2.0         8.0  300.0  0.000405  1589.894284   0.902981
# 2             3.0        16.0  300.0  0.000100  1440.316936   0.269536
# 3             4.0         8.0  300.0  0.000089  1574.294738   0.377248
# 4             5.0         8.0  300.0  0.000174  1594.634665   8.521169
# 5             6.0         8.0  250.0  0.000198  1560.639046   0.439534
# 6             7.0        16.0  300.0  0.000074  1550.269712   0.414361
# 7             8.0         8.0  300.0  0.000132  1567.340487   0.523671
# 8             9.0         8.0  250.0  0.000177  1583.294159   7.080466
# 9            10.0         8.0  300.0  0.000068  1667.208170   0.413179
# 10           11.0         8.0  100.0  0.000122  1495.353870  10.893808
# 11           12.0        16.0  200.0  0.000186  1568.992955   1.116730
# 12           13.0         8.0  300.0  0.000085  1659.102973   0.636365
# 13           14.0        16.0  250.0  0.000167  1545.194226   0.591028
# 14           15.0        16.0  300.0  0.000124  1576.496323   0.426080
# 15           16.0         8.0  300.0  0.000083  1622.868663   0.252533
# 16           17.0         8.0  300.0  0.000056  1169.933470   0.241328
# 17           18.0         8.0  300.0  0.000096  1069.030805   0.255447
# 18           19.0         8.0  250.0  0.000079   953.474845   0.141778
# 19           20.0         8.0  300.0  0.000096   798.612052   0.137941
#
#      Total Time
# 0   1635.748597
# 1   1590.797265
# 2   1440.586473
# 3   1574.671986
# 4   1603.155834
# 5   1561.078580
# 6   1550.684074
# 7   1567.864159
# 8   1590.374624
# 9   1667.621350
# 10  1506.247678
# 11  1570.109686
# 12  1659.739338
# 13  1545.785254
# 14  1576.922402
# 15  1623.121196
# 16  1170.174798
# 17  1069.286251
# 18   953.616623
# 19   798.749994

# %%
plt.title("Biểu đồ Tập Dữ Liệu "+nameData)
plt.plot(readData(filePath), label= nameData+'Stock')
plt.xlabel("Ngày")
plt.ylabel("Giá Cổ Phiếu")
plt.legend()
plt.show()

# %%
# Vẽ biểu đồ
plt.plot(range(1,len(df_MseWith_Neural[['MSE']])+1), df_MseWith_Neural[['MSE']])
plt.title("Biểu đồ MSE Theo Neural Hidden Tập Dữ Liệu "+nameData)
plt.xlabel("Neural Hidden")
plt.ylabel("MSE")
plt.xticks(range(1,len(df_MseWith_Neural[['MSE']])+1))
plt.show()

# %%
df_MseWith_Neural_Sort = df_MseWith_Neural.sort_values('MSE')
best_Neural=df_MseWith_Neural_Sort['Neural Hidden'].iloc[0]

# %%
df_MseWith_Neural_Sort
# Out:
#     Neural Hidden  Batch_Size  Epoch       MSE   Time Train  Time Test  \
# 16           17.0         8.0  300.0  0.000056  1169.933470   0.241328
# 9            10.0         8.0  300.0  0.000068  1667.208170   0.413179
# 6             7.0        16.0  300.0  0.000074  1550.269712   0.414361
# 18           19.0         8.0  250.0  0.000079   953.474845   0.141778
# 15           16.0         8.0  300.0  0.000083  1622.868663   0.252533
# 12           13.0         8.0  300.0  0.000085  1659.102973   0.636365
# 3             4.0         8.0  300.0  0.000089  1574.294738   0.377248
# 19           20.0         8.0  300.0  0.000096   798.612052   0.137941
# 17           18.0         8.0  300.0  0.000096  1069.030805   0.255447
# 2             3.0        16.0  300.0  0.000100  1440.316936   0.269536
# 10           11.0         8.0  100.0  0.000122  1495.353870  10.893808
# 14           15.0        16.0  300.0  0.000124  1576.496323   0.426080
# 7             8.0         8.0  300.0  0.000132  1567.340487   0.523671
# 13           14.0        16.0  250.0  0.000167  1545.194226   0.591028
# 4             5.0         8.0  300.0  0.000174  1594.634665   8.521169
# 8             9.0         8.0  250.0  0.000177  1583.294159   7.080466
# 11           12.0        16.0  200.0  0.000186  1568.992955   1.116730
# 5             6.0         8.0  250.0  0.000198  1560.639046   0.439534
# 1             2.0         8.0  300.0  0.000405  1589.894284   0.902981
# 0             1.0         8.0  300.0  0.001128  1635.227291   0.521306
#
#      Total Time
# 16  1170.174798
# 9   1667.621350
# 6   1550.684074
# 18   953.616623
# 15  1623.121196
# 12  1659.739338
# 3   1574.671986
# 19   798.749994
# 17  1069.286251
# 2   1440.586473
# 10  1506.247678
# 14  1576.922402
# 7   1567.864159
# 13  1545.785254
# 4   1603.155834
# 8   1590.374624
# 11  1570.109686
# 5   1561.078580
# 1   1590.797265
# 0   1635.748597

# %%
best_Neural
# Out:
# 17.0

# %%
# Vẽ biểu đồ
best_param = {'batch_size': df_MseWith_Neural_Sort['Batch_Size'].iloc[0],
              'epochs': df_MseWith_Neural_Sort['Epoch'].iloc[0],
              'neuralHidden': df_MseWith_Neural_Sort['Neural Hidden'].iloc[0],
              'num_layers_hidden' : numHiddenLayer,
              'neuralInput' : size_window,
              'neuralOutput' : size_predict}
y_pred= predict_FFNN(nameData, 'FFNN_Find_NeuralHidden', X_train, y_train, X_test, best_param)

plt.title("Biểu đồ Dự Đoán FFNN Với Neural Hidden Tốt Nhất Trên Tập Dữ Liệu "+nameData)
plt.plot(y_pred, label=nameData+' Prediction Stock')
plt.plot(y_test, label=nameData+' Actual Stock')
plt.xlabel("Ngày")
plt.ylabel("Giá Cổ Phiếu")
plt.legend()
plt.show()
# Out:
# 9/9 [==============================] - 0s 3ms/step

# %% [markdown]
# # Load Predict

# %%
# neural=range(1,21)
# batch_size=[8,
# 8,
# 16,
# 8,
# 8,
# 8,
# 16,
# 8,
# 8,
# 8,
# 8,
# 16,
# 8,
# 16,
# 16,
# 8,
# 8,
# 8,
# 8,
# 8,
# ]
# epochs=[300,
# 300,
# 300,
# 300,
# 300,
# 250,
# 300,
# 300,
# 250,
# 300,
# 100,
# 200,
# 300,
# 250,
# 300,
# 300,
# 300,
# 300,
# 250,
# 300,
# ]

# nameData= 'MDLY'
# filePath= '../../Dataset/'+nameData+'.csv'
# timeSeries = readData(filePath)
# timeSeries = cleanData(timeSeries)
# percentTrain = 80
# train_data, test_data = splitData(timeSeries, percentTrain)

# size_window = 7
# size_predict=1
# stepWindow=1
# X_train, y_train = prepare_data(train_data.values, size_window, size_predict, stepWindow)
# X_test, y_test =   prepare_data(test_data.values, size_window, size_predict, stepWindow)

# numHiddenLayer= 1

# df_MseWith_Neural = pd.DataFrame([],  columns =  ["Neural Hidden","Batch_Size","Epoch", "MSE"])

# for i in range(len(neural)):

#     best_param = {'batch_size': batch_size[i],
#               'epochs': epochs[i],
#               'neuralHidden': neural[i],
#               'num_layers_hidden' : numHiddenLayer,
#               'neuralInput' : size_window,
#               'neuralOutput' : size_predict}
#     y_pred= predict_FFNN(nameData, 'FFNN_Find_NeuralHidden', X_train, y_train, X_test, best_param)
#     rowMseWithNeural = pd.Series([neural[i],batch_size[i],epochs[i], mean_squared_error(y_test , y_pred)], index=df_MseWith_Neural.columns)
#     df_MseWith_Neural = df_MseWith_Neural.append(rowMseWithNeural,ignore_index=True)
# df_MseWith_Neural
# df_MseWith_Neural_Sort = df_MseWith_Neural.sort_values('MSE')
# best_Neural=df_MseWith_Neural_Sort['Neural Hidden'].iloc[0]
# Out:
# 9/9 [==============================] - 0s 2ms/step
# 9/9 [==============================] - 0s 3ms/step
# 9/9 [==============================] - 0s 3ms/step
# 9/9 [==============================] - 0s 2ms/step
# 9/9 [==============================] - 0s 3ms/step
# 9/9 [==============================] - 0s 2ms/step
# 9/9 [==============================] - 0s 3ms/step
# 9/9 [==============================] - 0s 3ms/step
# 9/9 [==============================] - 0s 4ms/step
# 9/9 [==============================] - 0s 1ms/step
# 9/9 [==============================] - 0s 2ms/step
# 9/9 [==============================] - 0s 2ms/step
# 9/9 [==============================] - 0s 2ms/step
# 9/9 [==============================] - 0s 2ms/step
# 9/9 [==============================] - 0s 2ms/step
# 9/9 [==============================] - 0s 3ms/step
# 9/9 [==============================] - 0s 2ms/step
# 9/9 [==============================] - 0s 3ms/step
# 9/9 [==============================] - 0s 3ms/step
# 9/9 [==============================] - 0s 2ms/step

# %% [markdown]
# Thay thế các giá trị null bằng 0 .
#
# Loại bỏ các giá trị nhiễu bằng cách thay thế các giá trị nằm ngoài khoảng 3 độ lệch chuẩn của dữ liệu với giá trị trung bình của dữ liệu.
#
# MinMaxScaler để chuyển đổi dữ liệu thành phạm vi [0, 1]. Tiếp theo, chúng ta sử dụng
#
# Interpolate để điền vào các giá trị bị thiếu bằng cách lấy trung bình của các giá trị trước và sau đó.
#
#
# std() là một hàm trong Python để tính độ lệch chuẩn của một tập dữ liệu.
#
# Công thức tính độ lệch chuẩn của một tập dữ liệu là:
# σ = sqrt(1/n * Σ(xi - x_mean)^2)
#
# Ví dụ, nếu chúng ta có tập dữ liệu [2, 4, 6, 8], thì giá trị trung bình là 5, độ lệch của mỗi giá trị so với giá trị trung bình lần lượt là [-3, -1, 1, 3], giá trị bình phương độ lệch của mỗi giá trị so với giá trị trung bình lần lượt là [9, 1, 1, 9], đưa vào công thức độ lệch chuẩn
#  ==> σ = sqrt(1/4 * (9 + 1 + 1 + 9)) = sqrt(20/4) = sqrt(5) ≈ 2.236
