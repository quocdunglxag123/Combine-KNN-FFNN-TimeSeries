# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
from numpy import sqrt 
import time

#Tien Xu Ly
from sklearn.preprocessing import MinMaxScaler

#Draw Flot
import matplotlib.pyplot as plt

#Cacuale error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error

#distance Libaray
from dtw import dtw
from scipy.spatial.distance import euclidean

#FFNN Libarary
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from sklearn.model_selection import GridSearchCV
from keras.wrappers.scikit_learn import KerasRegressor

# %%
# Đọc Dữ Liệu
# @param   filePath     Đường dẫn tập dữ liệu CSV
# @return  df           Tập dữ liệu csv dưới dạng df
def readData(filePath):
    # Load dữ liệu
    dataCSV = pd.read_csv(filePath)
    df=dataCSV[['Close']]
    return df

# Tiền Xử lý Dữ Liệu
# @param  Data   Tập dữ liệu
# @return df     Dữ liệu đã được tiền xử lý
def cleanData(df):
    # Replace null values with 0
    df.fillna(0, inplace=True)
    # Remove outliers by replacing values outside of 10 standard deviations with the mean
    std = df['Close'].std()
    mean = df['Close'].mean()
    df['Close'] = np.where(df['Close'] > (mean + 10*std), mean, df['Close'])
    df['Close'] = np.where(df['Close'] < (mean - 10*std), mean, df['Close'])
    # Scale data_AMZN to range [0, 1]
    scaler = MinMaxScaler()
    df['Close'] = scaler.fit_transform(df['Close'].values.reshape(-1, 1))
    # Fill in missing values with the mean of the previous and next values
    df['Close'] = df['Close'].interpolate(method='linear')
    return df

# Chia dữ liệu thành train set và test set
# @param  data                      Tập dữ liệu
# @param  percentTrain              Tỷ lệ Tập train
# @return train_data, test_data     Tập train và test   
def splitData(data, percentTrain):
    train_size = int(len(data) * (percentTrain/100))
    train = data.iloc[:train_size, :]
    test = data.iloc[train_size:, :]
    return train, test

# Xử lý dữ liệu thành dữ liệu đầu vào và đầu ra cho mô hình
# @param      data            Dữ liệu cần chia cửa sổ
# @param      size_window     Kích thước cửa sổ
# @param      size_predict    Kích thước cửa sổ dự đoán
# @param      stepWindow      số điểm dữ liệu trượt
# @return     X, y            mảng cửa sổ mẫu và mảng điểm dự đoán tương ứng
def prepare_data(data, size_window, size_predict, stepWindow):
    X, y = [], []
    startWindow = 0
    for i in range(len(data) - size_window - 1):
        if (len(data[(startWindow + size_window):(startWindow + size_window + size_predict) , 0]) != size_predict):
            break
        X.append(data[startWindow:(startWindow + size_window), :])
        y.append(data[(startWindow + size_window):(startWindow + size_window + size_predict) , 0])
        startWindow += stepWindow
    return np.array(X), np.array(y)

#---------KNN-----------
# Fucntion Tính khoảng cách giữa 2 chuỗi thời gian
# @param    ts1            Chuỗi thứ nhất
# @param    ts2            Chuỗi thứ hai
# @return   euclidean      Khoảng cách euclidean    
def euclidean_distance(ts1, ts2):
    ts1= ts1.flatten()
    ts2= ts2.flatten()
    return euclidean(ts1,ts2)

# Function lấy ra k chuỗi gần nhất
# @param    k             Số lượng chuỗi gần nhất
# @param    distanceArr   Mảng khoảng cách
# @return   argsort       Vị trí chuỗi gần nhất        
def kSimilarityTimeSeries(k, distanceArr):
    distances = np.array(distanceArr)
    return distances.argsort()[:k] 

# Tính khoảng cách DTW
# @param    ts1            Chuỗi thứ nhất
# @param    ts2            Chuỗi thứ hai
# @return   euclidean      Khoảng cách euclidean  
def dtw_dist(ts1, ts2):
    dist, _, _, _ = dtw(ts1, ts2, dist=lambda ts1, ts2: np.abs(ts1 - ts2))
    return dist

# Thêm Dữ liệu
# @param    X_train               Cửa sổ mẫu train
# @param    y_train               Cửa sổ dự đoán train
# @param    XTest                 Cửa sổ mẫu test
# @param    yTest                 Cửa sổ dự đoán test
# @return   X_train, y_train      Khoảng cách euclidean 
def toTrain(X_train, y_train, XTest, yTest):
    X_train.append(XTest)
    y_train.append(yTest)
    return np.array(X_train), np.array(y_train)

# Dự đoán Euclidean
# @param    nameData           Tên tập dữ liệu
# @param    k                  Số lượng chuỗi gần nhất
# @param    typeDistance       Độ đo sử dụng (Dtw, euclidean)
# @param    X_train            Cửa sổ mẫu train
# @param    y_train            Cửa sổ dự đoán train
# @param    X_test             Cửa sổ mẫu test
# @param    y_test             Cửa sổ dự đoán test
# @return   y_pred_arr         Mảng dự đoán
def predict_KNN(k, typeDistance, X_train, y_train, X_test, y_test):
    y_pred_arr=[]
    for iTest in range(len(X_test)):
        if(k>len(X_train)):
            k=len(X_train)
        distanceArr=[]
        for iTrain in range(len(X_train)-size_window+2):
            if(typeDistance == 'Dtw'):
                distance = dtw_dist(X_test[iTest],X_train[iTrain])
            else:
                distance = euclidean_distance(X_test[iTest],X_train[iTrain])
            distanceArr.append(distance)
        indexKNN= kSimilarityTimeSeries(k,distanceArr)
        y_pred = np.mean(y_train[indexKNN])
        y_pred_arr.append(y_pred)
        X_train, y_train = toTrain(X_train.tolist(), y_train.tolist(),X_test[iTest].tolist(), y_test[iTest].tolist())
        y_pred = np.array(y_pred_arr)
   
    return y_pred


#----------------FFNN--------------------------
# Khởi tạo mô hình FFNN
# @param    neuralInput         Kích thước Cửa sổ mẫu/ số neural lớp input
# @param    num_layers_hidden   Số lượng lớp ẩn
# @param    num_neural_hidden   Số neural lớp ẩn
# @param    neuralOutput         Số neural lớp ouput
# @return   model               Mô hình FFNN
def create_model_FFNN(neuralInput, num_layers_hidden=1, neuralHidden=1, neuralOutput=1):
    model = Sequential()
    for i in range(num_layers_hidden):
        if i == 0:
            model.add(Dense(neuralHidden, input_dim= neuralInput, activation='sigmoid'))
        else:
            model.add(Dense(neuralHidden, activation='sigmoid'))
    model.add(Dense(neuralOutput))
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model


# Train FFNN 
# @param    nameData          Tên tập dữ liệu
# @param    size_window       Kích thước Cửa sổ mẫu/ số neural lớp input
# @param    X_train           cửa sổ mẫu tập train
# @param    y_train           Cửa sổ dự đoán tập train
# @param    neuralHidden      Số neural lớp ẩn
# @param    numHiddenLayer    Số lớp ẩn
# @param    size_predict      Kích thước Cửa sổ dự đoán/ Số neural lớp ouput
# @return   best_params_FFNN  Tham số tốt nhất cho mô hình FFNN                
def train_FFNN(nameData, typePredict, size_window, X_train, y_train, neuralHidden, numHiddenLayer, size_predict):
    #param search
    param_grid_FFNN = {'batch_size': [8, 16, 32, 64, 128],
              'epochs': [50, 100, 150, 200, 250, 300],
              'neuralHidden': [neuralHidden],
              'num_layers_hidden' : [numHiddenLayer],
              'neuralInput' : [size_window],
              'neuralOutput' : [size_predict]}

    # create the model
    model_FFNN = KerasRegressor(build_fn=create_model_FFNN, verbose=0)
    
    # perform the grid search
    grid_FFNN = GridSearchCV(estimator=model_FFNN, param_grid=param_grid_FFNN, cv=3)
    grid_result_FFNN = grid_FFNN.fit(X_train, y_train)
    
    # train the model with the best parameters
    best_params_FFNN = grid_result_FFNN.best_params_
    
    model_FFNN = create_model_FFNN( best_params_FFNN['neuralInput'], best_params_FFNN['num_layers_hidden'], best_params_FFNN['neuralHidden'],best_params_FFNN['neuralOutput'])
    model_FFNN.fit(X_train, y_train, epochs=best_params_FFNN['epochs'], batch_size=best_params_FFNN['batch_size'], verbose=2, callbacks=[EarlyStopping(monitor='loss', patience=10)], shuffle=False)
    
    if(typePredict=='FFNN_Find_NeuralHidden'):
        model_FFNN.save_weights('../BestParam/FFNN/'+nameData+'/FFNN_Find_NeuralHidden/'+str(int(best_params_FFNN['num_layers_hidden']))+'_HiddenLayer_'+str(int(best_params_FFNN['neuralHidden']))+'_NeuralHidden_'+str(int(best_params_FFNN['batch_size']))+'_BatchSize_'+str(int(best_params_FFNN['epochs']))+'_Epoch_'+nameData+'.h5')   
    elif (typePredict=='FFNN_Find_NumberHiddenLayer'):
        model_FFNN.save_weights('../BestParam/FFNN/'+nameData+'/FFNN_Find_NumberHiddenLayer/'+str(int(best_params_FFNN['num_layers_hidden']))+'_HiddenLayer_'+str(int(best_params_FFNN['neuralHidden']))+'_NeuralHidden_'+str(int(best_params_FFNN['batch_size']))+'_BatchSize_'+str(int(best_params_FFNN['epochs']))+'_Epoch_'+nameData+'.h5')   
    else:
        model_FFNN.save_weights('../BestParam/TuanTu/'+nameData+'/FFNN_Find_NumberHiddenLayer/'+str(int(best_params_FFNN['num_layers_hidden']))+'_HiddenLayer_'+str(int(best_params_FFNN['neuralHidden']))+'_NeuralHidden_'+str(int(best_params_FFNN['batch_size']))+'_BatchSize_'+str(int(best_params_FFNN['epochs']))+'_Epoch_'+nameData+'.h5')   
    return best_params_FFNN



# Train FFNN 
# @param    nameData          Tên tập dữ liệu
# @param    size_window       Kích thước Cửa sổ mẫu/ số neural lớp input
# @param    X_train           cửa sổ mẫu tập train
# @param    y_train           Cửa sổ dự đoán tập train
# @param    batchSize         Số lượng mẫu được đưa vào với mỗi lần lặp (epoch)
# @param    epoch             Số lần lặp cập nhật trọng số
# @param    neuralHidden      Số neural lớp ẩn
# @param    numHiddenLayer    Số lớp ẩn
# @param    size_predict      Kích thước Cửa sổ dự đoán/ Số neural lớp ouput
# @return   best_params_FFNN  Tham số tốt nhất cho mô hình FFNN                
def train_best_param_FFNN(nameData, typePredict, size_window, X_train, y_train, batchSize, epoch, neuralHidden, numHiddenLayer, size_predict):
    #param search
    param_grid_FFNN = {'batch_size': batchSize,
              'epochs': epoch,
              'neuralHidden': neuralHidden,
              'num_layers_hidden' : numHiddenLayer,
              'neuralInput' : size_window,
              'neuralOutput' : size_predict}
    
    model_FFNN = create_model_FFNN( param_grid_FFNN['neuralInput'], param_grid_FFNN['num_layers_hidden'], param_grid_FFNN['neuralHidden'],param_grid_FFNN['neuralOutput'])
    model_FFNN.fit(X_train, y_train, epochs=param_grid_FFNN['epochs'], batch_size=param_grid_FFNN['batch_size'], verbose=2, callbacks=[EarlyStopping(monitor='loss', patience=10)], shuffle=False)
    
    if(typePredict=='FFNN_Find_NeuralHidden'):
        model_FFNN.save_weights('../BestParam/FFNN/'+nameData+'/FFNN_Find_NeuralHidden/'+str(int(param_grid_FFNN['num_layers_hidden']))+'_HiddenLayer_'+str(int(param_grid_FFNN['neuralHidden']))+'_NeuralHidden_'+str(int(param_grid_FFNN['batch_size']))+'_BatchSize_'+str(int(param_grid_FFNN['epochs']))+'_Epoch_'+nameData+'.h5')   
    elif (typePredict=='FFNN_Find_NumberHiddenLayer'):
        model_FFNN.save_weights('../BestParam/FFNN/'+nameData+'/FFNN_Find_NumberHiddenLayer/'+str(int(param_grid_FFNN['num_layers_hidden']))+'_HiddenLayer_'+str(int(param_grid_FFNN['neuralHidden']))+'_NeuralHidden_'+str(int(param_grid_FFNN['batch_size']))+'_BatchSize_'+str(int(param_grid_FFNN['epochs']))+'_Epoch_'+nameData+'.h5')   
    elif (typePredict=='FFNN_Find_NumberHiddenLayer_SongSong'):
        model_FFNN.save_weights('../BestParam/SongSong/'+nameData+'/FFNN_Find_BestWeights/'+str(int(param_grid_FFNN['num_layers_hidden']))+'_HiddenLayer_'+str(int(param_grid_FFNN['neuralHidden']))+'_NeuralHidden_'+str(int(param_grid_FFNN['batch_size']))+'_BatchSize_'+str(int(param_grid_FFNN['epochs']))+'_Epoch_'+nameData+'.h5')   
    else:
        model_FFNN.save_weights('../BestParam/TuanTu/'+nameData+'/FFNN_Find_BestWeights/'+str(int(param_grid_FFNN['num_layers_hidden']))+'_HiddenLayer_'+str(int(param_grid_FFNN['neuralHidden']))+'_NeuralHidden_'+str(int(param_grid_FFNN['batch_size']))+'_BatchSize_'+str(int(param_grid_FFNN['epochs']))+'_Epoch_'+nameData+'.h5')   
   
    return param_grid_FFNN

# Dự Đoán FFNN 
# @param    nameData          Tên tập dữ liệu
# @param    typePredict       Thực hiện loại dự đoán (FFNN_Find_NeuralHidden,FFNN_Find_NumberHiddenLayer,CombinePredict)
# @param    X_train           cửa sổ mẫu tập train
# @param    y_train           Cửa sổ dự đoán tập train
# @param    X_test            Cửa sổ dự đoán tập train
# @param    best_params_FFNN  Cửa sổ dự đoán tập train
# @return   predictions_FFNN  Mảng dự đoán
def predict_FFNN(nameData, typePredict, X_train, y_train, X_test, best_params_FFNN):
    model_FFNN1 = Sequential()
    for i in range(best_params_FFNN['num_layers_hidden']):
        if i == 0:
            model_FFNN1.add(Dense(best_params_FFNN['neuralHidden'], input_dim= best_params_FFNN['neuralInput'], activation='sigmoid'))
        else:
            model_FFNN1.add(Dense(best_params_FFNN['neuralHidden'], activation='sigmoid'))
    model_FFNN1.add(Dense(best_params_FFNN['neuralOutput']))
    
    if(typePredict=='FFNN_Find_NeuralHidden'):
        model_FFNN1.load_weights('../BestParam/FFNN/'+nameData+'/FFNN_Find_NeuralHidden/'+str(int(best_params_FFNN['num_layers_hidden']))+'_HiddenLayer_'+str(int(best_params_FFNN['neuralHidden']))+'_NeuralHidden_'+str(int(best_params_FFNN['batch_size']))+'_BatchSize_'+str(int(best_params_FFNN['epochs']))+'_Epoch_'+nameData+'.h5')   
    elif (typePredict=='FFNN_Find_NumberHiddenLayer'):
        model_FFNN1.load_weights('../BestParam/FFNN/'+nameData+'/FFNN_Find_NumberHiddenLayer/'+str(int(best_params_FFNN['num_layers_hidden']))+'_HiddenLayer_'+str(int(best_params_FFNN['neuralHidden']))+'_NeuralHidden_'+str(int(best_params_FFNN['batch_size']))+'_BatchSize_'+str(int(best_params_FFNN['epochs']))+'_Epoch_'+nameData+'.h5')   
    elif (typePredict=='FFNN_Find_NumberHiddenLayer_SongSong'):
        model_FFNN1.load_weights('../BestParam/SongSong/'+nameData+'/FFNN_Find_BestWeights/'+str(int(best_params_FFNN['num_layers_hidden']))+'_HiddenLayer_'+str(int(best_params_FFNN['neuralHidden']))+'_NeuralHidden_'+str(int(best_params_FFNN['batch_size']))+'_BatchSize_'+str(int(best_params_FFNN['epochs']))+'_Epoch_'+nameData+'.h5')   
    else:
        model_FFNN1.load_weights('../BestParam/TuanTu/'+nameData+'/FFNN_Find_BestWeights/'+str(int(best_params_FFNN['num_layers_hidden']))+'_HiddenLayer_'+str(int(best_params_FFNN['neuralHidden']))+'_NeuralHidden_'+str(int(best_params_FFNN['batch_size']))+'_BatchSize_'+str(int(best_params_FFNN['epochs']))+'_Epoch_'+nameData+'.h5')   
   
    model_FFNN1.compile(loss='mean_squared_error', optimizer='adam')
    
    predictions_FFNN = model_FFNN1.predict(X_test)
    return predictions_FFNN

#---------------------Song Song------------------------------#

# Lai Ghép Song Song
# @param    y_pred_FFNN     Mảng dự đoán của FFNN
# @param    y_pred_KNN      Mảng dự đoán của KNN
# @param    y_test          Mảng chuỗi thực tế
# @return   y_pred_combine  Mảng dự đoán kết hợp
def predictHybrid(y_pred_FFNN,y_pred_KNN,y_test):
    FFNNSubKNN=[]
    TestSubKNN=[]
    weightEl=[]
    for i in range(len(y_pred_FFNN)):
        FFNNSubKNN.append(y_pred_FFNN[i]-y_pred_KNN[i])
        TestSubKNN.append(y_test[i]-y_pred_KNN[i])

    for j in range(len(FFNNSubKNN)):
        weightEl.append(((FFNNSubKNN[j]*TestSubKNN[j])/ (FFNNSubKNN[j]*FFNNSubKNN[j])))
    
    weight = np.array(weightEl)
    
    y_pred_combine=[]
    for i in range(len(weight)):
        y_pred_combine.append(weight[i]*y_pred_FFNN[i]+(1-weight[i])*y_pred_KNN[i])
    y_pred_combine=np.array(y_pred_combine)
    return y_pred_combine

#---------------------Tuần Tự------------------------------#

# Tính Lỗi Theo Từng Ngày
# @param    y_pred_KNN      Mảng dự đoán của KNN
# @param    y_test          Mảng chuỗi thực tế
# @return   mseWithDay     Mảng lỗi theo ngày
def mseWithDay(y_pred_KNN, y_test):
    mseDay = []
    for i in range(len(y_pred_KNN)):
        mseDay.append([abs((y_test[i] - y_pred_KNN[i]))])
    mseDay=np.array(mseDay)
    return mseDay

def predictSum(y_pred_mse,y_pred_KNN):
    pred_knn_ffnn=[]
    for i in range(len(y_pred_mse)):
        pred_knn_ffnn.append(y_pred_KNN[i]+y_pred_mse[i])
    pred_knn_ffnn=np.array(pred_knn_ffnn)
    return pred_knn_ffnn

# %%
nameData= 'MDLY'
filePath= '../../Dataset/'+nameData+'.csv'
timeSeries = readData(filePath)
timeSeries = cleanData(timeSeries)
percentTrain = 80
train_data, test_data = splitData(timeSeries, percentTrain)

size_window = 7
size_predict=1
stepWindow=1
X_train, y_train = prepare_data(train_data.values, size_window, size_predict, stepWindow)
X_test, y_test =   prepare_data(test_data.values, size_window, size_predict, stepWindow)

neuralHidden=17
batchSize=8
epoch=300
df_MseWith_HiddenLayer = pd.DataFrame([],  columns =  ["Numer Hidden Layer", "Neural Hidden","Batch_Size","Epoch", "MSE","Time Train", "Time Test", "Total Time"])

for numHiddenLayer in range(1,21):
    
    start_Train= time.time()
    best_param = train_best_param_FFNN(nameData, 'FFNN_Find_NumberHiddenLayer', size_window, X_train, y_train, batchSize, epoch, neuralHidden, numHiddenLayer, size_predict)
    end_Train = time.time()
    
    start_Test= time.time()
    predictions_FFNN= predict_FFNN(nameData, 'FFNN_Find_NumberHiddenLayer', X_train, y_train, X_test, best_param)
    end_Test = time.time()

    timeTrain = end_Train - start_Train
    timeTest = end_Test -  start_Test
    totalTime = timeTrain+ timeTest
    
    rowMseWithHiddenLayer = pd.Series([numHiddenLayer,neuralHidden,best_param['batch_size'],best_param['epochs'], mean_squared_error(y_test , predictions_FFNN), timeTrain, timeTest, totalTime], index=df_MseWith_HiddenLayer.columns)
    df_MseWith_HiddenLayer = df_MseWith_HiddenLayer.append(rowMseWithHiddenLayer,ignore_index=True)
# Out:
# Epoch 1/300
# 138/138 - 2s - loss: 0.2394 - 2s/epoch - 11ms/step
# Epoch 2/300
# 138/138 - 0s - loss: 0.0401 - 242ms/epoch - 2ms/step
# Epoch 3/300
# 138/138 - 0s - loss: 0.0408 - 247ms/epoch - 2ms/step
# Epoch 4/300
# 138/138 - 0s - loss: 0.0402 - 306ms/epoch - 2ms/step
# Epoch 5/300
# 138/138 - 0s - loss: 0.0393 - 234ms/epoch - 2ms/step
# Epoch 6/300
# 138/138 - 0s - loss: 0.0381 - 207ms/epoch - 2ms/step
# Epoch 7/300
# 138/138 - 0s - loss: 0.0369 - 204ms/epoch - 1ms/step
# Epoch 8/300
# 138/138 - 0s - loss: 0.0355 - 211ms/epoch - 2ms/step
# Epoch 9/300
# 138/138 - 0s - loss: 0.0340 - 193ms/epoch - 1ms/step
# Epoch 10/300
# 138/138 - 0s - loss: 0.0324 - 316ms/epoch - 2ms/step
# Epoch 11/300
# 138/138 - 0s - loss: 0.0306 - 295ms/epoch - 2ms/step
# Epoch 12/300
# 138/138 - 0s - loss: 0.0286 - 309ms/epoch - 2ms/step
# Epoch 13/300
# 138/138 - 0s - loss: 0.0265 - 256ms/epoch - 2ms/step
# Epoch 14/300
# 138/138 - 0s - loss: 0.0242 - 191ms/epoch - 1ms/step
# Epoch 15/300
# 138/138 - 0s - loss: 0.0219 - 275ms/epoch - 2ms/step
# Epoch 16/300
# 138/138 - 0s - loss: 0.0195 - 219ms/epoch - 2ms/step
# Epoch 17/300
# 138/138 - 0s - loss: 0.0171 - 173ms/epoch - 1ms/step
# Epoch 18/300
# 138/138 - 0s - loss: 0.0148 - 198ms/epoch - 1ms/step
# Epoch 19/300
# 138/138 - 0s - loss: 0.0127 - 192ms/epoch - 1ms/step
# Epoch 20/300
# 138/138 - 0s - loss: 0.0108 - 184ms/epoch - 1ms/step
# Epoch 21/300
# 138/138 - 0s - loss: 0.0092 - 170ms/epoch - 1ms/step
# Epoch 22/300
# 138/138 - 0s - loss: 0.0079 - 201ms/epoch - 1ms/step
# Epoch 23/300
# 138/138 - 0s - loss: 0.0069 - 156ms/epoch - 1ms/step
# Epoch 24/300
# 138/138 - 0s - loss: 0.0060 - 167ms/epoch - 1ms/step
# Epoch 25/300
# 138/138 - 0s - loss: 0.0053 - 173ms/epoch - 1ms/step
# Epoch 26/300
# 138/138 - 0s - loss: 0.0048 - 203ms/epoch - 1ms/step
# Epoch 27/300
# 138/138 - 0s - loss: 0.0043 - 240ms/epoch - 2ms/step
# Epoch 28/300
# 138/138 - 0s - loss: 0.0040 - 202ms/epoch - 1ms/step
# Epoch 29/300
# 138/138 - 0s - loss: 0.0037 - 222ms/epoch - 2ms/step
# Epoch 30/300
# 138/138 - 0s - loss: 0.0034 - 201ms/epoch - 1ms/step
# Epoch 31/300
# 138/138 - 0s - loss: 0.0032 - 229ms/epoch - 2ms/step
# Epoch 32/300
# 138/138 - 0s - loss: 0.0030 - 201ms/epoch - 1ms/step
# Epoch 33/300
# 138/138 - 0s - loss: 0.0029 - 241ms/epoch - 2ms/step
# Epoch 34/300
# 138/138 - 0s - loss: 0.0027 - 185ms/epoch - 1ms/step
# Epoch 35/300
# 138/138 - 0s - loss: 0.0025 - 201ms/epoch - 1ms/step
# Epoch 36/300
# 138/138 - 0s - loss: 0.0024 - 225ms/epoch - 2ms/step
# Epoch 37/300
# 138/138 - 0s - loss: 0.0022 - 207ms/epoch - 2ms/step
# Epoch 38/300
# 138/138 - 0s - loss: 0.0021 - 202ms/epoch - 1ms/step
# Epoch 39/300
# 138/138 - 0s - loss: 0.0020 - 213ms/epoch - 2ms/step
# Epoch 40/300
# 138/138 - 0s - loss: 0.0018 - 181ms/epoch - 1ms/step
# Epoch 41/300
# 138/138 - 0s - loss: 0.0017 - 141ms/epoch - 1ms/step
# Epoch 42/300
# 138/138 - 0s - loss: 0.0016 - 141ms/epoch - 1ms/step
# Epoch 43/300
# 138/138 - 0s - loss: 0.0015 - 188ms/epoch - 1ms/step
# Epoch 44/300
# 138/138 - 0s - loss: 0.0014 - 175ms/epoch - 1ms/step
# Epoch 45/300
# 138/138 - 0s - loss: 0.0013 - 218ms/epoch - 2ms/step
# Epoch 46/300
# 138/138 - 0s - loss: 0.0012 - 192ms/epoch - 1ms/step
# Epoch 47/300
# 138/138 - 0s - loss: 0.0012 - 206ms/epoch - 1ms/step
# Epoch 48/300
# 138/138 - 0s - loss: 0.0011 - 198ms/epoch - 1ms/step
# Epoch 49/300
# 138/138 - 0s - loss: 0.0011 - 210ms/epoch - 2ms/step
# Epoch 50/300
# 138/138 - 0s - loss: 0.0010 - 227ms/epoch - 2ms/step
# Epoch 51/300
# 138/138 - 0s - loss: 9.8539e-04 - 299ms/epoch - 2ms/step
# Epoch 52/300
# 138/138 - 0s - loss: 9.6532e-04 - 326ms/epoch - 2ms/step
# Epoch 53/300
# 138/138 - 0s - loss: 9.5214e-04 - 313ms/epoch - 2ms/step
# Epoch 54/300
# 138/138 - 0s - loss: 9.4417e-04 - 247ms/epoch - 2ms/step
# Epoch 55/300
# 138/138 - 0s - loss: 9.3989e-04 - 222ms/epoch - 2ms/step
# Epoch 56/300
# 138/138 - 0s - loss: 9.3797e-04 - 187ms/epoch - 1ms/step
# Epoch 57/300
# 138/138 - 0s - loss: 9.3736e-04 - 176ms/epoch - 1ms/step
# Epoch 58/300
# 138/138 - 0s - loss: 9.3723e-04 - 207ms/epoch - 2ms/step
# Epoch 59/300
# 138/138 - 0s - loss: 9.3698e-04 - 190ms/epoch - 1ms/step
# Epoch 60/300
# 138/138 - 0s - loss: 9.3621e-04 - 187ms/epoch - 1ms/step
# Epoch 61/300
# 138/138 - 0s - loss: 9.3467e-04 - 188ms/epoch - 1ms/step
# Epoch 62/300
# 138/138 - 0s - loss: 9.3224e-04 - 192ms/epoch - 1ms/step
# Epoch 63/300
# 138/138 - 0s - loss: 9.2889e-04 - 192ms/epoch - 1ms/step
# Epoch 64/300
# 138/138 - 0s - loss: 9.2468e-04 - 187ms/epoch - 1ms/step
# Epoch 65/300
# 138/138 - 0s - loss: 9.1969e-04 - 186ms/epoch - 1ms/step
# Epoch 66/300
# 138/138 - 0s - loss: 9.1404e-04 - 209ms/epoch - 2ms/step
# Epoch 67/300
# 138/138 - 0s - loss: 9.0784e-04 - 176ms/epoch - 1ms/step
# Epoch 68/300
# 138/138 - 0s - loss: 9.0122e-04 - 187ms/epoch - 1ms/step
# Epoch 69/300
# 138/138 - 0s - loss: 8.9428e-04 - 185ms/epoch - 1ms/step
# Epoch 70/300
# 138/138 - 0s - loss: 8.8713e-04 - 187ms/epoch - 1ms/step
# Epoch 71/300
# 138/138 - 0s - loss: 8.7985e-04 - 171ms/epoch - 1ms/step
# Epoch 72/300
# 138/138 - 0s - loss: 8.7251e-04 - 187ms/epoch - 1ms/step
# Epoch 73/300
# 138/138 - 0s - loss: 8.6517e-04 - 190ms/epoch - 1ms/step
# Epoch 74/300
# 138/138 - 0s - loss: 8.5787e-04 - 202ms/epoch - 1ms/step
# Epoch 75/300
# 138/138 - 0s - loss: 8.5063e-04 - 213ms/epoch - 2ms/step
# Epoch 76/300
# 138/138 - 0s - loss: 8.4350e-04 - 200ms/epoch - 1ms/step
# Epoch 77/300
# 138/138 - 0s - loss: 8.3648e-04 - 214ms/epoch - 2ms/step
# Epoch 78/300
# 138/138 - 0s - loss: 8.2958e-04 - 200ms/epoch - 1ms/step
# Epoch 79/300
# 138/138 - 0s - loss: 8.2281e-04 - 214ms/epoch - 2ms/step
# Epoch 80/300
# 138/138 - 0s - loss: 8.1617e-04 - 229ms/epoch - 2ms/step
# Epoch 81/300
# 138/138 - 0s - loss: 8.0968e-04 - 197ms/epoch - 1ms/step
# Epoch 82/300
# 138/138 - 0s - loss: 8.0332e-04 - 198ms/epoch - 1ms/step
# Epoch 83/300
# 138/138 - 0s - loss: 7.9709e-04 - 200ms/epoch - 1ms/step
# Epoch 84/300
# 138/138 - 0s - loss: 7.9100e-04 - 214ms/epoch - 2ms/step
# Epoch 85/300
# 138/138 - 0s - loss: 7.8503e-04 - 213ms/epoch - 2ms/step
# Epoch 86/300
# 138/138 - 0s - loss: 7.7919e-04 - 213ms/epoch - 2ms/step
# Epoch 87/300
# 138/138 - 0s - loss: 7.7348e-04 - 200ms/epoch - 1ms/step
# Epoch 88/300
# 138/138 - 0s - loss: 7.6788e-04 - 227ms/epoch - 2ms/step
# Epoch 89/300
# 138/138 - 0s - loss: 7.6240e-04 - 182ms/epoch - 1ms/step
# Epoch 90/300
# 138/138 - 0s - loss: 7.5703e-04 - 187ms/epoch - 1ms/step
# Epoch 91/300
# 138/138 - 0s - loss: 7.5177e-04 - 187ms/epoch - 1ms/step
# Epoch 92/300
# 138/138 - 0s - loss: 7.4662e-04 - 199ms/epoch - 1ms/step
# Epoch 93/300
# 138/138 - 0s - loss: 7.4157e-04 - 201ms/epoch - 1ms/step
# Epoch 94/300
# 138/138 - 0s - loss: 7.3662e-04 - 185ms/epoch - 1ms/step
# Epoch 95/300
# 138/138 - 0s - loss: 7.3176e-04 - 187ms/epoch - 1ms/step
# Epoch 96/300
# 138/138 - 0s - loss: 7.2700e-04 - 187ms/epoch - 1ms/step
# Epoch 97/300
# 138/138 - 0s - loss: 7.2233e-04 - 186ms/epoch - 1ms/step
# Epoch 98/300
# 138/138 - 0s - loss: 7.1775e-04 - 185ms/epoch - 1ms/step
# Epoch 99/300
# 138/138 - 0s - loss: 7.1326e-04 - 189ms/epoch - 1ms/step
# Epoch 100/300
# 138/138 - 0s - loss: 7.0884e-04 - 171ms/epoch - 1ms/step
# Epoch 101/300
# 138/138 - 0s - loss: 7.0451e-04 - 231ms/epoch - 2ms/step
# Epoch 102/300
# 138/138 - 0s - loss: 7.0026e-04 - 195ms/epoch - 1ms/step
# Epoch 103/300
# 138/138 - 0s - loss: 6.9609e-04 - 182ms/epoch - 1ms/step
# Epoch 104/300
# 138/138 - 0s - loss: 6.9199e-04 - 187ms/epoch - 1ms/step
# Epoch 105/300
# 138/138 - 0s - loss: 6.8796e-04 - 204ms/epoch - 1ms/step
# Epoch 106/300
# 138/138 - 0s - loss: 6.8400e-04 - 201ms/epoch - 1ms/step
# Epoch 107/300
# 138/138 - 0s - loss: 6.8012e-04 - 180ms/epoch - 1ms/step
# Epoch 108/300
# 138/138 - 0s - loss: 6.7630e-04 - 188ms/epoch - 1ms/step
# Epoch 109/300
# 138/138 - 0s - loss: 6.7255e-04 - 205ms/epoch - 1ms/step
# Epoch 110/300
# 138/138 - 0s - loss: 6.6886e-04 - 163ms/epoch - 1ms/step
# Epoch 111/300
# 138/138 - 0s - loss: 6.6523e-04 - 173ms/epoch - 1ms/step
# Epoch 112/300
# 138/138 - 0s - loss: 6.6167e-04 - 171ms/epoch - 1ms/step
# Epoch 113/300
# 138/138 - 0s - loss: 6.5817e-04 - 193ms/epoch - 1ms/step
# Epoch 114/300
# 138/138 - 0s - loss: 6.5473e-04 - 179ms/epoch - 1ms/step
# Epoch 115/300
# 138/138 - 0s - loss: 6.5134e-04 - 207ms/epoch - 2ms/step
# Epoch 116/300
# 138/138 - 0s - loss: 6.4801e-04 - 213ms/epoch - 2ms/step
# Epoch 117/300
# 138/138 - 0s - loss: 6.4474e-04 - 214ms/epoch - 2ms/step
# Epoch 118/300
# 138/138 - 0s - loss: 6.4152e-04 - 200ms/epoch - 1ms/step
# Epoch 119/300
# 138/138 - 0s - loss: 6.3835e-04 - 213ms/epoch - 2ms/step
# Epoch 120/300
# 138/138 - 0s - loss: 6.3524e-04 - 240ms/epoch - 2ms/step
# Epoch 121/300
# 138/138 - 0s - loss: 6.3218e-04 - 237ms/epoch - 2ms/step
# Epoch 122/300
# 138/138 - 0s - loss: 6.2917e-04 - 424ms/epoch - 3ms/step
# Epoch 123/300
# 138/138 - 0s - loss: 6.2621e-04 - 253ms/epoch - 2ms/step
# Epoch 124/300
# 138/138 - 0s - loss: 6.2329e-04 - 404ms/epoch - 3ms/step
# Epoch 125/300
# 138/138 - 0s - loss: 6.2043e-04 - 257ms/epoch - 2ms/step
# Epoch 126/300
# 138/138 - 0s - loss: 6.1761e-04 - 209ms/epoch - 2ms/step
# Epoch 127/300
# 138/138 - 0s - loss: 6.1484e-04 - 198ms/epoch - 1ms/step
# Epoch 128/300
# 138/138 - 0s - loss: 6.1211e-04 - 216ms/epoch - 2ms/step
# Epoch 129/300
# 138/138 - 0s - loss: 6.0943e-04 - 196ms/epoch - 1ms/step
# Epoch 130/300
# 138/138 - 0s - loss: 6.0679e-04 - 184ms/epoch - 1ms/step
# Epoch 131/300
# 138/138 - 0s - loss: 6.0420e-04 - 189ms/epoch - 1ms/step
# Epoch 132/300
# 138/138 - 0s - loss: 6.0165e-04 - 187ms/epoch - 1ms/step
# Epoch 133/300
# 138/138 - 0s - loss: 5.9914e-04 - 172ms/epoch - 1ms/step
# Epoch 134/300
# 138/138 - 0s - loss: 5.9666e-04 - 171ms/epoch - 1ms/step
# Epoch 135/300
# 138/138 - 0s - loss: 5.9424e-04 - 189ms/epoch - 1ms/step
# Epoch 136/300
# 138/138 - 0s - loss: 5.9185e-04 - 185ms/epoch - 1ms/step
# Epoch 137/300
# 138/138 - 0s - loss: 5.8950e-04 - 189ms/epoch - 1ms/step
# Epoch 138/300
# 138/138 - 0s - loss: 5.8719e-04 - 184ms/epoch - 1ms/step
# Epoch 139/300
# 138/138 - 0s - loss: 5.8492e-04 - 171ms/epoch - 1ms/step
# Epoch 140/300
# 138/138 - 0s - loss: 5.8268e-04 - 187ms/epoch - 1ms/step
# Epoch 141/300
# 138/138 - 0s - loss: 5.8048e-04 - 184ms/epoch - 1ms/step
# Epoch 142/300
# 138/138 - 0s - loss: 5.7832e-04 - 173ms/epoch - 1ms/step
# Epoch 143/300
# 138/138 - 0s - loss: 5.7620e-04 - 189ms/epoch - 1ms/step
# Epoch 144/300
# 138/138 - 0s - loss: 5.7411e-04 - 187ms/epoch - 1ms/step
# Epoch 145/300
# 138/138 - 0s - loss: 5.7206e-04 - 185ms/epoch - 1ms/step
# Epoch 146/300
# 138/138 - 0s - loss: 5.7004e-04 - 217ms/epoch - 2ms/step
# Epoch 147/300
# 138/138 - 0s - loss: 5.6805e-04 - 229ms/epoch - 2ms/step
# Epoch 148/300
# 138/138 - 0s - loss: 5.6610e-04 - 193ms/epoch - 1ms/step
# Epoch 149/300
# 138/138 - 0s - loss: 5.6418e-04 - 213ms/epoch - 2ms/step
# Epoch 150/300
# 138/138 - 0s - loss: 5.6229e-04 - 216ms/epoch - 2ms/step
# Epoch 151/300
# 138/138 - 0s - loss: 5.6044e-04 - 166ms/epoch - 1ms/step
# Epoch 152/300
# 138/138 - 0s - loss: 5.5861e-04 - 203ms/epoch - 1ms/step
# Epoch 153/300
# 138/138 - 0s - loss: 5.5682e-04 - 182ms/epoch - 1ms/step
# Epoch 154/300
# 138/138 - 0s - loss: 5.5506e-04 - 203ms/epoch - 1ms/step
# Epoch 155/300
# 138/138 - 0s - loss: 5.5333e-04 - 199ms/epoch - 1ms/step
# Epoch 156/300
# 138/138 - 0s - loss: 5.5162e-04 - 218ms/epoch - 2ms/step
# Epoch 157/300
# 138/138 - 0s - loss: 5.4995e-04 - 242ms/epoch - 2ms/step
# Epoch 158/300
# 138/138 - 0s - loss: 5.4830e-04 - 211ms/epoch - 2ms/step
# Epoch 159/300
# 138/138 - 0s - loss: 5.4669e-04 - 229ms/epoch - 2ms/step
# Epoch 160/300
# 138/138 - 0s - loss: 5.4510e-04 - 193ms/epoch - 1ms/step
# Epoch 161/300
# 138/138 - 0s - loss: 5.4353e-04 - 198ms/epoch - 1ms/step
# Epoch 162/300
# 138/138 - 0s - loss: 5.4200e-04 - 245ms/epoch - 2ms/step
# Epoch 163/300
# 138/138 - 0s - loss: 5.4048e-04 - 240ms/epoch - 2ms/step
# Epoch 164/300
# 138/138 - 0s - loss: 5.3900e-04 - 238ms/epoch - 2ms/step
# Epoch 165/300
# 138/138 - 0s - loss: 5.3754e-04 - 211ms/epoch - 2ms/step
# Epoch 166/300
# 138/138 - 0s - loss: 5.3610e-04 - 209ms/epoch - 2ms/step
# Epoch 167/300
# 138/138 - 0s - loss: 5.3469e-04 - 229ms/epoch - 2ms/step
# Epoch 168/300
# 138/138 - 0s - loss: 5.3331e-04 - 224ms/epoch - 2ms/step
# Epoch 169/300
# 138/138 - 0s - loss: 5.3194e-04 - 212ms/epoch - 2ms/step
# Epoch 170/300
# 138/138 - 0s - loss: 5.3060e-04 - 213ms/epoch - 2ms/step
# Epoch 171/300
# 138/138 - 0s - loss: 5.2929e-04 - 213ms/epoch - 2ms/step
# Epoch 172/300
# 138/138 - 0s - loss: 5.2799e-04 - 182ms/epoch - 1ms/step
# Epoch 173/300
# 138/138 - 0s - loss: 5.2671e-04 - 155ms/epoch - 1ms/step
# Epoch 174/300
# 138/138 - 0s - loss: 5.2546e-04 - 147ms/epoch - 1ms/step
# Epoch 175/300
# 138/138 - 0s - loss: 5.2423e-04 - 147ms/epoch - 1ms/step
# Epoch 176/300
# 138/138 - 0s - loss: 5.2302e-04 - 147ms/epoch - 1ms/step
# Epoch 177/300
# 138/138 - 0s - loss: 5.2182e-04 - 147ms/epoch - 1ms/step
# Epoch 178/300
# 138/138 - 0s - loss: 5.2065e-04 - 147ms/epoch - 1ms/step
# Epoch 179/300
# 138/138 - 0s - loss: 5.1950e-04 - 144ms/epoch - 1ms/step
# Epoch 180/300
# 138/138 - 0s - loss: 5.1836e-04 - 133ms/epoch - 966us/step
# Epoch 181/300
# 138/138 - 0s - loss: 5.1724e-04 - 162ms/epoch - 1ms/step
# Epoch 182/300
# 138/138 - 0s - loss: 5.1614e-04 - 176ms/epoch - 1ms/step
# Epoch 183/300
# 138/138 - 0s - loss: 5.1506e-04 - 202ms/epoch - 1ms/step
# Epoch 184/300
# 138/138 - 0s - loss: 5.1399e-04 - 172ms/epoch - 1ms/step
# Epoch 185/300
# 138/138 - 0s - loss: 5.1295e-04 - 172ms/epoch - 1ms/step
# Epoch 186/300
# 138/138 - 0s - loss: 5.1191e-04 - 186ms/epoch - 1ms/step
# Epoch 187/300
# 138/138 - 0s - loss: 5.1090e-04 - 187ms/epoch - 1ms/step
# Epoch 188/300
# 138/138 - 0s - loss: 5.0990e-04 - 171ms/epoch - 1ms/step
# Epoch 189/300
# 138/138 - 0s - loss: 5.0891e-04 - 171ms/epoch - 1ms/step
# Epoch 190/300
# 138/138 - 0s - loss: 5.0794e-04 - 187ms/epoch - 1ms/step
# Epoch 191/300
# 138/138 - 0s - loss: 5.0698e-04 - 189ms/epoch - 1ms/step
# Epoch 192/300
# 138/138 - 0s - loss: 5.0604e-04 - 187ms/epoch - 1ms/step
# Epoch 193/300
# 138/138 - 0s - loss: 5.0511e-04 - 200ms/epoch - 1ms/step
# Epoch 194/300
# 138/138 - 0s - loss: 5.0419e-04 - 187ms/epoch - 1ms/step
# Epoch 195/300
# 138/138 - 0s - loss: 5.0329e-04 - 171ms/epoch - 1ms/step
# Epoch 196/300
# 138/138 - 0s - loss: 5.0240e-04 - 187ms/epoch - 1ms/step
# Epoch 197/300
# 138/138 - 0s - loss: 5.0153e-04 - 189ms/epoch - 1ms/step
# Epoch 198/300
# 138/138 - 0s - loss: 5.0066e-04 - 188ms/epoch - 1ms/step
# Epoch 199/300
# 138/138 - 0s - loss: 4.9981e-04 - 171ms/epoch - 1ms/step
# Epoch 200/300
# 138/138 - 0s - loss: 4.9896e-04 - 171ms/epoch - 1ms/step
# Epoch 201/300
# 138/138 - 0s - loss: 4.9813e-04 - 187ms/epoch - 1ms/step
# Epoch 202/300
# 138/138 - 0s - loss: 4.9731e-04 - 187ms/epoch - 1ms/step
# Epoch 203/300
# 138/138 - 0s - loss: 4.9650e-04 - 186ms/epoch - 1ms/step
# Epoch 204/300
# 138/138 - 0s - loss: 4.9570e-04 - 171ms/epoch - 1ms/step
# Epoch 205/300
# 138/138 - 0s - loss: 4.9492e-04 - 158ms/epoch - 1ms/step
# Epoch 206/300
# 138/138 - 0s - loss: 4.9414e-04 - 188ms/epoch - 1ms/step
# Epoch 207/300
# 138/138 - 0s - loss: 4.9337e-04 - 171ms/epoch - 1ms/step
# Epoch 208/300
# 138/138 - 0s - loss: 4.9261e-04 - 175ms/epoch - 1ms/step
# Epoch 209/300
# 138/138 - 0s - loss: 4.9186e-04 - 174ms/epoch - 1ms/step
# Epoch 210/300
# 138/138 - 0s - loss: 4.9112e-04 - 205ms/epoch - 1ms/step
# Epoch 211/300
# 138/138 - 0s - loss: 4.9038e-04 - 229ms/epoch - 2ms/step
# Epoch 212/300
# 138/138 - 0s - loss: 4.8966e-04 - 211ms/epoch - 2ms/step
# Epoch 213/300
# 138/138 - 0s - loss: 4.8894e-04 - 213ms/epoch - 2ms/step
# Epoch 214/300
# 138/138 - 0s - loss: 4.8823e-04 - 200ms/epoch - 1ms/step
# Epoch 215/300
# 138/138 - 0s - loss: 4.8753e-04 - 214ms/epoch - 2ms/step
# Epoch 216/300
# 138/138 - 0s - loss: 4.8684e-04 - 213ms/epoch - 2ms/step
# Epoch 217/300
# 138/138 - 0s - loss: 4.8615e-04 - 229ms/epoch - 2ms/step
# Epoch 218/300
# 138/138 - 0s - loss: 4.8547e-04 - 211ms/epoch - 2ms/step
# Epoch 219/300
# 138/138 - 0s - loss: 4.8480e-04 - 214ms/epoch - 2ms/step
# Epoch 220/300
# 138/138 - 0s - loss: 4.8413e-04 - 213ms/epoch - 2ms/step
# Epoch 221/300
# 138/138 - 0s - loss: 4.8347e-04 - 198ms/epoch - 1ms/step
# Epoch 222/300
# 138/138 - 0s - loss: 4.8282e-04 - 200ms/epoch - 1ms/step
# Epoch 223/300
# 138/138 - 0s - loss: 4.8218e-04 - 213ms/epoch - 2ms/step
# Epoch 224/300
# 138/138 - 0s - loss: 4.8154e-04 - 214ms/epoch - 2ms/step
# Epoch 225/300
# 138/138 - 0s - loss: 4.8090e-04 - 198ms/epoch - 1ms/step
# Epoch 226/300
# 138/138 - 0s - loss: 4.8027e-04 - 184ms/epoch - 1ms/step
# Epoch 227/300
# 138/138 - 0s - loss: 4.7965e-04 - 184ms/epoch - 1ms/step
# Epoch 228/300
# 138/138 - 0s - loss: 4.7904e-04 - 185ms/epoch - 1ms/step
# Epoch 229/300
# 138/138 - 0s - loss: 4.7842e-04 - 189ms/epoch - 1ms/step
# Epoch 230/300
# 138/138 - 0s - loss: 4.7781e-04 - 187ms/epoch - 1ms/step
# Epoch 231/300
# 138/138 - 0s - loss: 4.7721e-04 - 188ms/epoch - 1ms/step
# Epoch 232/300
# 138/138 - 0s - loss: 4.7662e-04 - 187ms/epoch - 1ms/step
# Epoch 233/300
# 138/138 - 0s - loss: 4.7603e-04 - 188ms/epoch - 1ms/step
# Epoch 234/300
# 138/138 - 0s - loss: 4.7544e-04 - 171ms/epoch - 1ms/step
# Epoch 235/300
# 138/138 - 0s - loss: 4.7486e-04 - 187ms/epoch - 1ms/step
# Epoch 236/300
# 138/138 - 0s - loss: 4.7428e-04 - 186ms/epoch - 1ms/step
# Epoch 237/300
# 138/138 - 0s - loss: 4.7370e-04 - 185ms/epoch - 1ms/step
# Epoch 238/300
# 138/138 - 0s - loss: 4.7314e-04 - 189ms/epoch - 1ms/step
# Epoch 239/300
# 138/138 - 0s - loss: 4.7257e-04 - 171ms/epoch - 1ms/step
# Epoch 240/300
# 138/138 - 0s - loss: 4.7201e-04 - 173ms/epoch - 1ms/step
# Epoch 241/300
# 138/138 - 0s - loss: 4.7145e-04 - 189ms/epoch - 1ms/step
# Epoch 242/300
# 138/138 - 0s - loss: 4.7090e-04 - 184ms/epoch - 1ms/step
# Epoch 243/300
# 138/138 - 0s - loss: 4.7035e-04 - 172ms/epoch - 1ms/step
# Epoch 244/300
# 138/138 - 0s - loss: 4.6980e-04 - 186ms/epoch - 1ms/step
# Epoch 245/300
# 138/138 - 0s - loss: 4.6926e-04 - 189ms/epoch - 1ms/step
# Epoch 246/300
# 138/138 - 0s - loss: 4.6872e-04 - 187ms/epoch - 1ms/step
# Epoch 247/300
# 138/138 - 0s - loss: 4.6818e-04 - 184ms/epoch - 1ms/step
# Epoch 248/300
# 138/138 - 0s - loss: 4.6765e-04 - 189ms/epoch - 1ms/step
# Epoch 249/300
# 138/138 - 0s - loss: 4.6712e-04 - 171ms/epoch - 1ms/step
# Epoch 250/300
# 138/138 - 0s - loss: 4.6660e-04 - 173ms/epoch - 1ms/step
# Epoch 251/300
# 138/138 - 0s - loss: 4.6607e-04 - 173ms/epoch - 1ms/step
# Epoch 252/300
# 138/138 - 0s - loss: 4.6555e-04 - 171ms/epoch - 1ms/step
# Epoch 253/300
# 138/138 - 0s - loss: 4.6504e-04 - 174ms/epoch - 1ms/step
# Epoch 254/300
# 138/138 - 0s - loss: 4.6452e-04 - 173ms/epoch - 1ms/step
# Epoch 255/300
# 138/138 - 0s - loss: 4.6401e-04 - 205ms/epoch - 1ms/step
# Epoch 256/300
# 138/138 - 0s - loss: 4.6350e-04 - 215ms/epoch - 2ms/step
# Epoch 257/300
# 138/138 - 0s - loss: 4.6300e-04 - 213ms/epoch - 2ms/step
# Epoch 258/300
# 138/138 - 0s - loss: 4.6249e-04 - 227ms/epoch - 2ms/step
# Epoch 259/300
# 138/138 - 0s - loss: 4.6199e-04 - 213ms/epoch - 2ms/step
# Epoch 260/300
# 138/138 - 0s - loss: 4.6150e-04 - 198ms/epoch - 1ms/step
# Epoch 261/300
# 138/138 - 0s - loss: 4.6100e-04 - 211ms/epoch - 2ms/step
# Epoch 262/300
# 138/138 - 0s - loss: 4.6051e-04 - 215ms/epoch - 2ms/step
# Epoch 263/300
# 138/138 - 0s - loss: 4.6002e-04 - 213ms/epoch - 2ms/step
# Epoch 264/300
# 138/138 - 0s - loss: 4.5953e-04 - 213ms/epoch - 2ms/step
# Epoch 265/300
# 138/138 - 0s - loss: 4.5905e-04 - 211ms/epoch - 2ms/step
# Epoch 266/300
# 138/138 - 0s - loss: 4.5856e-04 - 202ms/epoch - 1ms/step
# Epoch 267/300
# 138/138 - 0s - loss: 4.5808e-04 - 213ms/epoch - 2ms/step
# Epoch 268/300
# 138/138 - 0s - loss: 4.5760e-04 - 198ms/epoch - 1ms/step
# Epoch 269/300
# 138/138 - 0s - loss: 4.5713e-04 - 195ms/epoch - 1ms/step
# Epoch 270/300
# 138/138 - 0s - loss: 4.5665e-04 - 200ms/epoch - 1ms/step
# Epoch 271/300
# 138/138 - 0s - loss: 4.5618e-04 - 214ms/epoch - 2ms/step
# Epoch 272/300
# 138/138 - 0s - loss: 4.5571e-04 - 182ms/epoch - 1ms/step
# Epoch 273/300
# 138/138 - 0s - loss: 4.5524e-04 - 200ms/epoch - 1ms/step
# Epoch 274/300
# 138/138 - 0s - loss: 4.5478e-04 - 187ms/epoch - 1ms/step
# Epoch 275/300
# 138/138 - 0s - loss: 4.5431e-04 - 184ms/epoch - 1ms/step
# Epoch 276/300
# 138/138 - 0s - loss: 4.5385e-04 - 187ms/epoch - 1ms/step
# Epoch 277/300
# 138/138 - 0s - loss: 4.5339e-04 - 189ms/epoch - 1ms/step
# Epoch 278/300
# 138/138 - 0s - loss: 4.5293e-04 - 184ms/epoch - 1ms/step
# Epoch 279/300
# 138/138 - 0s - loss: 4.5247e-04 - 187ms/epoch - 1ms/step
# Epoch 280/300
# 138/138 - 0s - loss: 4.5202e-04 - 173ms/epoch - 1ms/step
# Epoch 281/300
# 138/138 - 0s - loss: 4.5157e-04 - 171ms/epoch - 1ms/step
# Epoch 282/300
# 138/138 - 0s - loss: 4.5112e-04 - 187ms/epoch - 1ms/step
# Epoch 283/300
# 138/138 - 0s - loss: 4.5067e-04 - 187ms/epoch - 1ms/step
# Epoch 284/300
# 138/138 - 0s - loss: 4.5022e-04 - 187ms/epoch - 1ms/step
# Epoch 285/300
# 138/138 - 0s - loss: 4.4977e-04 - 186ms/epoch - 1ms/step
# Epoch 286/300
# 138/138 - 0s - loss: 4.4933e-04 - 185ms/epoch - 1ms/step
# Epoch 287/300
# 138/138 - 0s - loss: 4.4889e-04 - 172ms/epoch - 1ms/step
# Epoch 288/300
# 138/138 - 0s - loss: 4.4845e-04 - 188ms/epoch - 1ms/step
# Epoch 289/300
# 138/138 - 0s - loss: 4.4801e-04 - 187ms/epoch - 1ms/step
# Epoch 290/300
# 138/138 - 0s - loss: 4.4757e-04 - 184ms/epoch - 1ms/step
# Epoch 291/300
# 138/138 - 0s - loss: 4.4713e-04 - 189ms/epoch - 1ms/step
# Epoch 292/300
# 138/138 - 0s - loss: 4.4670e-04 - 187ms/epoch - 1ms/step
# Epoch 293/300
# 138/138 - 0s - loss: 4.4627e-04 - 185ms/epoch - 1ms/step
# Epoch 294/300
# 138/138 - 0s - loss: 4.4584e-04 - 171ms/epoch - 1ms/step
# Epoch 295/300
# 138/138 - 0s - loss: 4.4541e-04 - 202ms/epoch - 1ms/step
# Epoch 296/300
# 138/138 - 0s - loss: 4.4498e-04 - 172ms/epoch - 1ms/step
# Epoch 297/300
# 138/138 - 0s - loss: 4.4455e-04 - 202ms/epoch - 1ms/step
# Epoch 298/300
# 138/138 - 0s - loss: 4.4413e-04 - 171ms/epoch - 1ms/step
# Epoch 299/300
# 138/138 - 0s - loss: 4.4371e-04 - 202ms/epoch - 1ms/step
# Epoch 300/300
# 138/138 - 0s - loss: 4.4328e-04 - 172ms/epoch - 1ms/step
# 9/9 [==============================] - 0s 2ms/step
# Epoch 1/300
# 138/138 - 2s - loss: 0.2750 - 2s/epoch - 13ms/step
# Epoch 2/300
# 138/138 - 0s - loss: 0.0410 - 230ms/epoch - 2ms/step
# Epoch 3/300
# 138/138 - 0s - loss: 0.0430 - 224ms/epoch - 2ms/step
# Epoch 4/300
# 138/138 - 0s - loss: 0.0436 - 242ms/epoch - 2ms/step
# Epoch 5/300
# 138/138 - 0s - loss: 0.0437 - 224ms/epoch - 2ms/step
# Epoch 6/300
# 138/138 - 0s - loss: 0.0437 - 227ms/epoch - 2ms/step
# Epoch 7/300
# 138/138 - 0s - loss: 0.0436 - 242ms/epoch - 2ms/step
# Epoch 8/300
# 138/138 - 0s - loss: 0.0435 - 223ms/epoch - 2ms/step
# Epoch 9/300
# 138/138 - 0s - loss: 0.0433 - 225ms/epoch - 2ms/step
# Epoch 10/300
# 138/138 - 0s - loss: 0.0430 - 226ms/epoch - 2ms/step
# Epoch 11/300
# 138/138 - 0s - loss: 0.0427 - 209ms/epoch - 2ms/step
# Epoch 12/300
# 138/138 - 0s - loss: 0.0424 - 184ms/epoch - 1ms/step
# 9/9 [==============================] - 0s 2ms/step
# Epoch 1/300
# 138/138 - 1s - loss: 0.1032 - 1s/epoch - 9ms/step
# Epoch 2/300
# 138/138 - 0s - loss: 0.0443 - 203ms/epoch - 1ms/step
# Epoch 3/300
# 138/138 - 0s - loss: 0.0448 - 199ms/epoch - 1ms/step
# Epoch 4/300
# 138/138 - 0s - loss: 0.0449 - 199ms/epoch - 1ms/step
# Epoch 5/300
# 138/138 - 0s - loss: 0.0448 - 184ms/epoch - 1ms/step
# Epoch 6/300
# 138/138 - 0s - loss: 0.0448 - 203ms/epoch - 1ms/step
# Epoch 7/300
# 138/138 - 0s - loss: 0.0447 - 215ms/epoch - 2ms/step
# Epoch 8/300
# 138/138 - 0s - loss: 0.0446 - 200ms/epoch - 1ms/step
# Epoch 9/300
# 138/138 - 0s - loss: 0.0445 - 214ms/epoch - 2ms/step
# Epoch 10/300
# 138/138 - 0s - loss: 0.0443 - 200ms/epoch - 1ms/step
# Epoch 11/300
# 138/138 - 0s - loss: 0.0442 - 198ms/epoch - 1ms/step
# Epoch 12/300
# 138/138 - 0s - loss: 0.0441 - 200ms/epoch - 1ms/step
# Epoch 13/300
# 138/138 - 0s - loss: 0.0439 - 198ms/epoch - 1ms/step
# Epoch 14/300
# 138/138 - 0s - loss: 0.0437 - 184ms/epoch - 1ms/step
# Epoch 15/300
# 138/138 - 0s - loss: 0.0436 - 185ms/epoch - 1ms/step
# Epoch 16/300
# 138/138 - 0s - loss: 0.0434 - 187ms/epoch - 1ms/step
# Epoch 17/300
# 138/138 - 0s - loss: 0.0432 - 187ms/epoch - 1ms/step
# Epoch 18/300
# 138/138 - 0s - loss: 0.0430 - 186ms/epoch - 1ms/step
# Epoch 19/300
# 138/138 - 0s - loss: 0.0427 - 187ms/epoch - 1ms/step
# Epoch 20/300
# 138/138 - 0s - loss: 0.0424 - 185ms/epoch - 1ms/step
# Epoch 21/300
# 138/138 - 0s - loss: 0.0420 - 218ms/epoch - 2ms/step
# Epoch 22/300
# 138/138 - 0s - loss: 0.0414 - 242ms/epoch - 2ms/step
# Epoch 23/300
# 138/138 - 0s - loss: 0.0407 - 236ms/epoch - 2ms/step
# Epoch 24/300
# 138/138 - 0s - loss: 0.0396 - 242ms/epoch - 2ms/step
# Epoch 25/300
# 138/138 - 0s - loss: 0.0381 - 240ms/epoch - 2ms/step
# Epoch 26/300
# 138/138 - 0s - loss: 0.0359 - 240ms/epoch - 2ms/step
# Epoch 27/300
# 138/138 - 0s - loss: 0.0328 - 240ms/epoch - 2ms/step
# Epoch 28/300
# 138/138 - 0s - loss: 0.0281 - 240ms/epoch - 2ms/step
# Epoch 29/300
# 138/138 - 0s - loss: 0.0219 - 240ms/epoch - 2ms/step
# Epoch 30/300
# 138/138 - 0s - loss: 0.0151 - 269ms/epoch - 2ms/step
# Epoch 31/300
# 138/138 - 0s - loss: 0.0096 - 238ms/epoch - 2ms/step
# Epoch 32/300
# 138/138 - 0s - loss: 0.0062 - 240ms/epoch - 2ms/step
# Epoch 33/300
# 138/138 - 0s - loss: 0.0046 - 238ms/epoch - 2ms/step
# Epoch 34/300
# 138/138 - 0s - loss: 0.0037 - 242ms/epoch - 2ms/step
# Epoch 35/300
# 138/138 - 0s - loss: 0.0031 - 240ms/epoch - 2ms/step
# Epoch 36/300
# 138/138 - 0s - loss: 0.0027 - 241ms/epoch - 2ms/step
# Epoch 37/300
# 138/138 - 0s - loss: 0.0025 - 192ms/epoch - 1ms/step
# Epoch 38/300
# 138/138 - 0s - loss: 0.0023 - 154ms/epoch - 1ms/step
# Epoch 39/300
# 138/138 - 0s - loss: 0.0023 - 187ms/epoch - 1ms/step
# Epoch 40/300
# 138/138 - 0s - loss: 0.0023 - 169ms/epoch - 1ms/step
# Epoch 41/300
# 138/138 - 0s - loss: 0.0023 - 150ms/epoch - 1ms/step
# Epoch 42/300
# 138/138 - 0s - loss: 0.0023 - 174ms/epoch - 1ms/step
# Epoch 43/300
# 138/138 - 0s - loss: 0.0023 - 160ms/epoch - 1ms/step
# Epoch 44/300
# 138/138 - 0s - loss: 0.0023 - 160ms/epoch - 1ms/step
# Epoch 45/300
# 138/138 - 0s - loss: 0.0022 - 200ms/epoch - 1ms/step
# Epoch 46/300
# 138/138 - 0s - loss: 0.0022 - 200ms/epoch - 1ms/step
# Epoch 47/300
# 138/138 - 0s - loss: 0.0021 - 198ms/epoch - 1ms/step
# Epoch 48/300
# 138/138 - 0s - loss: 0.0021 - 200ms/epoch - 1ms/step
# Epoch 49/300
# 138/138 - 0s - loss: 0.0020 - 200ms/epoch - 1ms/step
# Epoch 50/300
# 138/138 - 0s - loss: 0.0020 - 200ms/epoch - 1ms/step
# Epoch 51/300
# 138/138 - 0s - loss: 0.0019 - 213ms/epoch - 2ms/step
# Epoch 52/300
# 138/138 - 0s - loss: 0.0019 - 200ms/epoch - 1ms/step
# Epoch 53/300
# 138/138 - 0s - loss: 0.0018 - 214ms/epoch - 2ms/step
# Epoch 54/300
# 138/138 - 0s - loss: 0.0018 - 200ms/epoch - 1ms/step
# Epoch 55/300
# 138/138 - 0s - loss: 0.0018 - 200ms/epoch - 1ms/step
# Epoch 56/300
# 138/138 - 0s - loss: 0.0018 - 214ms/epoch - 2ms/step
# Epoch 57/300
# 138/138 - 0s - loss: 0.0017 - 200ms/epoch - 1ms/step
# Epoch 58/300
# 138/138 - 0s - loss: 0.0017 - 213ms/epoch - 2ms/step
# Epoch 59/300
# 138/138 - 0s - loss: 0.0017 - 201ms/epoch - 1ms/step
# Epoch 60/300
# 138/138 - 0s - loss: 0.0017 - 185ms/epoch - 1ms/step
# Epoch 61/300
# 138/138 - 0s - loss: 0.0017 - 217ms/epoch - 2ms/step
# Epoch 62/300
# 138/138 - 0s - loss: 0.0017 - 198ms/epoch - 1ms/step
# Epoch 63/300
# 138/138 - 0s - loss: 0.0017 - 213ms/epoch - 2ms/step
# Epoch 64/300
# 138/138 - 0s - loss: 0.0017 - 200ms/epoch - 1ms/step
# Epoch 65/300
# 138/138 - 0s - loss: 0.0017 - 200ms/epoch - 1ms/step
# Epoch 66/300
# 138/138 - 0s - loss: 0.0017 - 213ms/epoch - 2ms/step
# Epoch 67/300
# 138/138 - 0s - loss: 0.0017 - 200ms/epoch - 1ms/step
# Epoch 68/300
# 138/138 - 0s - loss: 0.0017 - 200ms/epoch - 1ms/step
# Epoch 69/300
# 138/138 - 0s - loss: 0.0018 - 198ms/epoch - 1ms/step
# Epoch 70/300
# 138/138 - 0s - loss: 0.0018 - 185ms/epoch - 1ms/step
# Epoch 71/300
# 138/138 - 0s - loss: 0.0018 - 186ms/epoch - 1ms/step
# Epoch 72/300
# 138/138 - 0s - loss: 0.0018 - 200ms/epoch - 1ms/step
# 9/9 [==============================] - 0s 2ms/step
# Epoch 1/300
# 138/138 - 2s - loss: 0.1115 - 2s/epoch - 16ms/step
# Epoch 2/300
# 138/138 - 0s - loss: 0.0440 - 257ms/epoch - 2ms/step
# Epoch 3/300
# 138/138 - 0s - loss: 0.0447 - 254ms/epoch - 2ms/step
# Epoch 4/300
# 138/138 - 0s - loss: 0.0449 - 238ms/epoch - 2ms/step
# Epoch 5/300
# 138/138 - 0s - loss: 0.0449 - 255ms/epoch - 2ms/step
# Epoch 6/300
# 138/138 - 0s - loss: 0.0449 - 251ms/epoch - 2ms/step
# Epoch 7/300
# 138/138 - 0s - loss: 0.0448 - 253ms/epoch - 2ms/step
# Epoch 8/300
# 138/138 - 0s - loss: 0.0447 - 207ms/epoch - 1ms/step
# Epoch 9/300
# 138/138 - 0s - loss: 0.0446 - 211ms/epoch - 2ms/step
# Epoch 10/300
# 138/138 - 0s - loss: 0.0445 - 215ms/epoch - 2ms/step
# Epoch 11/300
# 138/138 - 0s - loss: 0.0443 - 213ms/epoch - 2ms/step
# Epoch 12/300
# 138/138 - 0s - loss: 0.0442 - 213ms/epoch - 2ms/step
# 9/9 [==============================] - 0s 3ms/step
# Epoch 1/300
# 138/138 - 2s - loss: 0.1642 - 2s/epoch - 12ms/step
# Epoch 2/300
# 138/138 - 0s - loss: 0.0436 - 224ms/epoch - 2ms/step
# Epoch 3/300
# 138/138 - 0s - loss: 0.0447 - 212ms/epoch - 2ms/step
# Epoch 4/300
# 138/138 - 0s - loss: 0.0450 - 211ms/epoch - 2ms/step
# Epoch 5/300
# 138/138 - 0s - loss: 0.0451 - 229ms/epoch - 2ms/step
# Epoch 6/300
# 138/138 - 0s - loss: 0.0451 - 227ms/epoch - 2ms/step
# Epoch 7/300
# 138/138 - 0s - loss: 0.0450 - 211ms/epoch - 2ms/step
# Epoch 8/300
# 138/138 - 0s - loss: 0.0450 - 200ms/epoch - 1ms/step
# Epoch 9/300
# 138/138 - 0s - loss: 0.0449 - 206ms/epoch - 1ms/step
# Epoch 10/300
# 138/138 - 0s - loss: 0.0448 - 205ms/epoch - 1ms/step
# Epoch 11/300
# 138/138 - 0s - loss: 0.0447 - 200ms/epoch - 1ms/step
# Epoch 12/300
# 138/138 - 0s - loss: 0.0446 - 213ms/epoch - 2ms/step
# 9/9 [==============================] - 0s 3ms/step
# Epoch 1/300
# 138/138 - 3s - loss: 0.0921 - 3s/epoch - 21ms/step
# Epoch 2/300
# 138/138 - 0s - loss: 0.0449 - 252ms/epoch - 2ms/step
# Epoch 3/300
# 138/138 - 0s - loss: 0.0452 - 253ms/epoch - 2ms/step
# Epoch 4/300
# 138/138 - 0s - loss: 0.0453 - 250ms/epoch - 2ms/step
# Epoch 5/300
# 138/138 - 0s - loss: 0.0453 - 211ms/epoch - 2ms/step
# Epoch 6/300
# 138/138 - 0s - loss: 0.0453 - 227ms/epoch - 2ms/step
# Epoch 7/300
# 138/138 - 0s - loss: 0.0453 - 272ms/epoch - 2ms/step
# Epoch 8/300
# 138/138 - 0s - loss: 0.0452 - 295ms/epoch - 2ms/step
# Epoch 9/300
# 138/138 - 0s - loss: 0.0452 - 280ms/epoch - 2ms/step
# Epoch 10/300
# 138/138 - 0s - loss: 0.0451 - 264ms/epoch - 2ms/step
# Epoch 11/300
# 138/138 - 0s - loss: 0.0450 - 251ms/epoch - 2ms/step
# Epoch 12/300
# 138/138 - 0s - loss: 0.0449 - 270ms/epoch - 2ms/step
# 9/9 [==============================] - 0s 2ms/step
# Epoch 1/300
# 138/138 - 2s - loss: 0.0347 - 2s/epoch - 17ms/step
# Epoch 2/300
# 138/138 - 0s - loss: 0.0444 - 238ms/epoch - 2ms/step
# Epoch 3/300
# 138/138 - 0s - loss: 0.0449 - 273ms/epoch - 2ms/step
# Epoch 4/300
# 138/138 - 0s - loss: 0.0451 - 235ms/epoch - 2ms/step
# Epoch 5/300
# 138/138 - 0s - loss: 0.0452 - 227ms/epoch - 2ms/step
# Epoch 6/300
# 138/138 - 0s - loss: 0.0452 - 225ms/epoch - 2ms/step
# Epoch 7/300
# 138/138 - 0s - loss: 0.0450 - 258ms/epoch - 2ms/step
# Epoch 8/300
# 138/138 - 0s - loss: 0.0449 - 300ms/epoch - 2ms/step
# Epoch 9/300
# 138/138 - 0s - loss: 0.0447 - 276ms/epoch - 2ms/step
# Epoch 10/300
# 138/138 - 0s - loss: 0.0445 - 279ms/epoch - 2ms/step
# Epoch 11/300
# 138/138 - 0s - loss: 0.0444 - 280ms/epoch - 2ms/step
# 9/9 [==============================] - 0s 3ms/step
# Epoch 1/300
# 138/138 - 3s - loss: 0.0571 - 3s/epoch - 22ms/step
# Epoch 2/300
# 138/138 - 0s - loss: 0.0452 - 288ms/epoch - 2ms/step
# Epoch 3/300
# 138/138 - 0s - loss: 0.0452 - 291ms/epoch - 2ms/step
# Epoch 4/300
# 138/138 - 0s - loss: 0.0452 - 233ms/epoch - 2ms/step
# Epoch 5/300
# 138/138 - 0s - loss: 0.0452 - 209ms/epoch - 2ms/step
# Epoch 6/300
# 138/138 - 0s - loss: 0.0451 - 200ms/epoch - 1ms/step
# Epoch 7/300
# 138/138 - 0s - loss: 0.0450 - 200ms/epoch - 1ms/step
# Epoch 8/300
# 138/138 - 0s - loss: 0.0449 - 214ms/epoch - 2ms/step
# Epoch 9/300
# 138/138 - 0s - loss: 0.0448 - 214ms/epoch - 2ms/step
# Epoch 10/300
# 138/138 - 0s - loss: 0.0446 - 197ms/epoch - 1ms/step
# Epoch 11/300
# 138/138 - 0s - loss: 0.0445 - 216ms/epoch - 2ms/step
# Epoch 12/300
# 138/138 - 0s - loss: 0.0443 - 200ms/epoch - 1ms/step
# Epoch 13/300
# 138/138 - 0s - loss: 0.0442 - 213ms/epoch - 2ms/step
# Epoch 14/300
# 138/138 - 0s - loss: 0.0440 - 199ms/epoch - 1ms/step
# Epoch 15/300
# 138/138 - 0s - loss: 0.0439 - 214ms/epoch - 2ms/step
# Epoch 16/300
# 138/138 - 0s - loss: 0.0438 - 200ms/epoch - 1ms/step
# Epoch 17/300
# 138/138 - 0s - loss: 0.0436 - 214ms/epoch - 2ms/step
# Epoch 18/300
# 138/138 - 0s - loss: 0.0435 - 199ms/epoch - 1ms/step
# Epoch 19/300
# 138/138 - 0s - loss: 0.0434 - 196ms/epoch - 1ms/step
# Epoch 20/300
# 138/138 - 0s - loss: 0.0433 - 201ms/epoch - 1ms/step
# Epoch 21/300
# 138/138 - 0s - loss: 0.0432 - 199ms/epoch - 1ms/step
# Epoch 22/300
# 138/138 - 0s - loss: 0.0432 - 211ms/epoch - 2ms/step
# Epoch 23/300
# 138/138 - 0s - loss: 0.0431 - 216ms/epoch - 2ms/step
# Epoch 24/300
# 138/138 - 0s - loss: 0.0430 - 200ms/epoch - 1ms/step
# Epoch 25/300
# 138/138 - 0s - loss: 0.0430 - 198ms/epoch - 1ms/step
# Epoch 26/300
# 138/138 - 0s - loss: 0.0429 - 200ms/epoch - 1ms/step
# Epoch 27/300
# 138/138 - 0s - loss: 0.0429 - 213ms/epoch - 2ms/step
# Epoch 28/300
# 138/138 - 0s - loss: 0.0428 - 199ms/epoch - 1ms/step
# Epoch 29/300
# 138/138 - 0s - loss: 0.0428 - 215ms/epoch - 2ms/step
# Epoch 30/300
# 138/138 - 0s - loss: 0.0427 - 200ms/epoch - 1ms/step
# Epoch 31/300
# 138/138 - 0s - loss: 0.0427 - 214ms/epoch - 2ms/step
# Epoch 32/300
# 138/138 - 0s - loss: 0.0426 - 200ms/epoch - 1ms/step
# Epoch 33/300
# 138/138 - 0s - loss: 0.0426 - 198ms/epoch - 1ms/step
# Epoch 34/300
# 138/138 - 0s - loss: 0.0426 - 213ms/epoch - 2ms/step
# Epoch 35/300
# 138/138 - 0s - loss: 0.0425 - 200ms/epoch - 1ms/step
# Epoch 36/300
# 138/138 - 0s - loss: 0.0425 - 215ms/epoch - 2ms/step
# Epoch 37/300
# 138/138 - 0s - loss: 0.0425 - 212ms/epoch - 2ms/step
# Epoch 38/300
# 138/138 - 0s - loss: 0.0425 - 198ms/epoch - 1ms/step
# Epoch 39/300
# 138/138 - 0s - loss: 0.0424 - 216ms/epoch - 2ms/step
# Epoch 40/300
# 138/138 - 0s - loss: 0.0424 - 198ms/epoch - 1ms/step
# Epoch 41/300
# 138/138 - 0s - loss: 0.0424 - 216ms/epoch - 2ms/step
# Epoch 42/300
# 138/138 - 0s - loss: 0.0423 - 198ms/epoch - 1ms/step
# Epoch 43/300
# 138/138 - 0s - loss: 0.0423 - 201ms/epoch - 1ms/step
# Epoch 44/300
# 138/138 - 0s - loss: 0.0423 - 197ms/epoch - 1ms/step
# Epoch 45/300
# 138/138 - 0s - loss: 0.0423 - 215ms/epoch - 2ms/step
# Epoch 46/300
# 138/138 - 0s - loss: 0.0422 - 214ms/epoch - 2ms/step
# Epoch 47/300
# 138/138 - 0s - loss: 0.0422 - 200ms/epoch - 1ms/step
# Epoch 48/300
# 138/138 - 0s - loss: 0.0422 - 198ms/epoch - 1ms/step
# Epoch 49/300
# 138/138 - 0s - loss: 0.0422 - 200ms/epoch - 1ms/step
# Epoch 50/300
# 138/138 - 0s - loss: 0.0421 - 214ms/epoch - 2ms/step
# Epoch 51/300
# 138/138 - 0s - loss: 0.0421 - 200ms/epoch - 1ms/step
# Epoch 52/300
# 138/138 - 0s - loss: 0.0421 - 214ms/epoch - 2ms/step
# Epoch 53/300
# 138/138 - 0s - loss: 0.0421 - 199ms/epoch - 1ms/step
# Epoch 54/300
# 138/138 - 0s - loss: 0.0421 - 198ms/epoch - 1ms/step
# Epoch 55/300
# 138/138 - 0s - loss: 0.0420 - 215ms/epoch - 2ms/step
# Epoch 56/300
# 138/138 - 0s - loss: 0.0420 - 198ms/epoch - 1ms/step
# Epoch 57/300
# 138/138 - 0s - loss: 0.0420 - 200ms/epoch - 1ms/step
# Epoch 58/300
# 138/138 - 0s - loss: 0.0420 - 214ms/epoch - 2ms/step
# Epoch 59/300
# 138/138 - 0s - loss: 0.0419 - 213ms/epoch - 2ms/step
# Epoch 60/300
# 138/138 - 0s - loss: 0.0419 - 214ms/epoch - 2ms/step
# Epoch 61/300
# 138/138 - 0s - loss: 0.0419 - 198ms/epoch - 1ms/step
# Epoch 62/300
# 138/138 - 0s - loss: 0.0419 - 213ms/epoch - 2ms/step
# Epoch 63/300
# 138/138 - 0s - loss: 0.0418 - 215ms/epoch - 2ms/step
# Epoch 64/300
# 138/138 - 0s - loss: 0.0418 - 214ms/epoch - 2ms/step
# Epoch 65/300
# 138/138 - 0s - loss: 0.0418 - 198ms/epoch - 1ms/step
# Epoch 66/300
# 138/138 - 0s - loss: 0.0418 - 213ms/epoch - 2ms/step
# Epoch 67/300
# 138/138 - 0s - loss: 0.0418 - 200ms/epoch - 1ms/step
# Epoch 68/300
# 138/138 - 0s - loss: 0.0417 - 213ms/epoch - 2ms/step
# Epoch 69/300
# 138/138 - 0s - loss: 0.0417 - 201ms/epoch - 1ms/step
# Epoch 70/300
# 138/138 - 0s - loss: 0.0417 - 199ms/epoch - 1ms/step
# Epoch 71/300
# 138/138 - 0s - loss: 0.0416 - 198ms/epoch - 1ms/step
# Epoch 72/300
# 138/138 - 0s - loss: 0.0416 - 213ms/epoch - 2ms/step
# Epoch 73/300
# 138/138 - 0s - loss: 0.0416 - 198ms/epoch - 1ms/step
# Epoch 74/300
# 138/138 - 0s - loss: 0.0416 - 202ms/epoch - 1ms/step
# Epoch 75/300
# 138/138 - 0s - loss: 0.0416 - 214ms/epoch - 2ms/step
# Epoch 76/300
# 138/138 - 0s - loss: 0.0415 - 215ms/epoch - 2ms/step
# Epoch 77/300
# 138/138 - 0s - loss: 0.0415 - 198ms/epoch - 1ms/step
# Epoch 78/300
# 138/138 - 0s - loss: 0.0415 - 200ms/epoch - 1ms/step
# Epoch 79/300
# 138/138 - 0s - loss: 0.0415 - 213ms/epoch - 2ms/step
# Epoch 80/300
# 138/138 - 0s - loss: 0.0414 - 200ms/epoch - 1ms/step
# Epoch 81/300
# 138/138 - 0s - loss: 0.0414 - 213ms/epoch - 2ms/step
# Epoch 82/300
# 138/138 - 0s - loss: 0.0414 - 200ms/epoch - 1ms/step
# Epoch 83/300
# 138/138 - 0s - loss: 0.0414 - 213ms/epoch - 2ms/step
# Epoch 84/300
# 138/138 - 0s - loss: 0.0413 - 200ms/epoch - 1ms/step
# Epoch 85/300
# 138/138 - 0s - loss: 0.0413 - 214ms/epoch - 2ms/step
# Epoch 86/300
# 138/138 - 0s - loss: 0.0413 - 200ms/epoch - 1ms/step
# Epoch 87/300
# 138/138 - 0s - loss: 0.0413 - 212ms/epoch - 2ms/step
# Epoch 88/300
# 138/138 - 0s - loss: 0.0412 - 200ms/epoch - 1ms/step
# Epoch 89/300
# 138/138 - 0s - loss: 0.0412 - 213ms/epoch - 2ms/step
# Epoch 90/300
# 138/138 - 0s - loss: 0.0412 - 200ms/epoch - 1ms/step
# Epoch 91/300
# 138/138 - 0s - loss: 0.0412 - 214ms/epoch - 2ms/step
# Epoch 92/300
# 138/138 - 0s - loss: 0.0411 - 197ms/epoch - 1ms/step
# Epoch 93/300
# 138/138 - 0s - loss: 0.0411 - 201ms/epoch - 1ms/step
# Epoch 94/300
# 138/138 - 0s - loss: 0.0411 - 199ms/epoch - 1ms/step
# Epoch 95/300
# 138/138 - 0s - loss: 0.0410 - 215ms/epoch - 2ms/step
# Epoch 96/300
# 138/138 - 0s - loss: 0.0410 - 196ms/epoch - 1ms/step
# Epoch 97/300
# 138/138 - 0s - loss: 0.0410 - 202ms/epoch - 1ms/step
# Epoch 98/300
# 138/138 - 0s - loss: 0.0410 - 198ms/epoch - 1ms/step
# Epoch 99/300
# 138/138 - 0s - loss: 0.0409 - 214ms/epoch - 2ms/step
# Epoch 100/300
# 138/138 - 0s - loss: 0.0409 - 197ms/epoch - 1ms/step
# Epoch 101/300
# 138/138 - 0s - loss: 0.0409 - 216ms/epoch - 2ms/step
# Epoch 102/300
# 138/138 - 0s - loss: 0.0408 - 200ms/epoch - 1ms/step
# Epoch 103/300
# 138/138 - 0s - loss: 0.0408 - 213ms/epoch - 2ms/step
# Epoch 104/300
# 138/138 - 0s - loss: 0.0407 - 201ms/epoch - 1ms/step
# Epoch 105/300
# 138/138 - 0s - loss: 0.0407 - 212ms/epoch - 2ms/step
# Epoch 106/300
# 138/138 - 0s - loss: 0.0407 - 200ms/epoch - 1ms/step
# Epoch 107/300
# 138/138 - 0s - loss: 0.0406 - 214ms/epoch - 2ms/step
# Epoch 108/300
# 138/138 - 0s - loss: 0.0406 - 200ms/epoch - 1ms/step
# Epoch 109/300
# 138/138 - 0s - loss: 0.0405 - 214ms/epoch - 2ms/step
# Epoch 110/300
# 138/138 - 0s - loss: 0.0405 - 213ms/epoch - 2ms/step
# Epoch 111/300
# 138/138 - 0s - loss: 0.0405 - 200ms/epoch - 1ms/step
# Epoch 112/300
# 138/138 - 0s - loss: 0.0404 - 213ms/epoch - 2ms/step
# Epoch 113/300
# 138/138 - 0s - loss: 0.0404 - 200ms/epoch - 1ms/step
# Epoch 114/300
# 138/138 - 0s - loss: 0.0403 - 213ms/epoch - 2ms/step
# Epoch 115/300
# 138/138 - 0s - loss: 0.0403 - 200ms/epoch - 1ms/step
# Epoch 116/300
# 138/138 - 0s - loss: 0.0402 - 198ms/epoch - 1ms/step
# Epoch 117/300
# 138/138 - 0s - loss: 0.0402 - 199ms/epoch - 1ms/step
# Epoch 118/300
# 138/138 - 0s - loss: 0.0402 - 199ms/epoch - 1ms/step
# Epoch 119/300
# 138/138 - 0s - loss: 0.0401 - 213ms/epoch - 2ms/step
# Epoch 120/300
# 138/138 - 0s - loss: 0.0401 - 200ms/epoch - 1ms/step
# Epoch 121/300
# 138/138 - 0s - loss: 0.0401 - 214ms/epoch - 2ms/step
# Epoch 122/300
# 138/138 - 0s - loss: 0.0400 - 213ms/epoch - 2ms/step
# Epoch 123/300
# 138/138 - 0s - loss: 0.0400 - 200ms/epoch - 1ms/step
# Epoch 124/300
# 138/138 - 0s - loss: 0.0400 - 214ms/epoch - 2ms/step
# Epoch 125/300
# 138/138 - 0s - loss: 0.0400 - 199ms/epoch - 1ms/step
# Epoch 126/300
# 138/138 - 0s - loss: 0.0399 - 214ms/epoch - 2ms/step
# Epoch 127/300
# 138/138 - 0s - loss: 0.0399 - 213ms/epoch - 2ms/step
# Epoch 128/300
# 138/138 - 0s - loss: 0.0399 - 198ms/epoch - 1ms/step
# Epoch 129/300
# 138/138 - 0s - loss: 0.0398 - 216ms/epoch - 2ms/step
# Epoch 130/300
# 138/138 - 0s - loss: 0.0398 - 200ms/epoch - 1ms/step
# Epoch 131/300
# 138/138 - 0s - loss: 0.0398 - 214ms/epoch - 2ms/step
# Epoch 132/300
# 138/138 - 0s - loss: 0.0397 - 200ms/epoch - 1ms/step
# Epoch 133/300
# 138/138 - 0s - loss: 0.0397 - 214ms/epoch - 2ms/step
# Epoch 134/300
# 138/138 - 0s - loss: 0.0397 - 213ms/epoch - 2ms/step
# Epoch 135/300
# 138/138 - 0s - loss: 0.0397 - 200ms/epoch - 1ms/step
# Epoch 136/300
# 138/138 - 0s - loss: 0.0396 - 214ms/epoch - 2ms/step
# Epoch 137/300
# 138/138 - 0s - loss: 0.0396 - 200ms/epoch - 1ms/step
# Epoch 138/300
# 138/138 - 0s - loss: 0.0396 - 229ms/epoch - 2ms/step
# Epoch 139/300
# 138/138 - 0s - loss: 0.0395 - 211ms/epoch - 2ms/step
# Epoch 140/300
# 138/138 - 0s - loss: 0.0395 - 200ms/epoch - 1ms/step
# Epoch 141/300
# 138/138 - 0s - loss: 0.0396 - 214ms/epoch - 2ms/step
# Epoch 142/300
# 138/138 - 0s - loss: 0.0395 - 212ms/epoch - 2ms/step
# Epoch 143/300
# 138/138 - 0s - loss: 0.0394 - 214ms/epoch - 2ms/step
# Epoch 144/300
# 138/138 - 0s - loss: 0.0394 - 200ms/epoch - 1ms/step
# Epoch 145/300
# 138/138 - 0s - loss: 0.0393 - 225ms/epoch - 2ms/step
# Epoch 146/300
# 138/138 - 0s - loss: 0.0393 - 202ms/epoch - 1ms/step
# Epoch 147/300
# 138/138 - 0s - loss: 0.0392 - 213ms/epoch - 2ms/step
# Epoch 148/300
# 138/138 - 0s - loss: 0.0392 - 198ms/epoch - 1ms/step
# Epoch 149/300
# 138/138 - 0s - loss: 0.0392 - 216ms/epoch - 2ms/step
# Epoch 150/300
# 138/138 - 0s - loss: 0.0392 - 200ms/epoch - 1ms/step
# Epoch 151/300
# 138/138 - 0s - loss: 0.0392 - 214ms/epoch - 2ms/step
# Epoch 152/300
# 138/138 - 0s - loss: 0.0391 - 200ms/epoch - 1ms/step
# Epoch 153/300
# 138/138 - 0s - loss: 0.0390 - 214ms/epoch - 2ms/step
# Epoch 154/300
# 138/138 - 0s - loss: 0.0390 - 213ms/epoch - 2ms/step
# Epoch 155/300
# 138/138 - 0s - loss: 0.0389 - 197ms/epoch - 1ms/step
# Epoch 156/300
# 138/138 - 0s - loss: 0.0389 - 216ms/epoch - 2ms/step
# Epoch 157/300
# 138/138 - 0s - loss: 0.0389 - 200ms/epoch - 1ms/step
# Epoch 158/300
# 138/138 - 0s - loss: 0.0388 - 196ms/epoch - 1ms/step
# Epoch 159/300
# 138/138 - 0s - loss: 0.0388 - 216ms/epoch - 2ms/step
# Epoch 160/300
# 138/138 - 0s - loss: 0.0387 - 200ms/epoch - 1ms/step
# Epoch 161/300
# 138/138 - 0s - loss: 0.0387 - 214ms/epoch - 2ms/step
# Epoch 162/300
# 138/138 - 0s - loss: 0.0386 - 199ms/epoch - 1ms/step
# Epoch 163/300
# 138/138 - 0s - loss: 0.0386 - 199ms/epoch - 1ms/step
# Epoch 164/300
# 138/138 - 0s - loss: 0.0385 - 213ms/epoch - 2ms/step
# Epoch 165/300
# 138/138 - 0s - loss: 0.0385 - 201ms/epoch - 1ms/step
# Epoch 166/300
# 138/138 - 0s - loss: 0.0384 - 213ms/epoch - 2ms/step
# Epoch 167/300
# 138/138 - 0s - loss: 0.0384 - 200ms/epoch - 1ms/step
# Epoch 168/300
# 138/138 - 0s - loss: 0.0384 - 198ms/epoch - 1ms/step
# Epoch 169/300
# 138/138 - 0s - loss: 0.0383 - 213ms/epoch - 2ms/step
# Epoch 170/300
# 138/138 - 0s - loss: 0.0383 - 201ms/epoch - 1ms/step
# Epoch 171/300
# 138/138 - 0s - loss: 0.0382 - 199ms/epoch - 1ms/step
# Epoch 172/300
# 138/138 - 0s - loss: 0.0382 - 197ms/epoch - 1ms/step
# Epoch 173/300
# 138/138 - 0s - loss: 0.0382 - 201ms/epoch - 1ms/step
# Epoch 174/300
# 138/138 - 0s - loss: 0.0381 - 198ms/epoch - 1ms/step
# Epoch 175/300
# 138/138 - 0s - loss: 0.0381 - 200ms/epoch - 1ms/step
# Epoch 176/300
# 138/138 - 0s - loss: 0.0381 - 214ms/epoch - 2ms/step
# Epoch 177/300
# 138/138 - 0s - loss: 0.0380 - 215ms/epoch - 2ms/step
# Epoch 178/300
# 138/138 - 0s - loss: 0.0380 - 198ms/epoch - 1ms/step
# Epoch 179/300
# 138/138 - 0s - loss: 0.0380 - 200ms/epoch - 1ms/step
# Epoch 180/300
# 138/138 - 0s - loss: 0.0379 - 214ms/epoch - 2ms/step
# Epoch 181/300
# 138/138 - 0s - loss: 0.0379 - 201ms/epoch - 1ms/step
# Epoch 182/300
# 138/138 - 0s - loss: 0.0379 - 212ms/epoch - 2ms/step
# Epoch 183/300
# 138/138 - 0s - loss: 0.0379 - 200ms/epoch - 1ms/step
# Epoch 184/300
# 138/138 - 0s - loss: 0.0378 - 213ms/epoch - 2ms/step
# Epoch 185/300
# 138/138 - 0s - loss: 0.0378 - 200ms/epoch - 1ms/step
# Epoch 186/300
# 138/138 - 0s - loss: 0.0378 - 214ms/epoch - 2ms/step
# Epoch 187/300
# 138/138 - 0s - loss: 0.0378 - 215ms/epoch - 2ms/step
# Epoch 188/300
# 138/138 - 0s - loss: 0.0377 - 198ms/epoch - 1ms/step
# Epoch 189/300
# 138/138 - 0s - loss: 0.0377 - 200ms/epoch - 1ms/step
# Epoch 190/300
# 138/138 - 0s - loss: 0.0377 - 198ms/epoch - 1ms/step
# Epoch 191/300
# 138/138 - 0s - loss: 0.0377 - 200ms/epoch - 1ms/step
# Epoch 192/300
# 138/138 - 0s - loss: 0.0376 - 198ms/epoch - 1ms/step
# Epoch 193/300
# 138/138 - 0s - loss: 0.0376 - 230ms/epoch - 2ms/step
# Epoch 194/300
# 138/138 - 0s - loss: 0.0376 - 197ms/epoch - 1ms/step
# Epoch 195/300
# 138/138 - 0s - loss: 0.0376 - 213ms/epoch - 2ms/step
# Epoch 196/300
# 138/138 - 0s - loss: 0.0375 - 216ms/epoch - 2ms/step
# Epoch 197/300
# 138/138 - 0s - loss: 0.0375 - 198ms/epoch - 1ms/step
# Epoch 198/300
# 138/138 - 0s - loss: 0.0375 - 213ms/epoch - 2ms/step
# Epoch 199/300
# 138/138 - 0s - loss: 0.0375 - 200ms/epoch - 1ms/step
# Epoch 200/300
# 138/138 - 0s - loss: 0.0374 - 200ms/epoch - 1ms/step
# Epoch 201/300
# 138/138 - 0s - loss: 0.0374 - 213ms/epoch - 2ms/step
# Epoch 202/300
# 138/138 - 0s - loss: 0.0374 - 200ms/epoch - 1ms/step
# Epoch 203/300
# 138/138 - 0s - loss: 0.0374 - 198ms/epoch - 1ms/step
# Epoch 204/300
# 138/138 - 0s - loss: 0.0374 - 215ms/epoch - 2ms/step
# Epoch 205/300
# 138/138 - 0s - loss: 0.0373 - 198ms/epoch - 1ms/step
# Epoch 206/300
# 138/138 - 0s - loss: 0.0373 - 214ms/epoch - 2ms/step
# Epoch 207/300
# 138/138 - 0s - loss: 0.0373 - 215ms/epoch - 2ms/step
# Epoch 208/300
# 138/138 - 0s - loss: 0.0373 - 198ms/epoch - 1ms/step
# Epoch 209/300
# 138/138 - 0s - loss: 0.0373 - 214ms/epoch - 2ms/step
# Epoch 210/300
# 138/138 - 0s - loss: 0.0372 - 200ms/epoch - 1ms/step
# Epoch 211/300
# 138/138 - 0s - loss: 0.0372 - 214ms/epoch - 2ms/step
# Epoch 212/300
# 138/138 - 0s - loss: 0.0372 - 223ms/epoch - 2ms/step
# Epoch 213/300
# 138/138 - 0s - loss: 0.0372 - 204ms/epoch - 1ms/step
# Epoch 214/300
# 138/138 - 0s - loss: 0.0371 - 215ms/epoch - 2ms/step
# Epoch 215/300
# 138/138 - 0s - loss: 0.0371 - 199ms/epoch - 1ms/step
# Epoch 216/300
# 138/138 - 0s - loss: 0.0371 - 214ms/epoch - 2ms/step
# Epoch 217/300
# 138/138 - 0s - loss: 0.0371 - 200ms/epoch - 1ms/step
# Epoch 218/300
# 138/138 - 0s - loss: 0.0371 - 214ms/epoch - 2ms/step
# Epoch 219/300
# 138/138 - 0s - loss: 0.0371 - 200ms/epoch - 1ms/step
# Epoch 220/300
# 138/138 - 0s - loss: 0.0370 - 213ms/epoch - 2ms/step
# Epoch 221/300
# 138/138 - 0s - loss: 0.0370 - 213ms/epoch - 2ms/step
# Epoch 222/300
# 138/138 - 0s - loss: 0.0370 - 200ms/epoch - 1ms/step
# Epoch 223/300
# 138/138 - 0s - loss: 0.0370 - 214ms/epoch - 2ms/step
# Epoch 224/300
# 138/138 - 0s - loss: 0.0370 - 200ms/epoch - 1ms/step
# Epoch 225/300
# 138/138 - 0s - loss: 0.0369 - 214ms/epoch - 2ms/step
# Epoch 226/300
# 138/138 - 0s - loss: 0.0369 - 200ms/epoch - 1ms/step
# Epoch 227/300
# 138/138 - 0s - loss: 0.0369 - 198ms/epoch - 1ms/step
# Epoch 228/300
# 138/138 - 0s - loss: 0.0369 - 213ms/epoch - 2ms/step
# Epoch 229/300
# 138/138 - 0s - loss: 0.0369 - 200ms/epoch - 1ms/step
# Epoch 230/300
# 138/138 - 0s - loss: 0.0368 - 213ms/epoch - 2ms/step
# Epoch 231/300
# 138/138 - 0s - loss: 0.0368 - 200ms/epoch - 1ms/step
# Epoch 232/300
# 138/138 - 0s - loss: 0.0368 - 213ms/epoch - 2ms/step
# Epoch 233/300
# 138/138 - 0s - loss: 0.0368 - 200ms/epoch - 1ms/step
# Epoch 234/300
# 138/138 - 0s - loss: 0.0368 - 213ms/epoch - 2ms/step
# Epoch 235/300
# 138/138 - 0s - loss: 0.0368 - 200ms/epoch - 1ms/step
# Epoch 236/300
# 138/138 - 0s - loss: 0.0367 - 214ms/epoch - 2ms/step
# Epoch 237/300
# 138/138 - 0s - loss: 0.0367 - 214ms/epoch - 2ms/step
# Epoch 238/300
# 138/138 - 0s - loss: 0.0367 - 200ms/epoch - 1ms/step
# Epoch 239/300
# 138/138 - 0s - loss: 0.0367 - 213ms/epoch - 2ms/step
# Epoch 240/300
# 138/138 - 0s - loss: 0.0367 - 200ms/epoch - 1ms/step
# Epoch 241/300
# 138/138 - 0s - loss: 0.0366 - 213ms/epoch - 2ms/step
# Epoch 242/300
# 138/138 - 0s - loss: 0.0366 - 200ms/epoch - 1ms/step
# Epoch 243/300
# 138/138 - 0s - loss: 0.0366 - 214ms/epoch - 2ms/step
# Epoch 244/300
# 138/138 - 0s - loss: 0.0366 - 213ms/epoch - 2ms/step
# Epoch 245/300
# 138/138 - 0s - loss: 0.0366 - 200ms/epoch - 1ms/step
# Epoch 246/300
# 138/138 - 0s - loss: 0.0366 - 214ms/epoch - 2ms/step
# Epoch 247/300
# 138/138 - 0s - loss: 0.0365 - 213ms/epoch - 2ms/step
# Epoch 248/300
# 138/138 - 0s - loss: 0.0365 - 200ms/epoch - 1ms/step
# Epoch 249/300
# 138/138 - 0s - loss: 0.0365 - 196ms/epoch - 1ms/step
# Epoch 250/300
# 138/138 - 0s - loss: 0.0365 - 216ms/epoch - 2ms/step
# Epoch 251/300
# 138/138 - 0s - loss: 0.0365 - 200ms/epoch - 1ms/step
# Epoch 252/300
# 138/138 - 0s - loss: 0.0365 - 214ms/epoch - 2ms/step
# Epoch 253/300
# 138/138 - 0s - loss: 0.0364 - 200ms/epoch - 1ms/step
# Epoch 254/300
# 138/138 - 0s - loss: 0.0364 - 196ms/epoch - 1ms/step
# Epoch 255/300
# 138/138 - 0s - loss: 0.0364 - 216ms/epoch - 2ms/step
# Epoch 256/300
# 138/138 - 0s - loss: 0.0364 - 213ms/epoch - 2ms/step
# Epoch 257/300
# 138/138 - 0s - loss: 0.0364 - 200ms/epoch - 1ms/step
# Epoch 258/300
# 138/138 - 0s - loss: 0.0364 - 213ms/epoch - 2ms/step
# Epoch 259/300
# 138/138 - 0s - loss: 0.0363 - 201ms/epoch - 1ms/step
# Epoch 260/300
# 138/138 - 0s - loss: 0.0363 - 212ms/epoch - 2ms/step
# Epoch 261/300
# 138/138 - 0s - loss: 0.0363 - 200ms/epoch - 1ms/step
# Epoch 262/300
# 138/138 - 0s - loss: 0.0363 - 213ms/epoch - 2ms/step
# Epoch 263/300
# 138/138 - 0s - loss: 0.0363 - 200ms/epoch - 1ms/step
# Epoch 264/300
# 138/138 - 0s - loss: 0.0363 - 214ms/epoch - 2ms/step
# Epoch 265/300
# 138/138 - 0s - loss: 0.0363 - 260ms/epoch - 2ms/step
# Epoch 266/300
# 138/138 - 0s - loss: 0.0362 - 269ms/epoch - 2ms/step
# Epoch 267/300
# 138/138 - 0s - loss: 0.0362 - 251ms/epoch - 2ms/step
# Epoch 268/300
# 138/138 - 0s - loss: 0.0362 - 222ms/epoch - 2ms/step
# Epoch 269/300
# 138/138 - 0s - loss: 0.0362 - 242ms/epoch - 2ms/step
# Epoch 270/300
# 138/138 - 0s - loss: 0.0362 - 240ms/epoch - 2ms/step
# Epoch 271/300
# 138/138 - 0s - loss: 0.0362 - 224ms/epoch - 2ms/step
# Epoch 272/300
# ...
# Epoch 142/300
# 138/138 - 0s - loss: 0.0388 - 238ms/epoch - 2ms/step
# Epoch 143/300
# 138/138 - 0s - loss: 0.0387 - 240ms/epoch - 2ms/step
# Epoch 144/300
# 138/138 - 0s - loss: 0.0387 - 256ms/epoch - 2ms/step
# Epoch 145/300
# 138/138 - 0s - loss: 0.0387 - 240ms/epoch - 2ms/step
# Epoch 146/300
# 138/138 - 0s - loss: 0.0386 - 240ms/epoch - 2ms/step
# Epoch 147/300
# 138/138 - 0s - loss: 0.0386 - 239ms/epoch - 2ms/step
# Epoch 148/300
# 138/138 - 0s - loss: 0.0386 - 240ms/epoch - 2ms/step
# Epoch 149/300
# 138/138 - 0s - loss: 0.0385 - 240ms/epoch - 2ms/step
# Epoch 150/300
# 138/138 - 0s - loss: 0.0385 - 241ms/epoch - 2ms/step
# Epoch 151/300
# 138/138 - 0s - loss: 0.0384 - 239ms/epoch - 2ms/step
# Epoch 152/300
# 138/138 - 0s - loss: 0.0384 - 238ms/epoch - 2ms/step
# Epoch 153/300
# 138/138 - 0s - loss: 0.0384 - 240ms/epoch - 2ms/step
# Epoch 154/300
# 138/138 - 0s - loss: 0.0383 - 239ms/epoch - 2ms/step
# Epoch 155/300
# 138/138 - 0s - loss: 0.0383 - 257ms/epoch - 2ms/step
# Epoch 156/300
# 138/138 - 0s - loss: 0.0383 - 238ms/epoch - 2ms/step
# Epoch 157/300
# 138/138 - 0s - loss: 0.0382 - 240ms/epoch - 2ms/step
# Epoch 158/300
# 138/138 - 0s - loss: 0.0382 - 240ms/epoch - 2ms/step
# Epoch 159/300
# 138/138 - 0s - loss: 0.0382 - 240ms/epoch - 2ms/step
# Epoch 160/300
# 138/138 - 0s - loss: 0.0382 - 238ms/epoch - 2ms/step
# Epoch 161/300
# 138/138 - 0s - loss: 0.0381 - 253ms/epoch - 2ms/step
# Epoch 162/300
# 138/138 - 0s - loss: 0.0381 - 227ms/epoch - 2ms/step
# Epoch 163/300
# 138/138 - 0s - loss: 0.0381 - 240ms/epoch - 2ms/step
# Epoch 164/300
# 138/138 - 0s - loss: 0.0380 - 239ms/epoch - 2ms/step
# Epoch 165/300
# 138/138 - 0s - loss: 0.0380 - 255ms/epoch - 2ms/step
# Epoch 166/300
# 138/138 - 0s - loss: 0.0380 - 300ms/epoch - 2ms/step
# Epoch 167/300
# 138/138 - 0s - loss: 0.0379 - 307ms/epoch - 2ms/step
# Epoch 168/300
# 138/138 - 0s - loss: 0.0379 - 293ms/epoch - 2ms/step
# Epoch 169/300
# 138/138 - 0s - loss: 0.0379 - 278ms/epoch - 2ms/step
# Epoch 170/300
# 138/138 - 0s - loss: 0.0378 - 262ms/epoch - 2ms/step
# Epoch 171/300
# 138/138 - 0s - loss: 0.0378 - 285ms/epoch - 2ms/step
# Epoch 172/300
# 138/138 - 0s - loss: 0.0378 - 293ms/epoch - 2ms/step
# Epoch 173/300
# 138/138 - 0s - loss: 0.0377 - 233ms/epoch - 2ms/step
# Epoch 174/300
# 138/138 - 0s - loss: 0.0377 - 287ms/epoch - 2ms/step
# Epoch 175/300
# 138/138 - 0s - loss: 0.0377 - 231ms/epoch - 2ms/step
# Epoch 176/300
# 138/138 - 0s - loss: 0.0376 - 256ms/epoch - 2ms/step
# Epoch 177/300
# 138/138 - 0s - loss: 0.0376 - 249ms/epoch - 2ms/step
# Epoch 178/300
# 138/138 - 0s - loss: 0.0376 - 254ms/epoch - 2ms/step
# Epoch 179/300
# 138/138 - 0s - loss: 0.0376 - 299ms/epoch - 2ms/step
# Epoch 180/300
# 138/138 - 0s - loss: 0.0375 - 276ms/epoch - 2ms/step
# Epoch 181/300
# 138/138 - 0s - loss: 0.0375 - 282ms/epoch - 2ms/step
# Epoch 182/300
# 138/138 - 0s - loss: 0.0375 - 293ms/epoch - 2ms/step
# Epoch 183/300
# 138/138 - 0s - loss: 0.0374 - 262ms/epoch - 2ms/step
# Epoch 184/300
# 138/138 - 0s - loss: 0.0374 - 269ms/epoch - 2ms/step
# Epoch 185/300
# 138/138 - 0s - loss: 0.0374 - 249ms/epoch - 2ms/step
# Epoch 186/300
# 138/138 - 0s - loss: 0.0373 - 241ms/epoch - 2ms/step
# Epoch 187/300
# 138/138 - 0s - loss: 0.0373 - 239ms/epoch - 2ms/step
# Epoch 188/300
# 138/138 - 0s - loss: 0.0373 - 240ms/epoch - 2ms/step
# Epoch 189/300
# 138/138 - 0s - loss: 0.0372 - 240ms/epoch - 2ms/step
# Epoch 190/300
# 138/138 - 0s - loss: 0.0372 - 238ms/epoch - 2ms/step
# Epoch 191/300
# 138/138 - 0s - loss: 0.0372 - 240ms/epoch - 2ms/step
# Epoch 192/300
# 138/138 - 0s - loss: 0.0372 - 240ms/epoch - 2ms/step
# Epoch 193/300
# 138/138 - 0s - loss: 0.0371 - 240ms/epoch - 2ms/step
# Epoch 194/300
# 138/138 - 0s - loss: 0.0371 - 238ms/epoch - 2ms/step
# Epoch 195/300
# 138/138 - 0s - loss: 0.0371 - 240ms/epoch - 2ms/step
# Epoch 196/300
# 138/138 - 0s - loss: 0.0370 - 257ms/epoch - 2ms/step
# Epoch 197/300
# 138/138 - 0s - loss: 0.0370 - 237ms/epoch - 2ms/step
# Epoch 198/300
# 138/138 - 0s - loss: 0.0370 - 255ms/epoch - 2ms/step
# Epoch 199/300
# 138/138 - 0s - loss: 0.0370 - 238ms/epoch - 2ms/step
# Epoch 200/300
# 138/138 - 0s - loss: 0.0369 - 240ms/epoch - 2ms/step
# Epoch 201/300
# 138/138 - 0s - loss: 0.0369 - 255ms/epoch - 2ms/step
# Epoch 202/300
# 138/138 - 0s - loss: 0.0369 - 238ms/epoch - 2ms/step
# Epoch 203/300
# 138/138 - 0s - loss: 0.0369 - 255ms/epoch - 2ms/step
# Epoch 204/300
# 138/138 - 0s - loss: 0.0368 - 251ms/epoch - 2ms/step
# Epoch 205/300
# 138/138 - 0s - loss: 0.0368 - 240ms/epoch - 2ms/step
# Epoch 206/300
# 138/138 - 0s - loss: 0.0368 - 240ms/epoch - 2ms/step
# Epoch 207/300
# 138/138 - 0s - loss: 0.0368 - 254ms/epoch - 2ms/step
# Epoch 208/300
# 138/138 - 0s - loss: 0.0367 - 240ms/epoch - 2ms/step
# Epoch 209/300
# 138/138 - 0s - loss: 0.0367 - 240ms/epoch - 2ms/step
# Epoch 210/300
# 138/138 - 0s - loss: 0.0367 - 240ms/epoch - 2ms/step
# Epoch 211/300
# 138/138 - 0s - loss: 0.0367 - 240ms/epoch - 2ms/step
# Epoch 212/300
# 138/138 - 0s - loss: 0.0366 - 238ms/epoch - 2ms/step
# Epoch 213/300
# 138/138 - 0s - loss: 0.0366 - 240ms/epoch - 2ms/step
# Epoch 214/300
# 138/138 - 0s - loss: 0.0366 - 240ms/epoch - 2ms/step
# Epoch 215/300
# 138/138 - 0s - loss: 0.0366 - 240ms/epoch - 2ms/step
# Epoch 216/300
# 138/138 - 0s - loss: 0.0365 - 238ms/epoch - 2ms/step
# Epoch 217/300
# 138/138 - 0s - loss: 0.0365 - 241ms/epoch - 2ms/step
# Epoch 218/300
# 138/138 - 0s - loss: 0.0365 - 239ms/epoch - 2ms/step
# Epoch 219/300
# 138/138 - 0s - loss: 0.0365 - 256ms/epoch - 2ms/step
# Epoch 220/300
# 138/138 - 0s - loss: 0.0364 - 238ms/epoch - 2ms/step
# Epoch 221/300
# 138/138 - 0s - loss: 0.0364 - 241ms/epoch - 2ms/step
# Epoch 222/300
# 138/138 - 0s - loss: 0.0364 - 254ms/epoch - 2ms/step
# Epoch 223/300
# 138/138 - 0s - loss: 0.0364 - 238ms/epoch - 2ms/step
# Epoch 224/300
# 138/138 - 0s - loss: 0.0363 - 240ms/epoch - 2ms/step
# Epoch 225/300
# 138/138 - 0s - loss: 0.0363 - 271ms/epoch - 2ms/step
# Epoch 226/300
# 138/138 - 0s - loss: 0.0363 - 267ms/epoch - 2ms/step
# Epoch 227/300
# 138/138 - 0s - loss: 0.0363 - 249ms/epoch - 2ms/step
# Epoch 228/300
# 138/138 - 0s - loss: 0.0363 - 255ms/epoch - 2ms/step
# Epoch 229/300
# 138/138 - 0s - loss: 0.0362 - 316ms/epoch - 2ms/step
# Epoch 230/300
# 138/138 - 0s - loss: 0.0362 - 336ms/epoch - 2ms/step
# Epoch 231/300
# 138/138 - 0s - loss: 0.0362 - 318ms/epoch - 2ms/step
# Epoch 232/300
# 138/138 - 0s - loss: 0.0362 - 320ms/epoch - 2ms/step
# Epoch 233/300
# 138/138 - 0s - loss: 0.0361 - 289ms/epoch - 2ms/step
# Epoch 234/300
# 138/138 - 0s - loss: 0.0361 - 247ms/epoch - 2ms/step
# Epoch 235/300
# 138/138 - 0s - loss: 0.0361 - 240ms/epoch - 2ms/step
# Epoch 236/300
# 138/138 - 0s - loss: 0.0361 - 253ms/epoch - 2ms/step
# Epoch 237/300
# 138/138 - 0s - loss: 0.0361 - 240ms/epoch - 2ms/step
# Epoch 238/300
# 138/138 - 0s - loss: 0.0360 - 240ms/epoch - 2ms/step
# Epoch 239/300
# 138/138 - 0s - loss: 0.0360 - 240ms/epoch - 2ms/step
# Epoch 240/300
# 138/138 - 0s - loss: 0.0360 - 224ms/epoch - 2ms/step
# Epoch 241/300
# 138/138 - 0s - loss: 0.0360 - 239ms/epoch - 2ms/step
# Epoch 242/300
# 138/138 - 0s - loss: 0.0359 - 239ms/epoch - 2ms/step
# Epoch 243/300
# 138/138 - 0s - loss: 0.0359 - 240ms/epoch - 2ms/step
# Epoch 244/300
# 138/138 - 0s - loss: 0.0359 - 240ms/epoch - 2ms/step
# Epoch 245/300
# 138/138 - 0s - loss: 0.0359 - 240ms/epoch - 2ms/step
# Epoch 246/300
# 138/138 - 0s - loss: 0.0359 - 240ms/epoch - 2ms/step
# Epoch 247/300
# 138/138 - 0s - loss: 0.0358 - 238ms/epoch - 2ms/step
# Epoch 248/300
# 138/138 - 0s - loss: 0.0358 - 241ms/epoch - 2ms/step
# Epoch 249/300
# 138/138 - 0s - loss: 0.0358 - 239ms/epoch - 2ms/step
# Epoch 250/300
# 138/138 - 0s - loss: 0.0358 - 240ms/epoch - 2ms/step
# Epoch 251/300
# 138/138 - 0s - loss: 0.0358 - 238ms/epoch - 2ms/step
# Epoch 252/300
# 138/138 - 0s - loss: 0.0357 - 240ms/epoch - 2ms/step
# Epoch 253/300
# 138/138 - 0s - loss: 0.0357 - 241ms/epoch - 2ms/step
# Epoch 254/300
# 138/138 - 0s - loss: 0.0357 - 255ms/epoch - 2ms/step
# Epoch 255/300
# 138/138 - 0s - loss: 0.0357 - 240ms/epoch - 2ms/step
# Epoch 256/300
# 138/138 - 0s - loss: 0.0357 - 240ms/epoch - 2ms/step
# Epoch 257/300
# 138/138 - 0s - loss: 0.0356 - 239ms/epoch - 2ms/step
# Epoch 258/300
# 138/138 - 0s - loss: 0.0356 - 239ms/epoch - 2ms/step
# Epoch 259/300
# 138/138 - 0s - loss: 0.0356 - 240ms/epoch - 2ms/step
# Epoch 260/300
# 138/138 - 0s - loss: 0.0356 - 240ms/epoch - 2ms/step
# Epoch 261/300
# 138/138 - 0s - loss: 0.0356 - 240ms/epoch - 2ms/step
# Epoch 262/300
# 138/138 - 0s - loss: 0.0355 - 238ms/epoch - 2ms/step
# Epoch 263/300
# 138/138 - 0s - loss: 0.0355 - 240ms/epoch - 2ms/step
# Epoch 264/300
# 138/138 - 0s - loss: 0.0355 - 240ms/epoch - 2ms/step
# Epoch 265/300
# 138/138 - 0s - loss: 0.0355 - 238ms/epoch - 2ms/step
# Epoch 266/300
# 138/138 - 0s - loss: 0.0355 - 227ms/epoch - 2ms/step
# Epoch 267/300
# 138/138 - 0s - loss: 0.0354 - 240ms/epoch - 2ms/step
# Epoch 268/300
# 138/138 - 0s - loss: 0.0354 - 240ms/epoch - 2ms/step
# Epoch 269/300
# 138/138 - 0s - loss: 0.0354 - 240ms/epoch - 2ms/step
# Epoch 270/300
# 138/138 - 0s - loss: 0.0354 - 239ms/epoch - 2ms/step
# Epoch 271/300
# 138/138 - 0s - loss: 0.0354 - 239ms/epoch - 2ms/step
# Epoch 272/300
# 138/138 - 0s - loss: 0.0354 - 255ms/epoch - 2ms/step
# Epoch 273/300
# 138/138 - 0s - loss: 0.0353 - 253ms/epoch - 2ms/step
# Epoch 274/300
# 138/138 - 0s - loss: 0.0353 - 239ms/epoch - 2ms/step
# Epoch 275/300
# 138/138 - 0s - loss: 0.0353 - 239ms/epoch - 2ms/step
# Epoch 276/300
# 138/138 - 0s - loss: 0.0353 - 240ms/epoch - 2ms/step
# Epoch 277/300
# 138/138 - 0s - loss: 0.0353 - 240ms/epoch - 2ms/step
# Epoch 278/300
# 138/138 - 0s - loss: 0.0353 - 238ms/epoch - 2ms/step
# Epoch 279/300
# 138/138 - 0s - loss: 0.0352 - 240ms/epoch - 2ms/step
# Epoch 280/300
# 138/138 - 0s - loss: 0.0352 - 239ms/epoch - 2ms/step
# Epoch 281/300
# 138/138 - 0s - loss: 0.0352 - 242ms/epoch - 2ms/step
# Epoch 282/300
# 138/138 - 0s - loss: 0.0352 - 239ms/epoch - 2ms/step
# Epoch 283/300
# 138/138 - 0s - loss: 0.0352 - 238ms/epoch - 2ms/step
# Epoch 284/300
# 138/138 - 0s - loss: 0.0352 - 256ms/epoch - 2ms/step
# Epoch 285/300
# 138/138 - 0s - loss: 0.0351 - 240ms/epoch - 2ms/step
# Epoch 286/300
# 138/138 - 0s - loss: 0.0351 - 238ms/epoch - 2ms/step
# Epoch 287/300
# 138/138 - 0s - loss: 0.0351 - 241ms/epoch - 2ms/step
# Epoch 288/300
# 138/138 - 0s - loss: 0.0351 - 239ms/epoch - 2ms/step
# Epoch 289/300
# 138/138 - 0s - loss: 0.0351 - 253ms/epoch - 2ms/step
# Epoch 290/300
# 138/138 - 0s - loss: 0.0351 - 238ms/epoch - 2ms/step
# Epoch 291/300
# 138/138 - 0s - loss: 0.0351 - 241ms/epoch - 2ms/step
# Epoch 292/300
# 138/138 - 0s - loss: 0.0350 - 255ms/epoch - 2ms/step
# Epoch 293/300
# 138/138 - 0s - loss: 0.0350 - 238ms/epoch - 2ms/step
# Epoch 294/300
# 138/138 - 0s - loss: 0.0350 - 249ms/epoch - 2ms/step
# Epoch 295/300
# 138/138 - 0s - loss: 0.0350 - 245ms/epoch - 2ms/step
# Epoch 296/300
# 138/138 - 0s - loss: 0.0350 - 242ms/epoch - 2ms/step
# Epoch 297/300
# 138/138 - 0s - loss: 0.0350 - 239ms/epoch - 2ms/step
# Epoch 298/300
# 138/138 - 0s - loss: 0.0350 - 239ms/epoch - 2ms/step
# Epoch 299/300
# 138/138 - 0s - loss: 0.0349 - 240ms/epoch - 2ms/step
# Epoch 300/300
# 138/138 - 0s - loss: 0.0349 - 255ms/epoch - 2ms/step
# 9/9 [==============================] - 0s 2ms/step
# Epoch 1/300
# 138/138 - 2s - loss: 0.3073 - 2s/epoch - 17ms/step
# Epoch 2/300
# 138/138 - 0s - loss: 0.0417 - 249ms/epoch - 2ms/step
# Epoch 3/300
# 138/138 - 0s - loss: 0.0437 - 254ms/epoch - 2ms/step
# Epoch 4/300
# 138/138 - 0s - loss: 0.0444 - 253ms/epoch - 2ms/step
# Epoch 5/300
# 138/138 - 0s - loss: 0.0448 - 253ms/epoch - 2ms/step
# Epoch 6/300
# 138/138 - 0s - loss: 0.0449 - 253ms/epoch - 2ms/step
# Epoch 7/300
# 138/138 - 0s - loss: 0.0450 - 239ms/epoch - 2ms/step
# Epoch 8/300
# 138/138 - 0s - loss: 0.0450 - 253ms/epoch - 2ms/step
# Epoch 9/300
# 138/138 - 0s - loss: 0.0450 - 253ms/epoch - 2ms/step
# Epoch 10/300
# 138/138 - 0s - loss: 0.0450 - 253ms/epoch - 2ms/step
# Epoch 11/300
# 138/138 - 0s - loss: 0.0449 - 253ms/epoch - 2ms/step
# Epoch 12/300
# 138/138 - 0s - loss: 0.0449 - 253ms/epoch - 2ms/step
# 9/9 [==============================] - 0s 4ms/step
# Epoch 1/300
# 138/138 - 2s - loss: 0.3792 - 2s/epoch - 18ms/step
# Epoch 2/300
# 138/138 - 0s - loss: 0.0416 - 260ms/epoch - 2ms/step
# Epoch 3/300
# 138/138 - 0s - loss: 0.0440 - 254ms/epoch - 2ms/step
# Epoch 4/300
# 138/138 - 0s - loss: 0.0447 - 253ms/epoch - 2ms/step
# Epoch 5/300
# 138/138 - 0s - loss: 0.0451 - 251ms/epoch - 2ms/step
# Epoch 6/300
# 138/138 - 0s - loss: 0.0452 - 256ms/epoch - 2ms/step
# Epoch 7/300
# 138/138 - 0s - loss: 0.0453 - 253ms/epoch - 2ms/step
# Epoch 8/300
# 138/138 - 0s - loss: 0.0453 - 253ms/epoch - 2ms/step
# Epoch 9/300
# 138/138 - 0s - loss: 0.0454 - 253ms/epoch - 2ms/step
# Epoch 10/300
# 138/138 - 0s - loss: 0.0454 - 251ms/epoch - 2ms/step
# Epoch 11/300
# 138/138 - 0s - loss: 0.0454 - 253ms/epoch - 2ms/step
# Epoch 12/300
# 138/138 - 0s - loss: 0.0454 - 254ms/epoch - 2ms/step
# 9/9 [==============================] - 0s 3ms/step
# Epoch 1/300
# 138/138 - 3s - loss: 0.0427 - 3s/epoch - 19ms/step
# Epoch 2/300
# 138/138 - 0s - loss: 0.0443 - 253ms/epoch - 2ms/step
# Epoch 3/300
# 138/138 - 0s - loss: 0.0443 - 269ms/epoch - 2ms/step
# Epoch 4/300
# 138/138 - 0s - loss: 0.0446 - 252ms/epoch - 2ms/step
# Epoch 5/300
# 138/138 - 0s - loss: 0.0449 - 262ms/epoch - 2ms/step
# Epoch 6/300
# 138/138 - 0s - loss: 0.0451 - 256ms/epoch - 2ms/step
# Epoch 7/300
# 138/138 - 0s - loss: 0.0452 - 269ms/epoch - 2ms/step
# Epoch 8/300
# 138/138 - 0s - loss: 0.0452 - 267ms/epoch - 2ms/step
# Epoch 9/300
# 138/138 - 0s - loss: 0.0452 - 251ms/epoch - 2ms/step
# Epoch 10/300
# 138/138 - 0s - loss: 0.0451 - 269ms/epoch - 2ms/step
# Epoch 11/300
# 138/138 - 0s - loss: 0.0450 - 252ms/epoch - 2ms/step
# 9/9 [==============================] - 0s 2ms/step
# Epoch 1/300
# 138/138 - 3s - loss: 1.0657 - 3s/epoch - 22ms/step
# Epoch 2/300
# 138/138 - 0s - loss: 0.0441 - 279ms/epoch - 2ms/step
# Epoch 3/300
# 138/138 - 0s - loss: 0.0411 - 270ms/epoch - 2ms/step
# Epoch 4/300
# 138/138 - 0s - loss: 0.0424 - 279ms/epoch - 2ms/step
# Epoch 5/300
# 138/138 - 0s - loss: 0.0432 - 264ms/epoch - 2ms/step
# Epoch 6/300
# 138/138 - 0s - loss: 0.0438 - 282ms/epoch - 2ms/step
# Epoch 7/300
# 138/138 - 0s - loss: 0.0442 - 266ms/epoch - 2ms/step
# Epoch 8/300
# 138/138 - 0s - loss: 0.0445 - 280ms/epoch - 2ms/step
# Epoch 9/300
# 138/138 - 0s - loss: 0.0448 - 267ms/epoch - 2ms/step
# Epoch 10/300
# 138/138 - 0s - loss: 0.0449 - 280ms/epoch - 2ms/step
# Epoch 11/300
# 138/138 - 0s - loss: 0.0450 - 268ms/epoch - 2ms/step
# Epoch 12/300
# 138/138 - 0s - loss: 0.0451 - 279ms/epoch - 2ms/step
# Epoch 13/300
# 138/138 - 0s - loss: 0.0451 - 283ms/epoch - 2ms/step
# 9/9 [==============================] - 0s 2ms/step
# Epoch 1/300
# 138/138 - 3s - loss: 0.1449 - 3s/epoch - 21ms/step
# Epoch 2/300
# 138/138 - 0s - loss: 0.0450 - 278ms/epoch - 2ms/step
# Epoch 3/300
# 138/138 - 0s - loss: 0.0453 - 282ms/epoch - 2ms/step
# Epoch 4/300
# 138/138 - 0s - loss: 0.0451 - 279ms/epoch - 2ms/step
# Epoch 5/300
# 138/138 - 0s - loss: 0.0449 - 264ms/epoch - 2ms/step
# Epoch 6/300
# 138/138 - 0s - loss: 0.0449 - 296ms/epoch - 2ms/step
# Epoch 7/300
# 138/138 - 0s - loss: 0.0449 - 265ms/epoch - 2ms/step
# Epoch 8/300
# 138/138 - 0s - loss: 0.0449 - 263ms/epoch - 2ms/step
# Epoch 9/300
# 138/138 - 0s - loss: 0.0450 - 280ms/epoch - 2ms/step
# Epoch 10/300
# 138/138 - 0s - loss: 0.0451 - 295ms/epoch - 2ms/step
# Epoch 11/300
# 138/138 - 0s - loss: 0.0451 - 280ms/epoch - 2ms/step
# Epoch 12/300
# 138/138 - 0s - loss: 0.0452 - 280ms/epoch - 2ms/step
# Epoch 13/300
# 138/138 - 0s - loss: 0.0452 - 280ms/epoch - 2ms/step
# Epoch 14/300
# 138/138 - 0s - loss: 0.0453 - 266ms/epoch - 2ms/step
# Epoch 15/300
# 138/138 - 0s - loss: 0.0453 - 342ms/epoch - 2ms/step
# Epoch 16/300
# 138/138 - 0s - loss: 0.0453 - 300ms/epoch - 2ms/step
# 9/9 [==============================] - 0s 4ms/step
# Epoch 1/300
# 138/138 - 3s - loss: 0.1450 - 3s/epoch - 24ms/step
# Epoch 2/300
# 138/138 - 0s - loss: 0.0435 - 322ms/epoch - 2ms/step
# Epoch 3/300
# 138/138 - 0s - loss: 0.0445 - 273ms/epoch - 2ms/step
# Epoch 4/300
# 138/138 - 0s - loss: 0.0449 - 280ms/epoch - 2ms/step
# Epoch 5/300
# 138/138 - 0s - loss: 0.0449 - 282ms/epoch - 2ms/step
# Epoch 6/300
# 138/138 - 0s - loss: 0.0449 - 280ms/epoch - 2ms/step
# Epoch 7/300
# 138/138 - 0s - loss: 0.0449 - 278ms/epoch - 2ms/step
# Epoch 8/300
# 138/138 - 0s - loss: 0.0448 - 267ms/epoch - 2ms/step
# Epoch 9/300
# 138/138 - 0s - loss: 0.0447 - 282ms/epoch - 2ms/step
# Epoch 10/300
# 138/138 - 0s - loss: 0.0446 - 280ms/epoch - 2ms/step
# Epoch 11/300
# 138/138 - 0s - loss: 0.0445 - 280ms/epoch - 2ms/step
# Epoch 12/300
# 138/138 - 0s - loss: 0.0444 - 279ms/epoch - 2ms/step
# 9/9 [==============================] - 0s 3ms/step

# %%
df_MseWith_HiddenLayer
# Out:
#     Numer Hidden Layer  Neural Hidden  Batch_Size  Epoch       MSE  \
# 0                  1.0           17.0         8.0  300.0  0.000053
# 1                  2.0           17.0         8.0  300.0  0.000401
# 2                  3.0           17.0         8.0  300.0  0.000150
# 3                  4.0           17.0         8.0  300.0  0.012003
# 4                  5.0           17.0         8.0  300.0  0.003132
# 5                  6.0           17.0         8.0  300.0  0.014398
# 6                  7.0           17.0         8.0  300.0  0.013524
# 7                  8.0           17.0         8.0  300.0  0.012652
# 8                  9.0           17.0         8.0  300.0  0.014452
# 9                 10.0           17.0         8.0  300.0  0.058525
# 10                11.0           17.0         8.0  300.0  0.062236
# 11                12.0           17.0         8.0  300.0  0.012203
# 12                13.0           17.0         8.0  300.0  0.068190
# 13                14.0           17.0         8.0  300.0  0.065104
# 14                15.0           17.0         8.0  300.0  0.012719
# 15                16.0           17.0         8.0  300.0  0.010791
# 16                17.0           17.0         8.0  300.0  0.012303
# 17                18.0           17.0         8.0  300.0  0.011779
# 18                19.0           17.0         8.0  300.0  0.011006
# 19                20.0           17.0         8.0  300.0  0.014233
#
#     Time Train  Time Test  Total Time
# 0    58.732235   0.199588   58.931823
# 1    11.901498   0.238217   12.139715
# 2    61.914838   0.207903   62.122741
# 3     4.402402   0.230565    4.632967
# 4    16.142950   0.257780   16.400729
# 5     4.954020   0.300262    5.254282
# 6     4.134980   0.376472    4.511452
# 7     5.977040   0.329512    6.306551
# 8     5.125425   0.456413    5.581837
# 9    66.295928   0.266703   66.562631
# 10   68.681278   0.270054   68.951333
# 11    4.400235   0.295805    4.696040
# 12   72.866081   0.306441   73.172522
# 13   76.315366   0.588854   76.904220
# 14    5.377645   0.338110    5.715755
# 15    5.518989   0.355122    5.874110
# 16    5.461719   0.382328    5.844047
# 17    6.535331   0.378796    6.914127
# 18    7.481052   0.521319    8.002371
# 19    6.706863   0.466316    7.173180

# %%
plt.title("Biểu đồ Tập Dữ Liệu "+nameData)
plt.plot(readData(filePath), label= nameData+'Stock')
plt.xlabel("Ngày")
plt.ylabel("Giá Cổ Phiếu")
plt.legend()
plt.show()

# %%
# Vẽ biểu đồ
plt.plot(range(1,len(df_MseWith_HiddenLayer[['MSE']])+1), df_MseWith_HiddenLayer[['MSE']])
plt.title("Biểu đồ MSE Theo Số Lượng Lớp Ẩn Tập Dữ Liệu "+nameData)
plt.xlabel("Số Lớp Ẩn")
plt.ylabel("MSE")
plt.xticks(range(1,len(df_MseWith_HiddenLayer[['MSE']])+1))
plt.show()

# %%
df_MseWith_HiddenLayer_Sort = df_MseWith_HiddenLayer.sort_values('MSE')
best_NumberHiddenLayer=df_MseWith_HiddenLayer_Sort['Numer Hidden Layer'].iloc[0]

# %%
df_MseWith_HiddenLayer_Sort
# Out:
#     Numer Hidden Layer  Neural Hidden  Batch_Size  Epoch       MSE  \
# 0                  1.0           17.0         8.0  300.0  0.000053
# 2                  3.0           17.0         8.0  300.0  0.000150
# 1                  2.0           17.0         8.0  300.0  0.000401
# 4                  5.0           17.0         8.0  300.0  0.003132
# 15                16.0           17.0         8.0  300.0  0.010791
# 18                19.0           17.0         8.0  300.0  0.011006
# 17                18.0           17.0         8.0  300.0  0.011779
# 3                  4.0           17.0         8.0  300.0  0.012003
# 11                12.0           17.0         8.0  300.0  0.012203
# 16                17.0           17.0         8.0  300.0  0.012303
# 7                  8.0           17.0         8.0  300.0  0.012652
# 14                15.0           17.0         8.0  300.0  0.012719
# 6                  7.0           17.0         8.0  300.0  0.013524
# 19                20.0           17.0         8.0  300.0  0.014233
# 5                  6.0           17.0         8.0  300.0  0.014398
# 8                  9.0           17.0         8.0  300.0  0.014452
# 9                 10.0           17.0         8.0  300.0  0.058525
# 10                11.0           17.0         8.0  300.0  0.062236
# 13                14.0           17.0         8.0  300.0  0.065104
# 12                13.0           17.0         8.0  300.0  0.068190
#
#     Time Train  Time Test  Total Time
# 0    58.732235   0.199588   58.931823
# 2    61.914838   0.207903   62.122741
# 1    11.901498   0.238217   12.139715
# 4    16.142950   0.257780   16.400729
# 15    5.518989   0.355122    5.874110
# 18    7.481052   0.521319    8.002371
# 17    6.535331   0.378796    6.914127
# 3     4.402402   0.230565    4.632967
# 11    4.400235   0.295805    4.696040
# 16    5.461719   0.382328    5.844047
# 7     5.977040   0.329512    6.306551
# 14    5.377645   0.338110    5.715755
# 6     4.134980   0.376472    4.511452
# 19    6.706863   0.466316    7.173180
# 5     4.954020   0.300262    5.254282
# 8     5.125425   0.456413    5.581837
# 9    66.295928   0.266703   66.562631
# 10   68.681278   0.270054   68.951333
# 13   76.315366   0.588854   76.904220
# 12   72.866081   0.306441   73.172522

# %%
best_NumberHiddenLayer
# Out:
# 1.0

# %%
# Vẽ biểu đồ
best_param = {'batch_size': int(df_MseWith_HiddenLayer_Sort['Batch_Size'].iloc[0]),
              'epochs': int(df_MseWith_HiddenLayer_Sort['Epoch'].iloc[0]),
              'neuralHidden': int(df_MseWith_HiddenLayer_Sort['Neural Hidden'].iloc[0]),
              'num_layers_hidden' :int(df_MseWith_HiddenLayer_Sort['Numer Hidden Layer'].iloc[0]),
              'neuralInput' : size_window,
              'neuralOutput' : size_predict}
y_pred= predict_FFNN(nameData, 'FFNN_Find_NumberHiddenLayer', X_train, y_train, X_test, best_param)

plt.title("Biểu đồ Dự Đoán FFNN Với Số Lớp Ẩn Tốt Nhất Trên Tập Dữ Liệu "+nameData)
plt.plot(y_pred, label=nameData+' Prediction Stock')
plt.plot(y_test, label=nameData+' Actual Stock')
plt.xlabel("Ngày")
plt.ylabel("Giá Cổ Phiếu")
plt.legend()
plt.show()
# Out:
# 9/9 [==============================] - 0s 2ms/step

# %%
print("MSE: " + str(mean_squared_error(y_test , y_pred)))
print("RMSE: " + str(sqrt(mean_squared_error(y_test, y_pred)) ))
print("MAE: " + str(mean_absolute_error(y_test,y_pred)))
print("MAPE: " + str(mean_absolute_percentage_error(y_test, y_pred)))
# Out:
# MSE: 5.345068852233224e-05
# RMSE: 0.007310997778848811
# MAE: 0.004643256633421447
# MAPE: 423807078551.7528

# %% [markdown]
# # Load Predict

# %%
# neural=17
# batch_size=8
# epochs=300

# nameData= 'MDLY'
# filePath= '../../Dataset/'+nameData+'.csv'
# timeSeries = readData(filePath)
# timeSeries = cleanData(timeSeries)
# percentTrain = 80
# train_data, test_data = splitData(timeSeries, percentTrain)

# size_window = 7
# size_predict=1
# stepWindow=1
# X_train, y_train = prepare_data(train_data.values, size_window, size_predict, stepWindow)
# X_test, y_test =   prepare_data(test_data.values, size_window, size_predict, stepWindow)

# numHiddenLayer= range(1,21)

# df_MseWith_HiddenLayer = pd.DataFrame([],  columns =  ["Number Hidden Layer","Neural Hidden","Batch_Size","Epoch", "MSE"])

# for i in range(len(numHiddenLayer)):

#     best_param = {'batch_size': batch_size,
#               'epochs': epochs,
#               'neuralHidden': neural,
#               'num_layers_hidden' : numHiddenLayer[i],
#               'neuralInput' : size_window,
#               'neuralOutput' : size_predict}
#     y_pred= predict_FFNN(nameData, 'FFNN_Find_NumberHiddenLayer', X_train, y_train, X_test, best_param)
#     rowMseWithHiddenLayer = pd.Series([numHiddenLayer[i],neural,batch_size,epochs, mean_squared_error(y_test , y_pred)], index=df_MseWith_HiddenLayer.columns)
#     df_MseWith_HiddenLayer = df_MseWith_HiddenLayer.append(rowMseWithHiddenLayer,ignore_index=True)
# df_MseWith_HiddenLayer_Sort = df_MseWith_HiddenLayer.sort_values('MSE')
# best_Neural=df_MseWith_HiddenLayer_Sort['Number Hidden Layer'].iloc[0]
# Out:
# 9/9 [==============================] - 0s 2ms/step
# 9/9 [==============================] - 0s 2ms/step
# 9/9 [==============================] - 0s 2ms/step
# 9/9 [==============================] - 0s 2ms/step
# 9/9 [==============================] - 0s 2ms/step
# 9/9 [==============================] - 0s 2ms/step
# 9/9 [==============================] - 0s 2ms/step
# 9/9 [==============================] - 0s 2ms/step
# 9/9 [==============================] - 0s 3ms/step
# 9/9 [==============================] - 0s 2ms/step
# 9/9 [==============================] - 0s 2ms/step
# 9/9 [==============================] - 0s 2ms/step
# 9/9 [==============================] - 0s 2ms/step
# 9/9 [==============================] - 0s 2ms/step
# 9/9 [==============================] - 0s 2ms/step
# 9/9 [==============================] - 0s 2ms/step
# 9/9 [==============================] - 0s 2ms/step
# 9/9 [==============================] - 0s 2ms/step
# 9/9 [==============================] - 0s 2ms/step
# 9/9 [==============================] - 0s 2ms/step

# %% [markdown]
# Thay thế các giá trị null bằng 0 .
#
# Loại bỏ các giá trị nhiễu bằng cách thay thế các giá trị nằm ngoài khoảng 3 độ lệch chuẩn của dữ liệu với giá trị trung bình của dữ liệu.
#
# MinMaxScaler để chuyển đổi dữ liệu thành phạm vi [0, 1]. Tiếp theo, chúng ta sử dụng
#
# Interpolate để điền vào các giá trị bị thiếu bằng cách lấy trung bình của các giá trị trước và sau đó.
#
#
# std() là một hàm trong Python để tính độ lệch chuẩn của một tập dữ liệu.
#
# Công thức tính độ lệch chuẩn của một tập dữ liệu là:
# σ = sqrt(1/n * Σ(xi - x_mean)^2)
#
# Ví dụ, nếu chúng ta có tập dữ liệu [2, 4, 6, 8], thì giá trị trung bình là 5, độ lệch của mỗi giá trị so với giá trị trung bình lần lượt là [-3, -1, 1, 3], giá trị bình phương độ lệch của mỗi giá trị so với giá trị trung bình lần lượt là [9, 1, 1, 9], đưa vào công thức độ lệch chuẩn
#  ==> σ = sqrt(1/4 * (9 + 1 + 1 + 9)) = sqrt(20/4) = sqrt(5) ≈ 2.236
