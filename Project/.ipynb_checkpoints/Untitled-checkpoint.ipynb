# %%
import numpy as np
import matplotlib.pyplot as plt
 
# set height of bar
barWidth = 0.15

KNN_Euclidean = [0.0002474798982734776, 
                 0.01573149383477226, 
                 0.012186641454806123, 
                 0.03486357338144327, 
                 0]

KNN_DTW = [0.0002473621424033079,
           0.015727750710235328, 
           0.012255461008795872, 
           0.03510270283651688, 
          0]

FFNN = [0.0001843628085087995, 
        0.013578026679484744, 
        0.010446183864461818, 
        0.030149090641055264, 
        0]

SongSong = [0.000000000000010565559496370996, 
            0.00000010278890745781374, 
            0.00000003821726750348727, 
            0.00000011373101214597885, 
            0]

TuanTu = [0.0003873327889920729,
          0.019680772062906294, 
          0.017074060771534127,
          0.049512814216894, 
          0]

# Set position of bar on X axis
br1 = np.arange(len(KNN_Euclidean))
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]
br4 = [x + barWidth for x in br3]
br5 = [x + barWidth for x in br4]

# Make the plot
plt.bar(br1, KNN_Euclidean, color ='r', width = barWidth,
        edgecolor ='grey', label ='Mô Hình KNN Euclidean')

plt.bar(br2, KNN_DTW, color ='black', width = barWidth,
        edgecolor ='grey', label ='Mô Hình KNN DTW')

plt.bar(br3, FFNN, color ='g', width = barWidth,
        edgecolor ='grey', label ='Mô Hình FFNN')
plt.bar(br4, SongSong, color ='b', width = barWidth,
        edgecolor ='grey', label ='Mô Hình Song Song')
plt.bar(br5, TuanTu, color ='y', width = barWidth,
        edgecolor ='grey', label ='Mô Hình Tuần Tự')
# Adding Xticks
plt.xlabel('Tiêu Chí Đánh Giá')
plt.xticks([r + barWidth for r in range(len(IT))],
        ['MSE', 'RMSE', 'MAE', 'MAPE', 'Time Test'])
 
plt.legend()
plt.show()
