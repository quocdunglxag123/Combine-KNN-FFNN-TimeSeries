# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
from numpy import sqrt 
import time

#Tien Xu Ly
from sklearn.preprocessing import MinMaxScaler

#Draw Flot
import matplotlib.pyplot as plt

#Cacuale error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error

#distance Libaray
from dtw import dtw
from scipy.spatial.distance import euclidean

#FFNN Libarary
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from sklearn.model_selection import GridSearchCV
from keras.wrappers.scikit_learn import KerasRegressor

# %%
# Đọc Dữ Liệu
# @param   filePath     Đường dẫn tập dữ liệu CSV
# @return  df           Tập dữ liệu csv dưới dạng df
def readData(filePath):
    # Load dữ liệu
    dataCSV = pd.read_csv(filePath)
    df=dataCSV[['Close']]
    return df

# Tiền Xử lý Dữ Liệu
# @param  Data   Tập dữ liệu
# @return df     Dữ liệu đã được tiền xử lý
def cleanData(df):
    # Replace null values with 0
    df.fillna(0, inplace=True)
    # Remove outliers by replacing values outside of 10 standard deviations with the mean
    std = df['Close'].std()
    mean = df['Close'].mean()
    df['Close'] = np.where(df['Close'] > (mean + 10*std), mean, df['Close'])
    df['Close'] = np.where(df['Close'] < (mean - 10*std), mean, df['Close'])
    # Scale data_AMZN to range [0, 1]
    scaler = MinMaxScaler()
    df['Close'] = scaler.fit_transform(df['Close'].values.reshape(-1, 1))
    # Fill in missing values with the mean of the previous and next values
    df['Close'] = df['Close'].interpolate(method='linear')
    return df

# Chia dữ liệu thành train set và test set
# @param  data                      Tập dữ liệu
# @param  percentTrain              Tỷ lệ Tập train
# @return train_data, test_data     Tập train và test   
def splitData(data, percentTrain):
    train_size = int(len(data) * (percentTrain/100))
    train = data.iloc[:train_size, :]
    test = data.iloc[train_size:, :]
    return train, test

# Xử lý dữ liệu thành dữ liệu đầu vào và đầu ra cho mô hình
# @param      data            Dữ liệu cần chia cửa sổ
# @param      size_window     Kích thước cửa sổ
# @param      size_predict    Kích thước cửa sổ dự đoán
# @param      stepWindow      số điểm dữ liệu trượt
# @return     X, y            mảng cửa sổ mẫu và mảng điểm dự đoán tương ứng
def prepare_data(data, size_window, size_predict, stepWindow):
    X, y = [], []
    startWindow = 0
    for i in range(len(data) - size_window - 1):
        if (len(data[(startWindow + size_window):(startWindow + size_window + size_predict) , 0]) != size_predict):
            break
        X.append(data[startWindow:(startWindow + size_window), :])
        y.append(data[(startWindow + size_window):(startWindow + size_window + size_predict) , 0])
        startWindow += stepWindow
    return np.array(X), np.array(y)

#---------KNN-----------
# Fucntion Tính khoảng cách giữa 2 chuỗi thời gian
# @param    ts1            Chuỗi thứ nhất
# @param    ts2            Chuỗi thứ hai
# @return   euclidean      Khoảng cách euclidean    
def euclidean_distance(ts1, ts2):
    ts1= ts1.flatten()
    ts2= ts2.flatten()
    return euclidean(ts1,ts2)

# Function lấy ra k chuỗi gần nhất
# @param    k             Số lượng chuỗi gần nhất
# @param    distanceArr   Mảng khoảng cách
# @return   argsort       Vị trí chuỗi gần nhất        
def kSimilarityTimeSeries(k, distanceArr):
    distances = np.array(distanceArr)
    return distances.argsort()[:k] 

# Tính khoảng cách DTW
# @param    ts1            Chuỗi thứ nhất
# @param    ts2            Chuỗi thứ hai
# @return   euclidean      Khoảng cách euclidean  
def dtw_dist(ts1, ts2):
    dist, _, _, _ = dtw(ts1, ts2, dist=lambda ts1, ts2: np.abs(ts1 - ts2))
    return dist

# Thêm Dữ liệu
# @param    X_train               Cửa sổ mẫu train
# @param    y_train               Cửa sổ dự đoán train
# @param    XTest                 Cửa sổ mẫu test
# @param    yTest                 Cửa sổ dự đoán test
# @return   X_train, y_train      Khoảng cách euclidean 
def toTrain(X_train, y_train, XTest, yTest):
    X_train.append(XTest)
    y_train.append(yTest)
    return np.array(X_train), np.array(y_train)

# Dự đoán Euclidean
# @param    nameData           Tên tập dữ liệu
# @param    k                  Số lượng chuỗi gần nhất
# @param    typeDistance       Độ đo sử dụng (Dtw, euclidean)
# @param    X_train            Cửa sổ mẫu train
# @param    y_train            Cửa sổ dự đoán train
# @param    X_test             Cửa sổ mẫu test
# @param    y_test             Cửa sổ dự đoán test
# @return   y_pred_arr         Mảng dự đoán
def predict_KNN(k, typeDistance, X_train, y_train, X_test, y_test):
    y_pred_arr=[]
    for iTest in range(len(X_test)):
        if(k>len(X_train)):
            k=len(X_train)
        distanceArr=[]
        for iTrain in range(len(X_train)-size_window+2):
            if(typeDistance == 'Dtw'):
                distance = dtw_dist(X_test[iTest],X_train[iTrain])
            else:
                distance = euclidean_distance(X_test[iTest],X_train[iTrain])
            distanceArr.append(distance)
        indexKNN= kSimilarityTimeSeries(k,distanceArr)
        y_pred = np.mean(y_train[indexKNN])
        y_pred_arr.append(y_pred)
        X_train, y_train = toTrain(X_train.tolist(), y_train.tolist(),X_test[iTest].tolist(), y_test[iTest].tolist())
        y_pred = np.array(y_pred_arr)
   
    return y_pred


#----------------FFNN--------------------------
# Khởi tạo mô hình FFNN
# @param    neuralInput         Kích thước Cửa sổ mẫu/ số neural lớp input
# @param    num_layers_hidden   Số lượng lớp ẩn
# @param    num_neural_hidden   Số neural lớp ẩn
# @param    neuralOutput         Số neural lớp ouput
# @return   model               Mô hình FFNN
def create_model_FFNN(neuralInput, num_layers_hidden=1, neuralHidden=1, neuralOutput=1):
    model = Sequential()
    for i in range(num_layers_hidden):
        if i == 0:
            model.add(Dense(neuralHidden, input_dim= neuralInput, activation='sigmoid'))
        else:
            model.add(Dense(neuralHidden, activation='sigmoid'))
    model.add(Dense(neuralOutput))
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model


# Train FFNN 
# @param    nameData          Tên tập dữ liệu
# @param    size_window       Kích thước Cửa sổ mẫu/ số neural lớp input
# @param    X_train           cửa sổ mẫu tập train
# @param    y_train           Cửa sổ dự đoán tập train
# @param    neuralHidden      Số neural lớp ẩn
# @param    numHiddenLayer    Số lớp ẩn
# @param    size_predict      Kích thước Cửa sổ dự đoán/ Số neural lớp ouput
# @return   best_params_FFNN  Tham số tốt nhất cho mô hình FFNN                
def train_FFNN(nameData, typePredict, size_window, X_train, y_train, neuralHidden, numHiddenLayer, size_predict):
    #param search
    param_grid_FFNN = {'batch_size': [8, 16, 32, 64, 128],
              'epochs': [50, 100, 150, 200, 250, 300],
              'neuralHidden': [neuralHidden],
              'num_layers_hidden' : [numHiddenLayer],
              'neuralInput' : [size_window],
              'neuralOutput' : [size_predict]}

    # create the model
    model_FFNN = KerasRegressor(build_fn=create_model_FFNN, verbose=0)
    
    # perform the grid search
    grid_FFNN = GridSearchCV(estimator=model_FFNN, param_grid=param_grid_FFNN, cv=3)
    grid_result_FFNN = grid_FFNN.fit(X_train, y_train)
    
    # train the model with the best parameters
    best_params_FFNN = grid_result_FFNN.best_params_
    
    model_FFNN = create_model_FFNN( best_params_FFNN['neuralInput'], best_params_FFNN['num_layers_hidden'], best_params_FFNN['neuralHidden'],best_params_FFNN['neuralOutput'])
    model_FFNN.fit(X_train, y_train, epochs=best_params_FFNN['epochs'], batch_size=best_params_FFNN['batch_size'], verbose=2, callbacks=[EarlyStopping(monitor='loss', patience=10)], shuffle=False)
    
    if(typePredict=='FFNN_Find_NeuralHidden'):
        model_FFNN.save_weights('../BestParam/FFNN/'+nameData+'/FFNN_Find_NeuralHidden/'+str(int(best_params_FFNN['num_layers_hidden']))+'_HiddenLayer_'+str(int(best_params_FFNN['neuralHidden']))+'_NeuralHidden_'+str(int(best_params_FFNN['batch_size']))+'_BatchSize_'+str(int(best_params_FFNN['epochs']))+'_Epoch_'+nameData+'.h5')   
    elif (typePredict=='FFNN_Find_NumberHiddenLayer'):
        model_FFNN.save_weights('../BestParam/FFNN/'+nameData+'/FFNN_Find_NumberHiddenLayer/'+str(int(best_params_FFNN['num_layers_hidden']))+'_HiddenLayer_'+str(int(best_params_FFNN['neuralHidden']))+'_NeuralHidden_'+str(int(best_params_FFNN['batch_size']))+'_BatchSize_'+str(int(best_params_FFNN['epochs']))+'_Epoch_'+nameData+'.h5')   
    else:
        model_FFNN.save_weights('../BestParam/TuanTu/'+nameData+'/FFNN_Find_NumberHiddenLayer/'+str(int(best_params_FFNN['num_layers_hidden']))+'_HiddenLayer_'+str(int(best_params_FFNN['neuralHidden']))+'_NeuralHidden_'+str(int(best_params_FFNN['batch_size']))+'_BatchSize_'+str(int(best_params_FFNN['epochs']))+'_Epoch_'+nameData+'.h5')   
    return best_params_FFNN



# Train FFNN 
# @param    nameData          Tên tập dữ liệu
# @param    size_window       Kích thước Cửa sổ mẫu/ số neural lớp input
# @param    X_train           cửa sổ mẫu tập train
# @param    y_train           Cửa sổ dự đoán tập train
# @param    batchSize         Số lượng mẫu được đưa vào với mỗi lần lặp (epoch)
# @param    epoch             Số lần lặp cập nhật trọng số
# @param    neuralHidden      Số neural lớp ẩn
# @param    numHiddenLayer    Số lớp ẩn
# @param    size_predict      Kích thước Cửa sổ dự đoán/ Số neural lớp ouput
# @return   best_params_FFNN  Tham số tốt nhất cho mô hình FFNN                
def train_best_param_FFNN(nameData, typePredict, size_window, X_train, y_train, batchSize, epoch, neuralHidden, numHiddenLayer, size_predict):
    #param search
    param_grid_FFNN = {'batch_size': batchSize,
              'epochs': epoch,
              'neuralHidden': neuralHidden,
              'num_layers_hidden' : numHiddenLayer,
              'neuralInput' : size_window,
              'neuralOutput' : size_predict}
    
    model_FFNN = create_model_FFNN( param_grid_FFNN['neuralInput'], param_grid_FFNN['num_layers_hidden'], param_grid_FFNN['neuralHidden'],param_grid_FFNN['neuralOutput'])
    model_FFNN.fit(X_train, y_train, epochs=param_grid_FFNN['epochs'], batch_size=param_grid_FFNN['batch_size'], verbose=2, callbacks=[EarlyStopping(monitor='loss', patience=10)], shuffle=False)
    
    if(typePredict=='FFNN_Find_NeuralHidden'):
        model_FFNN.save_weights('../BestParam/FFNN/'+nameData+'/FFNN_Find_NeuralHidden/'+str(int(param_grid_FFNN['num_layers_hidden']))+'_HiddenLayer_'+str(int(param_grid_FFNN['neuralHidden']))+'_NeuralHidden_'+str(int(param_grid_FFNN['batch_size']))+'_BatchSize_'+str(int(param_grid_FFNN['epochs']))+'_Epoch_'+nameData+'.h5')   
    elif (typePredict=='FFNN_Find_NumberHiddenLayer'):
        model_FFNN.save_weights('../BestParam/FFNN/'+nameData+'/FFNN_Find_NumberHiddenLayer/'+str(int(param_grid_FFNN['num_layers_hidden']))+'_HiddenLayer_'+str(int(param_grid_FFNN['neuralHidden']))+'_NeuralHidden_'+str(int(param_grid_FFNN['batch_size']))+'_BatchSize_'+str(int(param_grid_FFNN['epochs']))+'_Epoch_'+nameData+'.h5')   
    elif (typePredict=='FFNN_Find_NumberHiddenLayer_SongSong'):
        model_FFNN.save_weights('../BestParam/SongSong/'+nameData+'/FFNN_Find_BestWeights/'+str(int(param_grid_FFNN['num_layers_hidden']))+'_HiddenLayer_'+str(int(param_grid_FFNN['neuralHidden']))+'_NeuralHidden_'+str(int(param_grid_FFNN['batch_size']))+'_BatchSize_'+str(int(param_grid_FFNN['epochs']))+'_Epoch_'+nameData+'.h5')   
    else:
        model_FFNN.save_weights('../BestParam/TuanTu/'+nameData+'/FFNN_Find_BestWeights/'+str(int(param_grid_FFNN['num_layers_hidden']))+'_HiddenLayer_'+str(int(param_grid_FFNN['neuralHidden']))+'_NeuralHidden_'+str(int(param_grid_FFNN['batch_size']))+'_BatchSize_'+str(int(param_grid_FFNN['epochs']))+'_Epoch_'+nameData+'.h5')   
   
    return param_grid_FFNN

# Dự Đoán FFNN 
# @param    nameData          Tên tập dữ liệu
# @param    typePredict       Thực hiện loại dự đoán (FFNN_Find_NeuralHidden,FFNN_Find_NumberHiddenLayer,CombinePredict)
# @param    X_train           cửa sổ mẫu tập train
# @param    y_train           Cửa sổ dự đoán tập train
# @param    X_test            Cửa sổ dự đoán tập train
# @param    best_params_FFNN  Cửa sổ dự đoán tập train
# @return   predictions_FFNN  Mảng dự đoán
def predict_FFNN(nameData, typePredict, X_train, y_train, X_test, best_params_FFNN):
    model_FFNN1 = Sequential()
    for i in range(best_params_FFNN['num_layers_hidden']):
        if i == 0:
            model_FFNN1.add(Dense(best_params_FFNN['neuralHidden'], input_dim= best_params_FFNN['neuralInput'], activation='sigmoid'))
        else:
            model_FFNN1.add(Dense(best_params_FFNN['neuralHidden'], activation='sigmoid'))
    model_FFNN1.add(Dense(best_params_FFNN['neuralOutput']))
    
    if(typePredict=='FFNN_Find_NeuralHidden'):
        model_FFNN1.load_weights('../BestParam/FFNN/'+nameData+'/FFNN_Find_NeuralHidden/'+str(int(best_params_FFNN['num_layers_hidden']))+'_HiddenLayer_'+str(int(best_params_FFNN['neuralHidden']))+'_NeuralHidden_'+str(int(best_params_FFNN['batch_size']))+'_BatchSize_'+str(int(best_params_FFNN['epochs']))+'_Epoch_'+nameData+'.h5')   
    elif (typePredict=='FFNN_Find_NumberHiddenLayer'):
        model_FFNN1.load_weights('../BestParam/FFNN/'+nameData+'/FFNN_Find_NumberHiddenLayer/'+str(int(best_params_FFNN['num_layers_hidden']))+'_HiddenLayer_'+str(int(best_params_FFNN['neuralHidden']))+'_NeuralHidden_'+str(int(best_params_FFNN['batch_size']))+'_BatchSize_'+str(int(best_params_FFNN['epochs']))+'_Epoch_'+nameData+'.h5')   
    elif (typePredict=='FFNN_Find_NumberHiddenLayer_SongSong'):
        model_FFNN1.load_weights('../BestParam/SongSong/'+nameData+'/FFNN_Find_BestWeights/'+str(int(best_params_FFNN['num_layers_hidden']))+'_HiddenLayer_'+str(int(best_params_FFNN['neuralHidden']))+'_NeuralHidden_'+str(int(best_params_FFNN['batch_size']))+'_BatchSize_'+str(int(best_params_FFNN['epochs']))+'_Epoch_'+nameData+'.h5')   
    else:
        model_FFNN1.load_weights('../BestParam/TuanTu/'+nameData+'/FFNN_Find_BestWeights/'+str(int(best_params_FFNN['num_layers_hidden']))+'_HiddenLayer_'+str(int(best_params_FFNN['neuralHidden']))+'_NeuralHidden_'+str(int(best_params_FFNN['batch_size']))+'_BatchSize_'+str(int(best_params_FFNN['epochs']))+'_Epoch_'+nameData+'.h5')   
   
    model_FFNN1.compile(loss='mean_squared_error', optimizer='adam')
    
    predictions_FFNN = model_FFNN1.predict(X_test)
    return predictions_FFNN

#---------------------Song Song------------------------------#

# Lai Ghép Song Song
# @param    y_pred_FFNN     Mảng dự đoán của FFNN
# @param    y_pred_KNN      Mảng dự đoán của KNN
# @param    y_test          Mảng chuỗi thực tế
# @return   y_pred_combine  Mảng dự đoán kết hợp
def predictHybrid(y_pred_FFNN,y_pred_KNN,y_test):
    FFNNSubKNN=[]
    TestSubKNN=[]
    weightEl=[]
    for i in range(len(y_pred_FFNN)):
        FFNNSubKNN.append(y_pred_FFNN[i]-y_pred_KNN[i])
        TestSubKNN.append(y_test[i]-y_pred_KNN[i])

    for j in range(len(FFNNSubKNN)):
        weightEl.append(((FFNNSubKNN[j]*TestSubKNN[j])/ (FFNNSubKNN[j]*FFNNSubKNN[j])))
    
    weight = np.array(weightEl)
    
    y_pred_combine=[]
    for i in range(len(weight)):
        y_pred_combine.append(weight[i]*y_pred_FFNN[i]+(1-weight[i])*y_pred_KNN[i])
    y_pred_combine=np.array(y_pred_combine)
    return y_pred_combine

#---------------------Tuần Tự------------------------------#

# Tính Lỗi Theo Từng Ngày
# @param    y_pred_KNN      Mảng dự đoán của KNN
# @param    y_test          Mảng chuỗi thực tế
# @return   mseWithDay     Mảng lỗi theo ngày
def mseWithDay(y_pred_KNN, y_test):
    mseDay = []
    for i in range(len(y_pred_KNN)):
        mseDay.append([abs((y_test[i] - y_pred_KNN[i]))])
    mseDay=np.array(mseDay)
    return mseDay

def predictSum(y_pred_mse,y_pred_KNN):
    pred_knn_ffnn=[]
    for i in range(len(y_pred_mse)):
        pred_knn_ffnn.append(y_pred_KNN[i]+y_pred_mse[i])
    pred_knn_ffnn=np.array(pred_knn_ffnn)
    return pred_knn_ffnn

# %%
nameData= 'GDDY'
filePath= '../../Dataset/'+nameData+'.csv'
timeSeries = readData(filePath)
timeSeries = cleanData(timeSeries)
percentTrain = 80
train_data, test_data = splitData(timeSeries, percentTrain)

size_window = 7
size_predict=1
stepWindow=1
X_train, y_train = prepare_data(train_data.values, size_window, size_predict, stepWindow)
X_test, y_test =   prepare_data(test_data.values, size_window, size_predict, stepWindow)

numHiddenLayer= 1

df_MseWith_Neural = pd.DataFrame([],  columns =  ["Neural Hidden","Batch_Size","Epoch", "MSE","Time Train", "Time Test", "Total Time"])

for neuralHidden in range(1,21):
    
    start_Train= time.time()
    best_param = train_FFNN(nameData, 'FFNN_Find_NeuralHidden', size_window, X_train, y_train, neuralHidden, numHiddenLayer, size_predict)
    end_Train = time.time()
    
    start_Test= time.time()
    predictions_FFNN= predict_FFNN(nameData, 'FFNN_Find_NeuralHidden', X_train, y_train, X_test, best_param)
    end_Test = time.time()

    timeTrain = end_Train - start_Train
    timeTest = end_Test -  start_Test
    totalTime = timeTrain+ timeTest
    
    rowMseWithNeural = pd.Series([neuralHidden,best_param['batch_size'],best_param['epochs'], mean_squared_error(y_test , predictions_FFNN), timeTrain, timeTest, totalTime], index=df_MseWith_Neural.columns)
    df_MseWith_Neural = df_MseWith_Neural.append(rowMseWithNeural,ignore_index=True)
# Out:
# WARNING:tensorflow:5 out of the last 16 calls to <function Model.make_test_function.<locals>.test_function at 0x000001ADA08048B0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_test_function.<locals>.test_function at 0x000001ADA0B20DC0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Epoch 1/250
# 125/125 - 2s - loss: 1.3559 - 2s/epoch - 19ms/step
# Epoch 2/250
# 125/125 - 0s - loss: 0.7172 - 296ms/epoch - 2ms/step
# Epoch 3/250
# 125/125 - 0s - loss: 0.4059 - 293ms/epoch - 2ms/step
# Epoch 4/250
# 125/125 - 0s - loss: 0.2377 - 308ms/epoch - 2ms/step
# Epoch 5/250
# 125/125 - 0s - loss: 0.1446 - 279ms/epoch - 2ms/step
# Epoch 6/250
# 125/125 - 0s - loss: 0.0926 - 249ms/epoch - 2ms/step
# Epoch 7/250
# 125/125 - 0s - loss: 0.0638 - 257ms/epoch - 2ms/step
# Epoch 8/250
# 125/125 - 0s - loss: 0.0482 - 279ms/epoch - 2ms/step
# Epoch 9/250
# 125/125 - 0s - loss: 0.0400 - 251ms/epoch - 2ms/step
# Epoch 10/250
# 125/125 - 0s - loss: 0.0358 - 250ms/epoch - 2ms/step
# Epoch 11/250
# 125/125 - 0s - loss: 0.0336 - 283ms/epoch - 2ms/step
# Epoch 12/250
# 125/125 - 0s - loss: 0.0325 - 252ms/epoch - 2ms/step
# Epoch 13/250
# 125/125 - 0s - loss: 0.0317 - 237ms/epoch - 2ms/step
# Epoch 14/250
# 125/125 - 0s - loss: 0.0310 - 227ms/epoch - 2ms/step
# Epoch 15/250
# 125/125 - 0s - loss: 0.0303 - 256ms/epoch - 2ms/step
# Epoch 16/250
# 125/125 - 0s - loss: 0.0296 - 222ms/epoch - 2ms/step
# Epoch 17/250
# 125/125 - 0s - loss: 0.0288 - 227ms/epoch - 2ms/step
# Epoch 18/250
# 125/125 - 0s - loss: 0.0279 - 227ms/epoch - 2ms/step
# Epoch 19/250
# 125/125 - 0s - loss: 0.0270 - 226ms/epoch - 2ms/step
# Epoch 20/250
# 125/125 - 0s - loss: 0.0260 - 238ms/epoch - 2ms/step
# Epoch 21/250
# 125/125 - 0s - loss: 0.0249 - 231ms/epoch - 2ms/step
# Epoch 22/250
# 125/125 - 0s - loss: 0.0239 - 226ms/epoch - 2ms/step
# Epoch 23/250
# 125/125 - 0s - loss: 0.0228 - 225ms/epoch - 2ms/step
# Epoch 24/250
# 125/125 - 0s - loss: 0.0216 - 242ms/epoch - 2ms/step
# Epoch 25/250
# 125/125 - 0s - loss: 0.0205 - 224ms/epoch - 2ms/step
# Epoch 26/250
# 125/125 - 0s - loss: 0.0193 - 212ms/epoch - 2ms/step
# Epoch 27/250
# 125/125 - 0s - loss: 0.0181 - 213ms/epoch - 2ms/step
# Epoch 28/250
# 125/125 - 0s - loss: 0.0169 - 244ms/epoch - 2ms/step
# Epoch 29/250
# 125/125 - 0s - loss: 0.0158 - 223ms/epoch - 2ms/step
# Epoch 30/250
# 125/125 - 0s - loss: 0.0146 - 227ms/epoch - 2ms/step
# Epoch 31/250
# 125/125 - 0s - loss: 0.0135 - 203ms/epoch - 2ms/step
# Epoch 32/250
# 125/125 - 0s - loss: 0.0124 - 227ms/epoch - 2ms/step
# Epoch 33/250
# 125/125 - 0s - loss: 0.0113 - 211ms/epoch - 2ms/step
# Epoch 34/250
# 125/125 - 0s - loss: 0.0103 - 227ms/epoch - 2ms/step
# Epoch 35/250
# 125/125 - 0s - loss: 0.0094 - 227ms/epoch - 2ms/step
# Epoch 36/250
# 125/125 - 0s - loss: 0.0086 - 240ms/epoch - 2ms/step
# Epoch 37/250
# 125/125 - 0s - loss: 0.0078 - 239ms/epoch - 2ms/step
# Epoch 38/250
# 125/125 - 0s - loss: 0.0071 - 209ms/epoch - 2ms/step
# Epoch 39/250
# 125/125 - 0s - loss: 0.0064 - 242ms/epoch - 2ms/step
# Epoch 40/250
# 125/125 - 0s - loss: 0.0059 - 271ms/epoch - 2ms/step
# Epoch 41/250
# 125/125 - 0s - loss: 0.0054 - 264ms/epoch - 2ms/step
# Epoch 42/250
# 125/125 - 0s - loss: 0.0050 - 249ms/epoch - 2ms/step
# Epoch 43/250
# 125/125 - 0s - loss: 0.0047 - 239ms/epoch - 2ms/step
# Epoch 44/250
# 125/125 - 0s - loss: 0.0044 - 288ms/epoch - 2ms/step
# Epoch 45/250
# 125/125 - 0s - loss: 0.0042 - 371ms/epoch - 3ms/step
# Epoch 46/250
# 125/125 - 0s - loss: 0.0040 - 247ms/epoch - 2ms/step
# Epoch 47/250
# 125/125 - 0s - loss: 0.0038 - 296ms/epoch - 2ms/step
# Epoch 48/250
# 125/125 - 0s - loss: 0.0037 - 258ms/epoch - 2ms/step
# Epoch 49/250
# 125/125 - 0s - loss: 0.0036 - 268ms/epoch - 2ms/step
# Epoch 50/250
# 125/125 - 0s - loss: 0.0035 - 283ms/epoch - 2ms/step
# Epoch 51/250
# 125/125 - 0s - loss: 0.0034 - 293ms/epoch - 2ms/step
# Epoch 52/250
# 125/125 - 0s - loss: 0.0033 - 261ms/epoch - 2ms/step
# Epoch 53/250
# 125/125 - 0s - loss: 0.0032 - 252ms/epoch - 2ms/step
# Epoch 54/250
# 125/125 - 0s - loss: 0.0031 - 269ms/epoch - 2ms/step
# Epoch 55/250
# 125/125 - 0s - loss: 0.0030 - 237ms/epoch - 2ms/step
# Epoch 56/250
# 125/125 - 0s - loss: 0.0029 - 270ms/epoch - 2ms/step
# Epoch 57/250
# 125/125 - 0s - loss: 0.0028 - 251ms/epoch - 2ms/step
# Epoch 58/250
# 125/125 - 0s - loss: 0.0028 - 268ms/epoch - 2ms/step
# Epoch 59/250
# 125/125 - 0s - loss: 0.0027 - 265ms/epoch - 2ms/step
# Epoch 60/250
# 125/125 - 0s - loss: 0.0026 - 248ms/epoch - 2ms/step
# Epoch 61/250
# 125/125 - 0s - loss: 0.0025 - 272ms/epoch - 2ms/step
# Epoch 62/250
# 125/125 - 0s - loss: 0.0024 - 267ms/epoch - 2ms/step
# Epoch 63/250
# 125/125 - 0s - loss: 0.0024 - 280ms/epoch - 2ms/step
# Epoch 64/250
# 125/125 - 0s - loss: 0.0023 - 295ms/epoch - 2ms/step
# Epoch 65/250
# 125/125 - 0s - loss: 0.0023 - 289ms/epoch - 2ms/step
# Epoch 66/250
# 125/125 - 0s - loss: 0.0022 - 249ms/epoch - 2ms/step
# Epoch 67/250
# 125/125 - 0s - loss: 0.0021 - 269ms/epoch - 2ms/step
# Epoch 68/250
# 125/125 - 0s - loss: 0.0021 - 311ms/epoch - 2ms/step
# Epoch 69/250
# 125/125 - 0s - loss: 0.0020 - 258ms/epoch - 2ms/step
# Epoch 70/250
# 125/125 - 0s - loss: 0.0020 - 329ms/epoch - 3ms/step
# Epoch 71/250
# 125/125 - 0s - loss: 0.0019 - 287ms/epoch - 2ms/step
# Epoch 72/250
# 125/125 - 0s - loss: 0.0019 - 230ms/epoch - 2ms/step
# Epoch 73/250
# 125/125 - 0s - loss: 0.0019 - 242ms/epoch - 2ms/step
# Epoch 74/250
# 125/125 - 0s - loss: 0.0018 - 224ms/epoch - 2ms/step
# Epoch 75/250
# 125/125 - 0s - loss: 0.0018 - 227ms/epoch - 2ms/step
# Epoch 76/250
# 125/125 - 0s - loss: 0.0017 - 226ms/epoch - 2ms/step
# Epoch 77/250
# 125/125 - 0s - loss: 0.0017 - 211ms/epoch - 2ms/step
# Epoch 78/250
# 125/125 - 0s - loss: 0.0017 - 230ms/epoch - 2ms/step
# Epoch 79/250
# 125/125 - 0s - loss: 0.0016 - 227ms/epoch - 2ms/step
# Epoch 80/250
# 125/125 - 0s - loss: 0.0016 - 211ms/epoch - 2ms/step
# Epoch 81/250
# 125/125 - 0s - loss: 0.0016 - 213ms/epoch - 2ms/step
# Epoch 82/250
# 125/125 - 0s - loss: 0.0016 - 230ms/epoch - 2ms/step
# Epoch 83/250
# 125/125 - 0s - loss: 0.0015 - 242ms/epoch - 2ms/step
# Epoch 84/250
# 125/125 - 0s - loss: 0.0015 - 241ms/epoch - 2ms/step
# Epoch 85/250
# 125/125 - 0s - loss: 0.0015 - 269ms/epoch - 2ms/step
# Epoch 86/250
# 125/125 - 0s - loss: 0.0015 - 314ms/epoch - 3ms/step
# Epoch 87/250
# 125/125 - 0s - loss: 0.0014 - 242ms/epoch - 2ms/step
# Epoch 88/250
# 125/125 - 0s - loss: 0.0014 - 215ms/epoch - 2ms/step
# Epoch 89/250
# 125/125 - 0s - loss: 0.0014 - 227ms/epoch - 2ms/step
# Epoch 90/250
# 125/125 - 0s - loss: 0.0014 - 242ms/epoch - 2ms/step
# Epoch 91/250
# 125/125 - 0s - loss: 0.0014 - 240ms/epoch - 2ms/step
# Epoch 92/250
# 125/125 - 0s - loss: 0.0013 - 240ms/epoch - 2ms/step
# Epoch 93/250
# 125/125 - 0s - loss: 0.0013 - 225ms/epoch - 2ms/step
# Epoch 94/250
# 125/125 - 0s - loss: 0.0013 - 227ms/epoch - 2ms/step
# Epoch 95/250
# 125/125 - 0s - loss: 0.0013 - 257ms/epoch - 2ms/step
# Epoch 96/250
# 125/125 - 0s - loss: 0.0013 - 238ms/epoch - 2ms/step
# Epoch 97/250
# 125/125 - 0s - loss: 0.0012 - 225ms/epoch - 2ms/step
# Epoch 98/250
# 125/125 - 0s - loss: 0.0012 - 258ms/epoch - 2ms/step
# Epoch 99/250
# 125/125 - 0s - loss: 0.0012 - 221ms/epoch - 2ms/step
# Epoch 100/250
# 125/125 - 0s - loss: 0.0012 - 260ms/epoch - 2ms/step
# Epoch 101/250
# 125/125 - 0s - loss: 0.0012 - 222ms/epoch - 2ms/step
# Epoch 102/250
# 125/125 - 0s - loss: 0.0012 - 242ms/epoch - 2ms/step
# Epoch 103/250
# 125/125 - 0s - loss: 0.0012 - 300ms/epoch - 2ms/step
# Epoch 104/250
# 125/125 - 0s - loss: 0.0012 - 262ms/epoch - 2ms/step
# Epoch 105/250
# 125/125 - 0s - loss: 0.0011 - 285ms/epoch - 2ms/step
# Epoch 106/250
# 125/125 - 0s - loss: 0.0011 - 232ms/epoch - 2ms/step
# Epoch 107/250
# 125/125 - 0s - loss: 0.0011 - 227ms/epoch - 2ms/step
# Epoch 108/250
# 125/125 - 0s - loss: 0.0011 - 241ms/epoch - 2ms/step
# Epoch 109/250
# 125/125 - 0s - loss: 0.0011 - 226ms/epoch - 2ms/step
# Epoch 110/250
# 125/125 - 0s - loss: 0.0011 - 210ms/epoch - 2ms/step
# Epoch 111/250
# 125/125 - 0s - loss: 0.0011 - 211ms/epoch - 2ms/step
# Epoch 112/250
# 125/125 - 0s - loss: 0.0011 - 242ms/epoch - 2ms/step
# Epoch 113/250
# 125/125 - 0s - loss: 0.0011 - 242ms/epoch - 2ms/step
# Epoch 114/250
# 125/125 - 0s - loss: 0.0010 - 222ms/epoch - 2ms/step
# Epoch 115/250
# 125/125 - 0s - loss: 0.0010 - 227ms/epoch - 2ms/step
# Epoch 116/250
# 125/125 - 0s - loss: 0.0010 - 227ms/epoch - 2ms/step
# Epoch 117/250
# 125/125 - 0s - loss: 0.0010 - 226ms/epoch - 2ms/step
# Epoch 118/250
# 125/125 - 0s - loss: 0.0010 - 214ms/epoch - 2ms/step
# Epoch 119/250
# 125/125 - 0s - loss: 0.0010 - 242ms/epoch - 2ms/step
# Epoch 120/250
# 125/125 - 0s - loss: 9.9839e-04 - 227ms/epoch - 2ms/step
# Epoch 121/250
# 125/125 - 0s - loss: 9.9077e-04 - 224ms/epoch - 2ms/step
# Epoch 122/250
# 125/125 - 0s - loss: 9.8334e-04 - 305ms/epoch - 2ms/step
# Epoch 123/250
# 125/125 - 0s - loss: 9.7608e-04 - 253ms/epoch - 2ms/step
# Epoch 124/250
# 125/125 - 0s - loss: 9.6898e-04 - 235ms/epoch - 2ms/step
# Epoch 125/250
# 125/125 - 0s - loss: 9.6205e-04 - 225ms/epoch - 2ms/step
# Epoch 126/250
# 125/125 - 0s - loss: 9.5528e-04 - 227ms/epoch - 2ms/step
# Epoch 127/250
# 125/125 - 0s - loss: 9.4865e-04 - 240ms/epoch - 2ms/step
# Epoch 128/250
# 125/125 - 0s - loss: 9.4217e-04 - 227ms/epoch - 2ms/step
# Epoch 129/250
# 125/125 - 0s - loss: 9.3582e-04 - 226ms/epoch - 2ms/step
# Epoch 130/250
# 125/125 - 0s - loss: 9.2960e-04 - 241ms/epoch - 2ms/step
# Epoch 131/250
# 125/125 - 0s - loss: 9.2351e-04 - 213ms/epoch - 2ms/step
# Epoch 132/250
# 125/125 - 0s - loss: 9.1755e-04 - 212ms/epoch - 2ms/step
# Epoch 133/250
# 125/125 - 0s - loss: 9.1170e-04 - 227ms/epoch - 2ms/step
# Epoch 134/250
# 125/125 - 0s - loss: 9.0597e-04 - 227ms/epoch - 2ms/step
# Epoch 135/250
# 125/125 - 0s - loss: 9.0035e-04 - 208ms/epoch - 2ms/step
# Epoch 136/250
# 125/125 - 0s - loss: 8.9482e-04 - 227ms/epoch - 2ms/step
# Epoch 137/250
# 125/125 - 0s - loss: 8.8941e-04 - 215ms/epoch - 2ms/step
# Epoch 138/250
# 125/125 - 0s - loss: 8.8409e-04 - 260ms/epoch - 2ms/step
# Epoch 139/250
# 125/125 - 0s - loss: 8.7887e-04 - 267ms/epoch - 2ms/step
# Epoch 140/250
# 125/125 - 0s - loss: 8.7374e-04 - 266ms/epoch - 2ms/step
# Epoch 141/250
# 125/125 - 0s - loss: 8.6870e-04 - 251ms/epoch - 2ms/step
# Epoch 142/250
# 125/125 - 0s - loss: 8.6375e-04 - 267ms/epoch - 2ms/step
# Epoch 143/250
# 125/125 - 0s - loss: 8.5888e-04 - 267ms/epoch - 2ms/step
# Epoch 144/250
# 125/125 - 0s - loss: 8.5409e-04 - 266ms/epoch - 2ms/step
# Epoch 145/250
# 125/125 - 0s - loss: 8.4938e-04 - 221ms/epoch - 2ms/step
# Epoch 146/250
# 125/125 - 0s - loss: 8.4475e-04 - 248ms/epoch - 2ms/step
# Epoch 147/250
# 125/125 - 0s - loss: 8.4018e-04 - 277ms/epoch - 2ms/step
# Epoch 148/250
# 125/125 - 0s - loss: 8.3569e-04 - 266ms/epoch - 2ms/step
# Epoch 149/250
# 125/125 - 0s - loss: 8.3127e-04 - 280ms/epoch - 2ms/step
# Epoch 150/250
# 125/125 - 0s - loss: 8.2692e-04 - 236ms/epoch - 2ms/step
# Epoch 151/250
# 125/125 - 0s - loss: 8.2263e-04 - 256ms/epoch - 2ms/step
# Epoch 152/250
# 125/125 - 0s - loss: 8.1840e-04 - 254ms/epoch - 2ms/step
# Epoch 153/250
# 125/125 - 0s - loss: 8.1423e-04 - 264ms/epoch - 2ms/step
# Epoch 154/250
# 125/125 - 0s - loss: 8.1013e-04 - 238ms/epoch - 2ms/step
# Epoch 155/250
# 125/125 - 0s - loss: 8.0608e-04 - 272ms/epoch - 2ms/step
# Epoch 156/250
# 125/125 - 0s - loss: 8.0209e-04 - 264ms/epoch - 2ms/step
# Epoch 157/250
# 125/125 - 0s - loss: 7.9815e-04 - 276ms/epoch - 2ms/step
# Epoch 158/250
# 125/125 - 0s - loss: 7.9427e-04 - 274ms/epoch - 2ms/step
# Epoch 159/250
# 125/125 - 0s - loss: 7.9043e-04 - 266ms/epoch - 2ms/step
# Epoch 160/250
# 125/125 - 0s - loss: 7.8665e-04 - 236ms/epoch - 2ms/step
# Epoch 161/250
# 125/125 - 0s - loss: 7.8292e-04 - 252ms/epoch - 2ms/step
# Epoch 162/250
# 125/125 - 0s - loss: 7.7923e-04 - 251ms/epoch - 2ms/step
# Epoch 163/250
# 125/125 - 0s - loss: 7.7560e-04 - 251ms/epoch - 2ms/step
# Epoch 164/250
# 125/125 - 0s - loss: 7.7200e-04 - 241ms/epoch - 2ms/step
# Epoch 165/250
# 125/125 - 0s - loss: 7.6845e-04 - 263ms/epoch - 2ms/step
# Epoch 166/250
# 125/125 - 0s - loss: 7.6495e-04 - 244ms/epoch - 2ms/step
# Epoch 167/250
# 125/125 - 0s - loss: 7.6148e-04 - 224ms/epoch - 2ms/step
# Epoch 168/250
# 125/125 - 0s - loss: 7.5806e-04 - 242ms/epoch - 2ms/step
# Epoch 169/250
# 125/125 - 0s - loss: 7.5468e-04 - 240ms/epoch - 2ms/step
# Epoch 170/250
# 125/125 - 0s - loss: 7.5134e-04 - 224ms/epoch - 2ms/step
# Epoch 171/250
# 125/125 - 0s - loss: 7.4803e-04 - 227ms/epoch - 2ms/step
# Epoch 172/250
# 125/125 - 0s - loss: 7.4476e-04 - 211ms/epoch - 2ms/step
# Epoch 173/250
# 125/125 - 0s - loss: 7.4153e-04 - 227ms/epoch - 2ms/step
# Epoch 174/250
# 125/125 - 0s - loss: 7.3834e-04 - 224ms/epoch - 2ms/step
# Epoch 175/250
# 125/125 - 0s - loss: 7.3518e-04 - 226ms/epoch - 2ms/step
# Epoch 176/250
# 125/125 - 0s - loss: 7.3205e-04 - 274ms/epoch - 2ms/step
# Epoch 177/250
# 125/125 - 0s - loss: 7.2896e-04 - 220ms/epoch - 2ms/step
# Epoch 178/250
# 125/125 - 0s - loss: 7.2590e-04 - 258ms/epoch - 2ms/step
# Epoch 179/250
# 125/125 - 0s - loss: 7.2287e-04 - 297ms/epoch - 2ms/step
# Epoch 180/250
# 125/125 - 0s - loss: 7.1988e-04 - 291ms/epoch - 2ms/step
# Epoch 181/250
# 125/125 - 0s - loss: 7.1691e-04 - 247ms/epoch - 2ms/step
# Epoch 182/250
# 125/125 - 0s - loss: 7.1397e-04 - 224ms/epoch - 2ms/step
# Epoch 183/250
# 125/125 - 0s - loss: 7.1107e-04 - 240ms/epoch - 2ms/step
# Epoch 184/250
# 125/125 - 0s - loss: 7.0819e-04 - 285ms/epoch - 2ms/step
# Epoch 185/250
# 125/125 - 0s - loss: 7.0534e-04 - 236ms/epoch - 2ms/step
# Epoch 186/250
# 125/125 - 0s - loss: 7.0252e-04 - 221ms/epoch - 2ms/step
# Epoch 187/250
# 125/125 - 0s - loss: 6.9973e-04 - 240ms/epoch - 2ms/step
# Epoch 188/250
# 125/125 - 0s - loss: 6.9696e-04 - 241ms/epoch - 2ms/step
# Epoch 189/250
# 125/125 - 0s - loss: 6.9422e-04 - 224ms/epoch - 2ms/step
# Epoch 190/250
# 125/125 - 0s - loss: 6.9151e-04 - 225ms/epoch - 2ms/step
# Epoch 191/250
# 125/125 - 0s - loss: 6.8882e-04 - 242ms/epoch - 2ms/step
# Epoch 192/250
# 125/125 - 0s - loss: 6.8615e-04 - 275ms/epoch - 2ms/step
# Epoch 193/250
# 125/125 - 0s - loss: 6.8351e-04 - 212ms/epoch - 2ms/step
# Epoch 194/250
# 125/125 - 0s - loss: 6.8090e-04 - 227ms/epoch - 2ms/step
# Epoch 195/250
# 125/125 - 0s - loss: 6.7830e-04 - 227ms/epoch - 2ms/step
# Epoch 196/250
# 125/125 - 0s - loss: 6.7573e-04 - 257ms/epoch - 2ms/step
# Epoch 197/250
# 125/125 - 0s - loss: 6.7319e-04 - 238ms/epoch - 2ms/step
# Epoch 198/250
# 125/125 - 0s - loss: 6.7066e-04 - 235ms/epoch - 2ms/step
# Epoch 199/250
# 125/125 - 0s - loss: 6.6816e-04 - 223ms/epoch - 2ms/step
# Epoch 200/250
# 125/125 - 0s - loss: 6.6568e-04 - 233ms/epoch - 2ms/step
# Epoch 201/250
# 125/125 - 0s - loss: 6.6322e-04 - 290ms/epoch - 2ms/step
# Epoch 202/250
# 125/125 - 0s - loss: 6.6078e-04 - 258ms/epoch - 2ms/step
# Epoch 203/250
# 125/125 - 0s - loss: 6.5836e-04 - 269ms/epoch - 2ms/step
# Epoch 204/250
# 125/125 - 0s - loss: 6.5596e-04 - 266ms/epoch - 2ms/step
# Epoch 205/250
# 125/125 - 0s - loss: 6.5358e-04 - 252ms/epoch - 2ms/step
# Epoch 206/250
# 125/125 - 0s - loss: 6.5122e-04 - 284ms/epoch - 2ms/step
# Epoch 207/250
# 125/125 - 0s - loss: 6.4888e-04 - 263ms/epoch - 2ms/step
# Epoch 208/250
# 125/125 - 0s - loss: 6.4656e-04 - 282ms/epoch - 2ms/step
# Epoch 209/250
# 125/125 - 0s - loss: 6.4426e-04 - 249ms/epoch - 2ms/step
# Epoch 210/250
# 125/125 - 0s - loss: 6.4197e-04 - 240ms/epoch - 2ms/step
# Epoch 211/250
# 125/125 - 0s - loss: 6.3971e-04 - 224ms/epoch - 2ms/step
# Epoch 212/250
# 125/125 - 0s - loss: 6.3746e-04 - 225ms/epoch - 2ms/step
# Epoch 213/250
# 125/125 - 0s - loss: 6.3523e-04 - 227ms/epoch - 2ms/step
# Epoch 214/250
# 125/125 - 0s - loss: 6.3302e-04 - 227ms/epoch - 2ms/step
# Epoch 215/250
# 125/125 - 0s - loss: 6.3082e-04 - 211ms/epoch - 2ms/step
# Epoch 216/250
# 125/125 - 0s - loss: 6.2864e-04 - 230ms/epoch - 2ms/step
# Epoch 217/250
# 125/125 - 0s - loss: 6.2648e-04 - 211ms/epoch - 2ms/step
# Epoch 218/250
# 125/125 - 0s - loss: 6.2434e-04 - 214ms/epoch - 2ms/step
# Epoch 219/250
# 125/125 - 0s - loss: 6.2220e-04 - 213ms/epoch - 2ms/step
# Epoch 220/250
# 125/125 - 0s - loss: 6.2009e-04 - 205ms/epoch - 2ms/step
# Epoch 221/250
# 125/125 - 0s - loss: 6.1799e-04 - 228ms/epoch - 2ms/step
# Epoch 222/250
# 125/125 - 0s - loss: 6.1591e-04 - 229ms/epoch - 2ms/step
# Epoch 223/250
# 125/125 - 0s - loss: 6.1384e-04 - 224ms/epoch - 2ms/step
# Epoch 224/250
# 125/125 - 0s - loss: 6.1179e-04 - 305ms/epoch - 2ms/step
# Epoch 225/250
# 125/125 - 0s - loss: 6.0975e-04 - 291ms/epoch - 2ms/step
# Epoch 226/250
# 125/125 - 0s - loss: 6.0772e-04 - 277ms/epoch - 2ms/step
# Epoch 227/250
# 125/125 - 0s - loss: 6.0572e-04 - 249ms/epoch - 2ms/step
# Epoch 228/250
# 125/125 - 0s - loss: 6.0372e-04 - 303ms/epoch - 2ms/step
# Epoch 229/250
# 125/125 - 0s - loss: 6.0174e-04 - 241ms/epoch - 2ms/step
# Epoch 230/250
# 125/125 - 0s - loss: 5.9977e-04 - 241ms/epoch - 2ms/step
# Epoch 231/250
# 125/125 - 0s - loss: 5.9782e-04 - 222ms/epoch - 2ms/step
# Epoch 232/250
# 125/125 - 0s - loss: 5.9588e-04 - 283ms/epoch - 2ms/step
# Epoch 233/250
# 125/125 - 0s - loss: 5.9396e-04 - 242ms/epoch - 2ms/step
# Epoch 234/250
# 125/125 - 0s - loss: 5.9204e-04 - 222ms/epoch - 2ms/step
# Epoch 235/250
# 125/125 - 0s - loss: 5.9014e-04 - 212ms/epoch - 2ms/step
# Epoch 236/250
# 125/125 - 0s - loss: 5.8826e-04 - 220ms/epoch - 2ms/step
# Epoch 237/250
# 125/125 - 0s - loss: 5.8638e-04 - 224ms/epoch - 2ms/step
# Epoch 238/250
# 125/125 - 0s - loss: 5.8452e-04 - 224ms/epoch - 2ms/step
# Epoch 239/250
# 125/125 - 0s - loss: 5.8267e-04 - 227ms/epoch - 2ms/step
# Epoch 240/250
# 125/125 - 0s - loss: 5.8084e-04 - 227ms/epoch - 2ms/step
# Epoch 241/250
# 125/125 - 0s - loss: 5.7901e-04 - 241ms/epoch - 2ms/step
# Epoch 242/250
# 125/125 - 0s - loss: 5.7720e-04 - 226ms/epoch - 2ms/step
# Epoch 243/250
# 125/125 - 0s - loss: 5.7540e-04 - 211ms/epoch - 2ms/step
# Epoch 244/250
# 125/125 - 0s - loss: 5.7361e-04 - 211ms/epoch - 2ms/step
# Epoch 245/250
# 125/125 - 0s - loss: 5.7183e-04 - 241ms/epoch - 2ms/step
# Epoch 246/250
# 125/125 - 0s - loss: 5.7007e-04 - 226ms/epoch - 2ms/step
# Epoch 247/250
# 125/125 - 0s - loss: 5.6832e-04 - 259ms/epoch - 2ms/step
# Epoch 248/250
# 125/125 - 0s - loss: 5.6657e-04 - 251ms/epoch - 2ms/step
# Epoch 249/250
# 125/125 - 0s - loss: 5.6484e-04 - 285ms/epoch - 2ms/step
# Epoch 250/250
# 125/125 - 0s - loss: 5.6312e-04 - 277ms/epoch - 2ms/step
# 8/8 [==============================] - 0s 2ms/step
# Epoch 1/200
# 63/63 - 3s - loss: 0.5791 - 3s/epoch - 50ms/step
# Epoch 2/200
# 63/63 - 0s - loss: 0.4254 - 183ms/epoch - 3ms/step
# Epoch 3/200
# 63/63 - 0s - loss: 0.3376 - 132ms/epoch - 2ms/step
# Epoch 4/200
# 63/63 - 0s - loss: 0.2833 - 134ms/epoch - 2ms/step
# Epoch 5/200
# 63/63 - 0s - loss: 0.2468 - 165ms/epoch - 3ms/step
# Epoch 6/200
# 63/63 - 0s - loss: 0.2203 - 173ms/epoch - 3ms/step
# Epoch 7/200
# 63/63 - 0s - loss: 0.1995 - 142ms/epoch - 2ms/step
# Epoch 8/200
# 63/63 - 0s - loss: 0.1822 - 137ms/epoch - 2ms/step
# Epoch 9/200
# 63/63 - 0s - loss: 0.1671 - 131ms/epoch - 2ms/step
# Epoch 10/200
# 63/63 - 0s - loss: 0.1533 - 163ms/epoch - 3ms/step
# Epoch 11/200
# 63/63 - 0s - loss: 0.1407 - 144ms/epoch - 2ms/step
# Epoch 12/200
# 63/63 - 0s - loss: 0.1289 - 131ms/epoch - 2ms/step
# Epoch 13/200
# 63/63 - 0s - loss: 0.1179 - 165ms/epoch - 3ms/step
# Epoch 14/200
# 63/63 - 0s - loss: 0.1076 - 142ms/epoch - 2ms/step
# Epoch 15/200
# 63/63 - 0s - loss: 0.0980 - 124ms/epoch - 2ms/step
# Epoch 16/200
# 63/63 - 0s - loss: 0.0892 - 133ms/epoch - 2ms/step
# Epoch 17/200
# 63/63 - 0s - loss: 0.0810 - 167ms/epoch - 3ms/step
# Epoch 18/200
# 63/63 - 0s - loss: 0.0736 - 192ms/epoch - 3ms/step
# Epoch 19/200
# 63/63 - 0s - loss: 0.0667 - 150ms/epoch - 2ms/step
# Epoch 20/200
# 63/63 - 0s - loss: 0.0605 - 118ms/epoch - 2ms/step
# Epoch 21/200
# 63/63 - 0s - loss: 0.0549 - 195ms/epoch - 3ms/step
# Epoch 22/200
# 63/63 - 0s - loss: 0.0498 - 125ms/epoch - 2ms/step
# Epoch 23/200
# 63/63 - 0s - loss: 0.0452 - 118ms/epoch - 2ms/step
# Epoch 24/200
# 63/63 - 0s - loss: 0.0410 - 133ms/epoch - 2ms/step
# Epoch 25/200
# 63/63 - 0s - loss: 0.0373 - 139ms/epoch - 2ms/step
# Epoch 26/200
# 63/63 - 0s - loss: 0.0339 - 131ms/epoch - 2ms/step
# Epoch 27/200
# 63/63 - 0s - loss: 0.0309 - 133ms/epoch - 2ms/step
# Epoch 28/200
# 63/63 - 0s - loss: 0.0281 - 119ms/epoch - 2ms/step
# Epoch 29/200
# 63/63 - 0s - loss: 0.0257 - 118ms/epoch - 2ms/step
# Epoch 30/200
# 63/63 - 0s - loss: 0.0234 - 135ms/epoch - 2ms/step
# Epoch 31/200
# 63/63 - 0s - loss: 0.0214 - 118ms/epoch - 2ms/step
# Epoch 32/200
# 63/63 - 0s - loss: 0.0196 - 136ms/epoch - 2ms/step
# Epoch 33/200
# 63/63 - 0s - loss: 0.0179 - 118ms/epoch - 2ms/step
# Epoch 34/200
# 63/63 - 0s - loss: 0.0164 - 121ms/epoch - 2ms/step
# Epoch 35/200
# 63/63 - 0s - loss: 0.0151 - 134ms/epoch - 2ms/step
# Epoch 36/200
# 63/63 - 0s - loss: 0.0138 - 120ms/epoch - 2ms/step
# Epoch 37/200
# 63/63 - 0s - loss: 0.0127 - 135ms/epoch - 2ms/step
# Epoch 38/200
# 63/63 - 0s - loss: 0.0117 - 118ms/epoch - 2ms/step
# Epoch 39/200
# 63/63 - 0s - loss: 0.0107 - 118ms/epoch - 2ms/step
# Epoch 40/200
# 63/63 - 0s - loss: 0.0099 - 121ms/epoch - 2ms/step
# Epoch 41/200
# 63/63 - 0s - loss: 0.0091 - 119ms/epoch - 2ms/step
# Epoch 42/200
# 63/63 - 0s - loss: 0.0083 - 133ms/epoch - 2ms/step
# Epoch 43/200
# 63/63 - 0s - loss: 0.0077 - 118ms/epoch - 2ms/step
# Epoch 44/200
# 63/63 - 0s - loss: 0.0071 - 120ms/epoch - 2ms/step
# Epoch 45/200
# 63/63 - 0s - loss: 0.0065 - 136ms/epoch - 2ms/step
# Epoch 46/200
# 63/63 - 0s - loss: 0.0060 - 133ms/epoch - 2ms/step
# Epoch 47/200
# 63/63 - 0s - loss: 0.0055 - 117ms/epoch - 2ms/step
# Epoch 48/200
# 63/63 - 0s - loss: 0.0051 - 136ms/epoch - 2ms/step
# Epoch 49/200
# 63/63 - 0s - loss: 0.0047 - 120ms/epoch - 2ms/step
# Epoch 50/200
# 63/63 - 0s - loss: 0.0043 - 117ms/epoch - 2ms/step
# Epoch 51/200
# 63/63 - 0s - loss: 0.0040 - 128ms/epoch - 2ms/step
# Epoch 52/200
# 63/63 - 0s - loss: 0.0037 - 147ms/epoch - 2ms/step
# Epoch 53/200
# 63/63 - 0s - loss: 0.0034 - 129ms/epoch - 2ms/step
# Epoch 54/200
# 63/63 - 0s - loss: 0.0031 - 149ms/epoch - 2ms/step
# Epoch 55/200
# 63/63 - 0s - loss: 0.0029 - 163ms/epoch - 3ms/step
# Epoch 56/200
# 63/63 - 0s - loss: 0.0027 - 124ms/epoch - 2ms/step
# Epoch 57/200
# 63/63 - 0s - loss: 0.0025 - 133ms/epoch - 2ms/step
# Epoch 58/200
# 63/63 - 0s - loss: 0.0023 - 120ms/epoch - 2ms/step
# Epoch 59/200
# 63/63 - 0s - loss: 0.0021 - 117ms/epoch - 2ms/step
# Epoch 60/200
# 63/63 - 0s - loss: 0.0020 - 134ms/epoch - 2ms/step
# Epoch 61/200
# 63/63 - 0s - loss: 0.0019 - 120ms/epoch - 2ms/step
# Epoch 62/200
# 63/63 - 0s - loss: 0.0017 - 120ms/epoch - 2ms/step
# Epoch 63/200
# 63/63 - 0s - loss: 0.0016 - 151ms/epoch - 2ms/step
# Epoch 64/200
# 63/63 - 0s - loss: 0.0015 - 113ms/epoch - 2ms/step
# Epoch 65/200
# 63/63 - 0s - loss: 0.0015 - 136ms/epoch - 2ms/step
# Epoch 66/200
# 63/63 - 0s - loss: 0.0014 - 118ms/epoch - 2ms/step
# Epoch 67/200
# 63/63 - 0s - loss: 0.0013 - 136ms/epoch - 2ms/step
# Epoch 68/200
# 63/63 - 0s - loss: 0.0013 - 133ms/epoch - 2ms/step
# Epoch 69/200
# 63/63 - 0s - loss: 0.0012 - 146ms/epoch - 2ms/step
# Epoch 70/200
# 63/63 - 0s - loss: 0.0012 - 118ms/epoch - 2ms/step
# Epoch 71/200
# 63/63 - 0s - loss: 0.0011 - 136ms/epoch - 2ms/step
# Epoch 72/200
# 63/63 - 0s - loss: 0.0011 - 117ms/epoch - 2ms/step
# Epoch 73/200
# 63/63 - 0s - loss: 0.0011 - 120ms/epoch - 2ms/step
# Epoch 74/200
# 63/63 - 0s - loss: 0.0010 - 121ms/epoch - 2ms/step
# Epoch 75/200
# 63/63 - 0s - loss: 0.0010 - 118ms/epoch - 2ms/step
# Epoch 76/200
# 63/63 - 0s - loss: 0.0010 - 136ms/epoch - 2ms/step
# Epoch 77/200
# 63/63 - 0s - loss: 9.9826e-04 - 103ms/epoch - 2ms/step
# Epoch 78/200
# 63/63 - 0s - loss: 9.8610e-04 - 113ms/epoch - 2ms/step
# Epoch 79/200
# 63/63 - 0s - loss: 9.7582e-04 - 120ms/epoch - 2ms/step
# Epoch 80/200
# 63/63 - 0s - loss: 9.6708e-04 - 136ms/epoch - 2ms/step
# Epoch 81/200
# 63/63 - 0s - loss: 9.5960e-04 - 117ms/epoch - 2ms/step
# Epoch 82/200
# 63/63 - 0s - loss: 9.5313e-04 - 114ms/epoch - 2ms/step
# Epoch 83/200
# 63/63 - 0s - loss: 9.4744e-04 - 133ms/epoch - 2ms/step
# Epoch 84/200
# 63/63 - 0s - loss: 9.4237e-04 - 134ms/epoch - 2ms/step
# Epoch 85/200
# 63/63 - 0s - loss: 9.3773e-04 - 118ms/epoch - 2ms/step
# Epoch 86/200
# 63/63 - 0s - loss: 9.3341e-04 - 120ms/epoch - 2ms/step
# Epoch 87/200
# 63/63 - 0s - loss: 9.2928e-04 - 119ms/epoch - 2ms/step
# Epoch 88/200
# 63/63 - 0s - loss: 9.2528e-04 - 133ms/epoch - 2ms/step
# Epoch 89/200
# 63/63 - 0s - loss: 9.2131e-04 - 118ms/epoch - 2ms/step
# Epoch 90/200
# 63/63 - 0s - loss: 9.1735e-04 - 136ms/epoch - 2ms/step
# Epoch 91/200
# 63/63 - 0s - loss: 9.1333e-04 - 150ms/epoch - 2ms/step
# Epoch 92/200
# 63/63 - 0s - loss: 9.0925e-04 - 162ms/epoch - 3ms/step
# Epoch 93/200
# 63/63 - 0s - loss: 9.0507e-04 - 124ms/epoch - 2ms/step
# Epoch 94/200
# 63/63 - 0s - loss: 9.0080e-04 - 196ms/epoch - 3ms/step
# Epoch 95/200
# 63/63 - 0s - loss: 8.9642e-04 - 157ms/epoch - 2ms/step
# Epoch 96/200
# 63/63 - 0s - loss: 8.9194e-04 - 144ms/epoch - 2ms/step
# Epoch 97/200
# 63/63 - 0s - loss: 8.8736e-04 - 149ms/epoch - 2ms/step
# Epoch 98/200
# 63/63 - 0s - loss: 8.8269e-04 - 113ms/epoch - 2ms/step
# Epoch 99/200
# 63/63 - 0s - loss: 8.7793e-04 - 164ms/epoch - 3ms/step
# Epoch 100/200
# 63/63 - 0s - loss: 8.7309e-04 - 143ms/epoch - 2ms/step
# Epoch 101/200
# 63/63 - 0s - loss: 8.6818e-04 - 129ms/epoch - 2ms/step
# Epoch 102/200
# 63/63 - 0s - loss: 8.6321e-04 - 167ms/epoch - 3ms/step
# Epoch 103/200
# 63/63 - 0s - loss: 8.5819e-04 - 128ms/epoch - 2ms/step
# Epoch 104/200
# 63/63 - 0s - loss: 8.5313e-04 - 163ms/epoch - 3ms/step
# Epoch 105/200
# 63/63 - 0s - loss: 8.4802e-04 - 133ms/epoch - 2ms/step
# Epoch 106/200
# 63/63 - 0s - loss: 8.4289e-04 - 129ms/epoch - 2ms/step
# Epoch 107/200
# 63/63 - 0s - loss: 8.3773e-04 - 151ms/epoch - 2ms/step
# Epoch 108/200
# 63/63 - 0s - loss: 8.3255e-04 - 131ms/epoch - 2ms/step
# Epoch 109/200
# 63/63 - 0s - loss: 8.2735e-04 - 147ms/epoch - 2ms/step
# Epoch 110/200
# 63/63 - 0s - loss: 8.2214e-04 - 131ms/epoch - 2ms/step
# Epoch 111/200
# 63/63 - 0s - loss: 8.1692e-04 - 165ms/epoch - 3ms/step
# Epoch 112/200
# 63/63 - 0s - loss: 8.1170e-04 - 108ms/epoch - 2ms/step
# Epoch 113/200
# 63/63 - 0s - loss: 8.0647e-04 - 128ms/epoch - 2ms/step
# Epoch 114/200
# 63/63 - 0s - loss: 8.0124e-04 - 144ms/epoch - 2ms/step
# Epoch 115/200
# 63/63 - 0s - loss: 7.9602e-04 - 135ms/epoch - 2ms/step
# Epoch 116/200
# 63/63 - 0s - loss: 7.9079e-04 - 129ms/epoch - 2ms/step
# Epoch 117/200
# 63/63 - 0s - loss: 7.8557e-04 - 118ms/epoch - 2ms/step
# Epoch 118/200
# 63/63 - 0s - loss: 7.8036e-04 - 118ms/epoch - 2ms/step
# Epoch 119/200
# 63/63 - 0s - loss: 7.7516e-04 - 118ms/epoch - 2ms/step
# Epoch 120/200
# 63/63 - 0s - loss: 7.6997e-04 - 123ms/epoch - 2ms/step
# Epoch 121/200
# 63/63 - 0s - loss: 7.6479e-04 - 139ms/epoch - 2ms/step
# Epoch 122/200
# 63/63 - 0s - loss: 7.5963e-04 - 146ms/epoch - 2ms/step
# Epoch 123/200
# 63/63 - 0s - loss: 7.5449e-04 - 125ms/epoch - 2ms/step
# Epoch 124/200
# 63/63 - 0s - loss: 7.4937e-04 - 121ms/epoch - 2ms/step
# Epoch 125/200
# 63/63 - 0s - loss: 7.4428e-04 - 105ms/epoch - 2ms/step
# Epoch 126/200
# 63/63 - 0s - loss: 7.3920e-04 - 112ms/epoch - 2ms/step
# Epoch 127/200
# 63/63 - 0s - loss: 7.3416e-04 - 120ms/epoch - 2ms/step
# Epoch 128/200
# 63/63 - 0s - loss: 7.2915e-04 - 122ms/epoch - 2ms/step
# Epoch 129/200
# 63/63 - 0s - loss: 7.2417e-04 - 120ms/epoch - 2ms/step
# Epoch 130/200
# 63/63 - 0s - loss: 7.1923e-04 - 120ms/epoch - 2ms/step
# Epoch 131/200
# 63/63 - 0s - loss: 7.1432e-04 - 120ms/epoch - 2ms/step
# Epoch 132/200
# 63/63 - 0s - loss: 7.0946e-04 - 120ms/epoch - 2ms/step
# Epoch 133/200
# 63/63 - 0s - loss: 7.0464e-04 - 118ms/epoch - 2ms/step
# Epoch 134/200
# 63/63 - 0s - loss: 6.9987e-04 - 120ms/epoch - 2ms/step
# Epoch 135/200
# 63/63 - 0s - loss: 6.9514e-04 - 105ms/epoch - 2ms/step
# Epoch 136/200
# 63/63 - 0s - loss: 6.9047e-04 - 119ms/epoch - 2ms/step
# Epoch 137/200
# 63/63 - 0s - loss: 6.8585e-04 - 122ms/epoch - 2ms/step
# Epoch 138/200
# 63/63 - 0s - loss: 6.8129e-04 - 127ms/epoch - 2ms/step
# Epoch 139/200
# 63/63 - 0s - loss: 6.7678e-04 - 112ms/epoch - 2ms/step
# Epoch 140/200
# 63/63 - 0s - loss: 6.7233e-04 - 136ms/epoch - 2ms/step
# Epoch 141/200
# 63/63 - 0s - loss: 6.6795e-04 - 135ms/epoch - 2ms/step
# Epoch 142/200
# 63/63 - 0s - loss: 6.6363e-04 - 115ms/epoch - 2ms/step
# Epoch 143/200
# 63/63 - 0s - loss: 6.5938e-04 - 168ms/epoch - 3ms/step
# Epoch 144/200
# 63/63 - 0s - loss: 6.5519e-04 - 172ms/epoch - 3ms/step
# Epoch 145/200
# 63/63 - 0s - loss: 6.5107e-04 - 160ms/epoch - 3ms/step
# Epoch 146/200
# 63/63 - 0s - loss: 6.4702e-04 - 208ms/epoch - 3ms/step
# Epoch 147/200
# 63/63 - 0s - loss: 6.4304e-04 - 122ms/epoch - 2ms/step
# Epoch 148/200
# 63/63 - 0s - loss: 6.3913e-04 - 125ms/epoch - 2ms/step
# Epoch 149/200
# 63/63 - 0s - loss: 6.3529e-04 - 114ms/epoch - 2ms/step
# Epoch 150/200
# 63/63 - 0s - loss: 6.3153e-04 - 133ms/epoch - 2ms/step
# Epoch 151/200
# 63/63 - 0s - loss: 6.2784e-04 - 149ms/epoch - 2ms/step
# Epoch 152/200
# 63/63 - 0s - loss: 6.2422e-04 - 162ms/epoch - 3ms/step
# Epoch 153/200
# 63/63 - 0s - loss: 6.2067e-04 - 142ms/epoch - 2ms/step
# Epoch 154/200
# 63/63 - 0s - loss: 6.1720e-04 - 144ms/epoch - 2ms/step
# Epoch 155/200
# 63/63 - 0s - loss: 6.1380e-04 - 163ms/epoch - 3ms/step
# Epoch 156/200
# 63/63 - 0s - loss: 6.1048e-04 - 129ms/epoch - 2ms/step
# Epoch 157/200
# 63/63 - 0s - loss: 6.0722e-04 - 133ms/epoch - 2ms/step
# Epoch 158/200
# 63/63 - 0s - loss: 6.0404e-04 - 121ms/epoch - 2ms/step
# Epoch 159/200
# 63/63 - 0s - loss: 6.0093e-04 - 147ms/epoch - 2ms/step
# Epoch 160/200
# 63/63 - 0s - loss: 5.9789e-04 - 180ms/epoch - 3ms/step
# Epoch 161/200
# 63/63 - 0s - loss: 5.9491e-04 - 124ms/epoch - 2ms/step
# Epoch 162/200
# 63/63 - 0s - loss: 5.9201e-04 - 149ms/epoch - 2ms/step
# Epoch 163/200
# 63/63 - 0s - loss: 5.8917e-04 - 131ms/epoch - 2ms/step
# Epoch 164/200
# 63/63 - 0s - loss: 5.8641e-04 - 149ms/epoch - 2ms/step
# Epoch 165/200
# 63/63 - 0s - loss: 5.8370e-04 - 164ms/epoch - 3ms/step
# Epoch 166/200
# 63/63 - 0s - loss: 5.8106e-04 - 127ms/epoch - 2ms/step
# Epoch 167/200
# 63/63 - 0s - loss: 5.7848e-04 - 121ms/epoch - 2ms/step
# Epoch 168/200
# 63/63 - 0s - loss: 5.7597e-04 - 149ms/epoch - 2ms/step
# Epoch 169/200
# 63/63 - 0s - loss: 5.7351e-04 - 146ms/epoch - 2ms/step
# Epoch 170/200
# 63/63 - 0s - loss: 5.7111e-04 - 147ms/epoch - 2ms/step
# Epoch 171/200
# 63/63 - 0s - loss: 5.6877e-04 - 132ms/epoch - 2ms/step
# Epoch 172/200
# 63/63 - 0s - loss: 5.6648e-04 - 159ms/epoch - 3ms/step
# Epoch 173/200
# 63/63 - 0s - loss: 5.6425e-04 - 133ms/epoch - 2ms/step
# Epoch 174/200
# 63/63 - 0s - loss: 5.6207e-04 - 119ms/epoch - 2ms/step
# Epoch 175/200
# 63/63 - 0s - loss: 5.5994e-04 - 120ms/epoch - 2ms/step
# Epoch 176/200
# 63/63 - 0s - loss: 5.5786e-04 - 133ms/epoch - 2ms/step
# Epoch 177/200
# 63/63 - 0s - loss: 5.5583e-04 - 164ms/epoch - 3ms/step
# Epoch 178/200
# 63/63 - 0s - loss: 5.5385e-04 - 127ms/epoch - 2ms/step
# Epoch 179/200
# 63/63 - 0s - loss: 5.5190e-04 - 116ms/epoch - 2ms/step
# Epoch 180/200
# 63/63 - 0s - loss: 5.5001e-04 - 149ms/epoch - 2ms/step
# Epoch 181/200
# 63/63 - 0s - loss: 5.4815e-04 - 161ms/epoch - 3ms/step
# Epoch 182/200
# 63/63 - 0s - loss: 5.4634e-04 - 127ms/epoch - 2ms/step
# Epoch 183/200
# 63/63 - 0s - loss: 5.4456e-04 - 161ms/epoch - 3ms/step
# Epoch 184/200
# 63/63 - 0s - loss: 5.4282e-04 - 168ms/epoch - 3ms/step
# Epoch 185/200
# 63/63 - 0s - loss: 5.4112e-04 - 147ms/epoch - 2ms/step
# Epoch 186/200
# 63/63 - 0s - loss: 5.3945e-04 - 147ms/epoch - 2ms/step
# Epoch 187/200
# 63/63 - 0s - loss: 5.3782e-04 - 125ms/epoch - 2ms/step
# Epoch 188/200
# 63/63 - 0s - loss: 5.3622e-04 - 145ms/epoch - 2ms/step
# Epoch 189/200
# 63/63 - 0s - loss: 5.3465e-04 - 133ms/epoch - 2ms/step
# Epoch 190/200
# 63/63 - 0s - loss: 5.3311e-04 - 147ms/epoch - 2ms/step
# Epoch 191/200
# 63/63 - 0s - loss: 5.3159e-04 - 117ms/epoch - 2ms/step
# Epoch 192/200
# 63/63 - 0s - loss: 5.3011e-04 - 136ms/epoch - 2ms/step
# Epoch 193/200
# 63/63 - 0s - loss: 5.2865e-04 - 131ms/epoch - 2ms/step
# Epoch 194/200
# 63/63 - 0s - loss: 5.2721e-04 - 133ms/epoch - 2ms/step
# Epoch 195/200
# 63/63 - 0s - loss: 5.2580e-04 - 139ms/epoch - 2ms/step
# Epoch 196/200
# 63/63 - 0s - loss: 5.2442e-04 - 162ms/epoch - 3ms/step
# Epoch 197/200
# 63/63 - 0s - loss: 5.2305e-04 - 155ms/epoch - 2ms/step
# Epoch 198/200
# 63/63 - 0s - loss: 5.2171e-04 - 144ms/epoch - 2ms/step
# Epoch 199/200
# 63/63 - 0s - loss: 5.2038e-04 - 114ms/epoch - 2ms/step
# Epoch 200/200
# 63/63 - 0s - loss: 5.1908e-04 - 151ms/epoch - 2ms/step
# 8/8 [==============================] - 0s 5ms/step
# Epoch 1/100
# 125/125 - 2s - loss: 0.1938 - 2s/epoch - 14ms/step
# Epoch 2/100
# 125/125 - 0s - loss: 0.1551 - 284ms/epoch - 2ms/step
# Epoch 3/100
# 125/125 - 0s - loss: 0.1284 - 266ms/epoch - 2ms/step
# Epoch 4/100
# 125/125 - 0s - loss: 0.1069 - 249ms/epoch - 2ms/step
# Epoch 5/100
# 125/125 - 0s - loss: 0.0889 - 240ms/epoch - 2ms/step
# Epoch 6/100
# 125/125 - 0s - loss: 0.0738 - 256ms/epoch - 2ms/step
# Epoch 7/100
# 125/125 - 0s - loss: 0.0610 - 267ms/epoch - 2ms/step
# Epoch 8/100
# 125/125 - 0s - loss: 0.0503 - 284ms/epoch - 2ms/step
# Epoch 9/100
# 125/125 - 0s - loss: 0.0412 - 233ms/epoch - 2ms/step
# Epoch 10/100
# 125/125 - 0s - loss: 0.0336 - 238ms/epoch - 2ms/step
# Epoch 11/100
# 125/125 - 0s - loss: 0.0271 - 280ms/epoch - 2ms/step
# Epoch 12/100
# 125/125 - 0s - loss: 0.0217 - 293ms/epoch - 2ms/step
# Epoch 13/100
# 125/125 - 0s - loss: 0.0171 - 264ms/epoch - 2ms/step
# Epoch 14/100
# 125/125 - 0s - loss: 0.0134 - 280ms/epoch - 2ms/step
# Epoch 15/100
# 125/125 - 0s - loss: 0.0103 - 218ms/epoch - 2ms/step
# Epoch 16/100
# 125/125 - 0s - loss: 0.0078 - 242ms/epoch - 2ms/step
# Epoch 17/100
# 125/125 - 0s - loss: 0.0059 - 240ms/epoch - 2ms/step
# Epoch 18/100
# 125/125 - 0s - loss: 0.0044 - 256ms/epoch - 2ms/step
# Epoch 19/100
# 125/125 - 0s - loss: 0.0033 - 237ms/epoch - 2ms/step
# Epoch 20/100
# 125/125 - 0s - loss: 0.0025 - 212ms/epoch - 2ms/step
# Epoch 21/100
# 125/125 - 0s - loss: 0.0020 - 222ms/epoch - 2ms/step
# Epoch 22/100
# 125/125 - 0s - loss: 0.0017 - 254ms/epoch - 2ms/step
# Epoch 23/100
# 125/125 - 0s - loss: 0.0015 - 233ms/epoch - 2ms/step
# Epoch 24/100
# 125/125 - 0s - loss: 0.0014 - 227ms/epoch - 2ms/step
# Epoch 25/100
# 125/125 - 0s - loss: 0.0013 - 227ms/epoch - 2ms/step
# Epoch 26/100
# 125/125 - 0s - loss: 0.0012 - 227ms/epoch - 2ms/step
# Epoch 27/100
# 125/125 - 0s - loss: 0.0012 - 241ms/epoch - 2ms/step
# Epoch 28/100
# 125/125 - 0s - loss: 0.0012 - 227ms/epoch - 2ms/step
# Epoch 29/100
# 125/125 - 0s - loss: 0.0011 - 224ms/epoch - 2ms/step
# Epoch 30/100
# 125/125 - 0s - loss: 0.0011 - 212ms/epoch - 2ms/step
# Epoch 31/100
# 125/125 - 0s - loss: 0.0011 - 240ms/epoch - 2ms/step
# Epoch 32/100
# 125/125 - 0s - loss: 0.0010 - 242ms/epoch - 2ms/step
# Epoch 33/100
# 125/125 - 0s - loss: 0.0010 - 222ms/epoch - 2ms/step
# Epoch 34/100
# 125/125 - 0s - loss: 9.8046e-04 - 242ms/epoch - 2ms/step
# Epoch 35/100
# 125/125 - 0s - loss: 9.5198e-04 - 241ms/epoch - 2ms/step
# Epoch 36/100
# 125/125 - 0s - loss: 9.2484e-04 - 227ms/epoch - 2ms/step
# Epoch 37/100
# 125/125 - 0s - loss: 8.9910e-04 - 224ms/epoch - 2ms/step
# Epoch 38/100
# 125/125 - 0s - loss: 8.7475e-04 - 242ms/epoch - 2ms/step
# Epoch 39/100
# 125/125 - 0s - loss: 8.5177e-04 - 240ms/epoch - 2ms/step
# Epoch 40/100
# 125/125 - 0s - loss: 8.3009e-04 - 227ms/epoch - 2ms/step
# Epoch 41/100
# 125/125 - 0s - loss: 8.0968e-04 - 240ms/epoch - 2ms/step
# Epoch 42/100
# 125/125 - 0s - loss: 7.9047e-04 - 211ms/epoch - 2ms/step
# Epoch 43/100
# 125/125 - 0s - loss: 7.7244e-04 - 226ms/epoch - 2ms/step
# Epoch 44/100
# 125/125 - 0s - loss: 7.5554e-04 - 224ms/epoch - 2ms/step
# Epoch 45/100
# 125/125 - 0s - loss: 7.3974e-04 - 241ms/epoch - 2ms/step
# Epoch 46/100
# 125/125 - 0s - loss: 7.2500e-04 - 289ms/epoch - 2ms/step
# Epoch 47/100
# 125/125 - 0s - loss: 7.1130e-04 - 265ms/epoch - 2ms/step
# Epoch 48/100
# 125/125 - 0s - loss: 6.9859e-04 - 254ms/epoch - 2ms/step
# Epoch 49/100
# 125/125 - 0s - loss: 6.8684e-04 - 296ms/epoch - 2ms/step
# Epoch 50/100
# 125/125 - 0s - loss: 6.7601e-04 - 262ms/epoch - 2ms/step
# Epoch 51/100
# 125/125 - 0s - loss: 6.6603e-04 - 269ms/epoch - 2ms/step
# Epoch 52/100
# 125/125 - 0s - loss: 6.5687e-04 - 266ms/epoch - 2ms/step
# Epoch 53/100
# 125/125 - 0s - loss: 6.4846e-04 - 296ms/epoch - 2ms/step
# Epoch 54/100
# 125/125 - 0s - loss: 6.4075e-04 - 256ms/epoch - 2ms/step
# Epoch 55/100
# 125/125 - 0s - loss: 6.3368e-04 - 280ms/epoch - 2ms/step
# Epoch 56/100
# 125/125 - 0s - loss: 6.2718e-04 - 236ms/epoch - 2ms/step
# Epoch 57/100
# 125/125 - 0s - loss: 6.2120e-04 - 316ms/epoch - 3ms/step
# Epoch 58/100
# 125/125 - 0s - loss: 6.1567e-04 - 260ms/epoch - 2ms/step
# Epoch 59/100
# 125/125 - 0s - loss: 6.1055e-04 - 251ms/epoch - 2ms/step
# Epoch 60/100
# 125/125 - 0s - loss: 6.0576e-04 - 267ms/epoch - 2ms/step
# Epoch 61/100
# 125/125 - 0s - loss: 6.0127e-04 - 266ms/epoch - 2ms/step
# Epoch 62/100
# 125/125 - 0s - loss: 5.9702e-04 - 259ms/epoch - 2ms/step
# Epoch 63/100
# 125/125 - 0s - loss: 5.9297e-04 - 264ms/epoch - 2ms/step
# Epoch 64/100
# 125/125 - 0s - loss: 5.8909e-04 - 283ms/epoch - 2ms/step
# Epoch 65/100
# 125/125 - 0s - loss: 5.8534e-04 - 251ms/epoch - 2ms/step
# Epoch 66/100
# 125/125 - 0s - loss: 5.8169e-04 - 312ms/epoch - 2ms/step
# Epoch 67/100
# 125/125 - 0s - loss: 5.7813e-04 - 273ms/epoch - 2ms/step
# Epoch 68/100
# 125/125 - 0s - loss: 5.7464e-04 - 251ms/epoch - 2ms/step
# Epoch 69/100
# 125/125 - 0s - loss: 5.7119e-04 - 267ms/epoch - 2ms/step
# Epoch 70/100
# 125/125 - 0s - loss: 5.6779e-04 - 296ms/epoch - 2ms/step
# Epoch 71/100
# 125/125 - 0s - loss: 5.6442e-04 - 277ms/epoch - 2ms/step
# Epoch 72/100
# 125/125 - 0s - loss: 5.6107e-04 - 263ms/epoch - 2ms/step
# Epoch 73/100
# 125/125 - 0s - loss: 5.5774e-04 - 251ms/epoch - 2ms/step
# Epoch 74/100
# 125/125 - 0s - loss: 5.5444e-04 - 267ms/epoch - 2ms/step
# Epoch 75/100
# 125/125 - 0s - loss: 5.5115e-04 - 268ms/epoch - 2ms/step
# Epoch 76/100
# 125/125 - 0s - loss: 5.4787e-04 - 247ms/epoch - 2ms/step
# Epoch 77/100
# 125/125 - 0s - loss: 5.4461e-04 - 257ms/epoch - 2ms/step
# Epoch 78/100
# 125/125 - 0s - loss: 5.4137e-04 - 253ms/epoch - 2ms/step
# Epoch 79/100
# 125/125 - 0s - loss: 5.3814e-04 - 253ms/epoch - 2ms/step
# Epoch 80/100
# 125/125 - 0s - loss: 5.3493e-04 - 348ms/epoch - 3ms/step
# Epoch 81/100
# 125/125 - 0s - loss: 5.3174e-04 - 284ms/epoch - 2ms/step
# Epoch 82/100
# 125/125 - 0s - loss: 5.2856e-04 - 325ms/epoch - 3ms/step
# Epoch 83/100
# 125/125 - 0s - loss: 5.2541e-04 - 304ms/epoch - 2ms/step
# Epoch 84/100
# 125/125 - 0s - loss: 5.2227e-04 - 318ms/epoch - 3ms/step
# Epoch 85/100
# 125/125 - 0s - loss: 5.1915e-04 - 309ms/epoch - 2ms/step
# Epoch 86/100
# 125/125 - 0s - loss: 5.1605e-04 - 369ms/epoch - 3ms/step
# Epoch 87/100
# 125/125 - 0s - loss: 5.1296e-04 - 283ms/epoch - 2ms/step
# Epoch 88/100
# 125/125 - 0s - loss: 5.0990e-04 - 325ms/epoch - 3ms/step
# Epoch 89/100
# 125/125 - 0s - loss: 5.0686e-04 - 317ms/epoch - 3ms/step
# Epoch 90/100
# 125/125 - 0s - loss: 5.0384e-04 - 289ms/epoch - 2ms/step
# Epoch 91/100
# 125/125 - 0s - loss: 5.0085e-04 - 278ms/epoch - 2ms/step
# Epoch 92/100
# 125/125 - 0s - loss: 4.9787e-04 - 282ms/epoch - 2ms/step
# Epoch 93/100
# 125/125 - 0s - loss: 4.9491e-04 - 279ms/epoch - 2ms/step
# Epoch 94/100
# 125/125 - 0s - loss: 4.9198e-04 - 277ms/epoch - 2ms/step
# Epoch 95/100
# 125/125 - 0s - loss: 4.8906e-04 - 262ms/epoch - 2ms/step
# Epoch 96/100
# 125/125 - 0s - loss: 4.8617e-04 - 314ms/epoch - 3ms/step
# Epoch 97/100
# 125/125 - 0s - loss: 4.8330e-04 - 278ms/epoch - 2ms/step
# Epoch 98/100
# 125/125 - 0s - loss: 4.8045e-04 - 263ms/epoch - 2ms/step
# Epoch 99/100
# 125/125 - 0s - loss: 4.7762e-04 - 220ms/epoch - 2ms/step
# Epoch 100/100
# 125/125 - 0s - loss: 4.7482e-04 - 228ms/epoch - 2ms/step
# 8/8 [==============================] - 0s 3ms/step
# Epoch 1/250
# 125/125 - 2s - loss: 0.1686 - 2s/epoch - 12ms/step
# Epoch 2/250
# 125/125 - 0s - loss: 0.0484 - 229ms/epoch - 2ms/step
# Epoch 3/250
# 125/125 - 0s - loss: 0.0459 - 242ms/epoch - 2ms/step
# Epoch 4/250
# 125/125 - 0s - loss: 0.0436 - 224ms/epoch - 2ms/step
# Epoch 5/250
# 125/125 - 0s - loss: 0.0390 - 320ms/epoch - 3ms/step
# Epoch 6/250
# 125/125 - 0s - loss: 0.0337 - 257ms/epoch - 2ms/step
# Epoch 7/250
# 125/125 - 0s - loss: 0.0284 - 300ms/epoch - 2ms/step
# Epoch 8/250
# 125/125 - 0s - loss: 0.0235 - 298ms/epoch - 2ms/step
# Epoch 9/250
# 125/125 - 0s - loss: 0.0190 - 276ms/epoch - 2ms/step
# Epoch 10/250
# 125/125 - 0s - loss: 0.0150 - 264ms/epoch - 2ms/step
# Epoch 11/250
# 125/125 - 0s - loss: 0.0116 - 234ms/epoch - 2ms/step
# Epoch 12/250
# 125/125 - 0s - loss: 0.0089 - 225ms/epoch - 2ms/step
# Epoch 13/250
# 125/125 - 0s - loss: 0.0068 - 242ms/epoch - 2ms/step
# Epoch 14/250
# 125/125 - 0s - loss: 0.0052 - 225ms/epoch - 2ms/step
# Epoch 15/250
# 125/125 - 0s - loss: 0.0041 - 258ms/epoch - 2ms/step
# Epoch 16/250
# 125/125 - 0s - loss: 0.0034 - 238ms/epoch - 2ms/step
# Epoch 17/250
# 125/125 - 0s - loss: 0.0029 - 224ms/epoch - 2ms/step
# Epoch 18/250
# 125/125 - 0s - loss: 0.0027 - 224ms/epoch - 2ms/step
# Epoch 19/250
# 125/125 - 0s - loss: 0.0025 - 228ms/epoch - 2ms/step
# Epoch 20/250
# 125/125 - 0s - loss: 0.0025 - 226ms/epoch - 2ms/step
# Epoch 21/250
# 125/125 - 0s - loss: 0.0024 - 211ms/epoch - 2ms/step
# Epoch 22/250
# 125/125 - 0s - loss: 0.0024 - 213ms/epoch - 2ms/step
# Epoch 23/250
# 125/125 - 0s - loss: 0.0023 - 224ms/epoch - 2ms/step
# Epoch 24/250
# 125/125 - 0s - loss: 0.0023 - 229ms/epoch - 2ms/step
# Epoch 25/250
# 125/125 - 0s - loss: 0.0022 - 227ms/epoch - 2ms/step
# Epoch 26/250
# 125/125 - 0s - loss: 0.0021 - 242ms/epoch - 2ms/step
# Epoch 27/250
# 125/125 - 0s - loss: 0.0021 - 224ms/epoch - 2ms/step
# Epoch 28/250
# 125/125 - 0s - loss: 0.0020 - 211ms/epoch - 2ms/step
# Epoch 29/250
# 125/125 - 0s - loss: 0.0019 - 214ms/epoch - 2ms/step
# Epoch 30/250
# 125/125 - 0s - loss: 0.0019 - 203ms/epoch - 2ms/step
# Epoch 31/250
# 125/125 - 0s - loss: 0.0018 - 259ms/epoch - 2ms/step
# Epoch 32/250
# 125/125 - 0s - loss: 0.0017 - 220ms/epoch - 2ms/step
# Epoch 33/250
# 125/125 - 0s - loss: 0.0017 - 245ms/epoch - 2ms/step
# Epoch 34/250
# 125/125 - 0s - loss: 0.0016 - 240ms/epoch - 2ms/step
# Epoch 35/250
# 125/125 - 0s - loss: 0.0016 - 220ms/epoch - 2ms/step
# Epoch 36/250
# 125/125 - 0s - loss: 0.0015 - 216ms/epoch - 2ms/step
# Epoch 37/250
# 125/125 - 0s - loss: 0.0015 - 258ms/epoch - 2ms/step
# Epoch 38/250
# 125/125 - 0s - loss: 0.0014 - 253ms/epoch - 2ms/step
# Epoch 39/250
# 125/125 - 0s - loss: 0.0014 - 314ms/epoch - 3ms/step
# Epoch 40/250
# 125/125 - 0s - loss: 0.0013 - 305ms/epoch - 2ms/step
# Epoch 41/250
# 125/125 - 0s - loss: 0.0013 - 278ms/epoch - 2ms/step
# Epoch 42/250
# 125/125 - 0s - loss: 0.0013 - 329ms/epoch - 3ms/step
# Epoch 43/250
# 125/125 - 0s - loss: 0.0012 - 280ms/epoch - 2ms/step
# Epoch 44/250
# 125/125 - 0s - loss: 0.0012 - 287ms/epoch - 2ms/step
# Epoch 45/250
# 125/125 - 0s - loss: 0.0012 - 277ms/epoch - 2ms/step
# Epoch 46/250
# 125/125 - 0s - loss: 0.0011 - 294ms/epoch - 2ms/step
# Epoch 47/250
# 125/125 - 0s - loss: 0.0011 - 277ms/epoch - 2ms/step
# Epoch 48/250
# 125/125 - 0s - loss: 0.0011 - 312ms/epoch - 2ms/step
# Epoch 49/250
# 125/125 - 0s - loss: 0.0011 - 259ms/epoch - 2ms/step
# Epoch 50/250
# 125/125 - 0s - loss: 0.0010 - 265ms/epoch - 2ms/step
# Epoch 51/250
# 125/125 - 0s - loss: 0.0010 - 282ms/epoch - 2ms/step
# Epoch 52/250
# 125/125 - 0s - loss: 9.8917e-04 - 295ms/epoch - 2ms/step
# Epoch 53/250
# 125/125 - 0s - loss: 9.7041e-04 - 294ms/epoch - 2ms/step
# Epoch 54/250
# 125/125 - 0s - loss: 9.5282e-04 - 262ms/epoch - 2ms/step
# Epoch 55/250
# 125/125 - 0s - loss: 9.3634e-04 - 265ms/epoch - 2ms/step
# Epoch 56/250
# 125/125 - 0s - loss: 9.2087e-04 - 281ms/epoch - 2ms/step
# Epoch 57/250
# 125/125 - 0s - loss: 9.0635e-04 - 281ms/epoch - 2ms/step
# Epoch 58/250
# 125/125 - 0s - loss: 8.9271e-04 - 262ms/epoch - 2ms/step
# Epoch 59/250
# 125/125 - 0s - loss: 8.7989e-04 - 332ms/epoch - 3ms/step
# Epoch 60/250
# 125/125 - 0s - loss: 8.6783e-04 - 255ms/epoch - 2ms/step
# Epoch 61/250
# 125/125 - 0s - loss: 8.5648e-04 - 240ms/epoch - 2ms/step
# Epoch 62/250
# 125/125 - 0s - loss: 8.4578e-04 - 223ms/epoch - 2ms/step
# Epoch 63/250
# 125/125 - 0s - loss: 8.3570e-04 - 225ms/epoch - 2ms/step
# Epoch 64/250
# 125/125 - 0s - loss: 8.2619e-04 - 223ms/epoch - 2ms/step
# Epoch 65/250
# 125/125 - 0s - loss: 8.1720e-04 - 227ms/epoch - 2ms/step
# Epoch 66/250
# 125/125 - 0s - loss: 8.0871e-04 - 226ms/epoch - 2ms/step
# Epoch 67/250
# 125/125 - 0s - loss: 8.0067e-04 - 235ms/epoch - 2ms/step
# Epoch 68/250
# 125/125 - 0s - loss: 7.9307e-04 - 254ms/epoch - 2ms/step
# Epoch 69/250
# 125/125 - 0s - loss: 7.8586e-04 - 285ms/epoch - 2ms/step
# Epoch 70/250
# 125/125 - 0s - loss: 7.7902e-04 - 218ms/epoch - 2ms/step
# Epoch 71/250
# 125/125 - 0s - loss: 7.7252e-04 - 224ms/epoch - 2ms/step
# Epoch 72/250
# 125/125 - 0s - loss: 7.6635e-04 - 234ms/epoch - 2ms/step
# Epoch 73/250
# 125/125 - 0s - loss: 7.6047e-04 - 234ms/epoch - 2ms/step
# Epoch 74/250
# 125/125 - 0s - loss: 7.5487e-04 - 241ms/epoch - 2ms/step
# Epoch 75/250
# 125/125 - 0s - loss: 7.4952e-04 - 256ms/epoch - 2ms/step
# Epoch 76/250
# 125/125 - 0s - loss: 7.4442e-04 - 237ms/epoch - 2ms/step
# Epoch 77/250
# 125/125 - 0s - loss: 7.3953e-04 - 256ms/epoch - 2ms/step
# Epoch 78/250
# 125/125 - 0s - loss: 7.3486e-04 - 267ms/epoch - 2ms/step
# Epoch 79/250
# 125/125 - 0s - loss: 7.3037e-04 - 251ms/epoch - 2ms/step
# Epoch 80/250
# 125/125 - 0s - loss: 7.2606e-04 - 280ms/epoch - 2ms/step
# Epoch 81/250
# 125/125 - 0s - loss: 7.2191e-04 - 262ms/epoch - 2ms/step
# Epoch 82/250
# 125/125 - 0s - loss: 7.1792e-04 - 251ms/epoch - 2ms/step
# Epoch 83/250
# 125/125 - 0s - loss: 7.1407e-04 - 316ms/epoch - 3ms/step
# Epoch 84/250
# 125/125 - 0s - loss: 7.1035e-04 - 289ms/epoch - 2ms/step
# Epoch 85/250
# 125/125 - 0s - loss: 7.0675e-04 - 293ms/epoch - 2ms/step
# Epoch 86/250
# 125/125 - 0s - loss: 7.0327e-04 - 293ms/epoch - 2ms/step
# Epoch 87/250
# 125/125 - 0s - loss: 6.9989e-04 - 294ms/epoch - 2ms/step
# Epoch 88/250
# 125/125 - 0s - loss: 6.9661e-04 - 293ms/epoch - 2ms/step
# Epoch 89/250
# 125/125 - 0s - loss: 6.9342e-04 - 294ms/epoch - 2ms/step
# Epoch 90/250
# 125/125 - 0s - loss: 6.9032e-04 - 263ms/epoch - 2ms/step
# Epoch 91/250
# 125/125 - 0s - loss: 6.8730e-04 - 283ms/epoch - 2ms/step
# Epoch 92/250
# 125/125 - 0s - loss: 6.8436e-04 - 326ms/epoch - 3ms/step
# Epoch 93/250
# 125/125 - 0s - loss: 6.8148e-04 - 319ms/epoch - 3ms/step
# Epoch 94/250
# 125/125 - 0s - loss: 6.7867e-04 - 287ms/epoch - 2ms/step
# Epoch 95/250
# 125/125 - 0s - loss: 6.7592e-04 - 278ms/epoch - 2ms/step
# Epoch 96/250
# 125/125 - 0s - loss: 6.7323e-04 - 306ms/epoch - 2ms/step
# Epoch 97/250
# 125/125 - 0s - loss: 6.7059e-04 - 296ms/epoch - 2ms/step
# Epoch 98/250
# 125/125 - 0s - loss: 6.6801e-04 - 268ms/epoch - 2ms/step
# Epoch 99/250
# 125/125 - 0s - loss: 6.6547e-04 - 278ms/epoch - 2ms/step
# Epoch 100/250
# 125/125 - 0s - loss: 6.6298e-04 - 264ms/epoch - 2ms/step
# Epoch 101/250
# 125/125 - 0s - loss: 6.6053e-04 - 223ms/epoch - 2ms/step
# Epoch 102/250
# 125/125 - 0s - loss: 6.5813e-04 - 227ms/epoch - 2ms/step
# Epoch 103/250
# 125/125 - 0s - loss: 6.5576e-04 - 228ms/epoch - 2ms/step
# Epoch 104/250
# 125/125 - 0s - loss: 6.5343e-04 - 211ms/epoch - 2ms/step
# Epoch 105/250
# 125/125 - 0s - loss: 6.5114e-04 - 211ms/epoch - 2ms/step
# Epoch 106/250
# 125/125 - 0s - loss: 6.4889e-04 - 200ms/epoch - 2ms/step
# Epoch 107/250
# 125/125 - 0s - loss: 6.4666e-04 - 252ms/epoch - 2ms/step
# Epoch 108/250
# 125/125 - 0s - loss: 6.4447e-04 - 213ms/epoch - 2ms/step
# Epoch 109/250
# 125/125 - 0s - loss: 6.4231e-04 - 216ms/epoch - 2ms/step
# Epoch 110/250
# 125/125 - 0s - loss: 6.4017e-04 - 226ms/epoch - 2ms/step
# Epoch 111/250
# 125/125 - 0s - loss: 6.3807e-04 - 213ms/epoch - 2ms/step
# Epoch 112/250
# 125/125 - 0s - loss: 6.3599e-04 - 227ms/epoch - 2ms/step
# Epoch 113/250
# 125/125 - 0s - loss: 6.3394e-04 - 211ms/epoch - 2ms/step
# Epoch 114/250
# 125/125 - 0s - loss: 6.3191e-04 - 216ms/epoch - 2ms/step
# Epoch 115/250
# 125/125 - 0s - loss: 6.2991e-04 - 226ms/epoch - 2ms/step
# Epoch 116/250
# 125/125 - 0s - loss: 6.2793e-04 - 284ms/epoch - 2ms/step
# Epoch 117/250
# 125/125 - 0s - loss: 6.2597e-04 - 225ms/epoch - 2ms/step
# Epoch 118/250
# 125/125 - 0s - loss: 6.2403e-04 - 224ms/epoch - 2ms/step
# Epoch 119/250
# 125/125 - 0s - loss: 6.2211e-04 - 243ms/epoch - 2ms/step
# Epoch 120/250
# 125/125 - 0s - loss: 6.2022e-04 - 223ms/epoch - 2ms/step
# Epoch 121/250
# 125/125 - 0s - loss: 6.1834e-04 - 227ms/epoch - 2ms/step
# Epoch 122/250
# 125/125 - 0s - loss: 6.1649e-04 - 240ms/epoch - 2ms/step
# Epoch 123/250
# 125/125 - 0s - loss: 6.1465e-04 - 238ms/epoch - 2ms/step
# Epoch 124/250
# 125/125 - 0s - loss: 6.1283e-04 - 224ms/epoch - 2ms/step
# Epoch 125/250
# 125/125 - 0s - loss: 6.1103e-04 - 239ms/epoch - 2ms/step
# Epoch 126/250
# 125/125 - 0s - loss: 6.0925e-04 - 243ms/epoch - 2ms/step
# Epoch 127/250
# 125/125 - 0s - loss: 6.0748e-04 - 219ms/epoch - 2ms/step
# Epoch 128/250
# 125/125 - 0s - loss: 6.0573e-04 - 226ms/epoch - 2ms/step
# Epoch 129/250
# 125/125 - 0s - loss: 6.0399e-04 - 226ms/epoch - 2ms/step
# Epoch 130/250
# 125/125 - 0s - loss: 6.0227e-04 - 272ms/epoch - 2ms/step
# Epoch 131/250
# 125/125 - 0s - loss: 6.0056e-04 - 238ms/epoch - 2ms/step
# Epoch 132/250
# ...
# Epoch 160/250
# 125/125 - 0s - loss: 5.7855e-04 - 332ms/epoch - 3ms/step
# Epoch 161/250
# 125/125 - 0s - loss: 5.7645e-04 - 273ms/epoch - 2ms/step
# Epoch 162/250
# 125/125 - 0s - loss: 5.7433e-04 - 281ms/epoch - 2ms/step
# Epoch 163/250
# 125/125 - 0s - loss: 5.7218e-04 - 340ms/epoch - 3ms/step
# Epoch 164/250
# 125/125 - 0s - loss: 5.7001e-04 - 331ms/epoch - 3ms/step
# Epoch 165/250
# 125/125 - 0s - loss: 5.6783e-04 - 315ms/epoch - 3ms/step
# Epoch 166/250
# 125/125 - 0s - loss: 5.6562e-04 - 247ms/epoch - 2ms/step
# Epoch 167/250
# 125/125 - 0s - loss: 5.6339e-04 - 256ms/epoch - 2ms/step
# Epoch 168/250
# 125/125 - 0s - loss: 5.6115e-04 - 235ms/epoch - 2ms/step
# Epoch 169/250
# 125/125 - 0s - loss: 5.5889e-04 - 225ms/epoch - 2ms/step
# Epoch 170/250
# 125/125 - 0s - loss: 5.5662e-04 - 258ms/epoch - 2ms/step
# Epoch 171/250
# 125/125 - 0s - loss: 5.5433e-04 - 239ms/epoch - 2ms/step
# Epoch 172/250
# 125/125 - 0s - loss: 5.5203e-04 - 240ms/epoch - 2ms/step
# Epoch 173/250
# 125/125 - 0s - loss: 5.4971e-04 - 256ms/epoch - 2ms/step
# Epoch 174/250
# 125/125 - 0s - loss: 5.4739e-04 - 222ms/epoch - 2ms/step
# Epoch 175/250
# 125/125 - 0s - loss: 5.4505e-04 - 231ms/epoch - 2ms/step
# Epoch 176/250
# 125/125 - 0s - loss: 5.4271e-04 - 234ms/epoch - 2ms/step
# Epoch 177/250
# 125/125 - 0s - loss: 5.4036e-04 - 224ms/epoch - 2ms/step
# Epoch 178/250
# 125/125 - 0s - loss: 5.3801e-04 - 242ms/epoch - 2ms/step
# Epoch 179/250
# 125/125 - 0s - loss: 5.3565e-04 - 225ms/epoch - 2ms/step
# Epoch 180/250
# 125/125 - 0s - loss: 5.3329e-04 - 227ms/epoch - 2ms/step
# Epoch 181/250
# 125/125 - 0s - loss: 5.3093e-04 - 211ms/epoch - 2ms/step
# Epoch 182/250
# 125/125 - 0s - loss: 5.2857e-04 - 200ms/epoch - 2ms/step
# Epoch 183/250
# 125/125 - 0s - loss: 5.2621e-04 - 229ms/epoch - 2ms/step
# Epoch 184/250
# 125/125 - 0s - loss: 5.2385e-04 - 196ms/epoch - 2ms/step
# Epoch 185/250
# 125/125 - 0s - loss: 5.2150e-04 - 217ms/epoch - 2ms/step
# Epoch 186/250
# 125/125 - 0s - loss: 5.1915e-04 - 211ms/epoch - 2ms/step
# Epoch 187/250
# 125/125 - 0s - loss: 5.1681e-04 - 200ms/epoch - 2ms/step
# Epoch 188/250
# 125/125 - 0s - loss: 5.1447e-04 - 213ms/epoch - 2ms/step
# Epoch 189/250
# 125/125 - 0s - loss: 5.1214e-04 - 229ms/epoch - 2ms/step
# Epoch 190/250
# 125/125 - 0s - loss: 5.0983e-04 - 242ms/epoch - 2ms/step
# Epoch 191/250
# 125/125 - 0s - loss: 5.0752e-04 - 224ms/epoch - 2ms/step
# Epoch 192/250
# 125/125 - 0s - loss: 5.0522e-04 - 227ms/epoch - 2ms/step
# Epoch 193/250
# 125/125 - 0s - loss: 5.0294e-04 - 223ms/epoch - 2ms/step
# Epoch 194/250
# 125/125 - 0s - loss: 5.0067e-04 - 238ms/epoch - 2ms/step
# Epoch 195/250
# 125/125 - 0s - loss: 4.9841e-04 - 228ms/epoch - 2ms/step
# Epoch 196/250
# 125/125 - 0s - loss: 4.9617e-04 - 242ms/epoch - 2ms/step
# Epoch 197/250
# 125/125 - 0s - loss: 4.9394e-04 - 240ms/epoch - 2ms/step
# Epoch 198/250
# 125/125 - 0s - loss: 4.9173e-04 - 240ms/epoch - 2ms/step
# Epoch 199/250
# 125/125 - 0s - loss: 4.8954e-04 - 224ms/epoch - 2ms/step
# Epoch 200/250
# 125/125 - 0s - loss: 4.8736e-04 - 227ms/epoch - 2ms/step
# Epoch 201/250
# 125/125 - 0s - loss: 4.8520e-04 - 242ms/epoch - 2ms/step
# Epoch 202/250
# 125/125 - 0s - loss: 4.8307e-04 - 238ms/epoch - 2ms/step
# Epoch 203/250
# 125/125 - 0s - loss: 4.8095e-04 - 225ms/epoch - 2ms/step
# Epoch 204/250
# 125/125 - 0s - loss: 4.7885e-04 - 227ms/epoch - 2ms/step
# Epoch 205/250
# 125/125 - 0s - loss: 4.7677e-04 - 257ms/epoch - 2ms/step
# Epoch 206/250
# 125/125 - 0s - loss: 4.7471e-04 - 222ms/epoch - 2ms/step
# Epoch 207/250
# 125/125 - 0s - loss: 4.7268e-04 - 272ms/epoch - 2ms/step
# Epoch 208/250
# 125/125 - 0s - loss: 4.7067e-04 - 282ms/epoch - 2ms/step
# Epoch 209/250
# 125/125 - 0s - loss: 4.6868e-04 - 295ms/epoch - 2ms/step
# Epoch 210/250
# 125/125 - 0s - loss: 4.6671e-04 - 310ms/epoch - 2ms/step
# Epoch 211/250
# 125/125 - 0s - loss: 4.6477e-04 - 247ms/epoch - 2ms/step
# Epoch 212/250
# 125/125 - 0s - loss: 4.6285e-04 - 253ms/epoch - 2ms/step
# Epoch 213/250
# 125/125 - 0s - loss: 4.6095e-04 - 254ms/epoch - 2ms/step
# Epoch 214/250
# 125/125 - 0s - loss: 4.5909e-04 - 267ms/epoch - 2ms/step
# Epoch 215/250
# 125/125 - 0s - loss: 4.5724e-04 - 237ms/epoch - 2ms/step
# Epoch 216/250
# 125/125 - 0s - loss: 4.5542e-04 - 289ms/epoch - 2ms/step
# Epoch 217/250
# 125/125 - 0s - loss: 4.5362e-04 - 245ms/epoch - 2ms/step
# Epoch 218/250
# 125/125 - 0s - loss: 4.5186e-04 - 270ms/epoch - 2ms/step
# Epoch 219/250
# 125/125 - 0s - loss: 4.5011e-04 - 238ms/epoch - 2ms/step
# Epoch 220/250
# 125/125 - 0s - loss: 4.4840e-04 - 224ms/epoch - 2ms/step
# Epoch 221/250
# 125/125 - 0s - loss: 4.4671e-04 - 303ms/epoch - 2ms/step
# Epoch 222/250
# 125/125 - 0s - loss: 4.4505e-04 - 287ms/epoch - 2ms/step
# Epoch 223/250
# 125/125 - 0s - loss: 4.4341e-04 - 327ms/epoch - 3ms/step
# Epoch 224/250
# 125/125 - 0s - loss: 4.4180e-04 - 288ms/epoch - 2ms/step
# Epoch 225/250
# 125/125 - 0s - loss: 4.4023e-04 - 341ms/epoch - 3ms/step
# Epoch 226/250
# 125/125 - 0s - loss: 4.3867e-04 - 330ms/epoch - 3ms/step
# Epoch 227/250
# 125/125 - 0s - loss: 4.3715e-04 - 303ms/epoch - 2ms/step
# Epoch 228/250
# 125/125 - 0s - loss: 4.3566e-04 - 307ms/epoch - 2ms/step
# Epoch 229/250
# 125/125 - 0s - loss: 4.3419e-04 - 335ms/epoch - 3ms/step
# Epoch 230/250
# 125/125 - 0s - loss: 4.3275e-04 - 302ms/epoch - 2ms/step
# Epoch 231/250
# 125/125 - 0s - loss: 4.3135e-04 - 293ms/epoch - 2ms/step
# Epoch 232/250
# 125/125 - 0s - loss: 4.2997e-04 - 276ms/epoch - 2ms/step
# Epoch 233/250
# 125/125 - 0s - loss: 4.2862e-04 - 344ms/epoch - 3ms/step
# Epoch 234/250
# 125/125 - 0s - loss: 4.2730e-04 - 300ms/epoch - 2ms/step
# Epoch 235/250
# 125/125 - 0s - loss: 4.2601e-04 - 320ms/epoch - 3ms/step
# Epoch 236/250
# 125/125 - 0s - loss: 4.2475e-04 - 306ms/epoch - 2ms/step
# Epoch 237/250
# 125/125 - 0s - loss: 4.2353e-04 - 291ms/epoch - 2ms/step
# Epoch 238/250
# 125/125 - 0s - loss: 4.2233e-04 - 292ms/epoch - 2ms/step
# Epoch 239/250
# 125/125 - 0s - loss: 4.2116e-04 - 259ms/epoch - 2ms/step
# Epoch 240/250
# 125/125 - 0s - loss: 4.2002e-04 - 301ms/epoch - 2ms/step
# Epoch 241/250
# 125/125 - 0s - loss: 4.1892e-04 - 339ms/epoch - 3ms/step
# Epoch 242/250
# 125/125 - 0s - loss: 4.1784e-04 - 284ms/epoch - 2ms/step
# Epoch 243/250
# 125/125 - 0s - loss: 4.1680e-04 - 326ms/epoch - 3ms/step
# Epoch 244/250
# 125/125 - 0s - loss: 4.1579e-04 - 302ms/epoch - 2ms/step
# Epoch 245/250
# 125/125 - 0s - loss: 4.1481e-04 - 309ms/epoch - 2ms/step
# Epoch 246/250
# 125/125 - 0s - loss: 4.1386e-04 - 290ms/epoch - 2ms/step
# Epoch 247/250
# 125/125 - 0s - loss: 4.1293e-04 - 306ms/epoch - 2ms/step
# Epoch 248/250
# 125/125 - 0s - loss: 4.1205e-04 - 276ms/epoch - 2ms/step
# Epoch 249/250
# 125/125 - 0s - loss: 4.1119e-04 - 287ms/epoch - 2ms/step
# Epoch 250/250
# 125/125 - 0s - loss: 4.1036e-04 - 305ms/epoch - 2ms/step
# 8/8 [==============================] - 0s 4ms/step
# Epoch 1/300
# 125/125 - 2s - loss: 1.3675 - 2s/epoch - 14ms/step
# Epoch 2/300
# 125/125 - 0s - loss: 0.0815 - 261ms/epoch - 2ms/step
# Epoch 3/300
# 125/125 - 0s - loss: 0.0028 - 267ms/epoch - 2ms/step
# Epoch 4/300
# 125/125 - 0s - loss: 0.0014 - 316ms/epoch - 3ms/step
# Epoch 5/300
# 125/125 - 0s - loss: 0.0013 - 273ms/epoch - 2ms/step
# Epoch 6/300
# 125/125 - 0s - loss: 0.0012 - 306ms/epoch - 2ms/step
# Epoch 7/300
# 125/125 - 0s - loss: 0.0011 - 263ms/epoch - 2ms/step
# Epoch 8/300
# 125/125 - 0s - loss: 0.0011 - 285ms/epoch - 2ms/step
# Epoch 9/300
# 125/125 - 0s - loss: 0.0010 - 291ms/epoch - 2ms/step
# Epoch 10/300
# 125/125 - 0s - loss: 0.0010 - 282ms/epoch - 2ms/step
# Epoch 11/300
# 125/125 - 0s - loss: 9.9930e-04 - 326ms/epoch - 3ms/step
# Epoch 12/300
# 125/125 - 0s - loss: 9.9871e-04 - 303ms/epoch - 2ms/step
# Epoch 13/300
# 125/125 - 0s - loss: 0.0010 - 322ms/epoch - 3ms/step
# Epoch 14/300
# 125/125 - 0s - loss: 0.0010 - 273ms/epoch - 2ms/step
# Epoch 15/300
# 125/125 - 0s - loss: 0.0010 - 312ms/epoch - 2ms/step
# Epoch 16/300
# 125/125 - 0s - loss: 0.0010 - 291ms/epoch - 2ms/step
# Epoch 17/300
# 125/125 - 0s - loss: 0.0010 - 336ms/epoch - 3ms/step
# Epoch 18/300
# 125/125 - 0s - loss: 0.0010 - 288ms/epoch - 2ms/step
# Epoch 19/300
# 125/125 - 0s - loss: 0.0010 - 262ms/epoch - 2ms/step
# Epoch 20/300
# 125/125 - 0s - loss: 0.0010 - 288ms/epoch - 2ms/step
# Epoch 21/300
# 125/125 - 0s - loss: 0.0010 - 276ms/epoch - 2ms/step
# Epoch 22/300
# 125/125 - 0s - loss: 0.0010 - 249ms/epoch - 2ms/step
# 8/8 [==============================] - 0s 3ms/step
# Epoch 1/300
# 125/125 - 2s - loss: 0.7181 - 2s/epoch - 12ms/step
# Epoch 2/300
# 125/125 - 0s - loss: 0.0091 - 274ms/epoch - 2ms/step
# Epoch 3/300
# 125/125 - 0s - loss: 0.0035 - 356ms/epoch - 3ms/step
# Epoch 4/300
# 125/125 - 0s - loss: 0.0026 - 296ms/epoch - 2ms/step
# Epoch 5/300
# 125/125 - 0s - loss: 0.0017 - 289ms/epoch - 2ms/step
# Epoch 6/300
# 125/125 - 0s - loss: 0.0012 - 340ms/epoch - 3ms/step
# Epoch 7/300
# 125/125 - 0s - loss: 9.3626e-04 - 406ms/epoch - 3ms/step
# Epoch 8/300
# 125/125 - 0s - loss: 8.0928e-04 - 375ms/epoch - 3ms/step
# Epoch 9/300
# 125/125 - 0s - loss: 7.6320e-04 - 336ms/epoch - 3ms/step
# Epoch 10/300
# 125/125 - 0s - loss: 7.5528e-04 - 300ms/epoch - 2ms/step
# Epoch 11/300
# 125/125 - 0s - loss: 7.6233e-04 - 291ms/epoch - 2ms/step
# Epoch 12/300
# 125/125 - 0s - loss: 7.7312e-04 - 291ms/epoch - 2ms/step
# Epoch 13/300
# 125/125 - 0s - loss: 7.8282e-04 - 323ms/epoch - 3ms/step
# Epoch 14/300
# 125/125 - 0s - loss: 7.8976e-04 - 297ms/epoch - 2ms/step
# Epoch 15/300
# 125/125 - 0s - loss: 7.9359e-04 - 308ms/epoch - 2ms/step
# Epoch 16/300
# 125/125 - 0s - loss: 7.9457e-04 - 290ms/epoch - 2ms/step
# Epoch 17/300
# 125/125 - 0s - loss: 7.9313e-04 - 270ms/epoch - 2ms/step
# Epoch 18/300
# 125/125 - 0s - loss: 7.8976e-04 - 309ms/epoch - 2ms/step
# Epoch 19/300
# 125/125 - 0s - loss: 7.8495e-04 - 301ms/epoch - 2ms/step
# Epoch 20/300
# 125/125 - 0s - loss: 7.7914e-04 - 289ms/epoch - 2ms/step
# 8/8 [==============================] - 0s 4ms/step
# Epoch 1/300
# 125/125 - 1s - loss: 0.0125 - 1s/epoch - 12ms/step
# Epoch 2/300
# 125/125 - 0s - loss: 0.0072 - 235ms/epoch - 2ms/step
# Epoch 3/300
# 125/125 - 0s - loss: 0.0040 - 268ms/epoch - 2ms/step
# Epoch 4/300
# 125/125 - 0s - loss: 0.0025 - 251ms/epoch - 2ms/step
# Epoch 5/300
# 125/125 - 0s - loss: 0.0017 - 248ms/epoch - 2ms/step
# Epoch 6/300
# 125/125 - 0s - loss: 0.0013 - 236ms/epoch - 2ms/step
# Epoch 7/300
# 125/125 - 0s - loss: 0.0011 - 235ms/epoch - 2ms/step
# Epoch 8/300
# 125/125 - 0s - loss: 9.2175e-04 - 224ms/epoch - 2ms/step
# Epoch 9/300
# 125/125 - 0s - loss: 8.3857e-04 - 205ms/epoch - 2ms/step
# Epoch 10/300
# 125/125 - 0s - loss: 7.8895e-04 - 216ms/epoch - 2ms/step
# Epoch 11/300
# 125/125 - 0s - loss: 7.6110e-04 - 209ms/epoch - 2ms/step
# Epoch 12/300
# 125/125 - 0s - loss: 7.4850e-04 - 243ms/epoch - 2ms/step
# Epoch 13/300
# 125/125 - 0s - loss: 7.4722e-04 - 220ms/epoch - 2ms/step
# Epoch 14/300
# 125/125 - 0s - loss: 7.5452e-04 - 223ms/epoch - 2ms/step
# Epoch 15/300
# 125/125 - 0s - loss: 7.6823e-04 - 240ms/epoch - 2ms/step
# Epoch 16/300
# 125/125 - 0s - loss: 7.8649e-04 - 249ms/epoch - 2ms/step
# Epoch 17/300
# 125/125 - 0s - loss: 8.0764e-04 - 236ms/epoch - 2ms/step
# Epoch 18/300
# 125/125 - 0s - loss: 8.3024e-04 - 255ms/epoch - 2ms/step
# Epoch 19/300
# 125/125 - 0s - loss: 8.5303e-04 - 216ms/epoch - 2ms/step
# Epoch 20/300
# 125/125 - 0s - loss: 8.7491e-04 - 241ms/epoch - 2ms/step
# Epoch 21/300
# 125/125 - 0s - loss: 8.9500e-04 - 235ms/epoch - 2ms/step
# Epoch 22/300
# 125/125 - 0s - loss: 9.1262e-04 - 270ms/epoch - 2ms/step
# Epoch 23/300
# 125/125 - 0s - loss: 9.2735e-04 - 233ms/epoch - 2ms/step
# 8/8 [==============================] - 0s 2ms/step
# Epoch 1/250
# 63/63 - 1s - loss: 0.1415 - 950ms/epoch - 15ms/step
# Epoch 2/250
# 63/63 - 0s - loss: 0.1057 - 111ms/epoch - 2ms/step
# Epoch 3/250
# 63/63 - 0s - loss: 0.0736 - 106ms/epoch - 2ms/step
# Epoch 4/250
# 63/63 - 0s - loss: 0.0493 - 92ms/epoch - 1ms/step
# Epoch 5/250
# 63/63 - 0s - loss: 0.0322 - 93ms/epoch - 1ms/step
# Epoch 6/250
# 63/63 - 0s - loss: 0.0204 - 78ms/epoch - 1ms/step
# Epoch 7/250
# 63/63 - 0s - loss: 0.0125 - 78ms/epoch - 1ms/step
# Epoch 8/250
# 63/63 - 0s - loss: 0.0075 - 109ms/epoch - 2ms/step
# Epoch 9/250
# 63/63 - 0s - loss: 0.0044 - 87ms/epoch - 1ms/step
# Epoch 10/250
# 63/63 - 0s - loss: 0.0026 - 93ms/epoch - 1ms/step
# Epoch 11/250
# 63/63 - 0s - loss: 0.0017 - 93ms/epoch - 1ms/step
# Epoch 12/250
# 63/63 - 0s - loss: 0.0012 - 109ms/epoch - 2ms/step
# Epoch 13/250
# 63/63 - 0s - loss: 9.4760e-04 - 105ms/epoch - 2ms/step
# Epoch 14/250
# 63/63 - 0s - loss: 8.4959e-04 - 125ms/epoch - 2ms/step
# Epoch 15/250
# 63/63 - 0s - loss: 8.1506e-04 - 88ms/epoch - 1ms/step
# Epoch 16/250
# 63/63 - 0s - loss: 8.0791e-04 - 78ms/epoch - 1ms/step
# Epoch 17/250
# 63/63 - 0s - loss: 8.1101e-04 - 96ms/epoch - 2ms/step
# Epoch 18/250
# 63/63 - 0s - loss: 8.1695e-04 - 93ms/epoch - 1ms/step
# Epoch 19/250
# 63/63 - 0s - loss: 8.2294e-04 - 75ms/epoch - 1ms/step
# Epoch 20/250
# 63/63 - 0s - loss: 8.2815e-04 - 98ms/epoch - 2ms/step
# Epoch 21/250
# 63/63 - 0s - loss: 8.3250e-04 - 122ms/epoch - 2ms/step
# Epoch 22/250
# 63/63 - 0s - loss: 8.3613e-04 - 89ms/epoch - 1ms/step
# Epoch 23/250
# 63/63 - 0s - loss: 8.3921e-04 - 93ms/epoch - 1ms/step
# Epoch 24/250
# 63/63 - 0s - loss: 8.4187e-04 - 109ms/epoch - 2ms/step
# Epoch 25/250
# 63/63 - 0s - loss: 8.4418e-04 - 89ms/epoch - 1ms/step
# Epoch 26/250
# 63/63 - 0s - loss: 8.4620e-04 - 95ms/epoch - 2ms/step
# 8/8 [==============================] - 0s 4ms/step
# Epoch 1/250
# 125/125 - 1s - loss: 0.4280 - 999ms/epoch - 8ms/step
# Epoch 2/250
# 125/125 - 0s - loss: 0.0012 - 191ms/epoch - 2ms/step
# Epoch 3/250
# 125/125 - 0s - loss: 9.9978e-04 - 185ms/epoch - 1ms/step
# Epoch 4/250
# 125/125 - 0s - loss: 8.3077e-04 - 186ms/epoch - 1ms/step
# Epoch 5/250
# 125/125 - 0s - loss: 7.5309e-04 - 205ms/epoch - 2ms/step
# Epoch 6/250
# 125/125 - 0s - loss: 7.1756e-04 - 167ms/epoch - 1ms/step
# Epoch 7/250
# 125/125 - 0s - loss: 6.9989e-04 - 189ms/epoch - 2ms/step
# Epoch 8/250
# 125/125 - 0s - loss: 6.8977e-04 - 189ms/epoch - 2ms/step
# Epoch 9/250
# 125/125 - 0s - loss: 6.8293e-04 - 169ms/epoch - 1ms/step
# Epoch 10/250
# 125/125 - 0s - loss: 6.7759e-04 - 205ms/epoch - 2ms/step
# Epoch 11/250
# 125/125 - 0s - loss: 6.7308e-04 - 169ms/epoch - 1ms/step
# Epoch 12/250
# 125/125 - 0s - loss: 6.6922e-04 - 173ms/epoch - 1ms/step
# Epoch 13/250
# 125/125 - 0s - loss: 6.6599e-04 - 189ms/epoch - 2ms/step
# Epoch 14/250
# 125/125 - 0s - loss: 6.6339e-04 - 183ms/epoch - 1ms/step
# Epoch 15/250
# 125/125 - 0s - loss: 6.6139e-04 - 158ms/epoch - 1ms/step
# Epoch 16/250
# 125/125 - 0s - loss: 6.5990e-04 - 173ms/epoch - 1ms/step
# Epoch 17/250
# 125/125 - 0s - loss: 6.5879e-04 - 202ms/epoch - 2ms/step
# Epoch 18/250
# 125/125 - 0s - loss: 6.5795e-04 - 169ms/epoch - 1ms/step
# Epoch 19/250
# 125/125 - 0s - loss: 6.5730e-04 - 176ms/epoch - 1ms/step
# Epoch 20/250
# 125/125 - 0s - loss: 6.5688e-04 - 204ms/epoch - 2ms/step
# Epoch 21/250
# 125/125 - 0s - loss: 6.5680e-04 - 169ms/epoch - 1ms/step
# Epoch 22/250
# 125/125 - 0s - loss: 6.5728e-04 - 172ms/epoch - 1ms/step
# Epoch 23/250
# 125/125 - 0s - loss: 6.5863e-04 - 173ms/epoch - 1ms/step
# Epoch 24/250
# 125/125 - 0s - loss: 6.6118e-04 - 190ms/epoch - 2ms/step
# Epoch 25/250
# 125/125 - 0s - loss: 6.6525e-04 - 186ms/epoch - 1ms/step
# Epoch 26/250
# 125/125 - 0s - loss: 6.7103e-04 - 216ms/epoch - 2ms/step
# Epoch 27/250
# 125/125 - 0s - loss: 6.7859e-04 - 200ms/epoch - 2ms/step
# Epoch 28/250
# 125/125 - 0s - loss: 6.8782e-04 - 183ms/epoch - 1ms/step
# Epoch 29/250
# 125/125 - 0s - loss: 6.9845e-04 - 205ms/epoch - 2ms/step
# Epoch 30/250
# 125/125 - 0s - loss: 7.1005e-04 - 182ms/epoch - 1ms/step
# Epoch 31/250
# 125/125 - 0s - loss: 7.2218e-04 - 204ms/epoch - 2ms/step
# 8/8 [==============================] - 0s 3ms/step
# Epoch 1/250
# 63/63 - 1s - loss: 0.3769 - 1s/epoch - 16ms/step
# Epoch 2/250
# 63/63 - 0s - loss: 0.0050 - 108ms/epoch - 2ms/step
# Epoch 3/250
# 63/63 - 0s - loss: 7.1263e-04 - 89ms/epoch - 1ms/step
# Epoch 4/250
# 63/63 - 0s - loss: 7.0946e-04 - 93ms/epoch - 1ms/step
# Epoch 5/250
# 63/63 - 0s - loss: 7.1459e-04 - 93ms/epoch - 1ms/step
# Epoch 6/250
# 63/63 - 0s - loss: 7.1900e-04 - 120ms/epoch - 2ms/step
# Epoch 7/250
# 63/63 - 0s - loss: 7.2343e-04 - 107ms/epoch - 2ms/step
# Epoch 8/250
# 63/63 - 0s - loss: 7.2800e-04 - 107ms/epoch - 2ms/step
# Epoch 9/250
# 63/63 - 0s - loss: 7.3280e-04 - 93ms/epoch - 1ms/step
# Epoch 10/250
# 63/63 - 0s - loss: 7.3782e-04 - 106ms/epoch - 2ms/step
# Epoch 11/250
# 63/63 - 0s - loss: 7.4302e-04 - 123ms/epoch - 2ms/step
# Epoch 12/250
# 63/63 - 0s - loss: 7.4832e-04 - 92ms/epoch - 1ms/step
# Epoch 13/250
# 63/63 - 0s - loss: 7.5367e-04 - 107ms/epoch - 2ms/step
# Epoch 14/250
# 63/63 - 0s - loss: 7.5898e-04 - 92ms/epoch - 1ms/step
# 8/8 [==============================] - 0s 2ms/step

# %%
df_MseWith_Neural
# Out:
#     Neural Hidden  Batch_Size  Epoch       MSE   Time Train  Time Test  \
# 0             1.0         8.0  250.0  0.001952  1401.978041   0.907636
# 1             2.0        16.0  200.0  0.002187  1325.857326   0.745602
# 2             3.0         8.0  100.0  0.001507  1350.882249   0.360301
# 3             4.0         8.0  250.0  0.001380  1433.192593   0.364706
# 4             5.0         8.0  200.0  0.001230  1456.983125   0.413893
# 5             6.0         8.0  200.0  0.002987  1450.952945   3.817568
# 6             7.0         8.0  300.0  0.001809  1494.395917   5.988313
# 7             8.0         8.0  250.0  0.000926  1574.738716   0.446380
# 8             9.0         8.0  250.0  0.000983  1531.727035   0.435215
# 9            10.0         8.0  250.0  0.002122  1507.876548   3.323826
# 10           11.0         8.0  200.0  0.001109  1449.571717   0.737322
# 11           12.0         8.0  300.0  0.000878  1722.029110   0.503167
# 12           13.0         8.0  300.0  0.002606  1487.876495   4.936436
# 13           14.0         8.0  250.0  0.000991  1531.416746   0.597785
# 14           15.0         8.0  300.0  0.003305  1541.569196   4.397083
# 15           16.0         8.0  300.0  0.002178  1504.086128   0.593633
# 16           17.0         8.0  300.0  0.001890  1449.109961   0.381961
# 17           18.0        16.0  250.0  0.003183  1026.754112   2.753983
# 18           19.0         8.0  250.0  0.001884   940.545224   0.210497
# 19           20.0        16.0  250.0  0.002527   907.666051   0.237548
#
#      Total Time
# 0   1402.885677
# 1   1326.602927
# 2   1351.242550
# 3   1433.557299
# 4   1457.397018
# 5   1454.770513
# 6   1500.384231
# 7   1575.185096
# 8   1532.162250
# 9   1511.200374
# 10  1450.309039
# 11  1722.532277
# 12  1492.812931
# 13  1532.014531
# 14  1545.966279
# 15  1504.679760
# 16  1449.491922
# 17  1029.508095
# 18   940.755721
# 19   907.903599

# %%
plt.title("Biểu đồ Tập Dữ Liệu "+nameData)
plt.plot(readData(filePath), label= nameData+'Stock')
plt.xlabel("Ngày")
plt.ylabel("Giá Cổ Phiếu")
plt.legend()
plt.show()

# %%
# Vẽ biểu đồ
plt.plot(range(1,len(df_MseWith_Neural[['MSE']])+1), df_MseWith_Neural[['MSE']])
plt.title("Biểu đồ MSE Theo Neural Hidden Tập Dữ Liệu "+nameData)
plt.xlabel("Neural Hidden")
plt.ylabel("MSE")
plt.xticks(range(1,len(df_MseWith_Neural[['MSE']])+1))
plt.show()

# %%
df_MseWith_Neural_Sort = df_MseWith_Neural.sort_values('MSE')
best_Neural=df_MseWith_Neural_Sort['Neural Hidden'].iloc[0]

# %%
df_MseWith_Neural_Sort
# Out:
#     Neural Hidden  Batch_Size  Epoch       MSE   Time Train  Time Test  \
# 11           12.0         8.0  300.0  0.000878  1722.029110   0.503167
# 7             8.0         8.0  250.0  0.000926  1574.738716   0.446380
# 8             9.0         8.0  250.0  0.000983  1531.727035   0.435215
# 13           14.0         8.0  250.0  0.000991  1531.416746   0.597785
# 10           11.0         8.0  200.0  0.001109  1449.571717   0.737322
# 4             5.0         8.0  200.0  0.001230  1456.983125   0.413893
# 3             4.0         8.0  250.0  0.001380  1433.192593   0.364706
# 2             3.0         8.0  100.0  0.001507  1350.882249   0.360301
# 6             7.0         8.0  300.0  0.001809  1494.395917   5.988313
# 18           19.0         8.0  250.0  0.001884   940.545224   0.210497
# 16           17.0         8.0  300.0  0.001890  1449.109961   0.381961
# 0             1.0         8.0  250.0  0.001952  1401.978041   0.907636
# 9            10.0         8.0  250.0  0.002122  1507.876548   3.323826
# 15           16.0         8.0  300.0  0.002178  1504.086128   0.593633
# 1             2.0        16.0  200.0  0.002187  1325.857326   0.745602
# 19           20.0        16.0  250.0  0.002527   907.666051   0.237548
# 12           13.0         8.0  300.0  0.002606  1487.876495   4.936436
# 5             6.0         8.0  200.0  0.002987  1450.952945   3.817568
# 17           18.0        16.0  250.0  0.003183  1026.754112   2.753983
# 14           15.0         8.0  300.0  0.003305  1541.569196   4.397083
#
#      Total Time
# 11  1722.532277
# 7   1575.185096
# 8   1532.162250
# 13  1532.014531
# 10  1450.309039
# 4   1457.397018
# 3   1433.557299
# 2   1351.242550
# 6   1500.384231
# 18   940.755721
# 16  1449.491922
# 0   1402.885677
# 9   1511.200374
# 15  1504.679760
# 1   1326.602927
# 19   907.903599
# 12  1492.812931
# 5   1454.770513
# 17  1029.508095
# 14  1545.966279

# %%
best_Neural
# Out:
# 12.0

# %%
# Vẽ biểu đồ
best_param = {'batch_size': df_MseWith_Neural_Sort['Batch_Size'].iloc[0],
              'epochs': df_MseWith_Neural_Sort['Epoch'].iloc[0],
              'neuralHidden': df_MseWith_Neural_Sort['Neural Hidden'].iloc[0],
              'num_layers_hidden' : numHiddenLayer,
              'neuralInput' : size_window,
              'neuralOutput' : size_predict}
y_pred= predict_FFNN(nameData, 'FFNN_Find_NeuralHidden', X_train, y_train, X_test, best_param)

plt.title("Biểu đồ Dự Đoán FFNN Với Neural Hidden Tốt Nhất Trên Tập Dữ Liệu "+nameData)
plt.plot(y_pred, label=nameData+' Prediction Stock')
plt.plot(y_test, label=nameData+' Actual Stock')
plt.xlabel("Ngày")
plt.ylabel("Giá Cổ Phiếu")
plt.legend()
plt.show()
# Out:
# 8/8 [==============================] - 0s 3ms/step

# %% [markdown]
# # Load Predict

# %%
# neural=range(1,21)
# batch_size=[8,
# 16,
# 8,
# 8,
# 8,
# 8,
# 8,
# 8,
# 8,
# 8,
# 8,
# 8,
# 8,
# 8,
# 8,
# 8,
# 8,
# 16,
# 8,
# 16,
# ]
# epochs=[250,
# 200,
# 100,
# 250,
# 200,
# 200,
# 300,
# 250,
# 250,
# 250,
# 200,
# 300,
# 300,
# 250,
# 300,
# 300,
# 300,
# 250,
# 250,
# 250,
# ]

# nameData= 'GDDY'
# filePath= '../../Dataset/'+nameData+'.csv'
# timeSeries = readData(filePath)
# timeSeries = cleanData(timeSeries)
# percentTrain = 80
# train_data, test_data = splitData(timeSeries, percentTrain)

# size_window = 7
# size_predict=1
# stepWindow=1
# X_train, y_train = prepare_data(train_data.values, size_window, size_predict, stepWindow)
# X_test, y_test =   prepare_data(test_data.values, size_window, size_predict, stepWindow)

# numHiddenLayer= 1

# df_MseWith_Neural = pd.DataFrame([],  columns =  ["Neural Hidden","Batch_Size","Epoch", "MSE"])

# for i in range(len(neural)):

#     best_param = {'batch_size': batch_size[i],
#               'epochs': epochs[i],
#               'neuralHidden': neural[i],
#               'num_layers_hidden' : numHiddenLayer,
#               'neuralInput' : size_window,
#               'neuralOutput' : size_predict}
#     y_pred= predict_FFNN(nameData, 'FFNN_Find_NeuralHidden', X_train, y_train, X_test, best_param)
#     rowMseWithNeural = pd.Series([neural[i],batch_size[i],epochs[i], mean_squared_error(y_test , y_pred)], index=df_MseWith_Neural.columns)
#     df_MseWith_Neural = df_MseWith_Neural.append(rowMseWithNeural,ignore_index=True)
# df_MseWith_Neural
# df_MseWith_Neural_Sort = df_MseWith_Neural.sort_values('MSE')
# best_Neural=df_MseWith_Neural_Sort['Neural Hidden'].iloc[0]
# Out:
# 8/8 [==============================] - 0s 3ms/step
# 8/8 [==============================] - 0s 3ms/step
# 8/8 [==============================] - 0s 2ms/step
# 8/8 [==============================] - 0s 6ms/step
# 8/8 [==============================] - 0s 2ms/step
# 8/8 [==============================] - 0s 2ms/step
# 8/8 [==============================] - 0s 1ms/step
# 8/8 [==============================] - 0s 2ms/step
# 8/8 [==============================] - 0s 2ms/step
# 8/8 [==============================] - 0s 2ms/step
# 8/8 [==============================] - 0s 3ms/step
# 8/8 [==============================] - 0s 2ms/step
# 8/8 [==============================] - 0s 2ms/step
# 8/8 [==============================] - 0s 3ms/step
# 8/8 [==============================] - 0s 922us/step
# 8/8 [==============================] - 0s 4ms/step
# 8/8 [==============================] - 0s 2ms/step
# 8/8 [==============================] - 0s 2ms/step
# 8/8 [==============================] - 0s 2ms/step
# 8/8 [==============================] - 0s 2ms/step

# %% [markdown]
# Thay thế các giá trị null bằng 0 .
#
# Loại bỏ các giá trị nhiễu bằng cách thay thế các giá trị nằm ngoài khoảng 3 độ lệch chuẩn của dữ liệu với giá trị trung bình của dữ liệu.
#
# MinMaxScaler để chuyển đổi dữ liệu thành phạm vi [0, 1]. Tiếp theo, chúng ta sử dụng
#
# Interpolate để điền vào các giá trị bị thiếu bằng cách lấy trung bình của các giá trị trước và sau đó.
#
#
# std() là một hàm trong Python để tính độ lệch chuẩn của một tập dữ liệu.
#
# Công thức tính độ lệch chuẩn của một tập dữ liệu là:
# σ = sqrt(1/n * Σ(xi - x_mean)^2)
#
# Ví dụ, nếu chúng ta có tập dữ liệu [2, 4, 6, 8], thì giá trị trung bình là 5, độ lệch của mỗi giá trị so với giá trị trung bình lần lượt là [-3, -1, 1, 3], giá trị bình phương độ lệch của mỗi giá trị so với giá trị trung bình lần lượt là [9, 1, 1, 9], đưa vào công thức độ lệch chuẩn
#  ==> σ = sqrt(1/4 * (9 + 1 + 1 + 9)) = sqrt(20/4) = sqrt(5) ≈ 2.236
